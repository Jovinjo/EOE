# %% [markdown]
# # **Pre-Installation**

# %%
# !pip install transformers timm seaborn openai fastapi_poe
# !pip install absl-py torch torchvision numpy scipy scikit-learn fastapi python-dotenv
# !pip install open_clip_torch
# Out:
# Requirement already satisfied: transformers in /usr/local/lib/python3.11/dist-packages (4.53.2)
# Requirement already satisfied: timm in /usr/local/lib/python3.11/dist-packages (1.0.17)
# Requirement already satisfied: seaborn in /usr/local/lib/python3.11/dist-packages (0.13.2)
# Requirement already satisfied: openai in /usr/local/lib/python3.11/dist-packages (1.96.1)
# Collecting fastapi_poe
#   Downloading fastapi_poe-0.0.66-py3-none-any.whl.metadata (2.4 kB)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from transformers) (3.18.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.30.0 in /usr/local/lib/python3.11/dist-packages (from transformers) (0.33.4)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.11/dist-packages (from transformers) (2.0.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from transformers) (25.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.11/dist-packages (from transformers) (6.0.2)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.11/dist-packages (from transformers) (2024.11.6)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from transformers) (2.32.3)
# Requirement already satisfied: tokenizers<0.22,>=0.21 in /usr/local/lib/python3.11/dist-packages (from transformers) (0.21.2)
# Requirement already satisfied: safetensors>=0.4.3 in /usr/local/lib/python3.11/dist-packages (from transformers) (0.5.3)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.11/dist-packages (from transformers) (4.67.1)
# Requirement already satisfied: torch in /usr/local/lib/python3.11/dist-packages (from timm) (2.6.0+cu124)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.11/dist-packages (from timm) (0.21.0+cu124)
# Requirement already satisfied: pandas>=1.2 in /usr/local/lib/python3.11/dist-packages (from seaborn) (2.2.2)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.4 in /usr/local/lib/python3.11/dist-packages (from seaborn) (3.10.0)
# Requirement already satisfied: anyio<5,>=3.5.0 in /usr/local/lib/python3.11/dist-packages (from openai) (4.9.0)
# Requirement already satisfied: distro<2,>=1.7.0 in /usr/local/lib/python3.11/dist-packages (from openai) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /usr/local/lib/python3.11/dist-packages (from openai) (0.28.1)
# Requirement already satisfied: jiter<1,>=0.4.0 in /usr/local/lib/python3.11/dist-packages (from openai) (0.10.0)
# Requirement already satisfied: pydantic<3,>=1.9.0 in /usr/local/lib/python3.11/dist-packages (from openai) (2.11.7)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.11/dist-packages (from openai) (1.3.1)
# Requirement already satisfied: typing-extensions<5,>=4.11 in /usr/local/lib/python3.11/dist-packages (from openai) (4.14.1)
# Requirement already satisfied: fastapi in /usr/local/lib/python3.11/dist-packages (from fastapi_poe) (0.116.1)
# Collecting httpx-sse (from fastapi_poe)
#   Downloading httpx_sse-0.4.1-py3-none-any.whl.metadata (9.4 kB)
# Collecting sse-starlette>=2.2.1 (from fastapi_poe)
#   Downloading sse_starlette-2.4.1-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: uvicorn in /usr/local/lib/python3.11/dist-packages (from fastapi_poe) (0.35.0)
# Requirement already satisfied: idna>=2.8 in /usr/local/lib/python3.11/dist-packages (from anyio<5,>=3.5.0->openai) (3.10)
# Requirement already satisfied: certifi in /usr/local/lib/python3.11/dist-packages (from httpx<1,>=0.23.0->openai) (2025.7.14)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.11/dist-packages (from httpx<1,>=0.23.0->openai) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.11/dist-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai) (0.16.0)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub<1.0,>=0.30.0->transformers) (2025.3.2)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.2 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub<1.0,>=0.30.0->transformers) (1.1.5)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (4.58.5)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.4.8)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.11/dist-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (11.2.1)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.11/dist-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas>=1.2->seaborn) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas>=1.2->seaborn) (2025.2)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.11/dist-packages (from pydantic<3,>=1.9.0->openai) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /usr/local/lib/python3.11/dist-packages (from pydantic<3,>=1.9.0->openai) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in /usr/local/lib/python3.11/dist-packages (from pydantic<3,>=1.9.0->openai) (0.4.1)
# Requirement already satisfied: starlette<0.48.0,>=0.40.0 in /usr/local/lib/python3.11/dist-packages (from fastapi->fastapi_poe) (0.47.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->transformers) (3.4.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->transformers) (2.4.0)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch->timm) (3.5)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch->timm) (3.1.6)
# Collecting nvidia-cuda-nvrtc-cu12==12.4.127 (from torch->timm)
#   Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-runtime-cu12==12.4.127 (from torch->timm)
#   Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-cupti-cu12==12.4.127 (from torch->timm)
#   Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cudnn-cu12==9.1.0.70 (from torch->timm)
#   Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cublas-cu12==12.4.5.8 (from torch->timm)
#   Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cufft-cu12==11.2.1.3 (from torch->timm)
#   Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-curand-cu12==10.3.5.147 (from torch->timm)
#   Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cusolver-cu12==11.6.1.9 (from torch->timm)
#   Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cusparse-cu12==12.3.1.170 (from torch->timm)
#   Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.2 in /usr/local/lib/python3.11/dist-packages (from torch->timm) (0.6.2)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch->timm) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch->timm) (12.4.127)
# Collecting nvidia-nvjitlink-cu12==12.4.127 (from torch->timm)
#   Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Requirement already satisfied: triton==3.2.0 in /usr/local/lib/python3.11/dist-packages (from torch->timm) (3.2.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch->timm) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch->timm) (1.3.0)
# Requirement already satisfied: click>=7.0 in /usr/local/lib/python3.11/dist-packages (from uvicorn->fastapi_poe) (8.2.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.4->seaborn) (1.17.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch->timm) (3.0.2)
# Downloading fastapi_poe-0.0.66-py3-none-any.whl (31 kB)
# Downloading sse_starlette-2.4.1-py3-none-any.whl (10 kB)
# Downloading httpx_sse-0.4.1-py3-none-any.whl (8.1 kB)
# Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl (363.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 3.4 MB/s eta 0:00:00
# Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (13.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 120.8 MB/s eta 0:00:00
# Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (24.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 93.9 MB/s eta 0:00:00
# Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (883 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 59.4 MB/s eta 0:00:00
# Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl (664.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.3 MB/s eta 0:00:00
# Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl (211.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 5.3 MB/s eta 0:00:00
# Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl (56.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 13.3 MB/s eta 0:00:00
# Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl (127.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 8.9 MB/s eta 0:00:00
# Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl (207.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 7.0 MB/s eta 0:00:00
# Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (21.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 102.3 MB/s eta 0:00:00
# Installing collected packages: nvidia-nvjitlink-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, httpx-sse, sse-starlette, nvidia-cusparse-cu12, nvidia-cudnn-cu12, nvidia-cusolver-cu12, fastapi_poe
#   Attempting uninstall: nvidia-nvjitlink-cu12
#     Found existing installation: nvidia-nvjitlink-cu12 12.5.82
#     Uninstalling nvidia-nvjitlink-cu12-12.5.82:
#       Successfully uninstalled nvidia-nvjitlink-cu12-12.5.82
#   Attempting uninstall: nvidia-curand-cu12
#     Found existing installation: nvidia-curand-cu12 10.3.6.82
#     Uninstalling nvidia-curand-cu12-10.3.6.82:
#       Successfully uninstalled nvidia-curand-cu12-10.3.6.82
#   Attempting uninstall: nvidia-cufft-cu12
#     Found existing installation: nvidia-cufft-cu12 11.2.3.61
#     Uninstalling nvidia-cufft-cu12-11.2.3.61:
#       Successfully uninstalled nvidia-cufft-cu12-11.2.3.61
#   Attempting uninstall: nvidia-cuda-runtime-cu12
#     Found existing installation: nvidia-cuda-runtime-cu12 12.5.82
#     Uninstalling nvidia-cuda-runtime-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-runtime-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-nvrtc-cu12
#     Found existing installation: nvidia-cuda-nvrtc-cu12 12.5.82
#     Uninstalling nvidia-cuda-nvrtc-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-nvrtc-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-cupti-cu12
#     Found existing installation: nvidia-cuda-cupti-cu12 12.5.82
#     Uninstalling nvidia-cuda-cupti-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-cupti-cu12-12.5.82
#   Attempting uninstall: nvidia-cublas-cu12
#     Found existing installation: nvidia-cublas-cu12 12.5.3.2
#     Uninstalling nvidia-cublas-cu12-12.5.3.2:
#       Successfully uninstalled nvidia-cublas-cu12-12.5.3.2
#   Attempting uninstall: nvidia-cusparse-cu12
#     Found existing installation: nvidia-cusparse-cu12 12.5.1.3
#     Uninstalling nvidia-cusparse-cu12-12.5.1.3:
#       Successfully uninstalled nvidia-cusparse-cu12-12.5.1.3
#   Attempting uninstall: nvidia-cudnn-cu12
#     Found existing installation: nvidia-cudnn-cu12 9.3.0.75
#     Uninstalling nvidia-cudnn-cu12-9.3.0.75:
#       Successfully uninstalled nvidia-cudnn-cu12-9.3.0.75
#   Attempting uninstall: nvidia-cusolver-cu12
#     Found existing installation: nvidia-cusolver-cu12 11.6.3.83
#     Uninstalling nvidia-cusolver-cu12-11.6.3.83:
#       Successfully uninstalled nvidia-cusolver-cu12-11.6.3.83
# Successfully installed fastapi_poe-0.0.66 httpx-sse-0.4.1 nvidia-cublas-cu12-12.4.5.8 nvidia-cuda-cupti-cu12-12.4.127 nvidia-cuda-nvrtc-cu12-12.4.127 nvidia-cuda-runtime-cu12-12.4.127 nvidia-cudnn-cu12-9.1.0.70 nvidia-cufft-cu12-11.2.1.3 nvidia-curand-cu12-10.3.5.147 nvidia-cusolver-cu12-11.6.1.9 nvidia-cusparse-cu12-12.3.1.170 nvidia-nvjitlink-cu12-12.4.127 sse-starlette-2.4.1
# Requirement already satisfied: absl-py in /usr/local/lib/python3.11/dist-packages (1.4.0)
# Requirement already satisfied: torch in /usr/local/lib/python3.11/dist-packages (2.6.0+cu124)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.11/dist-packages (0.21.0+cu124)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (2.0.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.11/dist-packages (1.15.3)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.11/dist-packages (1.6.1)
# Requirement already satisfied: fastapi in /usr/local/lib/python3.11/dist-packages (0.116.1)
# Collecting python-dotenv
#   Downloading python_dotenv-1.1.1-py3-none-any.whl.metadata (24 kB)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from torch) (3.18.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.11/dist-packages (from torch) (4.14.1)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch) (3.5)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch) (3.1.6)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.11/dist-packages (from torch) (2025.3.2)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch) (12.4.127)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch) (12.4.127)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch) (12.4.127)
# Requirement already satisfied: nvidia-cudnn-cu12==9.1.0.70 in /usr/local/lib/python3.11/dist-packages (from torch) (9.1.0.70)
# Requirement already satisfied: nvidia-cublas-cu12==12.4.5.8 in /usr/local/lib/python3.11/dist-packages (from torch) (12.4.5.8)
# Requirement already satisfied: nvidia-cufft-cu12==11.2.1.3 in /usr/local/lib/python3.11/dist-packages (from torch) (11.2.1.3)
# Requirement already satisfied: nvidia-curand-cu12==10.3.5.147 in /usr/local/lib/python3.11/dist-packages (from torch) (10.3.5.147)
# Requirement already satisfied: nvidia-cusolver-cu12==11.6.1.9 in /usr/local/lib/python3.11/dist-packages (from torch) (11.6.1.9)
# Requirement already satisfied: nvidia-cusparse-cu12==12.3.1.170 in /usr/local/lib/python3.11/dist-packages (from torch) (12.3.1.170)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.2 in /usr/local/lib/python3.11/dist-packages (from torch) (0.6.2)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch) (12.4.127)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch) (12.4.127)
# Requirement already satisfied: triton==3.2.0 in /usr/local/lib/python3.11/dist-packages (from torch) (3.2.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch) (1.3.0)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.11/dist-packages (from torchvision) (11.2.1)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn) (1.5.1)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn) (3.6.0)
# Requirement already satisfied: starlette<0.48.0,>=0.40.0 in /usr/local/lib/python3.11/dist-packages (from fastapi) (0.47.1)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,!=2.0.0,!=2.0.1,!=2.1.0,<3.0.0,>=1.7.4 in /usr/local/lib/python3.11/dist-packages (from fastapi) (2.11.7)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.11/dist-packages (from pydantic!=1.8,!=1.8.1,!=2.0.0,!=2.0.1,!=2.1.0,<3.0.0,>=1.7.4->fastapi) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /usr/local/lib/python3.11/dist-packages (from pydantic!=1.8,!=1.8.1,!=2.0.0,!=2.0.1,!=2.1.0,<3.0.0,>=1.7.4->fastapi) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in /usr/local/lib/python3.11/dist-packages (from pydantic!=1.8,!=1.8.1,!=2.0.0,!=2.0.1,!=2.1.0,<3.0.0,>=1.7.4->fastapi) (0.4.1)
# Requirement already satisfied: anyio<5,>=3.6.2 in /usr/local/lib/python3.11/dist-packages (from starlette<0.48.0,>=0.40.0->fastapi) (4.9.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch) (3.0.2)
# Requirement already satisfied: idna>=2.8 in /usr/local/lib/python3.11/dist-packages (from anyio<5,>=3.6.2->starlette<0.48.0,>=0.40.0->fastapi) (3.10)
# Requirement already satisfied: sniffio>=1.1 in /usr/local/lib/python3.11/dist-packages (from anyio<5,>=3.6.2->starlette<0.48.0,>=0.40.0->fastapi) (1.3.1)
# Downloading python_dotenv-1.1.1-py3-none-any.whl (20 kB)
# Installing collected packages: python-dotenv
# Successfully installed python-dotenv-1.1.1
# Collecting open_clip_torch
#   Downloading open_clip_torch-2.32.0-py3-none-any.whl.metadata (31 kB)
# Requirement already satisfied: torch>=1.9.0 in /usr/local/lib/python3.11/dist-packages (from open_clip_torch) (2.6.0+cu124)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.11/dist-packages (from open_clip_torch) (0.21.0+cu124)
# Requirement already satisfied: regex in /usr/local/lib/python3.11/dist-packages (from open_clip_torch) (2024.11.6)
# Collecting ftfy (from open_clip_torch)
#   Downloading ftfy-6.3.1-py3-none-any.whl.metadata (7.3 kB)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (from open_clip_torch) (4.67.1)
# Requirement already satisfied: huggingface-hub in /usr/local/lib/python3.11/dist-packages (from open_clip_torch) (0.33.4)
# Requirement already satisfied: safetensors in /usr/local/lib/python3.11/dist-packages (from open_clip_torch) (0.5.3)
# Requirement already satisfied: timm in /usr/local/lib/python3.11/dist-packages (from open_clip_torch) (1.0.17)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from torch>=1.9.0->open_clip_torch) (3.18.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.11/dist-packages (from torch>=1.9.0->open_clip_torch) (4.14.1)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch>=1.9.0->open_clip_torch) (3.5)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch>=1.9.0->open_clip_torch) (3.1.6)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.11/dist-packages (from torch>=1.9.0->open_clip_torch) (2025.3.2)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=1.9.0->open_clip_torch) (12.4.127)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=1.9.0->open_clip_torch) (12.4.127)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=1.9.0->open_clip_torch) (12.4.127)
# Requirement already satisfied: nvidia-cudnn-cu12==9.1.0.70 in /usr/local/lib/python3.11/dist-packages (from torch>=1.9.0->open_clip_torch) (9.1.0.70)
# Requirement already satisfied: nvidia-cublas-cu12==12.4.5.8 in /usr/local/lib/python3.11/dist-packages (from torch>=1.9.0->open_clip_torch) (12.4.5.8)
# Requirement already satisfied: nvidia-cufft-cu12==11.2.1.3 in /usr/local/lib/python3.11/dist-packages (from torch>=1.9.0->open_clip_torch) (11.2.1.3)
# Requirement already satisfied: nvidia-curand-cu12==10.3.5.147 in /usr/local/lib/python3.11/dist-packages (from torch>=1.9.0->open_clip_torch) (10.3.5.147)
# Requirement already satisfied: nvidia-cusolver-cu12==11.6.1.9 in /usr/local/lib/python3.11/dist-packages (from torch>=1.9.0->open_clip_torch) (11.6.1.9)
# Requirement already satisfied: nvidia-cusparse-cu12==12.3.1.170 in /usr/local/lib/python3.11/dist-packages (from torch>=1.9.0->open_clip_torch) (12.3.1.170)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.2 in /usr/local/lib/python3.11/dist-packages (from torch>=1.9.0->open_clip_torch) (0.6.2)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch>=1.9.0->open_clip_torch) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=1.9.0->open_clip_torch) (12.4.127)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=1.9.0->open_clip_torch) (12.4.127)
# Requirement already satisfied: triton==3.2.0 in /usr/local/lib/python3.11/dist-packages (from torch>=1.9.0->open_clip_torch) (3.2.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch>=1.9.0->open_clip_torch) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch>=1.9.0->open_clip_torch) (1.3.0)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.11/dist-packages (from ftfy->open_clip_torch) (0.2.13)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub->open_clip_torch) (25.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub->open_clip_torch) (6.0.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from huggingface-hub->open_clip_torch) (2.32.3)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.2 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub->open_clip_torch) (1.1.5)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from torchvision->open_clip_torch) (2.0.2)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.11/dist-packages (from torchvision->open_clip_torch) (11.2.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch>=1.9.0->open_clip_torch) (3.0.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->huggingface-hub->open_clip_torch) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->huggingface-hub->open_clip_torch) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->huggingface-hub->open_clip_torch) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests->huggingface-hub->open_clip_torch) (2025.7.14)
# Downloading open_clip_torch-2.32.0-py3-none-any.whl (1.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 37.5 MB/s eta 0:00:00
# Downloading ftfy-6.3.1-py3-none-any.whl (44 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.8/44.8 kB 4.1 MB/s eta 0:00:00
# Installing collected packages: ftfy, open_clip_torch
# Successfully installed ftfy-6.3.1 open_clip_torch-2.32.0

# %%
import os
os.environ['OPENAI_API_KEY'] = 'YOUR_OPENAI_API_KEY'

# %% [markdown]
# # **args_pool**

# %%
ALL_ID_DATASET = [
    'bird200', 'pet37', 'cub100_ID', 'pet18_ID', 'cifar10_ID'
]

ALL_OOD_TASK = [
    'far', 'fine_grained', 'near'
]

ALL_LLM = [
    'gpt-3.5-turbo', 'gpt-3.5-turbo-16k', 'gpt-4'
]

dataset_mappings = {
    'bird200': ['dtd'],
    'pet37': ['dtd'],
    'cub100_ID': ['cub100_OOD'],
    'pet18_ID': ['pet19_OOD'],
    'cifar10_ID': ['cifar100_OOD']
}

# %% [markdown]
# # **common**

# %%
import torch
import torch.nn.functional as F
import os
import numpy as np
import json
import random
import ast
import logging

seed = 5

def setup_seed(seed):
    torch.manual_seed(seed)
    torch.cuda.manual_seed(seed)
    np.random.seed(seed)
    random.seed(seed)

    def get_test_labels(args, loader=None):
        if args.in_dataset in ['bird200', 'pet37', 'cub100_ID', 'pet18_ID']:
            test_labels = loader.dataset.class_names_str
        elif args.in_dataset in ['dtd', 'cifar10_ID', 'cifar100_OOD']:
            test_labels = loader.dataset.classes
        else:
            raise ValueError(f"Unknown dataset for labels: {args.in_dataset}")
        return test_labels

def get_num_cls(args):
    NUM_CLS_DICT = {
        'bird200': 200,
        'pet37': 37,
        'dtd': 47,
        'cub100_ID': 100,
        'cub100_OOD': 100,
        'pet18_ID': 18,
        'pet19_OOD': 19,
        'cifar10_ID': 10,
        'cifar100_OOD': 100,
    }
    try:
        n_cls = NUM_CLS_DICT[args.in_dataset]
    except KeyError:
        raise ValueError(f"Unknown dataset: {args.in_dataset}")
    return n_cls

# %% [markdown]
# # **imagenet-template (only if ensemble activated)**

# %%
openai_imagenet_template_subset = {
    0: [
    lambda c: f'a photo of a {c}.',
    lambda c: f'a blurry photo of a {c}.',
    lambda c: f'a photo of many {c}.',
    lambda c: f'a photo of the large {c}.',
    lambda c: f'a photo of the small {c}.',
    ],
}

# %% [markdown]
# # **detection util**

# %%
import torch
import numpy as np
from tqdm import tqdm
import sklearn.metrics as sk
from transformers import CLIPTokenizer
import torch.nn.functional as F

def clip_text_ens(net, tokenizer, test_labels, prompt_pool):
    prompts = [template(label) for label in test_labels for template in prompt_pool]
    text_inputs = tokenizer(
        prompts,
        padding=True,
        truncation=True,
        max_length=tokenizer.model_max_length,
        return_tensors="pt"
    )
    features = net.get_text_features(
        input_ids=text_inputs['input_ids'].cuda(),
        attention_mask=text_inputs['attention_mask'].cuda()
    ).float()

    text_features = torch.zeros(len(test_labels), features.shape[1]).cuda()
    num_templates = len(prompt_pool)
    for i in range(len(test_labels)):
        for j in range(num_templates):
            idx = i * num_templates + j
            normed = features[idx] / features[idx].norm(dim=-1, keepdim=True)
            text_features[i] += normed
    return text_features

def pre_filter(net, tokenizer, test_labels, gpt_labels, args, prompt_pool=None):
    net.eval()
    if not args.ensemble:
        test_prompts = [f"a photo of a {c}" for c in test_labels]
        gpt_prompts  = [f"a photo of a {c}" for c in gpt_labels]

        test_in = tokenizer(
            test_prompts,
            padding=True,
            truncation=True,
            max_length=tokenizer.model_max_length,
            return_tensors="pt"
        )
        gpt_in  = tokenizer(
            gpt_prompts,
            padding=True,
            truncation=True,
            max_length=tokenizer.model_max_length,
            return_tensors="pt"
        )

        test_feats = net.get_text_features(
            input_ids=test_in['input_ids'].cuda(),
            attention_mask=test_in['attention_mask'].cuda()
        ).float()
        gpt_feats  = net.get_text_features(
            input_ids=gpt_in['input_ids'].cuda(),
            attention_mask=gpt_in['attention_mask'].cuda()
        ).float()

    else:
        test_feats = clip_text_ens(net, tokenizer, test_labels, prompt_pool)
        gpt_feats  = clip_text_ens(net, tokenizer, gpt_labels,  prompt_pool)

    return torch.cat((test_feats, gpt_feats), dim=0)

def remove_overlap_class(test_labels, gpt_labels):
    words_set = {word for phrase in test_labels for word in phrase.split()}
    gpt_labels = [phrase for phrase in gpt_labels if not any(word in words_set for word in phrase.split())]

    return gpt_labels

def get_ood_scores_clip(args, net, loader, test_labels, gpt_labels, softmax = True):
    net.eval()
    to_np = lambda x: x.data.cpu().numpy()
    concat = lambda x: np.concatenate(x, axis=0)
    _score = []
    id_class_nums = len(test_labels)
    if args.model == 'CLIP':
        tokenizer = CLIPTokenizer.from_pretrained(args.ckpt)

    tqdm_object = tqdm(loader, total=len(loader))
    with torch.no_grad():
        for batch_idx, (images, labels) in enumerate(tqdm_object):
            labels = labels.long().cuda()
            images = images.cuda()

            image_features = net.get_image_features(pixel_values = images).float()
            image_features /= image_features.norm(dim=-1, keepdim=True)
            if args.score in ['MCM', 'energy', 'max-logit']:
                if not args.ensemble:
                    text_inputs = tokenizer([f"a photo of a {c}" for c in test_labels], padding=True, return_tensors="pt")
                    text_features = net.get_text_features(input_ids = text_inputs['input_ids'].cuda(),
                                                    attention_mask = text_inputs['attention_mask'].cuda()).float()
                else:
                    text_features = clip_text_ens(net, tokenizer, test_labels)
                text_features /= text_features.norm(dim=-1, keepdim=True)
                output = image_features @ text_features.T
            elif args.score == 'EOE':
                if args.ood_task == 'near':
                    gpt_labels = remove_overlap_class(test_labels, gpt_labels)
                total_features = pre_filter(net, tokenizer, test_labels, gpt_labels, args)
                total_features /= total_features.norm(dim=-1, keepdim=True)
                output = image_features @ total_features.T

            if softmax:
                smax = to_np(F.softmax(output/ args.T, dim=1))
            else:
                smax = to_np(output/ args.T)

            # cal score
            if args.score == 'EOE':
                if args.score_ablation == 'EOE':
                    smax = np.max(smax[:, :id_class_nums], axis=1) - args.beta * np.max(smax[:, id_class_nums:], axis=1)
                    _score.append(-smax)
                elif args.score_ablation == 'MAX':
                    iid_values, iid_indices = torch.max(output[:, :id_class_nums], dim=1)
                    ood_values, ood_indices = torch.max(output[:, id_class_nums:], dim=1)
                    condition = ood_values > iid_values
                    output[:, :id_class_nums][condition] = 1/id_class_nums
                    output = output[:, :id_class_nums]
                    smax = to_np(F.softmax(output/ args.T, dim=1))
                    smax = np.max(smax[:, :id_class_nums], axis=1)
                    _score.append(-smax)
                elif args.score_ablation == 'MSP':
                    smax = np.max(smax[:, :id_class_nums], axis=1)
                    _score.append(-smax)
                elif args.score_ablation == 'energy':
                    _score.append(-to_np((args.T*torch.logsumexp(output[:, :id_class_nums] / args.T, dim=1)) - (args.T*torch.logsumexp(output[:, id_class_nums:] / args.T, dim=1))))
                elif args.score_ablation == 'max-logit':
                    _score.append(-to_np(torch.max(output[:, :id_class_nums], 1)[0] - torch.max(output[:, id_class_nums:], 1)[0]))
                else:
                    raise NotImplementedError
            elif args.score == 'MCM':
                _score.append(-np.max(smax, axis=1))
            elif args.score == 'energy':
                #Energy = - T * logsumexp(logit_k / T), by default T = 1 in https://arxiv.org/pdf/2010.03759.pdf
                _score.append(-to_np((args.T*torch.logsumexp(output / args.T, dim=1))))  #energy score is expected to be smaller for ID
            elif args.score == 'max-logit':
                _score.append(-to_np(torch.max(output, 1)[0]))

    return concat(_score)[:len(loader.dataset)].copy()

# Metric Calculations
def stable_cumsum(arr, rtol=1e-05, atol=1e-08):
    out = np.cumsum(arr, dtype=np.float64)
    expected = np.sum(arr, dtype=np.float64)
    if not np.allclose(out[-1], expected, rtol=rtol, atol=atol):
        raise RuntimeError('unstable cumsum')
    return out

def fpr_and_fdr_at_recall(y_true, y_score, recall_level=0.95, pos_label=1):
    y_true = (y_true == pos_label)
    desc_score_indices = np.argsort(y_score)[::-1]
    y_score = y_score[desc_score_indices]
    y_true = y_true[desc_score_indices]
    distinct_value_indices = np.where(np.diff(y_score))[0]
    threshold_idxs = np.r_[distinct_value_indices, y_true.size - 1]
    tps = stable_cumsum(y_true)[threshold_idxs]
    fps = 1 + threshold_idxs - tps
    recall = tps / tps[-1]
    last_ind = tps.searchsorted(tps[-1])
    sl = slice(last_ind, None, -1)
    recall, fps = np.r_[recall[sl], 1], np.r_[fps[sl], 0]
    return fps[np.argmin(np.abs(recall - recall_level))] / np.sum(~y_true)

def get_measures(pos, neg, recall_level=0.95):
    pos = np.array(pos).reshape((-1, 1))
    neg = np.array(neg).reshape((-1, 1))
    examples = np.squeeze(np.vstack((pos, neg)))
    labels = np.zeros(len(examples), dtype=np.int32)
    labels[:len(pos)] = 1
    auroc = sk.roc_auc_score(labels, examples)
    aupr = sk.average_precision_score(labels, examples)
    fpr = fpr_and_fdr_at_recall(labels, examples, recall_level)
    return auroc, aupr, fpr

# Final Evaluation Output Printed
def get_and_print_results(args, log, in_score, out_score, auroc_list, aupr_list, fpr_list):
    auroc, aupr, fpr = get_measures(-in_score, -out_score)
    auroc_list.append(auroc)
    aupr_list.append(aupr)
    fpr_list.append(fpr)
    print_measures(log, auroc, aupr, fpr, args.score)

def print_measures(log, auroc, aupr, fpr, method_name='Ours', recall_level=0.95):
    if log is None:
        print(f'FPR{int(100 * recall_level)}:\t\t\t{100 * fpr:.2f}')
        print(f'AUROC: \t\t\t{100 * auroc:.2f}')
        print(f'AUPR:  \t\t\t{100 * aupr:.2f}')
    else:
        log.debug('\t\t\t\t' + method_name)
        log.debug(f'  FPR{int(100 * recall_level)} AUROC AUPR')
        log.debug(f'& {100*fpr:.2f} & {100*auroc:.2f} & {100*aupr:.2f}')

# %% [markdown]
# # **file_ops**

# %%
def save_scores(args, scores, dataset_name):
    os.makedirs(args.log_directory, exist_ok=True)
    with open(os.path.join(args.log_directory, f'{dataset_name}_scores.npy'), 'wb') as f:
        np.save(f, scores)

# prevent any recomputation
def load_scores(args, dataset_name):
    with open(os.path.join(args.log_directory, f'{dataset_name}_scores.npy'), 'rb') as f:
        scores = np.load(f)
    return scores

def setup_log(args):
    log = logging.getLogger(__name__)
    if not log.handlers:
        formatter = logging.Formatter('%(asctime)s : %(message)s')
        fileHandler = logging.FileHandler(os.path.join(args.log_directory, "ood_eval_info.log"), mode='w')
        fileHandler.setFormatter(formatter)
        streamHandler = logging.StreamHandler()
        streamHandler.setFormatter(formatter)
        log.setLevel(logging.DEBUG)
        log.addHandler(fileHandler)
        log.addHandler(streamHandler)
        log.debug(f"#########{args.name}############")
    return log

def save_as_dataframe(args, out_datasets, fpr_list, auroc_list, aupr_list):
    os.makedirs(args.log_directory, exist_ok=True)
    fpr_list = [float('{:.2f}'.format(100*fpr)) for fpr in fpr_list]
    auroc_list = [float('{:.2f}'.format(100*auroc)) for auroc in auroc_list]
    aupr_list = [float('{:.2f}'.format(100*aupr)) for aupr in aupr_list]
    import pandas as pd
    data = {k:v for k,v in zip(out_datasets, zip(fpr_list,auroc_list,aupr_list))}
    data['AVG'] = [np.mean(fpr_list),np.mean(auroc_list),np.mean(aupr_list) ]
    data['AVG']  = [float('{:.2f}'.format(metric)) for metric in data['AVG']]
    df = pd.DataFrame.from_dict(data, orient='index',
                       columns=['FPR95', 'AUROC', 'AUPR'])
    df.to_csv(os.path.join(args.log_directory,f'{args.name}_{args.json_number}.csv'))

# %% [markdown]
# # **prompt_pool**

# %%
class PromptGenerator:
    def __init__(self):
        self.dataset_info = {
            'bird200': {'class_type': None, 'num_classes': 200},
            'pet37': {'class_type': None, 'num_classes': 37},
            'cub100_ID': {'class_type': 'bird', 'num_classes': 100},
            'dtd47': {'class_type': 'texture', 'num_classes': 47},
            'pet18_ID': {'class_type': 'pet (including dogs and cats)', 'num_classes': 18},
            'cifar10_ID': {'class_type': None, 'num_classes': 10},
        }

    def _fine_grained_prompt(self, class_type, num_classes, class_info, envision_nums=50):
        return f"""Q: I have a dataset containing 10 unique species of dogs. I need a list of 10 distinct dog species that are NOT present in my dataset, and ensure there are no repetitions in the list you provide. For context, the species in my dataset are: ['husky dog', 'alaskan Malamute', 'cossack sled dog', 'golden retriever', 'German Shepherd', 'Beagle', 'Bulldog', 'Poodle', 'Dachshund', 'Doberman Pinscher']
        A: The other 10 dog species not in the dataset are:
        - Labrador Retriever
        - Rottweiler
        - Boxer
        - Border Collie
        - Shih Tzu
        - Akita
        - Saint Bernard
        - Australian Shepherd
        - Great Dane
        - Boston Terrier

        Q: I have a dataset containing {num_classes} different species of {class_type}. I need a list of {envision_nums} distinct {class_type} species that are NOT present in my dataset, and ensure there are no repetitions in the list you provide. For context, the species in my dataset are: {class_info}
        A: The other {envision_nums} {class_type} species not in the dataset are:
        """

    def _far_prompt(self, class_type, num_classes, class_info, envision_nums=50):
       return f"""Q: I have gathered images of 4 distinct categories: ['Husky dog', 'Garfield cat', 'churches', 'truck'].
       Summarize what broad categories these categories might fall into based on visual features.
       Now, I am looking to identify 5 categories that visually resemble to these broad categories but have no direct relation to these broad categories.
       Please list these 5 items for me.
        A: These 5 items are:
        - black stone
        - mountain
        - Ginkgo Tree
        - river
        - Rapeseed

        Q: I have gathered images of {num_classes} distinct categories: [{class_info}].
        Summarize what broad categories these categories might fall into based on visual features.
        Now, I am looking to identify {envision_nums} classes that visually resemble to these broad categories but have no direct relation to these broad categories.
        Please list these {envision_nums} items for me.
        A: These {envision_nums} items are:
        """

    def _near_prompt(self, class_type, num_classes, class_info, envision_nums=3):
        return f"""Q: Given the image category [husky dog], please suggest visually similar categories that are not directly related or belong to the same primary group as [husky dog]. Provide suggestions that share visual characteristics but are from broader and different domains than [husky dog].
        A: There are 3 classes similar to [husky dog], and they are from broader and different domains than [husky dog]:
        - gray wolf
        - black stone
        - red panda

        Q: Given the image category [basketball], please suggest visually similar categories that are not directly related or belong to the same primary group as [basketball]. Provide suggestions that share visual characteristics but are from broader and different domains than [basketball].
        A: There are 3 classes similar to [basketball], and they are from broader and different domains than [basketball]:
        - balloons
        - blowfish
        - hat

        Q: Given the image category [water jug], please suggest visually similar categories that are not directly related or belong to the same primary group as [water jug]. Provide suggestions that share visual characteristics but are from broader and different domains than [water jug].
        A: There are 3 classes similar to [water jug], and they are from broader and different domains than [water jug]:
        - trumpets
        - helmets
        - rucksacks

        Q: Given the image category [{class_info}], please suggest visually similar categories that are not directly related or belong to the same primary group as [{class_info}]. Provide suggestions that share visual characteristics but are from broader and different domains than [{class_info}].
        A: There are {envision_nums} classes similar to [{class_info}], and they are from broader and different domains than [{class_info}]:
        """

    def _fine_grained_prompt_again(self, in_dataset, envision_nums=50):
        dataset_info = self.dataset_info[in_dataset]
        class_type = dataset_info["class_type"]
        num_classes = dataset_info["num_classes"]
        return f"""Q: Provide {envision_nums} additional {class_type} categories that aren't in the set I gave you, and haven't been mentioned in your previous responses to me.
A: The {envision_nums} additional categories are:
"""

    def _far_prompt_again(self, in_dataset, envision_nums=50):
        return f"""Q: Give me {envision_nums} more categories that are visually similar to these broad categories you summarized in the dataset but have no direct relation to these broad categories. Each category you give cannot exceed three words and could not have appeared in your previous answers.
A: The other {envision_nums} categories are:
"""

    def get_prompt(self, ood_task, in_dataset, class_info=None, envision_nums=50):
        prompt_dispatcher = {
            'fine_grained': self._fine_grained_prompt,
            'far': self._far_prompt,
            'near': self._near_prompt
        }
        if ood_task not in prompt_dispatcher:
            raise ValueError("Unknown OOD task")
        info = self.dataset_info[in_dataset]
        return prompt_dispatcher[ood_task](info["class_type"], info["num_classes"], class_info, envision_nums)

    def get_prompt_again(self, ood_task, in_dataset, class_info=None, envision_nums=50):
        prompt_dispatcher = {
            'fine_grained': self._fine_grained_prompt_again,
            'far': self._far_prompt_again,
        }
        if ood_task not in prompt_dispatcher:
            raise ValueError("Unknown OOD task")
        return prompt_dispatcher[ood_task](in_dataset, envision_nums)

# %% [markdown]
# # **generate_llm_class**

# %%
import os
import json
import itertools
import fastapi_poe
import asyncio
import openai
from dotenv import load_dotenv
import re

load_dotenv()
openai.api_key = os.getenv("OPENAI_API_KEY")

def stringtolist(description):
    lines = description.split("\n")
    candidates = []
    for line in lines:
        line = line.strip()
        bullet_match = re.match(r"^[-•*]\s+(.*)", line)
        number_match = re.match(r"^\d+[\.\)]\s+(.*)", line)

        if bullet_match:
            candidates.append(bullet_match.group(1).strip())
        elif number_match:
            candidates.append(number_match.group(1).strip())
    return candidates

def get_next_number(args, folder_path):
    files = os.listdir(folder_path)
    numbers = []
    for file in files:
        if file.startswith(f"{args.in_dataset}_{args.llm_model}") and file.endswith(".json"):
            try:
                number = int(file.split('_')[-1].split('.')[0])
                numbers.append(number)
            except ValueError:
                pass

    return 0 if not numbers else max(numbers) + 1

def load_json(filename):
    if not filename.endswith('.json'):
        filename += '.json'
    with open(filename, 'r') as fp:
        return json.load(fp)

client = openai.OpenAI(api_key=os.getenv("OPENAI_API_KEY"))

def get_completion(args, prompt):
    try:
        response = client.chat.completions.create(
            model=args.llm_model,
            messages=[{"role": "user", "content": prompt}],
            temperature=0.0,
        )
        return response.choices[0].message.content
    except Exception as e:
        print(f"An error occurred: {e}")
        return ""

def get_completion_from_messages(args, context, new_prompt):
    try:
        context.append({"role": "user", "content": new_prompt})
        response = client.chat.completions.create(
            model=args.llm_model,
            messages=context,
            temperature=0.0,
        )
        generated_text = response.choices[0].message.content
        context.append({"role": "assistant", "content": generated_text})
        return generated_text, context
    except Exception as e:
        print(f"An error occurred: {e}")
        return "", context

def load_llm_classes(args, test_labels):
    assert args.ood_task in ['far', 'fine_grained', 'near'], "Only 'far' and 'fine_grained' supported"
    if args.ood_task in ['far', 'fine_grained']:
      assert args.L in [50, 100, 300, 500], "L must be one of [50, 100, 300, 500] for far/fine_grained"
    elif args.ood_task == 'near':
      assert args.L in [1, 3, 10], "L must be one of [1, 3, 10] for near"

    folder_path = os.path.join("envisioned_classes", f'{args.ood_task}_{args.L}')
    os.makedirs(folder_path, exist_ok=True)

    if args.generate_class:
        print('Envisioning Outlier Exposure...')
        json_number = get_next_number(args, folder_path)
        file_path = os.path.join(folder_path, f"{args.in_dataset}_{args.llm_model}_{json_number}.json")
        asyncio.run(obtain_gpt_class_and_save(args, file_path, test_labels))
    else:
        file_path = os.path.join(folder_path, f"{args.in_dataset}_{args.llm_model}_{args.json_number}.json")

    print('=== load json: ', file_path)
    gpt_class_dict = load_json(file_path)
    print('Get Envisioned Candidate Class Names.')

    gpt_class = []
    for value in gpt_class_dict.values():
        gpt_class.extend(value)

    # Normalize and remove duplicates and overlap with test set
    gpt_class = [item.lower() for item in gpt_class]
    gpt_class = list(set(gpt_class))
    print('After set:', len(gpt_class))

    test_labels = [item.lower() for item in test_labels]
    gpt_class = [item for item in gpt_class if item not in test_labels]
    print('After removing ID class overlaps:', len(gpt_class))

    return gpt_class

async def obtain_gpt_class_and_save(args, file_path, class_list):
    assert args.ood_task in ['far', 'fine_grained', 'near'], "Only 'far', 'fine_grained', or 'near' supported"

    # Adjust L constraint depending on task
    if args.ood_task in ['far', 'fine_grained']:
        assert args.L in [50, 100, 300, 500], "L must be one of [50, 100, 300, 500] for far/fine_grained"
        envision_nums = 50
        envision_times = max(int(args.L / envision_nums) - 1, 0)
    elif args.ood_task == 'near':
        assert args.L in [1, 3, 5, 10], "L must be small (e.g. [1, 3, 5, 10]) for near task"
        envision_nums = args.L
        envision_times = 0

    prompt_gen = PromptGenerator()

    # === NEAR TASK: prompt per class ===
    if args.ood_task == 'near':
        descriptors = {}
        response_texts = []
        for cls in class_list:
            prompt = prompt_gen.get_prompt(
                ood_task='near',
                in_dataset=args.in_dataset,
                class_info=cls,
                envision_nums=envision_nums
            )
            print(f"\n Prompt for class '{cls}':\n{prompt}\n")
            response = get_completion(args, prompt)
            response_texts.append(response)
            descriptors[cls] = stringtolist(response)

        print(f"\n Raw GPT output for all classes:\n{response_texts}")

    # === FAR or FINE_GRAINED: single prompt with multiple batches ===
    else:
        prompt = prompt_gen.get_prompt(
            ood_task=args.ood_task,
            in_dataset=args.in_dataset,
            class_info=class_list,
            envision_nums=envision_nums
        )
        print("Generating via OpenAI GPT...")
        response_texts = get_completion(args, prompt)

        context = [
            {"role": "user", "content": prompt},
            {"role": "assistant", "content": response_texts}
        ]

        for i in range(envision_times):
            print(f"Continuing vision {i + 1}/{envision_times}")
            new_prompt = prompt_gen.get_prompt_again(
                ood_task=args.ood_task,
                in_dataset=args.in_dataset,
                class_info=class_list,
                envision_nums=envision_nums
            )
            generated_text, context = get_completion_from_messages(args, context, new_prompt)
            response_texts += generated_text

        print("Raw GPT output:\n", response_texts)
        descriptors_list = stringtolist(response_texts)
        descriptors = {args.ood_task: descriptors_list}

    # === Save Output ===
    print(f"\n Saving hallucinated class descriptors to: {file_path}")
    with open(file_path, 'w') as fp:
        json.dump(descriptors, fp)

# %% [markdown]
# # **plot_util**

# %%
import numpy as np
import seaborn as sns
from matplotlib import pyplot as plt
import os

class Args:
    def __init__(self):
        self.log_directory = "results/test_plot"
        self.score = "EOE"

args = Args()

def plot_distribution(args, id_scores, ood_scores, out_dataset):
    sns.set(style="white", palette="muted")
    palette = ['#8E8BFE', '#FEA3A2']

    import pandas as pd
    data = pd.DataFrame({
        "Score": np.concatenate([-1 * id_scores, -1 * ood_scores]),
        "Type": ["ID"] * len(id_scores) + ["OOD"] * len(ood_scores)
    })

    # Plot with seaborn
    plt.figure(figsize=(6, 4))
    sns.kdeplot(
        data=data,
        x="Score",
        hue="Type",
        fill=True,
        palette=palette,
        alpha=0.8,
        linewidth=2
    )

    # Add axis labels and ticks
    plt.xlabel("Score", fontsize=12)
    plt.ylabel("Density", fontsize=12)
    plt.xticks(fontsize=10)
    plt.yticks(fontsize=10)

    ax = plt.gca()
    for spine in ax.spines.values():
        spine.set_linewidth(1.5)

    # Save the figure
    os.makedirs(args.log_directory, exist_ok=True)
    plt.tight_layout()
    plt.savefig(os.path.join(args.log_directory, f"{args.score}_{out_dataset}.png"))
    plt.show()

# %% [markdown]
# # **dataloaders/cub200.py**

# %%
import os
import pandas as pd
from torchvision.datasets.folder import default_loader
from torch.utils.data import Dataset
import numpy as np
import pickle


class Cub2011(Dataset):
    base_folder = 'CUB_200_2011/images'

    def __init__(self, root, train=True, transform=None, loader=default_loader):
        self.root = os.path.expanduser(root)
        self.transform = transform
        self.loader = default_loader
        self.train = train

        self._load_metadata()

    def _load_metadata(self):
        images = pd.read_csv(os.path.join(self.root, 'CUB_200_2011', 'images.txt'), sep=' ',
                             names=['img_id', 'filepath'])
        image_class_labels = pd.read_csv(os.path.join(self.root, 'CUB_200_2011', 'image_class_labels.txt'),
                                         sep=' ', names=['img_id', 'target'])
        train_test_split = pd.read_csv(os.path.join(self.root, 'CUB_200_2011', 'train_test_split.txt'),
                                       sep=' ', names=['img_id', 'is_training_img'])

        data = images.merge(image_class_labels, on='img_id')
        self.data = data.merge(train_test_split, on='img_id')

        if self.train:
            self.data = self.data[self.data.is_training_img == 1]
        else:
            self.data = self.data[self.data.is_training_img == 0]

        class_names = pd.read_csv(os.path.join(self.root, 'CUB_200_2011', 'classes.txt'),
                                         sep=' ', names=['class_id', 'target'])
        self.class_names_str = [name.split(".")[1].replace('_', ' ') for name in class_names.target]

    def __len__(self):
        return len(self.data)

    def __getitem__(self, idx):
        sample = self.data.iloc[idx]
        path = os.path.join(self.root, self.base_folder, sample.filepath)
        target = sample.target - 1  # Targets start at 1 by default, so shift to 0
        img = self.loader(path)

        if self.transform is not None:
            img = self.transform(img)

        return img, target



class Cub100(Cub2011):
    def __init__(self, root, train=True, id=True, transform=None, loader=default_loader):
        self.id = id
        self.root = root
        self._select_or_load_classes()
        super().__init__(root, train, transform, loader)

    def _select_or_load_classes(self):
        subset_classes_file = os.path.join('data', 'CUB-100', "selected_100_classes.pkl")
        if os.path.exists(subset_classes_file):
            with open(subset_classes_file, 'rb') as f:
                self.selected_classes = pickle.load(f)
        else:
            all_classes = pd.read_csv(os.path.join(self.root, 'CUB_200_2011', 'classes.txt'),
                                      sep=' ', names=['class_id', 'target'])
            selected_class_ids = np.random.choice(all_classes['class_id'], 100, replace=False)
            self.selected_classes = all_classes[all_classes['class_id'].isin(selected_class_ids)]['target'].tolist()
            # self.selected_classes = all_classes['target'].iloc[:100].tolist()
            with open(subset_classes_file, 'wb') as f:
                pickle.dump(self.selected_classes, f)

    def _load_metadata(self):
        super()._load_metadata()

        all_classes = pd.read_csv(os.path.join(self.root, 'CUB_200_2011', 'classes.txt'),
                              sep=' ', names=['class_id', 'target'])

        selected_class_ids = all_classes[all_classes['target'].isin(self.selected_classes)]['class_id'].tolist()

        if self.id: # select cub100_iid
            self.data = self.data[self.data['target'].isin(selected_class_ids)]
            self.class_names_str = [name.split(".")[1].replace('_', ' ') for name in self.selected_classes]

            remaining_class_ids = set(all_classes['class_id']) - set(selected_class_ids)
            remaining_class_names = all_classes[all_classes['class_id'].isin(remaining_class_ids)]['target'].tolist()
            self.ood_class_name_str = [name.split(".")[1].replace('_', ' ') for name in remaining_class_names]
        else:  # select cub100_ood
            remaining_class_ids = set(all_classes['class_id']) - set(selected_class_ids)
            self.data = self.data[self.data['target'].isin(remaining_class_ids)]
            remaining_class_names = all_classes[all_classes['class_id'].isin(remaining_class_ids)]['target'].tolist()
            self.class_names_str = [name.split(".")[1].replace('_', ' ') for name in remaining_class_names]

# %% [markdown]
# # **datasets/pet37.py**

# %%
import os
import os.path

from typing import Any, Tuple, Callable, Optional, Union, Sequence
import torch
import pickle
import random
from PIL import Image
import pathlib
from torchvision.datasets.utils import download_and_extract_archive, verify_str_arg
from torchvision.datasets.vision import VisionDataset


class OxfordIIITPet(VisionDataset):
    _RESOURCES = (
        ("https://www.robots.ox.ac.uk/~vgg/data/pets/data/images.tar.gz", "5c4f3ee8e5d25df40f4fd59a7f44e54c"),
        ("https://www.robots.ox.ac.uk/~vgg/data/pets/data/annotations.tar.gz", "95a8c909bbe2e81eed6a22bccdf3f68f"),
    )
    _VALID_TARGET_TYPES = ("category", "segmentation")

    def __init__(
        self,
        root: str,
        split: str = "trainval",
        target_types: Union[Sequence[str], str] = "category",
        transforms: Optional[Callable] = None,
        transform: Optional[Callable] = None,
        target_transform: Optional[Callable] = None,
        download: bool = False,
    ):
        self._split = verify_str_arg(split, "split", ("trainval", "test"))
        if isinstance(target_types, str):
            target_types = [target_types]
        self._target_types = [
            verify_str_arg(target_type, "target_types", self._VALID_TARGET_TYPES) for target_type in target_types
        ]

        super().__init__(root, transforms=transforms, transform=transform, target_transform=target_transform)
        self._base_folder = pathlib.Path(self.root) / "oxford-iiit-pet"
        self._images_folder = self._base_folder / "images"
        self._anns_folder = self._base_folder / "annotations"
        self._segs_folder = self._anns_folder / "trimaps"

        if download:
            self._download()

        if not self._check_exists():
            raise RuntimeError("Dataset not found. You can use download=True to download it")

        image_ids = []
        self._labels = []
        with open(self._anns_folder / f"{self._split}.txt") as file:
            for line in file:
                image_id, label, *_ = line.strip().split()
                image_ids.append(image_id)
                self._labels.append(int(label) - 1)

        self.classes = [
            " ".join(part.title() for part in raw_cls.split("_"))
            for raw_cls, _ in sorted(
                {(image_id.rsplit("_", 1)[0], label) for image_id, label in zip(image_ids, self._labels)},
                key=lambda image_id_and_label: image_id_and_label[1],
            )
        ]
        self.class_to_idx = dict(zip(self.classes, range(len(self.classes))))

        self._images = [self._images_folder / f"{image_id}.jpg" for image_id in image_ids]
        self._segs = [self._segs_folder / f"{image_id}.png" for image_id in image_ids]

        self.class_names_str = self.classes

    def __len__(self) -> int:
        return len(self._images)

    def __getitem__(self, idx: int) -> Tuple[Any, Any]:
        image = Image.open(self._images[idx]).convert("RGB")

        target: Any = []
        for target_type in self._target_types:
            if target_type == "category":
                target.append(self._labels[idx])
            else:  # target_type == "segmentation"
                target.append(Image.open(self._segs[idx]))

        if not target:
            target = None
        elif len(target) == 1:
            target = target[0]
        else:
            target = tuple(target)

        if self.transforms:
            image, target = self.transforms(image, target)

        return image, target


    def _check_exists(self) -> bool:
        for folder in (self._images_folder, self._anns_folder):
            if not (os.path.exists(folder) and os.path.isdir(folder)):
                return False
        else:
            return True

    def _download(self) -> None:
        if self._check_exists():
            return

        for url, md5 in self._RESOURCES:
            download_and_extract_archive(url, download_root=str(self._base_folder), md5=md5)


class OxfordIIITPet_18(OxfordIIITPet):
    def __init__(self,
        root: str,
        split: str = "trainval",
        id: bool = True,
        target_types: Union[Sequence[str], str] = "category",
        transforms: Optional[Callable] = None,
        transform: Optional[Callable] = None,
        target_transform: Optional[Callable] = None,
        download: bool = False,
        ):
        super(OxfordIIITPet_18, self).__init__(root=root, split=split, target_types=target_types, transforms=transforms, transform=transform, target_transform=target_transform, download=download)

        subset_classes_file = os.path.join('data', 'Oxford-Pet-18', 'selected_18_classes.pkl')
        if os.path.exists(subset_classes_file):
            with open(subset_classes_file, 'rb') as f:
                stored_classes = pickle.load(f)
        else:
            stored_classes = random.sample(self.classes, 18)
            with open(subset_classes_file, 'wb') as f:
                pickle.dump(stored_classes, f)

        selected_classes = stored_classes if id else [cls for cls in self.classes if cls not in stored_classes]
        self.ood_class_name_str = [cls for cls in self.classes if cls not in stored_classes] if id else stored_classes

        selected_indices = [i for i, label in enumerate(self._labels) if self.classes[label] in selected_classes]
        self._images = [self._images[i] for i in selected_indices]
        self._segs = [self._segs[i] for i in selected_indices]
        self._labels = [self._labels[i] for i in selected_indices]

        self.classes = selected_classes
        self.class_to_idx = {cls: idx for idx, cls in enumerate(self.classes)}
        self.class_names_str = self.classes


def examine_count(counter, name = "train"):
    print(f"in the {name} set")
    for label in counter:
        print(label, counter[label])

# %% [markdown]
# # **train_eval_util**

# %%
import os
import torch
from torchvision import datasets, transforms
from transformers import CLIPModel
from torchvision.datasets import CIFAR10, CIFAR100

def set_model_clip(args):
    """Load the CLIP model and corresponding val transforms"""
    ckpt_mapping = {
        "ViT-B/16": "openai/clip-vit-base-patch16",
        "ViT-B/32": "openai/clip-vit-base-patch32",
        "ViT-L/14": "openai/clip-vit-large-patch14"
    }
    args.ckpt = ckpt_mapping[args.CLIP_ckpt]
    model = CLIPModel.from_pretrained(args.ckpt)

    normalize = transforms.Normalize(mean=(0.48145466, 0.4578275, 0.40821073),
                                     std=(0.26862954, 0.26130258, 0.27577711))
    val_preprocess = transforms.Compose([
        transforms.Resize(224),
        transforms.CenterCrop(224),
        transforms.ToTensor(),
        normalize
    ])

    return model.cuda(), val_preprocess

def set_val_loader(args, preprocess):
    """Create a dataloader for the selected ID dataset"""
    dataset_classes = {
        "bird200": lambda root, transform: Cub2011(root, train=False, transform=transform),
        "pet37": lambda root, transform: OxfordIIITPet(root, split="test", download=True, transform=transform),
        "cub100_ID": lambda root, transform: Cub100(root, train=False, id=True, transform=transform),
        "pet18_ID": lambda root, transform: OxfordIIITPet_18(root, split="test", id=True, download=True, transform=transform),
        "cifar10_ID": lambda root, transform: CIFAR10(root, train=False, download=True, transform=transform),
    }

    dataset_fn = dataset_classes.get(args.in_dataset)
    if dataset_fn is None:
        raise NotImplementedError(f"Unsupported ID dataset: {args.in_dataset}")

    return torch.utils.data.DataLoader(
        dataset_fn(args.root_dir, preprocess),
        batch_size=args.batch_size,
        shuffle=False,
        num_workers=4,
        pin_memory=True
    )

def set_ood_loader(args, out_dataset, preprocess):
    """Create a DataLoader for the selected OOD dataset."""
    dataset_paths = {
        'dtd': os.path.join(args.root_dir, 'dtd','dtd','images'),
    }

    ood_classes = {
        'bird200':  lambda root, tf: Cub2011(root, train=False, transform=tf),
        'pet37':    lambda root, tf: OxfordIIITPet(root, split='test', download=True, transform=tf),
        'cub100_OOD': lambda root, tf: Cub100(root, train=False, id=False, transform=tf),
        'pet19_OOD': lambda root, tf: OxfordIIITPet_18(root, split='test', id=False, download=True, transform=tf),
        'cifar100_OOD': lambda root, tf: CIFAR100(root, train=False, download=True, transform=tf),
    }

    if out_dataset in dataset_paths:
        dataset = datasets.ImageFolder(dataset_paths[out_dataset], transform=preprocess)
    elif out_dataset in ood_classes:
        dataset = ood_classes[out_dataset](args.root_dir, preprocess)
    else:
        raise ValueError(f"Unsupported OOD dataset: {out_dataset}")

    return torch.utils.data.DataLoader(
        dataset,
        batch_size=args.batch_size,
        shuffle=False,
        num_workers=getattr(args, 'num_workers', 4),
        pin_memory=getattr(args, 'pin_memory', True)
    )

# %% [markdown]
# # **RUN EVALUATION CUB200(ID) vs TEXTURE(OOD) at Beta 0.25 & 0.75, L=0,50,100,300**

# %%
import os
import openai
import re

client = openai.OpenAI(api_key=os.getenv("OPENAI_API_KEY"))

def fetch_synonym(name: str) -> str:
    system_prompt = (
        "You are a fine-grained classification assistant. "
        "When given a pet(including dogs and cats) species name, reply with *exactly one* known synonym or scientific name or name in other language. "
        "If no widely used alternative exists, reply with the original label and do not return *none*. "
        "Only return the name. Do not include explanations, punctuation, or prefixes.\n\n"
        "Here are a few examples:\n"
        "Input: American Goldfinch → Output: Eastern Goldfinch\n"
        "Input: Indigo Bunting → Output: Passerina cyanea\n"
        "Input: Bengal Cat → Output: Leopardette"
        "Input: Gadwall → Output: Anas strepera\n"
    )

    user_prompt = f"Class label: {name}"

    response = client.chat.completions.create(
        model="gpt-3.5-turbo",
        messages=[
            {"role": "system", "content": system_prompt},
            {"role": "user",   "content": user_prompt}
        ],
        temperature=0
    )

    raw = response.choices[0].message.content.strip()

    if ":" in raw:
        raw = raw.split(":")[-1].strip()
    if "known as" in raw:
        raw = re.split(r"known as", raw, flags=re.IGNORECASE)[-1].strip()

    return raw.rstrip(".")

# %%
import os
os.environ['CURL_CA_BUNDLE'] = ''
import argparse
import numpy as np
import torch
from scipy import stats

def main():
    args = process_args()
    setup_seed(args.seed)
    log = setup_log(args)
    assert torch.cuda.is_available()
    torch.cuda.set_device(args.gpu)

    net, preprocess = set_model_clip(args)
    net.eval()

    if args.in_dataset.startswith("ImageNet_C"):
        out_datasets = ['iNaturalist', 'SUN', 'places365', 'dtd']
    elif args.in_dataset == 'ImageNet':
        out_datasets = ['iNaturalist', 'SUN', 'places365', 'dtd'] if args.ood_task.startswith("far") else ['ssb_hard', 'ninco']
    else:
        out_datasets = dataset_mappings.get(args.in_dataset, [])

    test_loader = set_val_loader(args, preprocess)
    test_labels = list(get_test_labels(args, test_loader))
    print("Original ID Labels:", test_labels)

    if args.score == 'EOE':
        print("Using LLM-generated OOD candidate classes...")
        base_ood_labels = load_llm_classes(args, test_labels)

        if args.use_synonyms:
            print("Augmenting OOD candidates with synonyms...")

            base_ood_labels = [lbl.strip().lower() for lbl in base_ood_labels]
            original_count = len(base_ood_labels)

            synonym_labels = []
            for lbl in base_ood_labels:
                syn = fetch_synonym(lbl).strip().lower()
                print(f"  → {lbl!r}  → synonym: {syn!r}")
                if syn != lbl:
                    synonym_labels.append(syn)

            combined = base_ood_labels + synonym_labels

            filtered = [label for label in combined if label and label.lower() not in {"none", "null"}]

            removed_count = len(combined) - len(filtered)
            print(f"Removed {removed_count} invalid synonym labels like 'none' or 'null'")

            llm_labels = list(dict.fromkeys(filtered))
            final_count = len(llm_labels)

            print(f"OOD classes before synonym expansion: {original_count}")
            print(f"OOD classes after synonym + deduplication: {final_count}")
        else:
            llm_labels = base_ood_labels
    else:
        llm_labels = []

    print(f"\n Final ID Labels passed to CLIP: {test_labels}")
    print(f"OOD candidate labels: {llm_labels}\n")

    in_score = get_ood_scores_clip(args, net, test_loader, test_labels, llm_labels)

    auroc_list, aupr_list, fpr_list = [], [], []
    for out_dataset in out_datasets:
        log.debug(f"Evaluating OOD dataset {out_dataset}")
        ood_loader = set_ood_loader(args, out_dataset, preprocess)
        out_score = get_ood_scores_clip(args, net, ood_loader, test_labels, llm_labels)

        log.debug(f"in scores: {stats.describe(in_score)}")
        log.debug(f"out scores: {stats.describe(out_score)}")
        plot_distribution(args, in_score, out_score, out_dataset)
        get_and_print_results(args, log, in_score, out_score, auroc_list, aupr_list, fpr_list)

    log.debug('\n\n Mean Test Results')
    print_measures(log, np.mean(auroc_list), np.mean(aupr_list),
                   np.mean(fpr_list), method_name=args.score)

    save_as_dataframe(args, out_datasets, fpr_list, auroc_list, aupr_list)


def process_args():
    parser = argparse.ArgumentParser(
        description='Leverage LLMs for OOD Detection',
        formatter_class=argparse.ArgumentDefaultsHelpFormatter
    )
    parser.add_argument('--in_dataset',
                        default='bird200',
                        choices=ALL_ID_DATASET,
                        help='in-distribution dataset')
    parser.add_argument('--root_dir',
                        default="datasets",
                        help='root dir of datasets')
    # prompt pipeline
    parser.add_argument('--ensemble',
                        action='store_true',
                        default=False,
                        help='CLIP text prompt engineering')
    parser.add_argument('--L',
                        type=int,
                        default=100,
                        help='the length of envisioned OOD class labels, for far/fine-grained: L=500, for near: L=3')
    parser.add_argument('--beta',
                        type=float,
                        default=0.25,
                        help='beta in Eq. 3')
    parser.add_argument('--ood_task',
                        type=str,
                        default='far',
                        choices=ALL_OOD_TASK,
                        help='choose ood task')
    parser.add_argument('--generate_class',
                        action='store_true',
                        help='whether to envision OOD candidate classes or loaded from existing JSONs')
    parser.add_argument('--json_number',
                        type=int,
                        default=0,
                        help='loaded json number')
    parser.add_argument('--llm_model',
                        default="gpt-3.5-turbo",
                        choices=ALL_LLM,
                        help='LLMs')
    parser.add_argument('--name',
                        default="eval_ood",
                        help="unique ID for the run")
    parser.add_argument('--seed',
                        type=int,
                        default=5,
                        help="random seed")
    parser.add_argument('--gpu',
                        type=int,
                        default=0,
                        help='the GPU indice to use')
    parser.add_argument('--batch_size',
                        type=int,
                        default=512,
                        help='mini-batch size')
    parser.add_argument('--T',
                        type=float,
                        default=1,
                        help='score temperature parameter')
    parser.add_argument('--model',
                        default='CLIP',
                        choices=['CLIP'],
                        help='model architecture')
    parser.add_argument('--CLIP_ckpt',
                        default='ViT-B/16',
                        choices=['ViT-B/16'],
                        help='which pretrained img encoder to use')
    parser.add_argument('--score',
                        default='EOE',
                        choices=['EOE', 'MCM', 'energy', 'max-logit'],
                        help='which scoring method')
    parser.add_argument('--score_ablation',
                        default='EOE',
                        choices=['MAX', 'MSP', 'energy', 'max-logit', 'EOE'],
                        help='ablations on the EOE score formula')
    parser.add_argument('--feat_dim',
                        type=int,
                        default=512,
                        help='feat dim, 512 for ViT-B and 768 for ViT-L')
    parser.add_argument('--use_synonyms',
                    default=False,
                    action='store_true',
                    help='Augment ID labels with synonyms using LLM')
    parser.add_argument('--prompt_pool_id',
                    type=int,
                    default=0,
                    help='Which index of openai_imagenet_template_subset to use when --ensemble')
    args = parser.parse_args()

    args.n_cls = get_num_cls(args)
    args.log_directory = f"results/{args.in_dataset}/{args.score}/" \
                         f"{args.model}_{args.CLIP_ckpt}_T_{args.T}_ID_{args.name}"
    os.makedirs(args.log_directory, exist_ok=True)

    return args

# %% [markdown]
# L = 0 (MCM)

# %%
# !pip install -q nest_asyncio
import nest_asyncio
nest_asyncio.apply()
import os
os.environ['CURL_CA_BUNDLE'] = ''
import argparse
import numpy as np
import torch
from scipy import stats
import sys

sys.argv = [
    "eval_ood_detection.py",
    "--name",        "CUB200_TEXTURE_MCM_far_evaluation",
    "--in_dataset",  "bird200",
    "--ood_task",    "far",
    "--score",       "MCM",
    "--root_dir",    "datasets",
    "--batch_size",  "256",
    "--gpu",         "0",
    "--L",           "50",
]
main()
# Out:
# /usr/local/lib/python3.11/dist-packages/torch/utils/data/dataloader.py:624: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(
# Original ID Labels: ['Black footed Albatross', 'Laysan Albatross', 'Sooty Albatross', 'Groove billed Ani', 'Crested Auklet', 'Least Auklet', 'Parakeet Auklet', 'Rhinoceros Auklet', 'Brewer Blackbird', 'Red winged Blackbird', 'Rusty Blackbird', 'Yellow headed Blackbird', 'Bobolink', 'Indigo Bunting', 'Lazuli Bunting', 'Painted Bunting', 'Cardinal', 'Spotted Catbird', 'Gray Catbird', 'Yellow breasted Chat', 'Eastern Towhee', 'Chuck will Widow', 'Brandt Cormorant', 'Red faced Cormorant', 'Pelagic Cormorant', 'Bronzed Cowbird', 'Shiny Cowbird', 'Brown Creeper', 'American Crow', 'Fish Crow', 'Black billed Cuckoo', 'Mangrove Cuckoo', 'Yellow billed Cuckoo', 'Gray crowned Rosy Finch', 'Purple Finch', 'Northern Flicker', 'Acadian Flycatcher', 'Great Crested Flycatcher', 'Least Flycatcher', 'Olive sided Flycatcher', 'Scissor tailed Flycatcher', 'Vermilion Flycatcher', 'Yellow bellied Flycatcher', 'Frigatebird', 'Northern Fulmar', 'Gadwall', 'American Goldfinch', 'European Goldfinch', 'Boat tailed Grackle', 'Eared Grebe', 'Horned Grebe', 'Pied billed Grebe', 'Western Grebe', 'Blue Grosbeak', 'Evening Grosbeak', 'Pine Grosbeak', 'Rose breasted Grosbeak', 'Pigeon Guillemot', 'California Gull', 'Glaucous winged Gull', 'Heermann Gull', 'Herring Gull', 'Ivory Gull', 'Ring billed Gull', 'Slaty backed Gull', 'Western Gull', 'Anna Hummingbird', 'Ruby throated Hummingbird', 'Rufous Hummingbird', 'Green Violetear', 'Long tailed Jaeger', 'Pomarine Jaeger', 'Blue Jay', 'Florida Jay', 'Green Jay', 'Dark eyed Junco', 'Tropical Kingbird', 'Gray Kingbird', 'Belted Kingfisher', 'Green Kingfisher', 'Pied Kingfisher', 'Ringed Kingfisher', 'White breasted Kingfisher', 'Red legged Kittiwake', 'Horned Lark', 'Pacific Loon', 'Mallard', 'Western Meadowlark', 'Hooded Merganser', 'Red breasted Merganser', 'Mockingbird', 'Nighthawk', 'Clark Nutcracker', 'White breasted Nuthatch', 'Baltimore Oriole', 'Hooded Oriole', 'Orchard Oriole', 'Scott Oriole', 'Ovenbird', 'Brown Pelican', 'White Pelican', 'Western Wood Pewee', 'Sayornis', 'American Pipit', 'Whip poor Will', 'Horned Puffin', 'Common Raven', 'White necked Raven', 'American Redstart', 'Geococcyx', 'Loggerhead Shrike', 'Great Grey Shrike', 'Baird Sparrow', 'Black throated Sparrow', 'Brewer Sparrow', 'Chipping Sparrow', 'Clay colored Sparrow', 'House Sparrow', 'Field Sparrow', 'Fox Sparrow', 'Grasshopper Sparrow', 'Harris Sparrow', 'Henslow Sparrow', 'Le Conte Sparrow', 'Lincoln Sparrow', 'Nelson Sharp tailed Sparrow', 'Savannah Sparrow', 'Seaside Sparrow', 'Song Sparrow', 'Tree Sparrow', 'Vesper Sparrow', 'White crowned Sparrow', 'White throated Sparrow', 'Cape Glossy Starling', 'Bank Swallow', 'Barn Swallow', 'Cliff Swallow', 'Tree Swallow', 'Scarlet Tanager', 'Summer Tanager', 'Artic Tern', 'Black Tern', 'Caspian Tern', 'Common Tern', 'Elegant Tern', 'Forsters Tern', 'Least Tern', 'Green tailed Towhee', 'Brown Thrasher', 'Sage Thrasher', 'Black capped Vireo', 'Blue headed Vireo', 'Philadelphia Vireo', 'Red eyed Vireo', 'Warbling Vireo', 'White eyed Vireo', 'Yellow throated Vireo', 'Bay breasted Warbler', 'Black and white Warbler', 'Black throated Blue Warbler', 'Blue winged Warbler', 'Canada Warbler', 'Cape May Warbler', 'Cerulean Warbler', 'Chestnut sided Warbler', 'Golden winged Warbler', 'Hooded Warbler', 'Kentucky Warbler', 'Magnolia Warbler', 'Mourning Warbler', 'Myrtle Warbler', 'Nashville Warbler', 'Orange crowned Warbler', 'Palm Warbler', 'Pine Warbler', 'Prairie Warbler', 'Prothonotary Warbler', 'Swainson Warbler', 'Tennessee Warbler', 'Wilson Warbler', 'Worm eating Warbler', 'Yellow Warbler', 'Northern Waterthrush', 'Louisiana Waterthrush', 'Bohemian Waxwing', 'Cedar Waxwing', 'American Three toed Woodpecker', 'Pileated Woodpecker', 'Red bellied Woodpecker', 'Red cockaded Woodpecker', 'Red headed Woodpecker', 'Downy Woodpecker', 'Bewick Wren', 'Cactus Wren', 'Carolina Wren', 'House Wren', 'Marsh Wren', 'Rock Wren', 'Winter Wren', 'Common Yellowthroat']
# Using original ID labels (no synonyms).
# Final ID Labels passed to CLIP: ['Black footed Albatross', 'Laysan Albatross', 'Sooty Albatross', 'Groove billed Ani', 'Crested Auklet', 'Least Auklet', 'Parakeet Auklet', 'Rhinoceros Auklet', 'Brewer Blackbird', 'Red winged Blackbird', 'Rusty Blackbird', 'Yellow headed Blackbird', 'Bobolink', 'Indigo Bunting', 'Lazuli Bunting', 'Painted Bunting', 'Cardinal', 'Spotted Catbird', 'Gray Catbird', 'Yellow breasted Chat', 'Eastern Towhee', 'Chuck will Widow', 'Brandt Cormorant', 'Red faced Cormorant', 'Pelagic Cormorant', 'Bronzed Cowbird', 'Shiny Cowbird', 'Brown Creeper', 'American Crow', 'Fish Crow', 'Black billed Cuckoo', 'Mangrove Cuckoo', 'Yellow billed Cuckoo', 'Gray crowned Rosy Finch', 'Purple Finch', 'Northern Flicker', 'Acadian Flycatcher', 'Great Crested Flycatcher', 'Least Flycatcher', 'Olive sided Flycatcher', 'Scissor tailed Flycatcher', 'Vermilion Flycatcher', 'Yellow bellied Flycatcher', 'Frigatebird', 'Northern Fulmar', 'Gadwall', 'American Goldfinch', 'European Goldfinch', 'Boat tailed Grackle', 'Eared Grebe', 'Horned Grebe', 'Pied billed Grebe', 'Western Grebe', 'Blue Grosbeak', 'Evening Grosbeak', 'Pine Grosbeak', 'Rose breasted Grosbeak', 'Pigeon Guillemot', 'California Gull', 'Glaucous winged Gull', 'Heermann Gull', 'Herring Gull', 'Ivory Gull', 'Ring billed Gull', 'Slaty backed Gull', 'Western Gull', 'Anna Hummingbird', 'Ruby throated Hummingbird', 'Rufous Hummingbird', 'Green Violetear', 'Long tailed Jaeger', 'Pomarine Jaeger', 'Blue Jay', 'Florida Jay', 'Green Jay', 'Dark eyed Junco', 'Tropical Kingbird', 'Gray Kingbird', 'Belted Kingfisher', 'Green Kingfisher', 'Pied Kingfisher', 'Ringed Kingfisher', 'White breasted Kingfisher', 'Red legged Kittiwake', 'Horned Lark', 'Pacific Loon', 'Mallard', 'Western Meadowlark', 'Hooded Merganser', 'Red breasted Merganser', 'Mockingbird', 'Nighthawk', 'Clark Nutcracker', 'White breasted Nuthatch', 'Baltimore Oriole', 'Hooded Oriole', 'Orchard Oriole', 'Scott Oriole', 'Ovenbird', 'Brown Pelican', 'White Pelican', 'Western Wood Pewee', 'Sayornis', 'American Pipit', 'Whip poor Will', 'Horned Puffin', 'Common Raven', 'White necked Raven', 'American Redstart', 'Geococcyx', 'Loggerhead Shrike', 'Great Grey Shrike', 'Baird Sparrow', 'Black throated Sparrow', 'Brewer Sparrow', 'Chipping Sparrow', 'Clay colored Sparrow', 'House Sparrow', 'Field Sparrow', 'Fox Sparrow', 'Grasshopper Sparrow', 'Harris Sparrow', 'Henslow Sparrow', 'Le Conte Sparrow', 'Lincoln Sparrow', 'Nelson Sharp tailed Sparrow', 'Savannah Sparrow', 'Seaside Sparrow', 'Song Sparrow', 'Tree Sparrow', 'Vesper Sparrow', 'White crowned Sparrow', 'White throated Sparrow', 'Cape Glossy Starling', 'Bank Swallow', 'Barn Swallow', 'Cliff Swallow', 'Tree Swallow', 'Scarlet Tanager', 'Summer Tanager', 'Artic Tern', 'Black Tern', 'Caspian Tern', 'Common Tern', 'Elegant Tern', 'Forsters Tern', 'Least Tern', 'Green tailed Towhee', 'Brown Thrasher', 'Sage Thrasher', 'Black capped Vireo', 'Blue headed Vireo', 'Philadelphia Vireo', 'Red eyed Vireo', 'Warbling Vireo', 'White eyed Vireo', 'Yellow throated Vireo', 'Bay breasted Warbler', 'Black and white Warbler', 'Black throated Blue Warbler', 'Blue winged Warbler', 'Canada Warbler', 'Cape May Warbler', 'Cerulean Warbler', 'Chestnut sided Warbler', 'Golden winged Warbler', 'Hooded Warbler', 'Kentucky Warbler', 'Magnolia Warbler', 'Mourning Warbler', 'Myrtle Warbler', 'Nashville Warbler', 'Orange crowned Warbler', 'Palm Warbler', 'Pine Warbler', 'Prairie Warbler', 'Prothonotary Warbler', 'Swainson Warbler', 'Tennessee Warbler', 'Wilson Warbler', 'Worm eating Warbler', 'Yellow Warbler', 'Northern Waterthrush', 'Louisiana Waterthrush', 'Bohemian Waxwing', 'Cedar Waxwing', 'American Three toed Woodpecker', 'Pileated Woodpecker', 'Red bellied Woodpecker', 'Red cockaded Woodpecker', 'Red headed Woodpecker', 'Downy Woodpecker', 'Bewick Wren', 'Cactus Wren', 'Carolina Wren', 'House Wren', 'Marsh Wren', 'Rock Wren', 'Winter Wren', 'Common Yellowthroat']
# Envisioned OOD labels (LLM): []
# 100%|██████████| 23/23 [01:15<00:00,  3.30s/it]
# 2025-07-12 20:08:10,891 : Evaluating OOD dataset dtd
# DEBUG:__main__:Evaluating OOD dataset dtd
# 100%|██████████| 23/23 [01:16<00:00,  3.34s/it]
# 2025-07-12 20:09:28,997 : in scores: DescribeResult(nobs=5794, minmax=(np.float32(-0.00612707), np.float32(-0.005317356)), mean=np.float32(-0.005696114), variance=np.float64(1.567329524948791e-08), skewness=np.float64(-0.13309940695762634), kurtosis=np.float32(-0.10947347))
# DEBUG:__main__:in scores: DescribeResult(nobs=5794, minmax=(np.float32(-0.00612707), np.float32(-0.005317356)), mean=np.float32(-0.005696114), variance=np.float64(1.567329524948791e-08), skewness=np.float64(-0.13309940695762634), kurtosis=np.float32(-0.10947347))
# 2025-07-12 20:09:29,003 : out scores: DescribeResult(nobs=5640, minmax=(np.float32(-0.0057679457), np.float32(-0.005112402)), mean=np.float32(-0.0053473637), variance=np.float64(8.077742511057822e-09), skewness=np.float64(-0.47231942415237427), kurtosis=np.float32(0.20275927))
# DEBUG:__main__:out scores: DescribeResult(nobs=5640, minmax=(np.float32(-0.0057679457), np.float32(-0.005112402)), mean=np.float32(-0.0053473637), variance=np.float64(8.077742511057822e-09), skewness=np.float64(-0.47231942415237427), kurtosis=np.float32(0.20275927))
# 2025-07-12 20:09:30,926 : 				MCM
# DEBUG:__main__:				MCM
# 2025-07-12 20:09:30,934 :   FPR95 AUROC AUPR
# DEBUG:__main__:  FPR95 AUROC AUPR
# 2025-07-12 20:09:30,936 : & 6.70 & 98.79 & 98.85
# DEBUG:__main__:& 6.70 & 98.79 & 98.85
# 2025-07-12 20:09:30,946 :
#
# Mean Test Results
# DEBUG:__main__:
#
# Mean Test Results
# 2025-07-12 20:09:30,953 : 				MCM
# DEBUG:__main__:				MCM
# 2025-07-12 20:09:30,961 :   FPR95 AUROC AUPR
# DEBUG:__main__:  FPR95 AUROC AUPR
# 2025-07-12 20:09:30,969 : & 6.70 & 98.79 & 98.85
# DEBUG:__main__:& 6.70 & 98.79 & 98.85

# %% [markdown]
# L=50, Beta=0.25

# %%
sys.argv = [
    "eval_ood_detection.py",
    "--name",        "CUB200_TEXTURE_far_evaluation",
    "--in_dataset",  "bird200",
    "--ood_task",    "far",
    "--score",       "EOE",
    "--root_dir",    "datasets",
    "--batch_size",  "256",
    "--gpu",         "0",
    "--L",           "50",
    "--generate_class",
]
main()
# Out:
# 2025-07-12 19:34:33,672 : #########CUB200_TEXTURE_far_evaluation############
# DEBUG:__main__:#########CUB200_TEXTURE_far_evaluation############
# /usr/local/lib/python3.11/dist-packages/torch/utils/data/dataloader.py:624: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(
# Original ID Labels: ['Black footed Albatross', 'Laysan Albatross', 'Sooty Albatross', 'Groove billed Ani', 'Crested Auklet', 'Least Auklet', 'Parakeet Auklet', 'Rhinoceros Auklet', 'Brewer Blackbird', 'Red winged Blackbird', 'Rusty Blackbird', 'Yellow headed Blackbird', 'Bobolink', 'Indigo Bunting', 'Lazuli Bunting', 'Painted Bunting', 'Cardinal', 'Spotted Catbird', 'Gray Catbird', 'Yellow breasted Chat', 'Eastern Towhee', 'Chuck will Widow', 'Brandt Cormorant', 'Red faced Cormorant', 'Pelagic Cormorant', 'Bronzed Cowbird', 'Shiny Cowbird', 'Brown Creeper', 'American Crow', 'Fish Crow', 'Black billed Cuckoo', 'Mangrove Cuckoo', 'Yellow billed Cuckoo', 'Gray crowned Rosy Finch', 'Purple Finch', 'Northern Flicker', 'Acadian Flycatcher', 'Great Crested Flycatcher', 'Least Flycatcher', 'Olive sided Flycatcher', 'Scissor tailed Flycatcher', 'Vermilion Flycatcher', 'Yellow bellied Flycatcher', 'Frigatebird', 'Northern Fulmar', 'Gadwall', 'American Goldfinch', 'European Goldfinch', 'Boat tailed Grackle', 'Eared Grebe', 'Horned Grebe', 'Pied billed Grebe', 'Western Grebe', 'Blue Grosbeak', 'Evening Grosbeak', 'Pine Grosbeak', 'Rose breasted Grosbeak', 'Pigeon Guillemot', 'California Gull', 'Glaucous winged Gull', 'Heermann Gull', 'Herring Gull', 'Ivory Gull', 'Ring billed Gull', 'Slaty backed Gull', 'Western Gull', 'Anna Hummingbird', 'Ruby throated Hummingbird', 'Rufous Hummingbird', 'Green Violetear', 'Long tailed Jaeger', 'Pomarine Jaeger', 'Blue Jay', 'Florida Jay', 'Green Jay', 'Dark eyed Junco', 'Tropical Kingbird', 'Gray Kingbird', 'Belted Kingfisher', 'Green Kingfisher', 'Pied Kingfisher', 'Ringed Kingfisher', 'White breasted Kingfisher', 'Red legged Kittiwake', 'Horned Lark', 'Pacific Loon', 'Mallard', 'Western Meadowlark', 'Hooded Merganser', 'Red breasted Merganser', 'Mockingbird', 'Nighthawk', 'Clark Nutcracker', 'White breasted Nuthatch', 'Baltimore Oriole', 'Hooded Oriole', 'Orchard Oriole', 'Scott Oriole', 'Ovenbird', 'Brown Pelican', 'White Pelican', 'Western Wood Pewee', 'Sayornis', 'American Pipit', 'Whip poor Will', 'Horned Puffin', 'Common Raven', 'White necked Raven', 'American Redstart', 'Geococcyx', 'Loggerhead Shrike', 'Great Grey Shrike', 'Baird Sparrow', 'Black throated Sparrow', 'Brewer Sparrow', 'Chipping Sparrow', 'Clay colored Sparrow', 'House Sparrow', 'Field Sparrow', 'Fox Sparrow', 'Grasshopper Sparrow', 'Harris Sparrow', 'Henslow Sparrow', 'Le Conte Sparrow', 'Lincoln Sparrow', 'Nelson Sharp tailed Sparrow', 'Savannah Sparrow', 'Seaside Sparrow', 'Song Sparrow', 'Tree Sparrow', 'Vesper Sparrow', 'White crowned Sparrow', 'White throated Sparrow', 'Cape Glossy Starling', 'Bank Swallow', 'Barn Swallow', 'Cliff Swallow', 'Tree Swallow', 'Scarlet Tanager', 'Summer Tanager', 'Artic Tern', 'Black Tern', 'Caspian Tern', 'Common Tern', 'Elegant Tern', 'Forsters Tern', 'Least Tern', 'Green tailed Towhee', 'Brown Thrasher', 'Sage Thrasher', 'Black capped Vireo', 'Blue headed Vireo', 'Philadelphia Vireo', 'Red eyed Vireo', 'Warbling Vireo', 'White eyed Vireo', 'Yellow throated Vireo', 'Bay breasted Warbler', 'Black and white Warbler', 'Black throated Blue Warbler', 'Blue winged Warbler', 'Canada Warbler', 'Cape May Warbler', 'Cerulean Warbler', 'Chestnut sided Warbler', 'Golden winged Warbler', 'Hooded Warbler', 'Kentucky Warbler', 'Magnolia Warbler', 'Mourning Warbler', 'Myrtle Warbler', 'Nashville Warbler', 'Orange crowned Warbler', 'Palm Warbler', 'Pine Warbler', 'Prairie Warbler', 'Prothonotary Warbler', 'Swainson Warbler', 'Tennessee Warbler', 'Wilson Warbler', 'Worm eating Warbler', 'Yellow Warbler', 'Northern Waterthrush', 'Louisiana Waterthrush', 'Bohemian Waxwing', 'Cedar Waxwing', 'American Three toed Woodpecker', 'Pileated Woodpecker', 'Red bellied Woodpecker', 'Red cockaded Woodpecker', 'Red headed Woodpecker', 'Downy Woodpecker', 'Bewick Wren', 'Cactus Wren', 'Carolina Wren', 'House Wren', 'Marsh Wren', 'Rock Wren', 'Winter Wren', 'Common Yellowthroat']
# Using original ID labels (no synonyms).
# Envisioning Outlier Exposure...
# 🔵 Generating via OpenAI GPT...
# 🔍 Raw GPT output:
#  - Sunset over the ocean
# - Abstract art painting
# - Vintage car
# - Snow-capped mountain
# - Tropical beach
# - Desert landscape
# - City skyline at night
# - Starry night sky
# - Waterfall in a lush forest
# - Colorful hot air balloons
# - Aurora borealis
# - Fields of blooming flowers
# - Ancient ruins
# - Iceberg in the ocean
# - Volcanic eruption
# - Lightning storm
# - Rainbow over a waterfall
# - Sand dunes in the desert
# - Glacial lake
# - Urban graffiti art
# - Neon city lights
# - Surreal fantasy landscape
# - Underwater coral reef
# - Moonlit forest
# - Rustic barn in a field
# - Abstract geometric patterns
# - Vintage train station
# - Futuristic cityscape
# - Mountain range at sunrise
# - Vibrant street art
# - Frozen tundra
# - Lush tropical jungle
# - Abstract digital art
# - Old lighthouse on a rocky coast
# - Vibrant autumn foliage
# - Barren desert landscape
# - Colorful fireworks display
# - Abstract architectural design
# - Vintage steam locomotive
# - Stormy seascape
# - Vibrant street market
# - Abstract watercolor painting
# - Retro diner interior
# - Mountain peak covered in snow
# - Vibrant graffiti wall
# - Abstract mosaic tile pattern
# - Vintage biplane in flight
# - Colorful balloon festival
# - Abstract oil painting
#
# 💾 Saving hallucinated class descriptors to: envisioned_classes/far_50/bird200_gpt-3.5-turbo_1.json
# === load json:  envisioned_classes/far_50/bird200_gpt-3.5-turbo_1.json
# Get Envisioned Candidate Class Names.
# After set: 49
# After removing ID class overlaps: 49
# Final ID Labels passed to CLIP: ['Black footed Albatross', 'Laysan Albatross', 'Sooty Albatross', 'Groove billed Ani', 'Crested Auklet', 'Least Auklet', 'Parakeet Auklet', 'Rhinoceros Auklet', 'Brewer Blackbird', 'Red winged Blackbird', 'Rusty Blackbird', 'Yellow headed Blackbird', 'Bobolink', 'Indigo Bunting', 'Lazuli Bunting', 'Painted Bunting', 'Cardinal', 'Spotted Catbird', 'Gray Catbird', 'Yellow breasted Chat', 'Eastern Towhee', 'Chuck will Widow', 'Brandt Cormorant', 'Red faced Cormorant', 'Pelagic Cormorant', 'Bronzed Cowbird', 'Shiny Cowbird', 'Brown Creeper', 'American Crow', 'Fish Crow', 'Black billed Cuckoo', 'Mangrove Cuckoo', 'Yellow billed Cuckoo', 'Gray crowned Rosy Finch', 'Purple Finch', 'Northern Flicker', 'Acadian Flycatcher', 'Great Crested Flycatcher', 'Least Flycatcher', 'Olive sided Flycatcher', 'Scissor tailed Flycatcher', 'Vermilion Flycatcher', 'Yellow bellied Flycatcher', 'Frigatebird', 'Northern Fulmar', 'Gadwall', 'American Goldfinch', 'European Goldfinch', 'Boat tailed Grackle', 'Eared Grebe', 'Horned Grebe', 'Pied billed Grebe', 'Western Grebe', 'Blue Grosbeak', 'Evening Grosbeak', 'Pine Grosbeak', 'Rose breasted Grosbeak', 'Pigeon Guillemot', 'California Gull', 'Glaucous winged Gull', 'Heermann Gull', 'Herring Gull', 'Ivory Gull', 'Ring billed Gull', 'Slaty backed Gull', 'Western Gull', 'Anna Hummingbird', 'Ruby throated Hummingbird', 'Rufous Hummingbird', 'Green Violetear', 'Long tailed Jaeger', 'Pomarine Jaeger', 'Blue Jay', 'Florida Jay', 'Green Jay', 'Dark eyed Junco', 'Tropical Kingbird', 'Gray Kingbird', 'Belted Kingfisher', 'Green Kingfisher', 'Pied Kingfisher', 'Ringed Kingfisher', 'White breasted Kingfisher', 'Red legged Kittiwake', 'Horned Lark', 'Pacific Loon', 'Mallard', 'Western Meadowlark', 'Hooded Merganser', 'Red breasted Merganser', 'Mockingbird', 'Nighthawk', 'Clark Nutcracker', 'White breasted Nuthatch', 'Baltimore Oriole', 'Hooded Oriole', 'Orchard Oriole', 'Scott Oriole', 'Ovenbird', 'Brown Pelican', 'White Pelican', 'Western Wood Pewee', 'Sayornis', 'American Pipit', 'Whip poor Will', 'Horned Puffin', 'Common Raven', 'White necked Raven', 'American Redstart', 'Geococcyx', 'Loggerhead Shrike', 'Great Grey Shrike', 'Baird Sparrow', 'Black throated Sparrow', 'Brewer Sparrow', 'Chipping Sparrow', 'Clay colored Sparrow', 'House Sparrow', 'Field Sparrow', 'Fox Sparrow', 'Grasshopper Sparrow', 'Harris Sparrow', 'Henslow Sparrow', 'Le Conte Sparrow', 'Lincoln Sparrow', 'Nelson Sharp tailed Sparrow', 'Savannah Sparrow', 'Seaside Sparrow', 'Song Sparrow', 'Tree Sparrow', 'Vesper Sparrow', 'White crowned Sparrow', 'White throated Sparrow', 'Cape Glossy Starling', 'Bank Swallow', 'Barn Swallow', 'Cliff Swallow', 'Tree Swallow', 'Scarlet Tanager', 'Summer Tanager', 'Artic Tern', 'Black Tern', 'Caspian Tern', 'Common Tern', 'Elegant Tern', 'Forsters Tern', 'Least Tern', 'Green tailed Towhee', 'Brown Thrasher', 'Sage Thrasher', 'Black capped Vireo', 'Blue headed Vireo', 'Philadelphia Vireo', 'Red eyed Vireo', 'Warbling Vireo', 'White eyed Vireo', 'Yellow throated Vireo', 'Bay breasted Warbler', 'Black and white Warbler', 'Black throated Blue Warbler', 'Blue winged Warbler', 'Canada Warbler', 'Cape May Warbler', 'Cerulean Warbler', 'Chestnut sided Warbler', 'Golden winged Warbler', 'Hooded Warbler', 'Kentucky Warbler', 'Magnolia Warbler', 'Mourning Warbler', 'Myrtle Warbler', 'Nashville Warbler', 'Orange crowned Warbler', 'Palm Warbler', 'Pine Warbler', 'Prairie Warbler', 'Prothonotary Warbler', 'Swainson Warbler', 'Tennessee Warbler', 'Wilson Warbler', 'Worm eating Warbler', 'Yellow Warbler', 'Northern Waterthrush', 'Louisiana Waterthrush', 'Bohemian Waxwing', 'Cedar Waxwing', 'American Three toed Woodpecker', 'Pileated Woodpecker', 'Red bellied Woodpecker', 'Red cockaded Woodpecker', 'Red headed Woodpecker', 'Downy Woodpecker', 'Bewick Wren', 'Cactus Wren', 'Carolina Wren', 'House Wren', 'Marsh Wren', 'Rock Wren', 'Winter Wren', 'Common Yellowthroat']
# Envisioned OOD labels (LLM): ['abstract oil painting', 'sand dunes in the desert', 'vibrant autumn foliage', 'surreal fantasy landscape', 'barren desert landscape', 'vibrant street market', 'vintage train station', 'vibrant graffiti wall', 'lightning storm', 'starry night sky', 'mountain range at sunrise', 'colorful hot air balloons', 'city skyline at night', 'ancient ruins', 'lush tropical jungle', 'frozen tundra', 'abstract art painting', 'underwater coral reef', 'iceberg in the ocean', 'volcanic eruption', 'abstract architectural design', 'abstract watercolor painting', 'retro diner interior', 'vintage biplane in flight', 'stormy seascape', 'snow-capped mountain', 'fields of blooming flowers', 'colorful fireworks display', 'moonlit forest', 'abstract mosaic tile pattern', 'waterfall in a lush forest', 'tropical beach', 'abstract digital art', 'aurora borealis', 'sunset over the ocean', 'futuristic cityscape', 'rustic barn in a field', 'vibrant street art', 'colorful balloon festival', 'rainbow over a waterfall', 'neon city lights', 'abstract geometric patterns', 'desert landscape', 'glacial lake', 'vintage car', 'vintage steam locomotive', 'urban graffiti art', 'old lighthouse on a rocky coast', 'mountain peak covered in snow']
# 100%|██████████| 23/23 [03:31<00:00,  9.20s/it]
# 2025-07-12 19:38:13,444 : Evaluating OOD dataset dtd
# DEBUG:__main__:Evaluating OOD dataset dtd
# 100%|██████████| 23/23 [08:42<00:00, 22.72s/it]
# 2025-07-12 19:47:03,512 : in scores: DescribeResult(nobs=5794, minmax=(np.float32(-0.0039374144), np.float32(-0.0033088753)), mean=np.float32(-0.0036218099), variance=np.float64(7.763440206137011e-09), skewness=np.float64(-0.0349867045879364), kurtosis=np.float32(-0.006973028))
# DEBUG:__main__:in scores: DescribeResult(nobs=5794, minmax=(np.float32(-0.0039374144), np.float32(-0.0033088753)), mean=np.float32(-0.0036218099), variance=np.float64(7.763440206137011e-09), skewness=np.float64(-0.0349867045879364), kurtosis=np.float32(-0.006973028))
# 2025-07-12 19:47:03,517 : out scores: DescribeResult(nobs=5640, minmax=(np.float32(-0.0034998613), np.float32(-0.0029736771)), mean=np.float32(-0.0031871572), variance=np.float64(5.187900463303224e-09), skewness=np.float64(-0.42005494236946106), kurtosis=np.float32(0.078995466))
# DEBUG:__main__:out scores: DescribeResult(nobs=5640, minmax=(np.float32(-0.0034998613), np.float32(-0.0029736771)), mean=np.float32(-0.0031871572), variance=np.float64(5.187900463303224e-09), skewness=np.float64(-0.42005494236946106), kurtosis=np.float32(0.078995466))
# 2025-07-12 19:47:04,109 : 				EOE
# DEBUG:__main__:				EOE
# 2025-07-12 19:47:04,116 :   FPR95 AUROC AUPR
# DEBUG:__main__:  FPR95 AUROC AUPR
# 2025-07-12 19:47:04,123 : & 0.02 & 99.99 & 99.99
# DEBUG:__main__:& 0.02 & 99.99 & 99.99
# 2025-07-12 19:47:04,124 :
#
# Mean Test Results
# DEBUG:__main__:
#
# Mean Test Results
# 2025-07-12 19:47:04,125 : 				EOE
# DEBUG:__main__:				EOE
# 2025-07-12 19:47:04,126 :   FPR95 AUROC AUPR
# DEBUG:__main__:  FPR95 AUROC AUPR
# 2025-07-12 19:47:04,128 : & 0.02 & 99.99 & 99.99
# DEBUG:__main__:& 0.02 & 99.99 & 99.99

# %% [markdown]
# L=100, Beta=0.25

# %%
sys.argv = [
    "eval_ood_detection.py",
    "--name",        "CUB200_TEXTURE_100L_25B_far_evaluation",
    "--in_dataset",  "bird200",
    "--ood_task",    "far",
    "--score",       "EOE",
    "--root_dir",    "datasets",
    "--batch_size",  "256",
    "--gpu",         "0",
    "--L",           "100",
    "--generate_class",
]
main()
# Out:
# /usr/local/lib/python3.11/dist-packages/torch/utils/data/dataloader.py:624: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(
# Original ID Labels: ['Black footed Albatross', 'Laysan Albatross', 'Sooty Albatross', 'Groove billed Ani', 'Crested Auklet', 'Least Auklet', 'Parakeet Auklet', 'Rhinoceros Auklet', 'Brewer Blackbird', 'Red winged Blackbird', 'Rusty Blackbird', 'Yellow headed Blackbird', 'Bobolink', 'Indigo Bunting', 'Lazuli Bunting', 'Painted Bunting', 'Cardinal', 'Spotted Catbird', 'Gray Catbird', 'Yellow breasted Chat', 'Eastern Towhee', 'Chuck will Widow', 'Brandt Cormorant', 'Red faced Cormorant', 'Pelagic Cormorant', 'Bronzed Cowbird', 'Shiny Cowbird', 'Brown Creeper', 'American Crow', 'Fish Crow', 'Black billed Cuckoo', 'Mangrove Cuckoo', 'Yellow billed Cuckoo', 'Gray crowned Rosy Finch', 'Purple Finch', 'Northern Flicker', 'Acadian Flycatcher', 'Great Crested Flycatcher', 'Least Flycatcher', 'Olive sided Flycatcher', 'Scissor tailed Flycatcher', 'Vermilion Flycatcher', 'Yellow bellied Flycatcher', 'Frigatebird', 'Northern Fulmar', 'Gadwall', 'American Goldfinch', 'European Goldfinch', 'Boat tailed Grackle', 'Eared Grebe', 'Horned Grebe', 'Pied billed Grebe', 'Western Grebe', 'Blue Grosbeak', 'Evening Grosbeak', 'Pine Grosbeak', 'Rose breasted Grosbeak', 'Pigeon Guillemot', 'California Gull', 'Glaucous winged Gull', 'Heermann Gull', 'Herring Gull', 'Ivory Gull', 'Ring billed Gull', 'Slaty backed Gull', 'Western Gull', 'Anna Hummingbird', 'Ruby throated Hummingbird', 'Rufous Hummingbird', 'Green Violetear', 'Long tailed Jaeger', 'Pomarine Jaeger', 'Blue Jay', 'Florida Jay', 'Green Jay', 'Dark eyed Junco', 'Tropical Kingbird', 'Gray Kingbird', 'Belted Kingfisher', 'Green Kingfisher', 'Pied Kingfisher', 'Ringed Kingfisher', 'White breasted Kingfisher', 'Red legged Kittiwake', 'Horned Lark', 'Pacific Loon', 'Mallard', 'Western Meadowlark', 'Hooded Merganser', 'Red breasted Merganser', 'Mockingbird', 'Nighthawk', 'Clark Nutcracker', 'White breasted Nuthatch', 'Baltimore Oriole', 'Hooded Oriole', 'Orchard Oriole', 'Scott Oriole', 'Ovenbird', 'Brown Pelican', 'White Pelican', 'Western Wood Pewee', 'Sayornis', 'American Pipit', 'Whip poor Will', 'Horned Puffin', 'Common Raven', 'White necked Raven', 'American Redstart', 'Geococcyx', 'Loggerhead Shrike', 'Great Grey Shrike', 'Baird Sparrow', 'Black throated Sparrow', 'Brewer Sparrow', 'Chipping Sparrow', 'Clay colored Sparrow', 'House Sparrow', 'Field Sparrow', 'Fox Sparrow', 'Grasshopper Sparrow', 'Harris Sparrow', 'Henslow Sparrow', 'Le Conte Sparrow', 'Lincoln Sparrow', 'Nelson Sharp tailed Sparrow', 'Savannah Sparrow', 'Seaside Sparrow', 'Song Sparrow', 'Tree Sparrow', 'Vesper Sparrow', 'White crowned Sparrow', 'White throated Sparrow', 'Cape Glossy Starling', 'Bank Swallow', 'Barn Swallow', 'Cliff Swallow', 'Tree Swallow', 'Scarlet Tanager', 'Summer Tanager', 'Artic Tern', 'Black Tern', 'Caspian Tern', 'Common Tern', 'Elegant Tern', 'Forsters Tern', 'Least Tern', 'Green tailed Towhee', 'Brown Thrasher', 'Sage Thrasher', 'Black capped Vireo', 'Blue headed Vireo', 'Philadelphia Vireo', 'Red eyed Vireo', 'Warbling Vireo', 'White eyed Vireo', 'Yellow throated Vireo', 'Bay breasted Warbler', 'Black and white Warbler', 'Black throated Blue Warbler', 'Blue winged Warbler', 'Canada Warbler', 'Cape May Warbler', 'Cerulean Warbler', 'Chestnut sided Warbler', 'Golden winged Warbler', 'Hooded Warbler', 'Kentucky Warbler', 'Magnolia Warbler', 'Mourning Warbler', 'Myrtle Warbler', 'Nashville Warbler', 'Orange crowned Warbler', 'Palm Warbler', 'Pine Warbler', 'Prairie Warbler', 'Prothonotary Warbler', 'Swainson Warbler', 'Tennessee Warbler', 'Wilson Warbler', 'Worm eating Warbler', 'Yellow Warbler', 'Northern Waterthrush', 'Louisiana Waterthrush', 'Bohemian Waxwing', 'Cedar Waxwing', 'American Three toed Woodpecker', 'Pileated Woodpecker', 'Red bellied Woodpecker', 'Red cockaded Woodpecker', 'Red headed Woodpecker', 'Downy Woodpecker', 'Bewick Wren', 'Cactus Wren', 'Carolina Wren', 'House Wren', 'Marsh Wren', 'Rock Wren', 'Winter Wren', 'Common Yellowthroat']
# Using original ID labels (no synonyms).
# Envisioning Outlier Exposure...
# 🔵 Generating via OpenAI GPT...
# Continuing vision 1/1
# 🔍 Raw GPT output:
#  - Sunset over the ocean
#         - Desert landscape
#         - Snow-capped mountains
#         - Tropical beach
#         - City skyline
#         - Aurora borealis
#         - Waterfall
#         - Fields of flowers
#         - Starry night sky
#         - Urban street art
#         - Ancient ruins
#         - Volcanic landscape
#         - Iceberg
#         - Coral reef
#         - Sand dunes
#         - Rainforest canopy
#         - Glacier
#         - Countryside farm
#         - Urban graffiti
#         - Moonlit forest
#         - Mountain range
#         - Underwater cave
#         - Lush jungle
#         - Urban alleyway
#         - Abandoned factory
#         - Suburban neighborhood
#         - Rustic barn
#         - Industrial warehouse
#         - Coastal cliffs
#         - Urban park
#         - Countryside vineyard
#         - Suburban shopping mall
#         - Rural windmill
#         - Urban rooftop garden
#         - Desert oasis
#         - Mountain pass
#         - Tropical island
#         - City subway station
#         - Ancient temple ruins
#         - Urban skate park
#         - Countryside wind farm
#         - Suburban golf course
#         - Rural farmland
#         - Urban construction site
#         - Coastal boardwalk
#         - Mountain hiking trail
#         - Tropical rainstorm
#         - City traffic intersection- Desert canyon
# - Urban graffiti alley
# - Mountain lake
# - Coastal lighthouse
# - Rural farmhouse
# - Tropical waterfall
# - City skyscraper view
# - Snowy forest
# - Countryside barnyard
# - Industrial factory exterior
# - Urban street market
# - Ancient castle ruins
# - Suburban playground
# - Rustic cabin
# - Coastal marina
# - Mountain peak
# - Urban subway tunnel
# - Tropical palm trees
# - City skyline reflection
# - Abandoned warehouse district
# - Suburban backyard garden
# - Rural country road
# - Urban rooftop bar
# - Desert rock formations
# - Mountain valley
# - Coastal fishing village
# - Tropical beach resort
# - City street art
# - Ancient pyramid ruins
# - Suburban community center
# - Rustic windmill
# - Industrial smokestacks
# - Urban skateboarding park
# - Countryside horse farm
# - Suburban swimming pool
# - Rural wheat field
# - Urban construction crane
# - Coastal pier
# - Mountain ski slope
# - Tropical jungle waterfall
# - City traffic lights
# - Ancient stone temple
# - Suburban street festival
# - Rustic covered bridge
# - Industrial power plant
# - Urban rooftop garden
# - Countryside pumpkin patch
# - Suburban backyard barbecue
# - Rural cattle ranch
#
# 💾 Saving hallucinated class descriptors to: envisioned_classes/far_100/bird200_gpt-3.5-turbo_0.json
# === load json:  envisioned_classes/far_100/bird200_gpt-3.5-turbo_0.json
# Get Envisioned Candidate Class Names.
# After set: 95
# After removing ID class overlaps: 95
# Final ID Labels passed to CLIP: ['Black footed Albatross', 'Laysan Albatross', 'Sooty Albatross', 'Groove billed Ani', 'Crested Auklet', 'Least Auklet', 'Parakeet Auklet', 'Rhinoceros Auklet', 'Brewer Blackbird', 'Red winged Blackbird', 'Rusty Blackbird', 'Yellow headed Blackbird', 'Bobolink', 'Indigo Bunting', 'Lazuli Bunting', 'Painted Bunting', 'Cardinal', 'Spotted Catbird', 'Gray Catbird', 'Yellow breasted Chat', 'Eastern Towhee', 'Chuck will Widow', 'Brandt Cormorant', 'Red faced Cormorant', 'Pelagic Cormorant', 'Bronzed Cowbird', 'Shiny Cowbird', 'Brown Creeper', 'American Crow', 'Fish Crow', 'Black billed Cuckoo', 'Mangrove Cuckoo', 'Yellow billed Cuckoo', 'Gray crowned Rosy Finch', 'Purple Finch', 'Northern Flicker', 'Acadian Flycatcher', 'Great Crested Flycatcher', 'Least Flycatcher', 'Olive sided Flycatcher', 'Scissor tailed Flycatcher', 'Vermilion Flycatcher', 'Yellow bellied Flycatcher', 'Frigatebird', 'Northern Fulmar', 'Gadwall', 'American Goldfinch', 'European Goldfinch', 'Boat tailed Grackle', 'Eared Grebe', 'Horned Grebe', 'Pied billed Grebe', 'Western Grebe', 'Blue Grosbeak', 'Evening Grosbeak', 'Pine Grosbeak', 'Rose breasted Grosbeak', 'Pigeon Guillemot', 'California Gull', 'Glaucous winged Gull', 'Heermann Gull', 'Herring Gull', 'Ivory Gull', 'Ring billed Gull', 'Slaty backed Gull', 'Western Gull', 'Anna Hummingbird', 'Ruby throated Hummingbird', 'Rufous Hummingbird', 'Green Violetear', 'Long tailed Jaeger', 'Pomarine Jaeger', 'Blue Jay', 'Florida Jay', 'Green Jay', 'Dark eyed Junco', 'Tropical Kingbird', 'Gray Kingbird', 'Belted Kingfisher', 'Green Kingfisher', 'Pied Kingfisher', 'Ringed Kingfisher', 'White breasted Kingfisher', 'Red legged Kittiwake', 'Horned Lark', 'Pacific Loon', 'Mallard', 'Western Meadowlark', 'Hooded Merganser', 'Red breasted Merganser', 'Mockingbird', 'Nighthawk', 'Clark Nutcracker', 'White breasted Nuthatch', 'Baltimore Oriole', 'Hooded Oriole', 'Orchard Oriole', 'Scott Oriole', 'Ovenbird', 'Brown Pelican', 'White Pelican', 'Western Wood Pewee', 'Sayornis', 'American Pipit', 'Whip poor Will', 'Horned Puffin', 'Common Raven', 'White necked Raven', 'American Redstart', 'Geococcyx', 'Loggerhead Shrike', 'Great Grey Shrike', 'Baird Sparrow', 'Black throated Sparrow', 'Brewer Sparrow', 'Chipping Sparrow', 'Clay colored Sparrow', 'House Sparrow', 'Field Sparrow', 'Fox Sparrow', 'Grasshopper Sparrow', 'Harris Sparrow', 'Henslow Sparrow', 'Le Conte Sparrow', 'Lincoln Sparrow', 'Nelson Sharp tailed Sparrow', 'Savannah Sparrow', 'Seaside Sparrow', 'Song Sparrow', 'Tree Sparrow', 'Vesper Sparrow', 'White crowned Sparrow', 'White throated Sparrow', 'Cape Glossy Starling', 'Bank Swallow', 'Barn Swallow', 'Cliff Swallow', 'Tree Swallow', 'Scarlet Tanager', 'Summer Tanager', 'Artic Tern', 'Black Tern', 'Caspian Tern', 'Common Tern', 'Elegant Tern', 'Forsters Tern', 'Least Tern', 'Green tailed Towhee', 'Brown Thrasher', 'Sage Thrasher', 'Black capped Vireo', 'Blue headed Vireo', 'Philadelphia Vireo', 'Red eyed Vireo', 'Warbling Vireo', 'White eyed Vireo', 'Yellow throated Vireo', 'Bay breasted Warbler', 'Black and white Warbler', 'Black throated Blue Warbler', 'Blue winged Warbler', 'Canada Warbler', 'Cape May Warbler', 'Cerulean Warbler', 'Chestnut sided Warbler', 'Golden winged Warbler', 'Hooded Warbler', 'Kentucky Warbler', 'Magnolia Warbler', 'Mourning Warbler', 'Myrtle Warbler', 'Nashville Warbler', 'Orange crowned Warbler', 'Palm Warbler', 'Pine Warbler', 'Prairie Warbler', 'Prothonotary Warbler', 'Swainson Warbler', 'Tennessee Warbler', 'Wilson Warbler', 'Worm eating Warbler', 'Yellow Warbler', 'Northern Waterthrush', 'Louisiana Waterthrush', 'Bohemian Waxwing', 'Cedar Waxwing', 'American Three toed Woodpecker', 'Pileated Woodpecker', 'Red bellied Woodpecker', 'Red cockaded Woodpecker', 'Red headed Woodpecker', 'Downy Woodpecker', 'Bewick Wren', 'Cactus Wren', 'Carolina Wren', 'House Wren', 'Marsh Wren', 'Rock Wren', 'Winter Wren', 'Common Yellowthroat']
# Envisioned OOD labels (LLM): ['lush jungle', 'industrial factory exterior', 'ancient ruins', 'rainforest canopy', 'desert oasis', 'city traffic intersection- desert canyon', 'urban construction site', 'coastal fishing village', 'mountain ski slope', 'city skyline reflection', 'ancient pyramid ruins', 'city subway station', 'tropical beach', 'rural cattle ranch', 'countryside farm', 'aurora borealis', 'coastal pier', 'mountain hiking trail', 'desert rock formations', 'urban park', 'urban graffiti alley', 'coral reef', 'urban rooftop garden', 'industrial smokestacks', 'suburban backyard barbecue', 'rural wheat field', 'rustic windmill', 'urban rooftop bar', 'city traffic lights', 'urban subway tunnel', 'ancient castle ruins', 'abandoned factory', 'rural farmland', 'city skyline', 'tropical waterfall', 'rustic barn', 'mountain lake', 'countryside wind farm', 'suburban street festival', 'underwater cave', 'glacier', 'sunset over the ocean', 'mountain range', 'mountain valley', 'mountain peak', 'urban street market', 'city street art', 'industrial warehouse', 'suburban golf course', 'rural country road', 'ancient stone temple', 'volcanic landscape', 'starry night sky', 'fields of flowers', 'countryside pumpkin patch', 'city skyscraper view', 'tropical rainstorm', 'waterfall', 'countryside horse farm', 'rural farmhouse', 'tropical palm trees', 'coastal boardwalk', 'coastal lighthouse', 'suburban community center', 'moonlit forest', 'urban alleyway', 'suburban neighborhood', 'mountain pass', 'urban skateboarding park', 'suburban swimming pool', 'rustic covered bridge', 'industrial power plant', 'urban skate park', 'countryside barnyard', 'abandoned warehouse district', 'sand dunes', 'urban graffiti', 'urban street art', 'ancient temple ruins', 'suburban backyard garden', 'suburban shopping mall', 'suburban playground', 'rustic cabin', 'tropical beach resort', 'snowy forest', 'tropical island', 'coastal marina', 'countryside vineyard', 'desert landscape', 'iceberg', 'coastal cliffs', 'snow-capped mountains', 'tropical jungle waterfall', 'rural windmill', 'urban construction crane']
# 100%|██████████| 23/23 [01:19<00:00,  3.46s/it]
# 2025-07-12 19:48:42,594 : Evaluating OOD dataset dtd
# DEBUG:__main__:Evaluating OOD dataset dtd
# 100%|██████████| 23/23 [01:18<00:00,  3.41s/it]
# 2025-07-12 19:50:01,399 : in scores: DescribeResult(nobs=5794, minmax=(np.float32(-0.0033084142), np.float32(-0.0028245223)), mean=np.float32(-0.0030520936), variance=np.float64(5.168423766186058e-09), skewness=np.float64(-0.046687547117471695), kurtosis=np.float32(0.06527591))
# DEBUG:__main__:in scores: DescribeResult(nobs=5794, minmax=(np.float32(-0.0033084142), np.float32(-0.0028245223)), mean=np.float32(-0.0030520936), variance=np.float64(5.168423766186058e-09), skewness=np.float64(-0.046687547117471695), kurtosis=np.float32(0.06527591))
# 2025-07-12 19:50:01,414 : out scores: DescribeResult(nobs=5640, minmax=(np.float32(-0.0029252472), np.float32(-0.0025466215)), mean=np.float32(-0.0026975705), variance=np.float64(2.878068265474449e-09), skewness=np.float64(-0.45720791816711426), kurtosis=np.float32(0.26179647))
# DEBUG:__main__:out scores: DescribeResult(nobs=5640, minmax=(np.float32(-0.0029252472), np.float32(-0.0025466215)), mean=np.float32(-0.0026975705), variance=np.float64(2.878068265474449e-09), skewness=np.float64(-0.45720791816711426), kurtosis=np.float32(0.26179647))
# 2025-07-12 19:50:02,720 : 				EOE
# DEBUG:__main__:				EOE
# 2025-07-12 19:50:02,731 :   FPR95 AUROC AUPR
# DEBUG:__main__:  FPR95 AUROC AUPR
# 2025-07-12 19:50:02,737 : & 0.00 & 99.99 & 99.99
# DEBUG:__main__:& 0.00 & 99.99 & 99.99
# 2025-07-12 19:50:02,743 :
#
# Mean Test Results
# DEBUG:__main__:
#
# Mean Test Results
# 2025-07-12 19:50:02,748 : 				EOE
# DEBUG:__main__:				EOE
# 2025-07-12 19:50:02,754 :   FPR95 AUROC AUPR
# DEBUG:__main__:  FPR95 AUROC AUPR
# 2025-07-12 19:50:02,759 : & 0.00 & 99.99 & 99.99
# DEBUG:__main__:& 0.00 & 99.99 & 99.99

# %% [markdown]
# L=300, Beta=0.25

# %%
sys.argv = [
    "eval_ood_detection.py",
    "--name",        "CUB200_TEXTURE_300L_25B_far_evaluation",
    "--in_dataset",  "bird200",
    "--ood_task",    "far",
    "--score",       "EOE",
    "--root_dir",    "datasets",
    "--batch_size",  "256",
    "--gpu",         "0",
    "--L",           "300",
    "--generate_class",
]
main()
# Out:
# /usr/local/lib/python3.11/dist-packages/torch/utils/data/dataloader.py:624: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(
# Original ID Labels: ['Black footed Albatross', 'Laysan Albatross', 'Sooty Albatross', 'Groove billed Ani', 'Crested Auklet', 'Least Auklet', 'Parakeet Auklet', 'Rhinoceros Auklet', 'Brewer Blackbird', 'Red winged Blackbird', 'Rusty Blackbird', 'Yellow headed Blackbird', 'Bobolink', 'Indigo Bunting', 'Lazuli Bunting', 'Painted Bunting', 'Cardinal', 'Spotted Catbird', 'Gray Catbird', 'Yellow breasted Chat', 'Eastern Towhee', 'Chuck will Widow', 'Brandt Cormorant', 'Red faced Cormorant', 'Pelagic Cormorant', 'Bronzed Cowbird', 'Shiny Cowbird', 'Brown Creeper', 'American Crow', 'Fish Crow', 'Black billed Cuckoo', 'Mangrove Cuckoo', 'Yellow billed Cuckoo', 'Gray crowned Rosy Finch', 'Purple Finch', 'Northern Flicker', 'Acadian Flycatcher', 'Great Crested Flycatcher', 'Least Flycatcher', 'Olive sided Flycatcher', 'Scissor tailed Flycatcher', 'Vermilion Flycatcher', 'Yellow bellied Flycatcher', 'Frigatebird', 'Northern Fulmar', 'Gadwall', 'American Goldfinch', 'European Goldfinch', 'Boat tailed Grackle', 'Eared Grebe', 'Horned Grebe', 'Pied billed Grebe', 'Western Grebe', 'Blue Grosbeak', 'Evening Grosbeak', 'Pine Grosbeak', 'Rose breasted Grosbeak', 'Pigeon Guillemot', 'California Gull', 'Glaucous winged Gull', 'Heermann Gull', 'Herring Gull', 'Ivory Gull', 'Ring billed Gull', 'Slaty backed Gull', 'Western Gull', 'Anna Hummingbird', 'Ruby throated Hummingbird', 'Rufous Hummingbird', 'Green Violetear', 'Long tailed Jaeger', 'Pomarine Jaeger', 'Blue Jay', 'Florida Jay', 'Green Jay', 'Dark eyed Junco', 'Tropical Kingbird', 'Gray Kingbird', 'Belted Kingfisher', 'Green Kingfisher', 'Pied Kingfisher', 'Ringed Kingfisher', 'White breasted Kingfisher', 'Red legged Kittiwake', 'Horned Lark', 'Pacific Loon', 'Mallard', 'Western Meadowlark', 'Hooded Merganser', 'Red breasted Merganser', 'Mockingbird', 'Nighthawk', 'Clark Nutcracker', 'White breasted Nuthatch', 'Baltimore Oriole', 'Hooded Oriole', 'Orchard Oriole', 'Scott Oriole', 'Ovenbird', 'Brown Pelican', 'White Pelican', 'Western Wood Pewee', 'Sayornis', 'American Pipit', 'Whip poor Will', 'Horned Puffin', 'Common Raven', 'White necked Raven', 'American Redstart', 'Geococcyx', 'Loggerhead Shrike', 'Great Grey Shrike', 'Baird Sparrow', 'Black throated Sparrow', 'Brewer Sparrow', 'Chipping Sparrow', 'Clay colored Sparrow', 'House Sparrow', 'Field Sparrow', 'Fox Sparrow', 'Grasshopper Sparrow', 'Harris Sparrow', 'Henslow Sparrow', 'Le Conte Sparrow', 'Lincoln Sparrow', 'Nelson Sharp tailed Sparrow', 'Savannah Sparrow', 'Seaside Sparrow', 'Song Sparrow', 'Tree Sparrow', 'Vesper Sparrow', 'White crowned Sparrow', 'White throated Sparrow', 'Cape Glossy Starling', 'Bank Swallow', 'Barn Swallow', 'Cliff Swallow', 'Tree Swallow', 'Scarlet Tanager', 'Summer Tanager', 'Artic Tern', 'Black Tern', 'Caspian Tern', 'Common Tern', 'Elegant Tern', 'Forsters Tern', 'Least Tern', 'Green tailed Towhee', 'Brown Thrasher', 'Sage Thrasher', 'Black capped Vireo', 'Blue headed Vireo', 'Philadelphia Vireo', 'Red eyed Vireo', 'Warbling Vireo', 'White eyed Vireo', 'Yellow throated Vireo', 'Bay breasted Warbler', 'Black and white Warbler', 'Black throated Blue Warbler', 'Blue winged Warbler', 'Canada Warbler', 'Cape May Warbler', 'Cerulean Warbler', 'Chestnut sided Warbler', 'Golden winged Warbler', 'Hooded Warbler', 'Kentucky Warbler', 'Magnolia Warbler', 'Mourning Warbler', 'Myrtle Warbler', 'Nashville Warbler', 'Orange crowned Warbler', 'Palm Warbler', 'Pine Warbler', 'Prairie Warbler', 'Prothonotary Warbler', 'Swainson Warbler', 'Tennessee Warbler', 'Wilson Warbler', 'Worm eating Warbler', 'Yellow Warbler', 'Northern Waterthrush', 'Louisiana Waterthrush', 'Bohemian Waxwing', 'Cedar Waxwing', 'American Three toed Woodpecker', 'Pileated Woodpecker', 'Red bellied Woodpecker', 'Red cockaded Woodpecker', 'Red headed Woodpecker', 'Downy Woodpecker', 'Bewick Wren', 'Cactus Wren', 'Carolina Wren', 'House Wren', 'Marsh Wren', 'Rock Wren', 'Winter Wren', 'Common Yellowthroat']
# Using original ID labels (no synonyms).
# Envisioning Outlier Exposure...
# 🔵 Generating via OpenAI GPT...
# Continuing vision 1/5
# Continuing vision 2/5
# Continuing vision 3/5
# Continuing vision 4/5
# Continuing vision 5/5
# 🔍 Raw GPT output:
#  - Sunset
# - Waterfall
# - Desert landscape
# - Aurora borealis
# - Snow-capped mountain
# - Tropical beach
# - City skyline
# - Starry night sky
# - Autumn foliage
# - Volcano eruption
# - Glacier
# - Coral reef
# - Sand dunes
# - Iceberg
# - Rainbow
# - Lightning storm
# - Tornado
# - Lunar eclipse
# - Solar eclipse
# - Meteor shower
# - Milky Way galaxy
# - Bioluminescent plankton
# - Hot air balloon festival
# - Cherry blossom trees
# - Lavender fields
# - Sunflower fields
# - Tulip fields
# - Bamboo forest
# - Redwood forest
# - Moss-covered forest
# - Cactus garden
# - Sunflower garden
# - Zen garden
# - Botanical garden
# - Koi pond
# - Water lilies
# - Lotus flowers
# - Orchid garden
# - Bonsai trees
# - Succulent garden
# - Carnivorous plant garden
# - Tropical rainforest
# - Mangrove forest
# - Alpine meadow
# - Wildflower meadow
# - Vineyard
# - Olive grove
# - Tea plantation
# - Rice terraces- Sandstone formations
# - Lighthouse at sunset
# - Mossy waterfall
# - Desert oasis
# - Northern lights
# - Snowy pine forest
# - Tropical island paradise
# - Urban cityscape at night
# - Fall harvest festival
# - Active volcano crater
# - Glacial lake view
# - Colorful coral reef
# - Sandstone arches
# - Iceberg floating
# - Double rainbow
# - Thunderstorm clouds
# - Twisting tornado funnel
# - Lunar eclipse shadow
# - Solar eclipse totality
# - Shooting star streak
# - Spiral galaxy view
# - Bioluminescent jellyfish
# - Hot air balloon ride
# - Cherry blossom festival
# - Lavender scented fields
# - Sunflower maze
# - Tulip garden display
# - Bamboo grove walk
# - Redwood tree canopy
# - Moss-covered ruins
# - Cactus flower bloom
# - Sunflower field maze
# - Zen rock garden
# - Botanical greenhouse tour
# - Koi fish pond
# - Water lily pond
# - Lotus pond view
# - Orchid greenhouse exhibit
# - Bonsai tree display
# - Succulent plant collection
# - Carnivorous plant exhibit
# - Tropical jungle trek
# - Mangrove swamp tour
# - Alpine wildflowers hike
# - Wildflower meadow walk
# - Vineyard wine tasting
# - Olive tree grove
# - Tea plantation tour
# - Rice terrace view- Sand dune sunset
# - Cliffside lighthouse
# - Moss-covered waterfall
# - Oasis in desert
# - Aurora borealis display
# - Snow-covered forest
# - Tropical beach paradise
# - City skyline lights
# - Fall foliage colors
# - Active volcano eruption
# - Glacial ice cave
# - Colorful coral reef
# - Iceberg calving
# - Double rainbow sky
# - Thunderstorm lightning
# - Tornado touchdown
# - Lunar eclipse phase
# - Solar eclipse corona
# - Shooting star night
# - Spiral galaxy cluster
# - Bioluminescent sea creatures
# - Hot air balloon race
# - Cherry blossom trees
# - Lavender field rows
# - Sunflower field maze
# - Bamboo forest walk
# - Redwood tree grove
# - Moss-covered rocks
# - Cactus garden blooms
# - Sunflower field rows
# - Zen garden tranquility
# - Botanical garden tour
# - Koi pond serenity
# - Water lily pond
# - Lotus flower bloom
# - Orchid garden display
# - Bonsai tree art
# - Succulent garden variety
# - Carnivorous plant collection
# - Tropical rainforest canopy
# - Mangrove swamp ecosystem
# - Alpine meadow flowers
# - Wildflower meadow bloom
# - Vineyard grapevines
# - Olive tree orchard
# - Tea plantation fields
# - Rice terrace landscape- Sandstone canyon view
# - Coastal lighthouse beacon
# - Mossy forest stream
# - Desert palm oasis
# - Northern lights dance
# - Snowy mountain peak
# - Tropical island getaway
# - Urban skyline panorama
# - Fall harvest bounty
# - Volcano lava flow
# - Glacial ice tunnel
# - Coral reef ecosystem
# - Iceberg melting
# - Rainbow after rain
# - Lightning storm strike
# - Tornado swirling clouds
# - Lunar eclipse shadow
# - Solar eclipse ring
# - Shooting star wish
# - Spiral galaxy spiral
# - Bioluminescent ocean glow
# - Hot air balloon ride
# - Cherry blossom petals
# - Lavender field fragrance
# - Sunflower field bloom
# - Bamboo forest grove
# - Redwood tree bark
# - Moss-covered stones
# - Cactus garden oasis
# - Sunflower field sunset
# - Zen garden meditation
# - Botanical garden beauty
# - Koi pond tranquility
# - Water lily bloom
# - Lotus flower pond
# - Orchid garden exhibit
# - Bonsai tree garden
# - Succulent garden display
# - Carnivorous plant showcase
# - Tropical rainforest canopy
# - Mangrove swamp wildlife
# - Alpine meadow hike
# - Wildflower meadow field
# - Vineyard grape harvest
# - Olive tree grove
# - Tea plantation rows
# - Rice terrace farming- Sandstone rock formations
# - Coastal lighthouse view
# - Moss-covered forest floor
# - Desert oasis palm
# - Northern lights display
# - Snowy winter landscape
# - Tropical island vacation
# - Urban cityscape lights
# - Fall foliage scenery
# - Volcano eruption smoke
# - Glacial ice formation
# - Coral reef underwater
# - Iceberg drifting sea
# - Rainbow colors sky
# - Lightning storm clouds
# - Tornado swirling winds
# - Lunar eclipse moon
# - Solar eclipse sun
# - Shooting star meteor
# - Spiral galaxy stars
# - Bioluminescent sea life
# - Hot air balloon festival
# - Cherry blossom season
# - Lavender field view
# - Sunflower field landscape
# - Bamboo forest canopy
# - Redwood tree trunk
# - Moss-covered pathway
# - Cactus garden desert
# - Sunflower field sunrise
# - Zen garden rocks
# - Botanical garden plants
# - Koi pond fish
# - Water lily pond
# - Lotus flower garden
# - Orchid garden flowers
# - Bonsai tree display
# - Succulent garden arrangement
# - Carnivorous plant garden
# - Tropical rainforest trees
# - Mangrove swamp habitat
# - Alpine meadow flowers
# - Wildflower meadow scene
# - Vineyard grape vines
# - Olive tree plantation
# - Tea plantation fields
# - Rice terrace view- Sandstone cliff formation
# - Coastal lighthouse scene
# - Moss-covered creek
# - Desert oasis view
# - Northern lights spectacle
# - Snowy mountain range
# - Tropical island paradise
# - Urban cityscape view
# - Fall foliage display
# - Volcano eruption plume
# - Glacial ice cave
# - Coral reef marine
# - Iceberg floating ocean
# - Rainbow arcing sky
# - Lightning storm sky
# - Tornado swirling sky
# - Lunar eclipse lunar
# - Solar eclipse solar
# - Shooting star night
# - Spiral galaxy universe
# - Bioluminescent sea creatures
# - Hot air balloon flight
# - Cherry blossom bloom
# - Lavender field vista
# - Sunflower field vista
# - Bamboo forest canopy
# - Redwood tree forest
# - Moss-covered trail
# - Cactus garden display
# - Sunflower field sunrise
# - Zen garden meditation
# - Botanical garden exhibit
# - Koi pond fish
# - Water lily pond view
# - Lotus flower pond
# - Orchid garden display
# - Bonsai tree collection
# - Succulent garden arrangement
# - Carnivorous plant collection
# - Tropical rainforest canopy
# - Mangrove swamp ecosystem
# - Alpine meadow view
# - Wildflower meadow view
# - Vineyard grape vines
# - Olive tree grove
# - Tea plantation fields
# - Rice terrace landscape
#
# 💾 Saving hallucinated class descriptors to: envisioned_classes/far_300/bird200_gpt-3.5-turbo_0.json
# === load json:  envisioned_classes/far_300/bird200_gpt-3.5-turbo_0.json
# Get Envisioned Candidate Class Names.
# After set: 250
# After removing ID class overlaps: 250
# Final ID Labels passed to CLIP: ['Black footed Albatross', 'Laysan Albatross', 'Sooty Albatross', 'Groove billed Ani', 'Crested Auklet', 'Least Auklet', 'Parakeet Auklet', 'Rhinoceros Auklet', 'Brewer Blackbird', 'Red winged Blackbird', 'Rusty Blackbird', 'Yellow headed Blackbird', 'Bobolink', 'Indigo Bunting', 'Lazuli Bunting', 'Painted Bunting', 'Cardinal', 'Spotted Catbird', 'Gray Catbird', 'Yellow breasted Chat', 'Eastern Towhee', 'Chuck will Widow', 'Brandt Cormorant', 'Red faced Cormorant', 'Pelagic Cormorant', 'Bronzed Cowbird', 'Shiny Cowbird', 'Brown Creeper', 'American Crow', 'Fish Crow', 'Black billed Cuckoo', 'Mangrove Cuckoo', 'Yellow billed Cuckoo', 'Gray crowned Rosy Finch', 'Purple Finch', 'Northern Flicker', 'Acadian Flycatcher', 'Great Crested Flycatcher', 'Least Flycatcher', 'Olive sided Flycatcher', 'Scissor tailed Flycatcher', 'Vermilion Flycatcher', 'Yellow bellied Flycatcher', 'Frigatebird', 'Northern Fulmar', 'Gadwall', 'American Goldfinch', 'European Goldfinch', 'Boat tailed Grackle', 'Eared Grebe', 'Horned Grebe', 'Pied billed Grebe', 'Western Grebe', 'Blue Grosbeak', 'Evening Grosbeak', 'Pine Grosbeak', 'Rose breasted Grosbeak', 'Pigeon Guillemot', 'California Gull', 'Glaucous winged Gull', 'Heermann Gull', 'Herring Gull', 'Ivory Gull', 'Ring billed Gull', 'Slaty backed Gull', 'Western Gull', 'Anna Hummingbird', 'Ruby throated Hummingbird', 'Rufous Hummingbird', 'Green Violetear', 'Long tailed Jaeger', 'Pomarine Jaeger', 'Blue Jay', 'Florida Jay', 'Green Jay', 'Dark eyed Junco', 'Tropical Kingbird', 'Gray Kingbird', 'Belted Kingfisher', 'Green Kingfisher', 'Pied Kingfisher', 'Ringed Kingfisher', 'White breasted Kingfisher', 'Red legged Kittiwake', 'Horned Lark', 'Pacific Loon', 'Mallard', 'Western Meadowlark', 'Hooded Merganser', 'Red breasted Merganser', 'Mockingbird', 'Nighthawk', 'Clark Nutcracker', 'White breasted Nuthatch', 'Baltimore Oriole', 'Hooded Oriole', 'Orchard Oriole', 'Scott Oriole', 'Ovenbird', 'Brown Pelican', 'White Pelican', 'Western Wood Pewee', 'Sayornis', 'American Pipit', 'Whip poor Will', 'Horned Puffin', 'Common Raven', 'White necked Raven', 'American Redstart', 'Geococcyx', 'Loggerhead Shrike', 'Great Grey Shrike', 'Baird Sparrow', 'Black throated Sparrow', 'Brewer Sparrow', 'Chipping Sparrow', 'Clay colored Sparrow', 'House Sparrow', 'Field Sparrow', 'Fox Sparrow', 'Grasshopper Sparrow', 'Harris Sparrow', 'Henslow Sparrow', 'Le Conte Sparrow', 'Lincoln Sparrow', 'Nelson Sharp tailed Sparrow', 'Savannah Sparrow', 'Seaside Sparrow', 'Song Sparrow', 'Tree Sparrow', 'Vesper Sparrow', 'White crowned Sparrow', 'White throated Sparrow', 'Cape Glossy Starling', 'Bank Swallow', 'Barn Swallow', 'Cliff Swallow', 'Tree Swallow', 'Scarlet Tanager', 'Summer Tanager', 'Artic Tern', 'Black Tern', 'Caspian Tern', 'Common Tern', 'Elegant Tern', 'Forsters Tern', 'Least Tern', 'Green tailed Towhee', 'Brown Thrasher', 'Sage Thrasher', 'Black capped Vireo', 'Blue headed Vireo', 'Philadelphia Vireo', 'Red eyed Vireo', 'Warbling Vireo', 'White eyed Vireo', 'Yellow throated Vireo', 'Bay breasted Warbler', 'Black and white Warbler', 'Black throated Blue Warbler', 'Blue winged Warbler', 'Canada Warbler', 'Cape May Warbler', 'Cerulean Warbler', 'Chestnut sided Warbler', 'Golden winged Warbler', 'Hooded Warbler', 'Kentucky Warbler', 'Magnolia Warbler', 'Mourning Warbler', 'Myrtle Warbler', 'Nashville Warbler', 'Orange crowned Warbler', 'Palm Warbler', 'Pine Warbler', 'Prairie Warbler', 'Prothonotary Warbler', 'Swainson Warbler', 'Tennessee Warbler', 'Wilson Warbler', 'Worm eating Warbler', 'Yellow Warbler', 'Northern Waterthrush', 'Louisiana Waterthrush', 'Bohemian Waxwing', 'Cedar Waxwing', 'American Three toed Woodpecker', 'Pileated Woodpecker', 'Red bellied Woodpecker', 'Red cockaded Woodpecker', 'Red headed Woodpecker', 'Downy Woodpecker', 'Bewick Wren', 'Cactus Wren', 'Carolina Wren', 'House Wren', 'Marsh Wren', 'Rock Wren', 'Winter Wren', 'Common Yellowthroat']
# Envisioned OOD labels (LLM): ['rice terrace view- sandstone cliff formation', 'bonsai tree collection', 'desert palm oasis', 'tropical island paradise', 'iceberg calving', 'sunflower fields', 'carnivorous plant exhibit', 'urban cityscape lights', 'lavender field vista', 'koi pond serenity', 'fall foliage display', 'bioluminescent ocean glow', 'succulent garden display', 'tea plantation', 'orchid garden exhibit', 'water lily pond', 'lavender fields', 'glacial lake view', 'redwood tree bark', 'botanical garden beauty', 'bamboo forest', 'desert oasis', 'thunderstorm lightning', 'orchid greenhouse exhibit', 'coastal lighthouse scene', 'koi fish pond', 'spiral galaxy cluster', 'volcano eruption', 'alpine meadow flowers', 'urban cityscape view', 'snowy mountain range', 'spiral galaxy spiral', 'bamboo forest canopy', 'sunflower garden', 'iceberg drifting sea', 'tornado touchdown', 'mangrove forest', 'redwood tree grove', 'vineyard grape vines', 'tropical beach', 'rainbow arcing sky', 'sunflower field sunset', 'koi pond tranquility', 'aurora borealis', 'moss-covered rocks', 'tropical island getaway', 'mangrove swamp tour', 'water lilies', 'iceberg floating', 'shooting star streak', 'moss-covered ruins', 'succulent garden arrangement', 'lavender field view', 'botanical garden exhibit', 'alpine meadow view', 'olive tree plantation', 'bioluminescent plankton', 'bamboo grove walk', 'cherry blossom trees', 'alpine meadow hike', 'sunflower field vista', 'coral reef', 'cactus garden blooms', 'aurora borealis display', 'rice terraces- sandstone formations', 'tulip fields', 'lunar eclipse moon', 'lotus flower garden', 'glacial ice tunnel', 'alpine wildflowers hike', 'meteor shower', 'city skyline lights', 'botanical garden tour', 'tea plantation rows', 'cactus garden desert', 'carnivorous plant collection', 'hot air balloon race', 'bioluminescent jellyfish', 'rice terrace farming- sandstone rock formations', 'moss-covered waterfall', 'tea plantation fields', 'hot air balloon ride', 'vineyard grape harvest', 'volcano lava flow', 'fall harvest bounty', 'zen garden', 'lotus flowers', 'tornado', 'twisting tornado funnel', 'bonsai trees', 'olive grove', 'tropical rainforest canopy', 'hot air balloon festival', 'carnivorous plant garden', 'lavender field rows', 'wildflower meadow walk', 'rainbow colors sky', 'rice terrace view- sand dune sunset', 'orchid garden flowers', 'solar eclipse', 'city skyline', 'water lily pond view', 'tornado swirling clouds', 'coastal lighthouse view', 'zen garden rocks', 'succulent garden', 'northern lights display', 'double rainbow', 'northern lights spectacle', 'bioluminescent sea life', 'snowy pine forest', 'redwood tree trunk', 'coral reef marine', 'wildflower meadow', 'fall harvest festival', 'glacial ice cave', 'redwood tree canopy', 'botanical garden plants', 'glacier', 'mangrove swamp habitat', 'autumn foliage', 'urban cityscape at night', 'sunflower field maze', 'coral reef ecosystem', 'lightning storm strike', 'alpine meadow', 'wildflower meadow scene', 'lavender scented fields', 'northern lights dance', 'moss-covered stones', 'active volcano crater', 'orchid garden display', 'shooting star meteor', 'coral reef underwater', 'cherry blossom petals', 'sunflower field rows', 'desert oasis view', 'urban skyline panorama', 'bamboo forest walk', 'water lily bloom', 'zen garden tranquility', 'rice terrace landscape- sandstone canyon view', 'tulip garden display', 'oasis in desert', 'sunflower field sunrise', 'solar eclipse totality', 'glacial ice formation', 'starry night sky', 'cactus flower bloom', 'solar eclipse sun', 'koi pond fish', 'spiral galaxy universe', 'northern lights', 'lunar eclipse shadow', 'olive tree orchard', 'active volcano eruption', 'mossy forest stream', 'desert oasis palm', 'cherry blossom festival', 'fall foliage colors', 'waterfall', 'rainbow after rain', 'hot air balloon flight', 'bonsai tree display', 'lightning storm sky', 'cherry blossom bloom', 'lavender field fragrance', 'olive tree grov ...
# 100%|██████████| 23/23 [01:24<00:00,  3.67s/it]
# 2025-07-12 19:52:01,354 : Evaluating OOD dataset dtd
# DEBUG:__main__:Evaluating OOD dataset dtd
# 100%|██████████| 23/23 [01:19<00:00,  3.47s/it]
# 2025-07-12 19:53:21,639 : in scores: DescribeResult(nobs=5794, minmax=(np.float32(-0.0022228262), np.float32(-0.0018734911)), mean=np.float32(-0.0020376076), variance=np.float64(2.4437048961090355e-09), skewness=np.float64(0.07026629149913788), kurtosis=np.float32(-0.074220896))
# DEBUG:__main__:in scores: DescribeResult(nobs=5794, minmax=(np.float32(-0.0022228262), np.float32(-0.0018734911)), mean=np.float32(-0.0020376076), variance=np.float64(2.4437048961090355e-09), skewness=np.float64(0.07026629149913788), kurtosis=np.float32(-0.074220896))
# 2025-07-12 19:53:21,643 : out scores: DescribeResult(nobs=5640, minmax=(np.float32(-0.0019410981), np.float32(-0.0016516221)), mean=np.float32(-0.0017651605), variance=np.float64(1.3992215815385455e-09), skewness=np.float64(-0.4120877683162689), kurtosis=np.float32(0.31557322))
# DEBUG:__main__:out scores: DescribeResult(nobs=5640, minmax=(np.float32(-0.0019410981), np.float32(-0.0016516221)), mean=np.float32(-0.0017651605), variance=np.float64(1.3992215815385455e-09), skewness=np.float64(-0.4120877683162689), kurtosis=np.float32(0.31557322))
# 2025-07-12 19:53:21,986 : 				EOE
# DEBUG:__main__:				EOE
# 2025-07-12 19:53:21,988 :   FPR95 AUROC AUPR
# DEBUG:__main__:  FPR95 AUROC AUPR
# 2025-07-12 19:53:21,990 : & 0.00 & 100.00 & 100.00
# DEBUG:__main__:& 0.00 & 100.00 & 100.00
# 2025-07-12 19:53:21,992 :
#
# Mean Test Results
# DEBUG:__main__:
#
# Mean Test Results
# 2025-07-12 19:53:21,993 : 				EOE
# DEBUG:__main__:				EOE
# 2025-07-12 19:53:21,995 :   FPR95 AUROC AUPR
# DEBUG:__main__:  FPR95 AUROC AUPR
# 2025-07-12 19:53:21,997 : & 0.00 & 100.00 & 100.00
# DEBUG:__main__:& 0.00 & 100.00 & 100.00

# %% [markdown]
# L=50, Beta=0.75

# %%
sys.argv = [
    "eval_ood_detection.py",
    "--name",        "CUB200_TEXTURE_50L_75B_far_evaluation",
    "--in_dataset",  "bird200",
    "--ood_task",    "far",
    "--score",       "EOE",
    "--root_dir",    "datasets",
    "--batch_size",  "256",
    "--gpu",         "0",
    "--L",           "50",
    "--beta",        "0.75",
    "--generate_class",
]
main()
# Out:
# /usr/local/lib/python3.11/dist-packages/torch/utils/data/dataloader.py:624: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(
# Original ID Labels: ['Black footed Albatross', 'Laysan Albatross', 'Sooty Albatross', 'Groove billed Ani', 'Crested Auklet', 'Least Auklet', 'Parakeet Auklet', 'Rhinoceros Auklet', 'Brewer Blackbird', 'Red winged Blackbird', 'Rusty Blackbird', 'Yellow headed Blackbird', 'Bobolink', 'Indigo Bunting', 'Lazuli Bunting', 'Painted Bunting', 'Cardinal', 'Spotted Catbird', 'Gray Catbird', 'Yellow breasted Chat', 'Eastern Towhee', 'Chuck will Widow', 'Brandt Cormorant', 'Red faced Cormorant', 'Pelagic Cormorant', 'Bronzed Cowbird', 'Shiny Cowbird', 'Brown Creeper', 'American Crow', 'Fish Crow', 'Black billed Cuckoo', 'Mangrove Cuckoo', 'Yellow billed Cuckoo', 'Gray crowned Rosy Finch', 'Purple Finch', 'Northern Flicker', 'Acadian Flycatcher', 'Great Crested Flycatcher', 'Least Flycatcher', 'Olive sided Flycatcher', 'Scissor tailed Flycatcher', 'Vermilion Flycatcher', 'Yellow bellied Flycatcher', 'Frigatebird', 'Northern Fulmar', 'Gadwall', 'American Goldfinch', 'European Goldfinch', 'Boat tailed Grackle', 'Eared Grebe', 'Horned Grebe', 'Pied billed Grebe', 'Western Grebe', 'Blue Grosbeak', 'Evening Grosbeak', 'Pine Grosbeak', 'Rose breasted Grosbeak', 'Pigeon Guillemot', 'California Gull', 'Glaucous winged Gull', 'Heermann Gull', 'Herring Gull', 'Ivory Gull', 'Ring billed Gull', 'Slaty backed Gull', 'Western Gull', 'Anna Hummingbird', 'Ruby throated Hummingbird', 'Rufous Hummingbird', 'Green Violetear', 'Long tailed Jaeger', 'Pomarine Jaeger', 'Blue Jay', 'Florida Jay', 'Green Jay', 'Dark eyed Junco', 'Tropical Kingbird', 'Gray Kingbird', 'Belted Kingfisher', 'Green Kingfisher', 'Pied Kingfisher', 'Ringed Kingfisher', 'White breasted Kingfisher', 'Red legged Kittiwake', 'Horned Lark', 'Pacific Loon', 'Mallard', 'Western Meadowlark', 'Hooded Merganser', 'Red breasted Merganser', 'Mockingbird', 'Nighthawk', 'Clark Nutcracker', 'White breasted Nuthatch', 'Baltimore Oriole', 'Hooded Oriole', 'Orchard Oriole', 'Scott Oriole', 'Ovenbird', 'Brown Pelican', 'White Pelican', 'Western Wood Pewee', 'Sayornis', 'American Pipit', 'Whip poor Will', 'Horned Puffin', 'Common Raven', 'White necked Raven', 'American Redstart', 'Geococcyx', 'Loggerhead Shrike', 'Great Grey Shrike', 'Baird Sparrow', 'Black throated Sparrow', 'Brewer Sparrow', 'Chipping Sparrow', 'Clay colored Sparrow', 'House Sparrow', 'Field Sparrow', 'Fox Sparrow', 'Grasshopper Sparrow', 'Harris Sparrow', 'Henslow Sparrow', 'Le Conte Sparrow', 'Lincoln Sparrow', 'Nelson Sharp tailed Sparrow', 'Savannah Sparrow', 'Seaside Sparrow', 'Song Sparrow', 'Tree Sparrow', 'Vesper Sparrow', 'White crowned Sparrow', 'White throated Sparrow', 'Cape Glossy Starling', 'Bank Swallow', 'Barn Swallow', 'Cliff Swallow', 'Tree Swallow', 'Scarlet Tanager', 'Summer Tanager', 'Artic Tern', 'Black Tern', 'Caspian Tern', 'Common Tern', 'Elegant Tern', 'Forsters Tern', 'Least Tern', 'Green tailed Towhee', 'Brown Thrasher', 'Sage Thrasher', 'Black capped Vireo', 'Blue headed Vireo', 'Philadelphia Vireo', 'Red eyed Vireo', 'Warbling Vireo', 'White eyed Vireo', 'Yellow throated Vireo', 'Bay breasted Warbler', 'Black and white Warbler', 'Black throated Blue Warbler', 'Blue winged Warbler', 'Canada Warbler', 'Cape May Warbler', 'Cerulean Warbler', 'Chestnut sided Warbler', 'Golden winged Warbler', 'Hooded Warbler', 'Kentucky Warbler', 'Magnolia Warbler', 'Mourning Warbler', 'Myrtle Warbler', 'Nashville Warbler', 'Orange crowned Warbler', 'Palm Warbler', 'Pine Warbler', 'Prairie Warbler', 'Prothonotary Warbler', 'Swainson Warbler', 'Tennessee Warbler', 'Wilson Warbler', 'Worm eating Warbler', 'Yellow Warbler', 'Northern Waterthrush', 'Louisiana Waterthrush', 'Bohemian Waxwing', 'Cedar Waxwing', 'American Three toed Woodpecker', 'Pileated Woodpecker', 'Red bellied Woodpecker', 'Red cockaded Woodpecker', 'Red headed Woodpecker', 'Downy Woodpecker', 'Bewick Wren', 'Cactus Wren', 'Carolina Wren', 'House Wren', 'Marsh Wren', 'Rock Wren', 'Winter Wren', 'Common Yellowthroat']
# Using original ID labels (no synonyms).
# Envisioning Outlier Exposure...
# 🔵 Generating via OpenAI GPT...
# 🔍 Raw GPT output:
#  - Sunset over the ocean
#         - Desert landscape
#         - Snow-capped mountains
#         - Tropical beach
#         - City skyline
#         - Aurora borealis
#         - Waterfall
#         - Fields of flowers
#         - Starry night sky
#         - Urban street art
#         - Ancient ruins
#         - Volcanic landscape
#         - Iceberg
#         - Sand dunes
#         - Coral reef
#         - Bamboo forest
#         - Moss-covered forest
#         - Lush jungle
#         - Cactus garden
#         - Rock formations
#         - Glacial lake
#         - Hot air balloons in the sky
#         - Fields of wheat
#         - Cherry blossom trees
#         - Lavender fields
#         - Sunflower fields
#         - Tulip fields
#         - Autumn foliage
#         - Cherry orchard
#         - Vineyard
#         - Tea plantation
#         - Rice terraces
#         - Water lilies on a pond
#         - Koi pond
#         - Zen garden
#         - Bonsai tree
#         - Sand garden
#         - Water garden
#         - Botanical garden
#         - Topiary garden
#         - Succulent garden
#         - Moss garden
#         - Herb garden
#         - Vegetable garden
#         - Butterfly garden
#         - Bird of paradise flower
#         - Orchid garden
#         - Carnivorous plant garden
#
# 💾 Saving hallucinated class descriptors to: envisioned_classes/far_50/bird200_gpt-3.5-turbo_2.json
# === load json:  envisioned_classes/far_50/bird200_gpt-3.5-turbo_2.json
# Get Envisioned Candidate Class Names.
# After set: 48
# After removing ID class overlaps: 48
# Final ID Labels passed to CLIP: ['Black footed Albatross', 'Laysan Albatross', 'Sooty Albatross', 'Groove billed Ani', 'Crested Auklet', 'Least Auklet', 'Parakeet Auklet', 'Rhinoceros Auklet', 'Brewer Blackbird', 'Red winged Blackbird', 'Rusty Blackbird', 'Yellow headed Blackbird', 'Bobolink', 'Indigo Bunting', 'Lazuli Bunting', 'Painted Bunting', 'Cardinal', 'Spotted Catbird', 'Gray Catbird', 'Yellow breasted Chat', 'Eastern Towhee', 'Chuck will Widow', 'Brandt Cormorant', 'Red faced Cormorant', 'Pelagic Cormorant', 'Bronzed Cowbird', 'Shiny Cowbird', 'Brown Creeper', 'American Crow', 'Fish Crow', 'Black billed Cuckoo', 'Mangrove Cuckoo', 'Yellow billed Cuckoo', 'Gray crowned Rosy Finch', 'Purple Finch', 'Northern Flicker', 'Acadian Flycatcher', 'Great Crested Flycatcher', 'Least Flycatcher', 'Olive sided Flycatcher', 'Scissor tailed Flycatcher', 'Vermilion Flycatcher', 'Yellow bellied Flycatcher', 'Frigatebird', 'Northern Fulmar', 'Gadwall', 'American Goldfinch', 'European Goldfinch', 'Boat tailed Grackle', 'Eared Grebe', 'Horned Grebe', 'Pied billed Grebe', 'Western Grebe', 'Blue Grosbeak', 'Evening Grosbeak', 'Pine Grosbeak', 'Rose breasted Grosbeak', 'Pigeon Guillemot', 'California Gull', 'Glaucous winged Gull', 'Heermann Gull', 'Herring Gull', 'Ivory Gull', 'Ring billed Gull', 'Slaty backed Gull', 'Western Gull', 'Anna Hummingbird', 'Ruby throated Hummingbird', 'Rufous Hummingbird', 'Green Violetear', 'Long tailed Jaeger', 'Pomarine Jaeger', 'Blue Jay', 'Florida Jay', 'Green Jay', 'Dark eyed Junco', 'Tropical Kingbird', 'Gray Kingbird', 'Belted Kingfisher', 'Green Kingfisher', 'Pied Kingfisher', 'Ringed Kingfisher', 'White breasted Kingfisher', 'Red legged Kittiwake', 'Horned Lark', 'Pacific Loon', 'Mallard', 'Western Meadowlark', 'Hooded Merganser', 'Red breasted Merganser', 'Mockingbird', 'Nighthawk', 'Clark Nutcracker', 'White breasted Nuthatch', 'Baltimore Oriole', 'Hooded Oriole', 'Orchard Oriole', 'Scott Oriole', 'Ovenbird', 'Brown Pelican', 'White Pelican', 'Western Wood Pewee', 'Sayornis', 'American Pipit', 'Whip poor Will', 'Horned Puffin', 'Common Raven', 'White necked Raven', 'American Redstart', 'Geococcyx', 'Loggerhead Shrike', 'Great Grey Shrike', 'Baird Sparrow', 'Black throated Sparrow', 'Brewer Sparrow', 'Chipping Sparrow', 'Clay colored Sparrow', 'House Sparrow', 'Field Sparrow', 'Fox Sparrow', 'Grasshopper Sparrow', 'Harris Sparrow', 'Henslow Sparrow', 'Le Conte Sparrow', 'Lincoln Sparrow', 'Nelson Sharp tailed Sparrow', 'Savannah Sparrow', 'Seaside Sparrow', 'Song Sparrow', 'Tree Sparrow', 'Vesper Sparrow', 'White crowned Sparrow', 'White throated Sparrow', 'Cape Glossy Starling', 'Bank Swallow', 'Barn Swallow', 'Cliff Swallow', 'Tree Swallow', 'Scarlet Tanager', 'Summer Tanager', 'Artic Tern', 'Black Tern', 'Caspian Tern', 'Common Tern', 'Elegant Tern', 'Forsters Tern', 'Least Tern', 'Green tailed Towhee', 'Brown Thrasher', 'Sage Thrasher', 'Black capped Vireo', 'Blue headed Vireo', 'Philadelphia Vireo', 'Red eyed Vireo', 'Warbling Vireo', 'White eyed Vireo', 'Yellow throated Vireo', 'Bay breasted Warbler', 'Black and white Warbler', 'Black throated Blue Warbler', 'Blue winged Warbler', 'Canada Warbler', 'Cape May Warbler', 'Cerulean Warbler', 'Chestnut sided Warbler', 'Golden winged Warbler', 'Hooded Warbler', 'Kentucky Warbler', 'Magnolia Warbler', 'Mourning Warbler', 'Myrtle Warbler', 'Nashville Warbler', 'Orange crowned Warbler', 'Palm Warbler', 'Pine Warbler', 'Prairie Warbler', 'Prothonotary Warbler', 'Swainson Warbler', 'Tennessee Warbler', 'Wilson Warbler', 'Worm eating Warbler', 'Yellow Warbler', 'Northern Waterthrush', 'Louisiana Waterthrush', 'Bohemian Waxwing', 'Cedar Waxwing', 'American Three toed Woodpecker', 'Pileated Woodpecker', 'Red bellied Woodpecker', 'Red cockaded Woodpecker', 'Red headed Woodpecker', 'Downy Woodpecker', 'Bewick Wren', 'Cactus Wren', 'Carolina Wren', 'House Wren', 'Marsh Wren', 'Rock Wren', 'Winter Wren', 'Common Yellowthroat']
# Envisioned OOD labels (LLM): ['coral reef', 'tulip fields', 'sand dunes', 'sunflower fields', 'lush jungle', 'bonsai tree', 'sand garden', 'water lilies on a pond', 'urban street art', 'fields of wheat', 'tea plantation', 'volcanic landscape', 'starry night sky', 'lavender fields', 'cherry orchard', 'ancient ruins', 'botanical garden', 'bamboo forest', 'zen garden', 'vegetable garden', 'fields of flowers', 'carnivorous plant garden', 'koi pond', 'moss garden', 'waterfall', 'city skyline', 'herb garden', 'succulent garden', 'moss-covered forest', 'tropical beach', 'rice terraces', 'rock formations', 'aurora borealis', 'sunset over the ocean', 'autumn foliage', 'vineyard', 'bird of paradise flower', 'desert landscape', 'hot air balloons in the sky', 'topiary garden', 'iceberg', 'orchid garden', 'glacial lake', 'cherry blossom trees', 'butterfly garden', 'snow-capped mountains', 'cactus garden', 'water garden']
# 100%|██████████| 23/23 [01:21<00:00,  3.54s/it]
# 2025-07-12 19:54:59,838 : Evaluating OOD dataset dtd
# DEBUG:__main__:Evaluating OOD dataset dtd
# 100%|██████████| 23/23 [01:15<00:00,  3.28s/it]
# 2025-07-12 19:56:15,892 : in scores: DescribeResult(nobs=5794, minmax=(np.float32(-0.0019359961), np.float32(-0.0010505747)), mean=np.float32(-0.0015931862), variance=np.float64(8.375848111984108e-09), skewness=np.float64(0.2849658131599426), kurtosis=np.float32(0.4023564))
# DEBUG:__main__:in scores: DescribeResult(nobs=5794, minmax=(np.float32(-0.0019359961), np.float32(-0.0010505747)), mean=np.float32(-0.0015931862), variance=np.float64(8.375848111984108e-09), skewness=np.float64(0.2849658131599426), kurtosis=np.float32(0.4023564))
# 2025-07-12 19:56:15,896 : out scores: DescribeResult(nobs=5640, minmax=(np.float32(-0.0013778294), np.float32(-0.0007294251)), mean=np.float32(-0.0010634328), variance=np.float64(7.296037987873638e-09), skewness=np.float64(0.060403019189834595), kurtosis=np.float32(0.28363252))
# DEBUG:__main__:out scores: DescribeResult(nobs=5640, minmax=(np.float32(-0.0013778294), np.float32(-0.0007294251)), mean=np.float32(-0.0010634328), variance=np.float64(7.296037987873638e-09), skewness=np.float64(0.060403019189834595), kurtosis=np.float32(0.28363252))
# 2025-07-12 19:56:16,213 : 				EOE
# DEBUG:__main__:				EOE
# 2025-07-12 19:56:16,216 :   FPR95 AUROC AUPR
# DEBUG:__main__:  FPR95 AUROC AUPR
# 2025-07-12 19:56:16,218 : & 0.00 & 99.99 & 99.99
# DEBUG:__main__:& 0.00 & 99.99 & 99.99
# 2025-07-12 19:56:16,220 :
#
# Mean Test Results
# DEBUG:__main__:
#
# Mean Test Results
# 2025-07-12 19:56:16,221 : 				EOE
# DEBUG:__main__:				EOE
# 2025-07-12 19:56:16,223 :   FPR95 AUROC AUPR
# DEBUG:__main__:  FPR95 AUROC AUPR
# 2025-07-12 19:56:16,225 : & 0.00 & 99.99 & 99.99
# DEBUG:__main__:& 0.00 & 99.99 & 99.99

# %% [markdown]
# L=100, Beta=0.75

# %%
sys.argv = [
    "eval_ood_detection.py",
    "--name",        "CUB200_TEXTURE_100L_75B_far_evaluation",
    "--in_dataset",  "bird200",
    "--ood_task",    "far",
    "--score",       "EOE",
    "--root_dir",    "datasets",
    "--batch_size",  "256",
    "--gpu",         "0",
    "--L",           "100",
    "--beta",        "0.75",
    "--generate_class",
]
main()
# Out:
# /usr/local/lib/python3.11/dist-packages/torch/utils/data/dataloader.py:624: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(
# Original ID Labels: ['Black footed Albatross', 'Laysan Albatross', 'Sooty Albatross', 'Groove billed Ani', 'Crested Auklet', 'Least Auklet', 'Parakeet Auklet', 'Rhinoceros Auklet', 'Brewer Blackbird', 'Red winged Blackbird', 'Rusty Blackbird', 'Yellow headed Blackbird', 'Bobolink', 'Indigo Bunting', 'Lazuli Bunting', 'Painted Bunting', 'Cardinal', 'Spotted Catbird', 'Gray Catbird', 'Yellow breasted Chat', 'Eastern Towhee', 'Chuck will Widow', 'Brandt Cormorant', 'Red faced Cormorant', 'Pelagic Cormorant', 'Bronzed Cowbird', 'Shiny Cowbird', 'Brown Creeper', 'American Crow', 'Fish Crow', 'Black billed Cuckoo', 'Mangrove Cuckoo', 'Yellow billed Cuckoo', 'Gray crowned Rosy Finch', 'Purple Finch', 'Northern Flicker', 'Acadian Flycatcher', 'Great Crested Flycatcher', 'Least Flycatcher', 'Olive sided Flycatcher', 'Scissor tailed Flycatcher', 'Vermilion Flycatcher', 'Yellow bellied Flycatcher', 'Frigatebird', 'Northern Fulmar', 'Gadwall', 'American Goldfinch', 'European Goldfinch', 'Boat tailed Grackle', 'Eared Grebe', 'Horned Grebe', 'Pied billed Grebe', 'Western Grebe', 'Blue Grosbeak', 'Evening Grosbeak', 'Pine Grosbeak', 'Rose breasted Grosbeak', 'Pigeon Guillemot', 'California Gull', 'Glaucous winged Gull', 'Heermann Gull', 'Herring Gull', 'Ivory Gull', 'Ring billed Gull', 'Slaty backed Gull', 'Western Gull', 'Anna Hummingbird', 'Ruby throated Hummingbird', 'Rufous Hummingbird', 'Green Violetear', 'Long tailed Jaeger', 'Pomarine Jaeger', 'Blue Jay', 'Florida Jay', 'Green Jay', 'Dark eyed Junco', 'Tropical Kingbird', 'Gray Kingbird', 'Belted Kingfisher', 'Green Kingfisher', 'Pied Kingfisher', 'Ringed Kingfisher', 'White breasted Kingfisher', 'Red legged Kittiwake', 'Horned Lark', 'Pacific Loon', 'Mallard', 'Western Meadowlark', 'Hooded Merganser', 'Red breasted Merganser', 'Mockingbird', 'Nighthawk', 'Clark Nutcracker', 'White breasted Nuthatch', 'Baltimore Oriole', 'Hooded Oriole', 'Orchard Oriole', 'Scott Oriole', 'Ovenbird', 'Brown Pelican', 'White Pelican', 'Western Wood Pewee', 'Sayornis', 'American Pipit', 'Whip poor Will', 'Horned Puffin', 'Common Raven', 'White necked Raven', 'American Redstart', 'Geococcyx', 'Loggerhead Shrike', 'Great Grey Shrike', 'Baird Sparrow', 'Black throated Sparrow', 'Brewer Sparrow', 'Chipping Sparrow', 'Clay colored Sparrow', 'House Sparrow', 'Field Sparrow', 'Fox Sparrow', 'Grasshopper Sparrow', 'Harris Sparrow', 'Henslow Sparrow', 'Le Conte Sparrow', 'Lincoln Sparrow', 'Nelson Sharp tailed Sparrow', 'Savannah Sparrow', 'Seaside Sparrow', 'Song Sparrow', 'Tree Sparrow', 'Vesper Sparrow', 'White crowned Sparrow', 'White throated Sparrow', 'Cape Glossy Starling', 'Bank Swallow', 'Barn Swallow', 'Cliff Swallow', 'Tree Swallow', 'Scarlet Tanager', 'Summer Tanager', 'Artic Tern', 'Black Tern', 'Caspian Tern', 'Common Tern', 'Elegant Tern', 'Forsters Tern', 'Least Tern', 'Green tailed Towhee', 'Brown Thrasher', 'Sage Thrasher', 'Black capped Vireo', 'Blue headed Vireo', 'Philadelphia Vireo', 'Red eyed Vireo', 'Warbling Vireo', 'White eyed Vireo', 'Yellow throated Vireo', 'Bay breasted Warbler', 'Black and white Warbler', 'Black throated Blue Warbler', 'Blue winged Warbler', 'Canada Warbler', 'Cape May Warbler', 'Cerulean Warbler', 'Chestnut sided Warbler', 'Golden winged Warbler', 'Hooded Warbler', 'Kentucky Warbler', 'Magnolia Warbler', 'Mourning Warbler', 'Myrtle Warbler', 'Nashville Warbler', 'Orange crowned Warbler', 'Palm Warbler', 'Pine Warbler', 'Prairie Warbler', 'Prothonotary Warbler', 'Swainson Warbler', 'Tennessee Warbler', 'Wilson Warbler', 'Worm eating Warbler', 'Yellow Warbler', 'Northern Waterthrush', 'Louisiana Waterthrush', 'Bohemian Waxwing', 'Cedar Waxwing', 'American Three toed Woodpecker', 'Pileated Woodpecker', 'Red bellied Woodpecker', 'Red cockaded Woodpecker', 'Red headed Woodpecker', 'Downy Woodpecker', 'Bewick Wren', 'Cactus Wren', 'Carolina Wren', 'House Wren', 'Marsh Wren', 'Rock Wren', 'Winter Wren', 'Common Yellowthroat']
# Using original ID labels (no synonyms).
# Envisioning Outlier Exposure...
# 🔵 Generating via OpenAI GPT...
# Continuing vision 1/1
# 🔍 Raw GPT output:
#  - Sunset over the ocean
#         - Desert landscape
#         - Snow-capped mountains
#         - Tropical beach
#         - City skyline
#         - Starry night sky
#         - Waterfall
#         - Autumn forest
#         - Fields of flowers
#         - Urban street art
#         - Ancient ruins
#         - Northern lights
#         - Volcanic landscape
#         - Iceberg
#         - Sand dunes
#         - Coral reef
#         - Bamboo forest
#         - Glacier
#         - Hot air balloons
#         - Rainbow
#         - Thunderstorm
#         - Tornado
#         - Lunar eclipse
#         - Solar eclipse
#         - Meteor shower
#         - Rainbow waterfall
#         - Cherry blossom trees
#         - Aurora borealis
#         - Bioluminescent plankton
#         - Redwood forest
#         - Geothermal hot springs
#         - Ice cave
#         - Sandstone arches
#         - Lava flow
#         - Mangrove swamp
#         - Cactus garden
#         - Water lilies
#         - Moss-covered forest
#         - Sunflower fields
#         - Lavender fields
#         - Tulip fields
#         - Cherry orchard
#         - Vineyard
#         - Wheat fields
#         - Rice terraces
#         - Tea plantation
#         - Coffee plantation
#         - Olive grove- Desert oasis
# - Alpine meadow
# - Rocky coastline
# - Misty forest
# - Urban graffiti
# - Ancient temple
# - Nighttime cityscape
# - Frozen tundra
# - Cherry blossom
# - Tropical rainforest
# - Sandstone cliffs
# - Coral reef
# - Bamboo forest
# - Glacial lake
# - Hot air balloons
# - Rainbow waterfall
# - Thunderstorm clouds
# - Tornado alley
# - Lunar eclipse
# - Solar eclipse
# - Meteor shower
# - Rainbow bridge
# - Cherry blossom
# - Aurora borealis
# - Bioluminescent sea
# - Redwood forest
# - Geothermal pools
# - Ice cave
# - Sandstone arches
# - Lava flow
# - Mangrove swamp
# - Cactus garden
# - Water lilies
# - Moss-covered trees
# - Sunflower field
# - Lavender field
# - Tulip field
# - Cherry orchard
# - Vineyard sunset
# - Wheat field
# - Rice terraces
# - Tea plantation
# - Coffee plantation
# - Olive grove
# - Desert mirage
# - Alpine lake
# - Rocky desert
# - Misty mountains
# - Urban skyline
# - Ancient ruins
#
# 💾 Saving hallucinated class descriptors to: envisioned_classes/far_100/bird200_gpt-3.5-turbo_1.json
# === load json:  envisioned_classes/far_100/bird200_gpt-3.5-turbo_1.json
# Get Envisioned Candidate Class Names.
# After set: 76
# After removing ID class overlaps: 76
# Final ID Labels passed to CLIP: ['Black footed Albatross', 'Laysan Albatross', 'Sooty Albatross', 'Groove billed Ani', 'Crested Auklet', 'Least Auklet', 'Parakeet Auklet', 'Rhinoceros Auklet', 'Brewer Blackbird', 'Red winged Blackbird', 'Rusty Blackbird', 'Yellow headed Blackbird', 'Bobolink', 'Indigo Bunting', 'Lazuli Bunting', 'Painted Bunting', 'Cardinal', 'Spotted Catbird', 'Gray Catbird', 'Yellow breasted Chat', 'Eastern Towhee', 'Chuck will Widow', 'Brandt Cormorant', 'Red faced Cormorant', 'Pelagic Cormorant', 'Bronzed Cowbird', 'Shiny Cowbird', 'Brown Creeper', 'American Crow', 'Fish Crow', 'Black billed Cuckoo', 'Mangrove Cuckoo', 'Yellow billed Cuckoo', 'Gray crowned Rosy Finch', 'Purple Finch', 'Northern Flicker', 'Acadian Flycatcher', 'Great Crested Flycatcher', 'Least Flycatcher', 'Olive sided Flycatcher', 'Scissor tailed Flycatcher', 'Vermilion Flycatcher', 'Yellow bellied Flycatcher', 'Frigatebird', 'Northern Fulmar', 'Gadwall', 'American Goldfinch', 'European Goldfinch', 'Boat tailed Grackle', 'Eared Grebe', 'Horned Grebe', 'Pied billed Grebe', 'Western Grebe', 'Blue Grosbeak', 'Evening Grosbeak', 'Pine Grosbeak', 'Rose breasted Grosbeak', 'Pigeon Guillemot', 'California Gull', 'Glaucous winged Gull', 'Heermann Gull', 'Herring Gull', 'Ivory Gull', 'Ring billed Gull', 'Slaty backed Gull', 'Western Gull', 'Anna Hummingbird', 'Ruby throated Hummingbird', 'Rufous Hummingbird', 'Green Violetear', 'Long tailed Jaeger', 'Pomarine Jaeger', 'Blue Jay', 'Florida Jay', 'Green Jay', 'Dark eyed Junco', 'Tropical Kingbird', 'Gray Kingbird', 'Belted Kingfisher', 'Green Kingfisher', 'Pied Kingfisher', 'Ringed Kingfisher', 'White breasted Kingfisher', 'Red legged Kittiwake', 'Horned Lark', 'Pacific Loon', 'Mallard', 'Western Meadowlark', 'Hooded Merganser', 'Red breasted Merganser', 'Mockingbird', 'Nighthawk', 'Clark Nutcracker', 'White breasted Nuthatch', 'Baltimore Oriole', 'Hooded Oriole', 'Orchard Oriole', 'Scott Oriole', 'Ovenbird', 'Brown Pelican', 'White Pelican', 'Western Wood Pewee', 'Sayornis', 'American Pipit', 'Whip poor Will', 'Horned Puffin', 'Common Raven', 'White necked Raven', 'American Redstart', 'Geococcyx', 'Loggerhead Shrike', 'Great Grey Shrike', 'Baird Sparrow', 'Black throated Sparrow', 'Brewer Sparrow', 'Chipping Sparrow', 'Clay colored Sparrow', 'House Sparrow', 'Field Sparrow', 'Fox Sparrow', 'Grasshopper Sparrow', 'Harris Sparrow', 'Henslow Sparrow', 'Le Conte Sparrow', 'Lincoln Sparrow', 'Nelson Sharp tailed Sparrow', 'Savannah Sparrow', 'Seaside Sparrow', 'Song Sparrow', 'Tree Sparrow', 'Vesper Sparrow', 'White crowned Sparrow', 'White throated Sparrow', 'Cape Glossy Starling', 'Bank Swallow', 'Barn Swallow', 'Cliff Swallow', 'Tree Swallow', 'Scarlet Tanager', 'Summer Tanager', 'Artic Tern', 'Black Tern', 'Caspian Tern', 'Common Tern', 'Elegant Tern', 'Forsters Tern', 'Least Tern', 'Green tailed Towhee', 'Brown Thrasher', 'Sage Thrasher', 'Black capped Vireo', 'Blue headed Vireo', 'Philadelphia Vireo', 'Red eyed Vireo', 'Warbling Vireo', 'White eyed Vireo', 'Yellow throated Vireo', 'Bay breasted Warbler', 'Black and white Warbler', 'Black throated Blue Warbler', 'Blue winged Warbler', 'Canada Warbler', 'Cape May Warbler', 'Cerulean Warbler', 'Chestnut sided Warbler', 'Golden winged Warbler', 'Hooded Warbler', 'Kentucky Warbler', 'Magnolia Warbler', 'Mourning Warbler', 'Myrtle Warbler', 'Nashville Warbler', 'Orange crowned Warbler', 'Palm Warbler', 'Pine Warbler', 'Prairie Warbler', 'Prothonotary Warbler', 'Swainson Warbler', 'Tennessee Warbler', 'Wilson Warbler', 'Worm eating Warbler', 'Yellow Warbler', 'Northern Waterthrush', 'Louisiana Waterthrush', 'Bohemian Waxwing', 'Cedar Waxwing', 'American Three toed Woodpecker', 'Pileated Woodpecker', 'Red bellied Woodpecker', 'Red cockaded Woodpecker', 'Red headed Woodpecker', 'Downy Woodpecker', 'Bewick Wren', 'Cactus Wren', 'Carolina Wren', 'House Wren', 'Marsh Wren', 'Rock Wren', 'Winter Wren', 'Common Yellowthroat']
# Envisioned OOD labels (LLM): ['coral reef', 'tulip fields', 'urban skyline', 'lunar eclipse', 'sand dunes', 'coffee plantation', 'sunflower field', 'meteor shower', 'wheat fields', 'sunflower fields', 'misty forest', 'geothermal hot springs', 'lava flow', 'urban graffiti', 'nighttime cityscape', 'lavender field', 'urban street art', 'mangrove swamp', 'rainbow bridge', 'tea plantation', 'volcanic landscape', 'sandstone arches', 'starry night sky', 'lavender fields', 'desert mirage', 'bioluminescent sea', 'cherry orchard', 'ancient ruins', 'northern lights', 'bamboo forest', 'ancient temple', 'tornado', 'fields of flowers', 'olive grove', 'tropical rainforest', 'frozen tundra', 'waterfall', 'solar eclipse', 'city skyline', 'thunderstorm clouds', 'autumn forest', 'geothermal pools', 'moss-covered forest', 'wheat field', 'tropical beach', 'rice terraces', 'rocky coastline', 'hot air balloons', 'glacier', 'sunset over the ocean', 'aurora borealis', 'rainbow waterfall', 'water lilies', 'vineyard', 'moss-covered trees', 'thunderstorm', 'ice cave', 'olive grove- desert oasis', 'alpine meadow', 'tulip field', 'desert landscape', 'redwood forest', 'misty mountains', 'iceberg', 'bioluminescent plankton', 'cherry blossom trees', 'glacial lake', 'tornado alley', 'snow-capped mountains', 'cherry blossom', 'rainbow', 'vineyard sunset', 'alpine lake', 'cactus garden', 'rocky desert', 'sandstone cliffs']
# 100%|██████████| 23/23 [01:21<00:00,  3.53s/it]
# 2025-07-12 19:57:54,662 : Evaluating OOD dataset dtd
# DEBUG:__main__:Evaluating OOD dataset dtd
# 100%|██████████| 23/23 [01:17<00:00,  3.35s/it]
# 2025-07-12 19:59:12,125 : in scores: DescribeResult(nobs=5794, minmax=(np.float32(-0.0017028803), np.float32(-0.0011158967)), mean=np.float32(-0.0014274153), variance=np.float64(6.402524421215763e-09), skewness=np.float64(0.13974988460540771), kurtosis=np.float32(0.097366095))
# DEBUG:__main__:in scores: DescribeResult(nobs=5794, minmax=(np.float32(-0.0017028803), np.float32(-0.0011158967)), mean=np.float32(-0.0014274153), variance=np.float64(6.402524421215763e-09), skewness=np.float64(0.13974988460540771), kurtosis=np.float32(0.097366095))
# 2025-07-12 19:59:12,130 : out scores: DescribeResult(nobs=5640, minmax=(np.float32(-0.0012685747), np.float32(-0.0006657613)), mean=np.float32(-0.000956176), variance=np.float64(5.585480092863443e-09), skewness=np.float64(-0.01495871227234602), kurtosis=np.float32(0.30160975))
# DEBUG:__main__:out scores: DescribeResult(nobs=5640, minmax=(np.float32(-0.0012685747), np.float32(-0.0006657613)), mean=np.float32(-0.000956176), variance=np.float64(5.585480092863443e-09), skewness=np.float64(-0.01495871227234602), kurtosis=np.float32(0.30160975))
# 2025-07-12 19:59:13,181 : 				EOE
# DEBUG:__main__:				EOE
# 2025-07-12 19:59:13,189 :   FPR95 AUROC AUPR
# DEBUG:__main__:  FPR95 AUROC AUPR
# 2025-07-12 19:59:13,199 : & 0.00 & 100.00 & 100.00
# DEBUG:__main__:& 0.00 & 100.00 & 100.00
# 2025-07-12 19:59:13,209 :
#
# Mean Test Results
# DEBUG:__main__:
#
# Mean Test Results
# 2025-07-12 19:59:13,212 : 				EOE
# DEBUG:__main__:				EOE
# 2025-07-12 19:59:13,217 :   FPR95 AUROC AUPR
# DEBUG:__main__:  FPR95 AUROC AUPR
# 2025-07-12 19:59:13,226 : & 0.00 & 100.00 & 100.00
# DEBUG:__main__:& 0.00 & 100.00 & 100.00

# %% [markdown]
# L=300, Beta=0.75

# %%
sys.argv = [
    "eval_ood_detection.py",
    "--name",        "CUB200_TEXTURE_300L_75B_far_evaluation",
    "--in_dataset",  "bird200",
    "--ood_task",    "far",
    "--score",       "EOE",
    "--root_dir",    "datasets",
    "--batch_size",  "256",
    "--gpu",         "0",
    "--L",           "300",
    "--beta",        "0.75",
    "--generate_class",
]
main()
# Out:
# /usr/local/lib/python3.11/dist-packages/torch/utils/data/dataloader.py:624: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(
# Original ID Labels: ['Black footed Albatross', 'Laysan Albatross', 'Sooty Albatross', 'Groove billed Ani', 'Crested Auklet', 'Least Auklet', 'Parakeet Auklet', 'Rhinoceros Auklet', 'Brewer Blackbird', 'Red winged Blackbird', 'Rusty Blackbird', 'Yellow headed Blackbird', 'Bobolink', 'Indigo Bunting', 'Lazuli Bunting', 'Painted Bunting', 'Cardinal', 'Spotted Catbird', 'Gray Catbird', 'Yellow breasted Chat', 'Eastern Towhee', 'Chuck will Widow', 'Brandt Cormorant', 'Red faced Cormorant', 'Pelagic Cormorant', 'Bronzed Cowbird', 'Shiny Cowbird', 'Brown Creeper', 'American Crow', 'Fish Crow', 'Black billed Cuckoo', 'Mangrove Cuckoo', 'Yellow billed Cuckoo', 'Gray crowned Rosy Finch', 'Purple Finch', 'Northern Flicker', 'Acadian Flycatcher', 'Great Crested Flycatcher', 'Least Flycatcher', 'Olive sided Flycatcher', 'Scissor tailed Flycatcher', 'Vermilion Flycatcher', 'Yellow bellied Flycatcher', 'Frigatebird', 'Northern Fulmar', 'Gadwall', 'American Goldfinch', 'European Goldfinch', 'Boat tailed Grackle', 'Eared Grebe', 'Horned Grebe', 'Pied billed Grebe', 'Western Grebe', 'Blue Grosbeak', 'Evening Grosbeak', 'Pine Grosbeak', 'Rose breasted Grosbeak', 'Pigeon Guillemot', 'California Gull', 'Glaucous winged Gull', 'Heermann Gull', 'Herring Gull', 'Ivory Gull', 'Ring billed Gull', 'Slaty backed Gull', 'Western Gull', 'Anna Hummingbird', 'Ruby throated Hummingbird', 'Rufous Hummingbird', 'Green Violetear', 'Long tailed Jaeger', 'Pomarine Jaeger', 'Blue Jay', 'Florida Jay', 'Green Jay', 'Dark eyed Junco', 'Tropical Kingbird', 'Gray Kingbird', 'Belted Kingfisher', 'Green Kingfisher', 'Pied Kingfisher', 'Ringed Kingfisher', 'White breasted Kingfisher', 'Red legged Kittiwake', 'Horned Lark', 'Pacific Loon', 'Mallard', 'Western Meadowlark', 'Hooded Merganser', 'Red breasted Merganser', 'Mockingbird', 'Nighthawk', 'Clark Nutcracker', 'White breasted Nuthatch', 'Baltimore Oriole', 'Hooded Oriole', 'Orchard Oriole', 'Scott Oriole', 'Ovenbird', 'Brown Pelican', 'White Pelican', 'Western Wood Pewee', 'Sayornis', 'American Pipit', 'Whip poor Will', 'Horned Puffin', 'Common Raven', 'White necked Raven', 'American Redstart', 'Geococcyx', 'Loggerhead Shrike', 'Great Grey Shrike', 'Baird Sparrow', 'Black throated Sparrow', 'Brewer Sparrow', 'Chipping Sparrow', 'Clay colored Sparrow', 'House Sparrow', 'Field Sparrow', 'Fox Sparrow', 'Grasshopper Sparrow', 'Harris Sparrow', 'Henslow Sparrow', 'Le Conte Sparrow', 'Lincoln Sparrow', 'Nelson Sharp tailed Sparrow', 'Savannah Sparrow', 'Seaside Sparrow', 'Song Sparrow', 'Tree Sparrow', 'Vesper Sparrow', 'White crowned Sparrow', 'White throated Sparrow', 'Cape Glossy Starling', 'Bank Swallow', 'Barn Swallow', 'Cliff Swallow', 'Tree Swallow', 'Scarlet Tanager', 'Summer Tanager', 'Artic Tern', 'Black Tern', 'Caspian Tern', 'Common Tern', 'Elegant Tern', 'Forsters Tern', 'Least Tern', 'Green tailed Towhee', 'Brown Thrasher', 'Sage Thrasher', 'Black capped Vireo', 'Blue headed Vireo', 'Philadelphia Vireo', 'Red eyed Vireo', 'Warbling Vireo', 'White eyed Vireo', 'Yellow throated Vireo', 'Bay breasted Warbler', 'Black and white Warbler', 'Black throated Blue Warbler', 'Blue winged Warbler', 'Canada Warbler', 'Cape May Warbler', 'Cerulean Warbler', 'Chestnut sided Warbler', 'Golden winged Warbler', 'Hooded Warbler', 'Kentucky Warbler', 'Magnolia Warbler', 'Mourning Warbler', 'Myrtle Warbler', 'Nashville Warbler', 'Orange crowned Warbler', 'Palm Warbler', 'Pine Warbler', 'Prairie Warbler', 'Prothonotary Warbler', 'Swainson Warbler', 'Tennessee Warbler', 'Wilson Warbler', 'Worm eating Warbler', 'Yellow Warbler', 'Northern Waterthrush', 'Louisiana Waterthrush', 'Bohemian Waxwing', 'Cedar Waxwing', 'American Three toed Woodpecker', 'Pileated Woodpecker', 'Red bellied Woodpecker', 'Red cockaded Woodpecker', 'Red headed Woodpecker', 'Downy Woodpecker', 'Bewick Wren', 'Cactus Wren', 'Carolina Wren', 'House Wren', 'Marsh Wren', 'Rock Wren', 'Winter Wren', 'Common Yellowthroat']
# Using original ID labels (no synonyms).
# Envisioning Outlier Exposure...
# 🔵 Generating via OpenAI GPT...
# Continuing vision 1/5
# Continuing vision 2/5
# Continuing vision 3/5
# Continuing vision 4/5
# Continuing vision 5/5
# 🔍 Raw GPT output:
#  - Sunset
# - Waterfall
# - Desert landscape
# - Aurora borealis
# - Snow-capped mountain
# - Tropical beach
# - City skyline
# - Starry night sky
# - Autumn forest
# - Fields of flowers
# - Iceberg
# - Volcano eruption
# - Coral reef
# - Sand dunes
# - Glacier
# - Rainbow
# - Lightning storm
# - Tornado
# - Lunar eclipse
# - Solar eclipse
# - Milky Way galaxy
# - Water lilies
# - Bamboo forest
# - Cherry blossom trees
# - Moss-covered forest
# - Cactus garden
# - Lavender fields
# - Sunflower fields
# - Tulip fields
# - Moss-covered rocks
# - Moss-covered ruins
# - Moss-covered tree trunk
# - Moss-covered pathway
# - Moss-covered bridge
# - Moss-covered statue
# - Moss-covered wall
# - Moss-covered fence
# - Moss-covered roof
# - Moss-covered steps
# - Moss-covered bench
# - Moss-covered gate
# - Moss-covered window
# - Moss-covered door
# - Moss-covered balcony
# - Moss-covered sign
# - Moss-covered car
# - Moss-covered bicycle
# - Moss-covered boat
# - Moss-covered train
# - Moss-covered plane- Desert oasis
# - Snowy forest
# - Urban graffiti
# - Mountain lake
# - Tropical waterfall
# - City park
# - Night cityscape
# - Autumn foliage
# - Flower field
# - Ice cave
# - Volcanic landscape
# - Underwater coral
# - Sandstone formations
# - Glacial lake
# - Double rainbow
# - Thunderstorm clouds
# - Twisting tornado
# - Lunar landscape
# - Solar system
# - Star-filled sky
# - Lily pond
# - Bamboo grove
# - Blossom trees
# - Mossy rocks
# - Desert cactus
# - Lavender garden
# - Sunflower field
# - Tulip garden
# - Mossy ruins
# - Cactus garden
# - Lavender field
# - Sunflower field
# - Tulip field
# - Mossy pathway
# - Mossy bridge
# - Mossy statue
# - Mossy wall
# - Mossy fence
# - Mossy roof
# - Mossy steps
# - Mossy bench
# - Mossy gate
# - Mossy window
# - Mossy door
# - Mossy balcony
# - Mossy sign
# - Mossy car
# - Mossy bicycle
# - Mossy boat
# - Mossy train
# - Mossy plane- Desert canyon
# - Snowy mountains
# - Urban skyline
# - Mountain stream
# - Tropical paradise
# - City lights
# - Fall colors
# - Wildflower meadow
# - Iceberg floating
# - Volcanic eruption
# - Coral reef underwater
# - Sandstone cliffs
# - Glacial landscape
# - Rainbow colors
# - Stormy skies
# - Tornado warning
# - Lunar surface
# - Solar flare
# - Starry sky
# - Lily pads
# - Bamboo forest
# - Cherry blossoms
# - Mossy boulders
# - Desert flora
# - Lavender fields
# - Sunflower patch
# - Tulip bloom
# - Mossy stones
# - Cactus garden
# - Lavender rows
# - Sunflower patch
# - Tulip display
# - Mossy trail
# - Mossy arch
# - Mossy sculpture
# - Mossy barrier
# - Mossy shelter
# - Mossy staircase
# - Mossy seat
# - Mossy entrance
# - Mossy window
# - Mossy portal
# - Mossy vehicle
# - Mossy bike
# - Mossy vessel
# - Mossy locomotive
# - Mossy aircraft- Desert dunes
# - Snowy landscape
# - Urban architecture
# - Mountain peak
# - Tropical island
# - Cityscape view
# - Autumn trees
# - Wildflower field
# - Iceberg melting
# - Volcanic ash
# - Underwater world
# - Sand dune
# - Glacial ice
# - Rainbow sky
# - Storm clouds
# - Tornado alley
# - Lunar crater
# - Solar panels
# - Starry night
# - Lily pond
# - Bamboo garden
# - Cherry tree
# - Mossy forest floor
# - Desert plants
# - Lavender farm
# - Sunflower garden
# - Tulip festival
# - Mossy creek
# - Cactus landscape
# - Lavender rows
# - Sunflower farm
# - Tulip season
# - Mossy path
# - Mossy structure
# - Mossy fence
# - Mossy garden
# - Mossy stairs
# - Mossy bench
# - Mossy entrance
# - Mossy window
# - Mossy vehicle
# - Mossy bike
# - Mossy boat
# - Mossy train
# - Mossy plane- Desert oasis
# - Snowy forest
# - Urban graffiti
# - Mountain lake
# - Tropical waterfall
# - City park
# - Night cityscape
# - Autumn foliage
# - Flower field
# - Ice cave
# - Volcanic landscape
# - Underwater coral
# - Sandstone formations
# - Glacial lake
# - Double rainbow
# - Thunderstorm clouds
# - Twisting tornado
# - Lunar landscape
# - Solar system
# - Star-filled sky
# - Lily pond
# - Bamboo grove
# - Blossom trees
# - Mossy rocks
# - Desert cactus
# - Lavender garden
# - Sunflower field
# - Tulip garden
# - Mossy ruins
# - Cactus garden
# - Lavender field
# - Sunflower field
# - Tulip field
# - Mossy pathway
# - Mossy bridge
# - Mossy statue
# - Mossy wall
# - Mossy fence
# - Mossy roof
# - Mossy steps
# - Mossy bench
# - Mossy gate
# - Mossy window
# - Mossy door
# - Mossy balcony
# - Mossy sign
# - Mossy car
# - Mossy bicycle
# - Mossy boat
# - Mossy train
# - Mossy plane- Desert oasis
# - Snowy forest
# - Urban graffiti
# - Mountain lake
# - Tropical waterfall
# - City park
# - Night cityscape
# - Autumn foliage
# - Flower field
# - Ice cave
# - Volcanic landscape
# - Underwater coral
# - Sandstone formations
# - Glacial lake
# - Double rainbow
# - Thunderstorm clouds
# - Twisting tornado
# - Lunar landscape
# - Solar system
# - Star-filled sky
# - Lily pond
# - Bamboo grove
# - Blossom trees
# - Mossy rocks
# - Desert cactus
# - Lavender garden
# - Sunflower field
# - Tulip garden
# - Mossy ruins
# - Cactus garden
# - Lavender field
# - Sunflower field
# - Tulip field
# - Mossy pathway
# - Mossy bridge
# - Mossy statue
# - Mossy wall
# - Mossy fence
# - Mossy roof
# - Mossy steps
# - Mossy bench
# - Mossy gate
# - Mossy window
# - Mossy door
# - Mossy balcony
# - Mossy sign
# - Mossy car
# - Mossy bicycle
# - Mossy boat
# - Mossy train
# - Mossy plane
#
# 💾 Saving hallucinated class descriptors to: envisioned_classes/far_300/bird200_gpt-3.5-turbo_1.json
# === load json:  envisioned_classes/far_300/bird200_gpt-3.5-turbo_1.json
# Get Envisioned Candidate Class Names.
# After set: 174
# After removing ID class overlaps: 174
# Final ID Labels passed to CLIP: ['Black footed Albatross', 'Laysan Albatross', 'Sooty Albatross', 'Groove billed Ani', 'Crested Auklet', 'Least Auklet', 'Parakeet Auklet', 'Rhinoceros Auklet', 'Brewer Blackbird', 'Red winged Blackbird', 'Rusty Blackbird', 'Yellow headed Blackbird', 'Bobolink', 'Indigo Bunting', 'Lazuli Bunting', 'Painted Bunting', 'Cardinal', 'Spotted Catbird', 'Gray Catbird', 'Yellow breasted Chat', 'Eastern Towhee', 'Chuck will Widow', 'Brandt Cormorant', 'Red faced Cormorant', 'Pelagic Cormorant', 'Bronzed Cowbird', 'Shiny Cowbird', 'Brown Creeper', 'American Crow', 'Fish Crow', 'Black billed Cuckoo', 'Mangrove Cuckoo', 'Yellow billed Cuckoo', 'Gray crowned Rosy Finch', 'Purple Finch', 'Northern Flicker', 'Acadian Flycatcher', 'Great Crested Flycatcher', 'Least Flycatcher', 'Olive sided Flycatcher', 'Scissor tailed Flycatcher', 'Vermilion Flycatcher', 'Yellow bellied Flycatcher', 'Frigatebird', 'Northern Fulmar', 'Gadwall', 'American Goldfinch', 'European Goldfinch', 'Boat tailed Grackle', 'Eared Grebe', 'Horned Grebe', 'Pied billed Grebe', 'Western Grebe', 'Blue Grosbeak', 'Evening Grosbeak', 'Pine Grosbeak', 'Rose breasted Grosbeak', 'Pigeon Guillemot', 'California Gull', 'Glaucous winged Gull', 'Heermann Gull', 'Herring Gull', 'Ivory Gull', 'Ring billed Gull', 'Slaty backed Gull', 'Western Gull', 'Anna Hummingbird', 'Ruby throated Hummingbird', 'Rufous Hummingbird', 'Green Violetear', 'Long tailed Jaeger', 'Pomarine Jaeger', 'Blue Jay', 'Florida Jay', 'Green Jay', 'Dark eyed Junco', 'Tropical Kingbird', 'Gray Kingbird', 'Belted Kingfisher', 'Green Kingfisher', 'Pied Kingfisher', 'Ringed Kingfisher', 'White breasted Kingfisher', 'Red legged Kittiwake', 'Horned Lark', 'Pacific Loon', 'Mallard', 'Western Meadowlark', 'Hooded Merganser', 'Red breasted Merganser', 'Mockingbird', 'Nighthawk', 'Clark Nutcracker', 'White breasted Nuthatch', 'Baltimore Oriole', 'Hooded Oriole', 'Orchard Oriole', 'Scott Oriole', 'Ovenbird', 'Brown Pelican', 'White Pelican', 'Western Wood Pewee', 'Sayornis', 'American Pipit', 'Whip poor Will', 'Horned Puffin', 'Common Raven', 'White necked Raven', 'American Redstart', 'Geococcyx', 'Loggerhead Shrike', 'Great Grey Shrike', 'Baird Sparrow', 'Black throated Sparrow', 'Brewer Sparrow', 'Chipping Sparrow', 'Clay colored Sparrow', 'House Sparrow', 'Field Sparrow', 'Fox Sparrow', 'Grasshopper Sparrow', 'Harris Sparrow', 'Henslow Sparrow', 'Le Conte Sparrow', 'Lincoln Sparrow', 'Nelson Sharp tailed Sparrow', 'Savannah Sparrow', 'Seaside Sparrow', 'Song Sparrow', 'Tree Sparrow', 'Vesper Sparrow', 'White crowned Sparrow', 'White throated Sparrow', 'Cape Glossy Starling', 'Bank Swallow', 'Barn Swallow', 'Cliff Swallow', 'Tree Swallow', 'Scarlet Tanager', 'Summer Tanager', 'Artic Tern', 'Black Tern', 'Caspian Tern', 'Common Tern', 'Elegant Tern', 'Forsters Tern', 'Least Tern', 'Green tailed Towhee', 'Brown Thrasher', 'Sage Thrasher', 'Black capped Vireo', 'Blue headed Vireo', 'Philadelphia Vireo', 'Red eyed Vireo', 'Warbling Vireo', 'White eyed Vireo', 'Yellow throated Vireo', 'Bay breasted Warbler', 'Black and white Warbler', 'Black throated Blue Warbler', 'Blue winged Warbler', 'Canada Warbler', 'Cape May Warbler', 'Cerulean Warbler', 'Chestnut sided Warbler', 'Golden winged Warbler', 'Hooded Warbler', 'Kentucky Warbler', 'Magnolia Warbler', 'Mourning Warbler', 'Myrtle Warbler', 'Nashville Warbler', 'Orange crowned Warbler', 'Palm Warbler', 'Pine Warbler', 'Prairie Warbler', 'Prothonotary Warbler', 'Swainson Warbler', 'Tennessee Warbler', 'Wilson Warbler', 'Worm eating Warbler', 'Yellow Warbler', 'Northern Waterthrush', 'Louisiana Waterthrush', 'Bohemian Waxwing', 'Cedar Waxwing', 'American Three toed Woodpecker', 'Pileated Woodpecker', 'Red bellied Woodpecker', 'Red cockaded Woodpecker', 'Red headed Woodpecker', 'Downy Woodpecker', 'Bewick Wren', 'Cactus Wren', 'Carolina Wren', 'House Wren', 'Marsh Wren', 'Rock Wren', 'Winter Wren', 'Common Yellowthroat']
# Envisioned OOD labels (LLM): ['lunar crater', 'snowy mountains', 'sunflower fields', 'tulip festival', 'lavender fields', 'rainbow colors', 'stormy skies', 'mossy trail', 'lily pads', 'bamboo forest', 'mossy barrier', 'mossy wall', 'mossy creek', 'cactus landscape', 'star-filled sky', 'glacial landscape', 'cherry blossoms', 'moss-covered statue', 'volcano eruption', 'volcanic eruption', 'moss-covered bridge', 'moss-covered train', 'night cityscape', 'desert flora', 'sunflower garden', 'mossy bridge', 'moss-covered car', 'tropical beach', 'lavender rows', 'city park', 'aurora borealis', 'moss-covered rocks', 'mossy gate', 'wildflower field', 'water lilies', 'iceberg floating', 'mossy path', 'moss-covered ruins', 'mossy bench', 'fall colors', 'tulip bloom', 'tornado alley', 'cherry blossom trees', 'moss-covered steps', 'urban architecture', 'mossy fence', 'sandstone cliffs', 'mossy balcony', 'coral reef', 'lavender garden', 'tulip fields', 'mossy train', 'mossy ruins', 'mossy statue', 'starry night', 'moss-covered boat', 'lavender field', 'bamboo garden', 'mossy plane- desert oasis', 'mossy bicycle', 'mossy arch', 'tornado', 'cityscape view', 'autumn trees', 'solar eclipse', 'city skyline', 'moss-covered balcony', 'underwater world', 'autumn forest', 'tropical waterfall', 'cherry tree', 'double rainbow', 'solar flare', 'mountain lake', 'tropical paradise', 'wildflower meadow', 'sand dune', 'sandstone formations', 'sunflower patch', 'glacier', 'mossy aircraft- desert dunes', 'autumn foliage', 'snowy landscape', 'flower field', 'tulip display', 'mountain peak', 'tulip field', 'mossy steps', 'mossy entrance', 'volcanic ash', 'coral reef underwater', 'blossom trees', 'urban skyline', 'sunflower field', 'mossy pathway', 'mossy boulders', 'moss-covered sign', 'mossy car', 'solar panels', 'desert cactus', 'moss-covered wall', 'volcanic landscape', 'mossy bike', 'starry night sky', 'rainbow sky', 'desert plants', 'bamboo grove', 'moss-covered window', 'tulip season', 'fields of flowers', 'mossy door', 'glacial ice', 'waterfall', 'lunar surface', 'tulip garden', 'mossy sign', 'mossy stones', 'mountain stream', 'tornado warning', 'mossy seat', 'moss-covered gate', 'moss-covered pathway', 'moss-covered bench', 'mossy portal', 'mossy roof', 'lily pond', 'lunar landscape', 'milky way galaxy', 'glacial lake', 'moss-covered door', 'rainbow', 'sunset', 'storm clouds', 'mossy boat', 'moss-covered roof', 'mossy staircase', 'lunar eclipse', 'sand dunes', 'mossy vehicle', 'urban graffiti', 'mossy stairs', 'twisting tornado', 'lightning storm', 'mossy window', 'moss-covered bicycle', 'mossy rocks', 'starry sky', 'mossy forest floor', 'mossy vessel', 'mossy structure', 'snowy forest', 'underwater coral', 'mossy plane- desert canyon', 'thunderstorm clouds', 'solar system', 'iceberg melting', 'mossy shelter', 'snow-capped mountain', 'moss-covered forest', 'mossy sculpture', 'tropical island', 'moss-covered plane- desert oasis', 'mossy garden', 'city lights', 'ice cave', 'mossy plane', 'desert landscape', 'lavender farm', 'sunflower farm', 'iceberg', 'moss-covered fence', 'cactus garden', 'moss-covered tree trunk', 'mossy locomotive']
# 100%|██████████| 23/23 [01:21<00:00,  3.56s/it]
# 2025-07-12 20:00:59,734 : Evaluating OOD dataset dtd
# DEBUG:__main__:Evaluating OOD dataset dtd
# 100%|██████████| 23/23 [01:18<00:00,  3.43s/it]
# 2025-07-12 20:02:19,662 : in scores: DescribeResult(nobs=5794, minmax=(np.float32(-0.001268846), np.float32(-0.0008153755)), mean=np.float32(-0.0010550139), variance=np.float64(3.945031061937667e-09), skewness=np.float64(0.22572411596775055), kurtosis=np.float32(0.09471822))
# DEBUG:__main__:in scores: DescribeResult(nobs=5794, minmax=(np.float32(-0.001268846), np.float32(-0.0008153755)), mean=np.float32(-0.0010550139), variance=np.float64(3.945031061937667e-09), skewness=np.float64(0.22572411596775055), kurtosis=np.float32(0.09471822))
# 2025-07-12 20:02:19,667 : out scores: DescribeResult(nobs=5640, minmax=(np.float32(-0.0009116444), np.float32(-0.00047768373)), mean=np.float32(-0.0006825481), variance=np.float64(3.5824369279427572e-09), skewness=np.float64(-0.06077508628368378), kurtosis=np.float32(0.055977106))
# DEBUG:__main__:out scores: DescribeResult(nobs=5640, minmax=(np.float32(-0.0009116444), np.float32(-0.00047768373)), mean=np.float32(-0.0006825481), variance=np.float64(3.5824369279427572e-09), skewness=np.float64(-0.06077508628368378), kurtosis=np.float32(0.055977106))
# 2025-07-12 20:02:21,067 : 				EOE
# DEBUG:__main__:				EOE
# 2025-07-12 20:02:21,070 :   FPR95 AUROC AUPR
# DEBUG:__main__:  FPR95 AUROC AUPR
# 2025-07-12 20:02:21,084 : & 0.00 & 100.00 & 100.00
# DEBUG:__main__:& 0.00 & 100.00 & 100.00
# 2025-07-12 20:02:21,092 :
#
# Mean Test Results
# DEBUG:__main__:
#
# Mean Test Results
# 2025-07-12 20:02:21,102 : 				EOE
# DEBUG:__main__:				EOE
# 2025-07-12 20:02:21,111 :   FPR95 AUROC AUPR
# DEBUG:__main__:  FPR95 AUROC AUPR
# 2025-07-12 20:02:21,119 : & 0.00 & 100.00 & 100.00
# DEBUG:__main__:& 0.00 & 100.00 & 100.00

# %% [markdown]
# # **RUN EVALUATION PET37(ID) vs TEXTURE(OOD) at Beta 0.25 & 0.75, L=0,50,100,300**

# %%
import os
import openai
import re

client = openai.OpenAI(api_key=os.getenv("OPENAI_API_KEY"))

def fetch_synonym(name: str) -> str:
    system_prompt = (
        "You are a fine-grained classification assistant. "
        "When given a pet(including dogs and cats) species name, reply with *exactly one* known synonym or scientific name or name in other language. "
        "If no widely used alternative exists, reply with the original label and do not return *none*. "
        "Only return the name. Do not include explanations, punctuation, or prefixes.\n\n"
        "Here are a few examples:\n"
        "Input: American Goldfinch → Output: Eastern Goldfinch\n"
        "Input: Indigo Bunting → Output: Passerina cyanea\n"
        "Input: Bengal Cat → Output: Leopardette"
        "Input: Gadwall → Output: Anas strepera\n"
    )

    user_prompt = f"Class label: {name}"

    response = client.chat.completions.create(
        model="gpt-3.5-turbo",
        messages=[
            {"role": "system", "content": system_prompt},
            {"role": "user",   "content": user_prompt}
        ],
        temperature=0
    )

    raw = response.choices[0].message.content.strip()

    if ":" in raw:
        raw = raw.split(":")[-1].strip()
    if "known as" in raw:
        raw = re.split(r"known as", raw, flags=re.IGNORECASE)[-1].strip()

    return raw.rstrip(".")

# %%
import os
os.environ['CURL_CA_BUNDLE'] = ''
import argparse
import numpy as np
import torch
from scipy import stats

def main():
    args = process_args()
    setup_seed(args.seed)
    log = setup_log(args)
    assert torch.cuda.is_available()
    torch.cuda.set_device(args.gpu)

    net, preprocess = set_model_clip(args)
    net.eval()

    if args.in_dataset.startswith("ImageNet_C"):
        out_datasets = ['iNaturalist', 'SUN', 'places365', 'dtd']
    elif args.in_dataset == 'ImageNet':
        out_datasets = ['iNaturalist', 'SUN', 'places365', 'dtd'] if args.ood_task.startswith("far") else ['ssb_hard', 'ninco']
    else:
        out_datasets = dataset_mappings.get(args.in_dataset, [])

    test_loader = set_val_loader(args, preprocess)
    test_labels = list(get_test_labels(args, test_loader))
    print("✅ Original ID Labels:", test_labels)

    if args.score == 'EOE':
        print("🔮 Using LLM-generated OOD candidate classes...")
        base_ood_labels = load_llm_classes(args, test_labels)

        if args.use_synonyms:
            print("🔁 Augmenting OOD candidates with synonyms...")

            base_ood_labels = [lbl.strip().lower() for lbl in base_ood_labels]
            original_count = len(base_ood_labels)

            synonym_labels = []
            for lbl in base_ood_labels:
                syn = fetch_synonym(lbl).strip().lower()
                print(f"  → {lbl!r}  → synonym: {syn!r}")
                if syn != lbl:
                    synonym_labels.append(syn)

            combined = base_ood_labels + synonym_labels

            filtered = [label for label in combined if label and label.lower() not in {"none", "null"}]

            removed_count = len(combined) - len(filtered)
            print(f"Removed {removed_count} invalid synonym labels like 'none' or 'null'")

            llm_labels = list(dict.fromkeys(filtered))
            final_count = len(llm_labels)

            print(f"OOD classes before synonym expansion: {original_count}")
            print(f"OOD classes after synonym + deduplication: {final_count}")
        else:
            llm_labels = base_ood_labels
    else:
        llm_labels = []

    print(f"\n Final ID Labels passed to CLIP: {test_labels}")
    print(f"OOD candidate labels: {llm_labels}\n")

    in_score = get_ood_scores_clip(args, net, test_loader, test_labels, llm_labels)

    auroc_list, aupr_list, fpr_list = [], [], []
    for out_dataset in out_datasets:
        log.debug(f"Evaluating OOD dataset {out_dataset}")
        ood_loader = set_ood_loader(args, out_dataset, preprocess)
        out_score = get_ood_scores_clip(args, net, ood_loader, test_labels, llm_labels)

        log.debug(f"in scores: {stats.describe(in_score)}")
        log.debug(f"out scores: {stats.describe(out_score)}")
        plot_distribution(args, in_score, out_score, out_dataset)
        get_and_print_results(args, log, in_score, out_score, auroc_list, aupr_list, fpr_list)

    log.debug('\n\n Mean Test Results')
    print_measures(log, np.mean(auroc_list), np.mean(aupr_list),
                   np.mean(fpr_list), method_name=args.score)

    save_as_dataframe(args, out_datasets, fpr_list, auroc_list, aupr_list)


def process_args():
    parser = argparse.ArgumentParser(
        description='Leverage LLMs for OOD Detection',
        formatter_class=argparse.ArgumentDefaultsHelpFormatter
    )
    parser.add_argument('--in_dataset',
                        default='bird200',
                        choices=ALL_ID_DATASET,
                        help='in-distribution dataset')
    parser.add_argument('--root_dir',
                        default="datasets",
                        help='root dir of datasets')
    # prompt pipeline
    parser.add_argument('--ensemble',
                        action='store_true',
                        default=False,
                        help='CLIP text prompt engineering')
    parser.add_argument('--L',
                        type=int,
                        default=100,
                        help='the length of envisioned OOD class labels, for far/fine-grained: L=500, for near: L=3')
    parser.add_argument('--beta',
                        type=float,
                        default=0.25,
                        help='beta in Eq. 3')
    parser.add_argument('--ood_task',
                        type=str,
                        default='far',
                        choices=ALL_OOD_TASK,
                        help='choose ood task')
    parser.add_argument('--generate_class',
                        action='store_true',
                        help='whether to envision OOD candidate classes or loaded from existing JSONs')
    parser.add_argument('--json_number',
                        type=int,
                        default=0,
                        help='loaded json number')
    parser.add_argument('--llm_model',
                        default="gpt-3.5-turbo",
                        choices=ALL_LLM,
                        help='LLMs')
    parser.add_argument('--name',
                        default="eval_ood",
                        help="unique ID for the run")
    parser.add_argument('--seed',
                        type=int,
                        default=5,
                        help="random seed")
    parser.add_argument('--gpu',
                        type=int,
                        default=0,
                        help='the GPU indice to use')
    parser.add_argument('--batch_size',
                        type=int,
                        default=512,
                        help='mini-batch size')
    parser.add_argument('--T',
                        type=float,
                        default=1,
                        help='score temperature parameter')
    parser.add_argument('--model',
                        default='CLIP',
                        choices=['CLIP'],
                        help='model architecture')
    parser.add_argument('--CLIP_ckpt',
                        default='ViT-B/16',
                        choices=['ViT-B/16'],
                        help='which pretrained img encoder to use')
    parser.add_argument('--score',
                        default='EOE',
                        choices=['EOE', 'MCM', 'energy', 'max-logit'],
                        help='which scoring method')
    parser.add_argument('--score_ablation',
                        default='EOE',
                        choices=['MAX', 'MSP', 'energy', 'max-logit', 'EOE'],
                        help='ablations on the EOE score formula')
    parser.add_argument('--feat_dim',
                        type=int,
                        default=512,
                        help='feat dim, 512 for ViT-B and 768 for ViT-L')
    parser.add_argument('--use_synonyms',
                    default=False,
                    action='store_true',
                    help='Augment ID labels with synonyms using LLM')
    parser.add_argument('--prompt_pool_id',
                    type=int,
                    default=0,
                    help='Which index of openai_imagenet_template_subset to use when --ensemble')
    args = parser.parse_args()

    args.n_cls = get_num_cls(args)
    args.log_directory = f"results/{args.in_dataset}/{args.score}/" \
                         f"{args.model}_{args.CLIP_ckpt}_T_{args.T}_ID_{args.name}"
    os.makedirs(args.log_directory, exist_ok=True)

    return args

# %% [markdown]
# L = 0 (MCM)

# %%
# !pip install -q nest_asyncio
import nest_asyncio
nest_asyncio.apply()
import os
os.environ['CURL_CA_BUNDLE'] = ''
import argparse
import numpy as np
import torch
from scipy import stats
import sys

sys.argv = [
    "eval_ood_detection.py",
    "--name",        "PET37_TEXTURE_MCM_far_evaluation",
    "--in_dataset",  "pet37",
    "--ood_task",    "far",
    "--score",       "MCM",
    "--root_dir",    "datasets",
    "--batch_size",  "256",
    "--gpu",         "0",
    "--L",           "50",
]
main()
# Out:
# /usr/local/lib/python3.11/dist-packages/torch/utils/data/dataloader.py:624: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(
# Original ID Labels: ['Abyssinian', 'American Bulldog', 'American Pit Bull Terrier', 'Basset Hound', 'Beagle', 'Bengal', 'Birman', 'Bombay', 'Boxer', 'British Shorthair', 'Chihuahua', 'Egyptian Mau', 'English Cocker Spaniel', 'English Setter', 'German Shorthaired', 'Great Pyrenees', 'Havanese', 'Japanese Chin', 'Keeshond', 'Leonberger', 'Maine Coon', 'Miniature Pinscher', 'Newfoundland', 'Persian', 'Pomeranian', 'Pug', 'Ragdoll', 'Russian Blue', 'Saint Bernard', 'Samoyed', 'Scottish Terrier', 'Shiba Inu', 'Siamese', 'Sphynx', 'Staffordshire Bull Terrier', 'Wheaten Terrier', 'Yorkshire Terrier']
# Using original ID labels (no synonyms).
# Final ID Labels passed to CLIP: ['Abyssinian', 'American Bulldog', 'American Pit Bull Terrier', 'Basset Hound', 'Beagle', 'Bengal', 'Birman', 'Bombay', 'Boxer', 'British Shorthair', 'Chihuahua', 'Egyptian Mau', 'English Cocker Spaniel', 'English Setter', 'German Shorthaired', 'Great Pyrenees', 'Havanese', 'Japanese Chin', 'Keeshond', 'Leonberger', 'Maine Coon', 'Miniature Pinscher', 'Newfoundland', 'Persian', 'Pomeranian', 'Pug', 'Ragdoll', 'Russian Blue', 'Saint Bernard', 'Samoyed', 'Scottish Terrier', 'Shiba Inu', 'Siamese', 'Sphynx', 'Staffordshire Bull Terrier', 'Wheaten Terrier', 'Yorkshire Terrier']
# Envisioned OOD labels (LLM): []
# 100%|██████████| 15/15 [06:02<00:00, 24.17s/it]
# 2025-07-12 20:23:37,514 : Evaluating OOD dataset dtd
# DEBUG:__main__:Evaluating OOD dataset dtd
# 100%|██████████| 23/23 [01:14<00:00,  3.26s/it]
# 2025-07-12 20:24:52,875 : in scores: DescribeResult(nobs=3669, minmax=(np.float32(-0.032776862), np.float32(-0.028267441)), mean=np.float32(-0.030399622), variance=np.float64(4.845653849470043e-07), skewness=np.float64(-0.09211401641368866), kurtosis=np.float32(-0.060034513))
# DEBUG:__main__:in scores: DescribeResult(nobs=3669, minmax=(np.float32(-0.032776862), np.float32(-0.028267441)), mean=np.float32(-0.030399622), variance=np.float64(4.845653849470043e-07), skewness=np.float64(-0.09211401641368866), kurtosis=np.float32(-0.060034513))
# 2025-07-12 20:24:52,879 : out scores: DescribeResult(nobs=5640, minmax=(np.float32(-0.031989742), np.float32(-0.027364923)), mean=np.float32(-0.028026737), variance=np.float64(1.2536840454578997e-07), skewness=np.float64(-1.4906368255615234), kurtosis=np.float32(5.1149263))
# DEBUG:__main__:out scores: DescribeResult(nobs=5640, minmax=(np.float32(-0.031989742), np.float32(-0.027364923)), mean=np.float32(-0.028026737), variance=np.float64(1.2536840454578997e-07), skewness=np.float64(-1.4906368255615234), kurtosis=np.float32(5.1149263))
# 2025-07-12 20:24:53,400 : 				MCM
# DEBUG:__main__:				MCM
# 2025-07-12 20:24:53,401 :   FPR95 AUROC AUPR
# DEBUG:__main__:  FPR95 AUROC AUPR
# 2025-07-12 20:24:53,402 : & 0.80 & 99.82 & 99.62
# DEBUG:__main__:& 0.80 & 99.82 & 99.62
# 2025-07-12 20:24:53,404 :
#
# Mean Test Results
# DEBUG:__main__:
#
# Mean Test Results
# 2025-07-12 20:24:53,405 : 				MCM
# DEBUG:__main__:				MCM
# 2025-07-12 20:24:53,406 :   FPR95 AUROC AUPR
# DEBUG:__main__:  FPR95 AUROC AUPR
# 2025-07-12 20:24:53,407 : & 0.80 & 99.82 & 99.62
# DEBUG:__main__:& 0.80 & 99.82 & 99.62

# %% [markdown]
# L=50, Beta=0.25

# %%
sys.argv = [
    "eval_ood_detection.py",
    "--name",        "PET37_TEXTURE_50L_25B_far_evaluation",
    "--in_dataset",  "pet37",
    "--ood_task",    "far",
    "--score",       "EOE",
    "--root_dir",    "datasets",
    "--batch_size",  "256",
    "--gpu",         "0",
    "--L",           "50",
    "--generate_class",
]
main()
# Out:
# /usr/local/lib/python3.11/dist-packages/torch/utils/data/dataloader.py:624: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(
# Original ID Labels: ['Abyssinian', 'American Bulldog', 'American Pit Bull Terrier', 'Basset Hound', 'Beagle', 'Bengal', 'Birman', 'Bombay', 'Boxer', 'British Shorthair', 'Chihuahua', 'Egyptian Mau', 'English Cocker Spaniel', 'English Setter', 'German Shorthaired', 'Great Pyrenees', 'Havanese', 'Japanese Chin', 'Keeshond', 'Leonberger', 'Maine Coon', 'Miniature Pinscher', 'Newfoundland', 'Persian', 'Pomeranian', 'Pug', 'Ragdoll', 'Russian Blue', 'Saint Bernard', 'Samoyed', 'Scottish Terrier', 'Shiba Inu', 'Siamese', 'Sphynx', 'Staffordshire Bull Terrier', 'Wheaten Terrier', 'Yorkshire Terrier']
# Using original ID labels (no synonyms).
# Envisioning Outlier Exposure...
# 🔵 Generating via OpenAI GPT...
# 🔍 Raw GPT output:
#  - Sunflower
#         - Waterfall
#         - Desert
#         - Snowy Owl
#         - Coral Reef
#         - Bamboo Forest
#         - Aurora Borealis
#         - Red Panda
#         - Jellyfish
#         - Savannah
#         - Cherry Blossom
#         - Glacier
#         - Peacock
#         - Volcano
#         - Tundra
#         - Mangrove Forest
#         - Cactus
#         - Toucan
#         - Lighthouse
#         - Rainbow
#         - Fireworks
#         - Sand Dunes
#         - Northern Lights
#         - Orchid
#         - Water Lily
#         - Monarch Butterfly
#         - Rainbow Lorikeet
#         - Iceberg
#         - Pine Forest
#         - Sea Turtle
#         - Lavender Field
#         - Hummingbird
#         - Mushroom
#         - Starfish
#         - Dragonfly
#         - Waterfall
#         - Coral Reef
#         - Bamboo Forest
#         - Aurora Borealis
#         - Red Panda
#         - Jellyfish
#         - Savannah
#         - Cherry Blossom
#         - Glacier
#         - Peacock
#         - Volcano
#         - Tundra
#         - Mangrove Forest
#         - Cactus
#
# 💾 Saving hallucinated class descriptors to: envisioned_classes/far_50/pet37_gpt-3.5-turbo_0.json
# === load json:  envisioned_classes/far_50/pet37_gpt-3.5-turbo_0.json
# Get Envisioned Candidate Class Names.
# After set: 35
# After removing ID class overlaps: 35
# Final ID Labels passed to CLIP: ['Abyssinian', 'American Bulldog', 'American Pit Bull Terrier', 'Basset Hound', 'Beagle', 'Bengal', 'Birman', 'Bombay', 'Boxer', 'British Shorthair', 'Chihuahua', 'Egyptian Mau', 'English Cocker Spaniel', 'English Setter', 'German Shorthaired', 'Great Pyrenees', 'Havanese', 'Japanese Chin', 'Keeshond', 'Leonberger', 'Maine Coon', 'Miniature Pinscher', 'Newfoundland', 'Persian', 'Pomeranian', 'Pug', 'Ragdoll', 'Russian Blue', 'Saint Bernard', 'Samoyed', 'Scottish Terrier', 'Shiba Inu', 'Siamese', 'Sphynx', 'Staffordshire Bull Terrier', 'Wheaten Terrier', 'Yorkshire Terrier']
# Envisioned OOD labels (LLM): ['lighthouse', 'pine forest', 'coral reef', 'mushroom', 'monarch butterfly', 'sand dunes', 'rainbow lorikeet', 'lavender field', 'sea turtle', 'fireworks', 'northern lights', 'orchid', 'bamboo forest', 'sunflower', 'waterfall', 'cactus', 'desert', 'water lily', 'mangrove forest', 'savannah', 'starfish', 'tundra', 'glacier', 'aurora borealis', 'toucan', 'red panda', 'jellyfish', 'peacock', 'snowy owl', 'hummingbird', 'iceberg', 'dragonfly', 'cherry blossom', 'rainbow', 'volcano']
# 100%|██████████| 15/15 [00:54<00:00,  3.63s/it]
# 2025-07-12 20:25:56,871 : Evaluating OOD dataset dtd
# DEBUG:__main__:Evaluating OOD dataset dtd
# 100%|██████████| 23/23 [01:16<00:00,  3.32s/it]
# 2025-07-12 20:27:14,413 : in scores: DescribeResult(nobs=3669, minmax=(np.float32(-0.013311479), np.float32(-0.011055753)), mean=np.float32(-0.012259135), variance=np.float64(1.1295184995824713e-07), skewness=np.float64(0.02630564756691456), kurtosis=np.float32(0.11811662))
# DEBUG:__main__:in scores: DescribeResult(nobs=3669, minmax=(np.float32(-0.013311479), np.float32(-0.011055753)), mean=np.float32(-0.012259135), variance=np.float64(1.1295184995824713e-07), skewness=np.float64(0.02630564756691456), kurtosis=np.float32(0.11811662))
# 2025-07-12 20:27:14,418 : out scores: DescribeResult(nobs=5640, minmax=(np.float32(-0.012724882), np.float32(-0.010216387)), mean=np.float32(-0.010753742), variance=np.float64(3.242863902099852e-08), skewness=np.float64(-1.1554871797561646), kurtosis=np.float32(5.1262426))
# DEBUG:__main__:out scores: DescribeResult(nobs=5640, minmax=(np.float32(-0.012724882), np.float32(-0.010216387)), mean=np.float32(-0.010753742), variance=np.float64(3.242863902099852e-08), skewness=np.float64(-1.1554871797561646), kurtosis=np.float32(5.1262426))
# 2025-07-12 20:27:14,771 : 				EOE
# DEBUG:__main__:				EOE
# 2025-07-12 20:27:14,779 :   FPR95 AUROC AUPR
# DEBUG:__main__:  FPR95 AUROC AUPR
# 2025-07-12 20:27:14,782 : & 0.11 & 99.96 & 99.89
# DEBUG:__main__:& 0.11 & 99.96 & 99.89
# 2025-07-12 20:27:14,783 :
#
# Mean Test Results
# DEBUG:__main__:
#
# Mean Test Results
# 2025-07-12 20:27:14,784 : 				EOE
# DEBUG:__main__:				EOE
# 2025-07-12 20:27:14,785 :   FPR95 AUROC AUPR
# DEBUG:__main__:  FPR95 AUROC AUPR
# 2025-07-12 20:27:14,786 : & 0.11 & 99.96 & 99.89
# DEBUG:__main__:& 0.11 & 99.96 & 99.89

# %% [markdown]
# L=100, Beta=0.25

# %%
sys.argv = [
    "eval_ood_detection.py",
    "--name",        "PET37_TEXTURE_100L_25B_far_evaluation",
    "--in_dataset",  "pet37",
    "--ood_task",    "far",
    "--score",       "EOE",
    "--root_dir",    "datasets",
    "--batch_size",  "256",
    "--gpu",         "0",
    "--L",           "100",
    "--generate_class",
]
main()
# Out:
# /usr/local/lib/python3.11/dist-packages/torch/utils/data/dataloader.py:624: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(
# Original ID Labels: ['Abyssinian', 'American Bulldog', 'American Pit Bull Terrier', 'Basset Hound', 'Beagle', 'Bengal', 'Birman', 'Bombay', 'Boxer', 'British Shorthair', 'Chihuahua', 'Egyptian Mau', 'English Cocker Spaniel', 'English Setter', 'German Shorthaired', 'Great Pyrenees', 'Havanese', 'Japanese Chin', 'Keeshond', 'Leonberger', 'Maine Coon', 'Miniature Pinscher', 'Newfoundland', 'Persian', 'Pomeranian', 'Pug', 'Ragdoll', 'Russian Blue', 'Saint Bernard', 'Samoyed', 'Scottish Terrier', 'Shiba Inu', 'Siamese', 'Sphynx', 'Staffordshire Bull Terrier', 'Wheaten Terrier', 'Yorkshire Terrier']
# Using original ID labels (no synonyms).
# Envisioning Outlier Exposure...
# 🔵 Generating via OpenAI GPT...
# Continuing vision 1/1
# 🔍 Raw GPT output:
#  - Sunflower
# - Waterfall
# - Desert
# - Snowy Owl
# - Coral Reef
# - Bamboo Forest
# - Aurora Borealis
# - Red Panda
# - Jellyfish
# - Peacock
# - Cherry Blossoms
# - Elephant
# - Glacier
# - Rainbow Lorikeet
# - Fireworks
# - Lighthouse
# - Monarch Butterfly
# - Redwood Forest
# - Sea Turtle
# - Tulip Fields
# - White Tiger
# - Zebra
# - Kangaroo
# - Polar Bear
# - Cactus
# - Dolphin
# - Giraffe
# - Koala
# - Lion
# - Orca
# - Panda
# - Penguin
# - Rhino
# - Tiger
# - Wolf
# - Bald Eagle
# - Blue Morpho Butterfly
# - Elephant Seal
# - Flamingo
# - Golden Retriever
# - Hippopotamus
# - Jaguar
# - Kangaroo
# - Leopard
# - Macaw
# - Octopus
# - Peacock
# - Quetzal
# - Raccoon- Lavender Field
# - Sand Dunes
# - Northern Lights
# - Cherry Blossom
# - Water Lily
# - Mountain Range
# - Rainbow Trout
# - Coral Reef
# - Autumn Leaves
# - Snow Leopard
# - Cherry Blossoms
# - Desert Oasis
# - Northern Cardinal
# - Mountain Goat
# - Rainbow Lorikeet
# - Coral Reef
# - Autumn Forest
# - Snow Leopard
# - Cherry Blossoms
# - Desert Oasis
# - Northern Cardinal
# - Mountain Goat
# - Rainbow Lorikeet
# - Coral Reef
# - Autumn Forest
# - Snow Leopard
# - Cherry Blossoms
# - Desert Oasis
# - Northern Cardinal
# - Mountain Goat
# - Rainbow Lorikeet
# - Coral Reef
# - Autumn Forest
# - Snow Leopard
# - Cherry Blossoms
# - Desert Oasis
# - Northern Cardinal
# - Mountain Goat
# - Rainbow Lorikeet
# - Coral Reef
# - Autumn Forest
# - Snow Leopard
# - Cherry Blossoms
# - Desert Oasis
# - Northern Cardinal
# - Mountain Goat
#
# 💾 Saving hallucinated class descriptors to: envisioned_classes/far_100/pet37_gpt-3.5-turbo_0.json
# === load json:  envisioned_classes/far_100/pet37_gpt-3.5-turbo_0.json
# Get Envisioned Candidate Class Names.
# After set: 59
# After removing ID class overlaps: 59
# Final ID Labels passed to CLIP: ['Abyssinian', 'American Bulldog', 'American Pit Bull Terrier', 'Basset Hound', 'Beagle', 'Bengal', 'Birman', 'Bombay', 'Boxer', 'British Shorthair', 'Chihuahua', 'Egyptian Mau', 'English Cocker Spaniel', 'English Setter', 'German Shorthaired', 'Great Pyrenees', 'Havanese', 'Japanese Chin', 'Keeshond', 'Leonberger', 'Maine Coon', 'Miniature Pinscher', 'Newfoundland', 'Persian', 'Pomeranian', 'Pug', 'Ragdoll', 'Russian Blue', 'Saint Bernard', 'Samoyed', 'Scottish Terrier', 'Shiba Inu', 'Siamese', 'Sphynx', 'Staffordshire Bull Terrier', 'Wheaten Terrier', 'Yorkshire Terrier']
# Envisioned OOD labels (LLM): ['lighthouse', 'coral reef', 'tulip fields', 'monarch butterfly', 'sand dunes', 'mountain goat', 'rainbow lorikeet', 'sea turtle', 'fireworks', 'flamingo', 'northern cardinal', 'northern lights', 'bamboo forest', 'desert oasis', 'orca', 'quetzal', 'hippopotamus', 'raccoon- lavender field', 'blue morpho butterfly', 'wolf', 'rhino', 'cherry blossoms', 'sunflower', 'waterfall', 'dolphin', 'leopard', 'octopus', 'elephant', 'white tiger', 'cactus', 'desert', 'bald eagle', 'autumn forest', 'polar bear', 'water lily', 'penguin', 'giraffe', 'golden retriever', 'autumn leaves', 'macaw', 'elephant seal', 'lion', 'jaguar', 'glacier', 'aurora borealis', 'zebra', 'kangaroo', 'mountain range', 'panda', 'red panda', 'jellyfish', 'peacock', 'snowy owl', 'redwood forest', 'koala', 'cherry blossom', 'snow leopard', 'rainbow trout', 'tiger']
# 100%|██████████| 15/15 [00:50<00:00,  3.36s/it]
# 2025-07-12 20:28:15,782 : Evaluating OOD dataset dtd
# DEBUG:__main__:Evaluating OOD dataset dtd
# 100%|██████████| 23/23 [01:15<00:00,  3.28s/it]
# 2025-07-12 20:29:32,017 : in scores: DescribeResult(nobs=3669, minmax=(np.float32(-0.010083891), np.float32(-0.008347314)), mean=np.float32(-0.009197965), variance=np.float64(6.685597140820469e-08), skewness=np.float64(-0.07830316573381424), kurtosis=np.float32(0.0992794))
# DEBUG:__main__:in scores: DescribeResult(nobs=3669, minmax=(np.float32(-0.010083891), np.float32(-0.008347314)), mean=np.float32(-0.009197965), variance=np.float64(6.685597140820469e-08), skewness=np.float64(-0.07830316573381424), kurtosis=np.float32(0.0992794))
# 2025-07-12 20:29:32,022 : out scores: DescribeResult(nobs=5640, minmax=(np.float32(-0.009465594), np.float32(-0.007674936)), mean=np.float32(-0.008074825), variance=np.float64(1.8903328348759807e-08), skewness=np.float64(-1.028343677520752), kurtosis=np.float32(4.0489635))
# DEBUG:__main__:out scores: DescribeResult(nobs=5640, minmax=(np.float32(-0.009465594), np.float32(-0.007674936)), mean=np.float32(-0.008074825), variance=np.float64(1.8903328348759807e-08), skewness=np.float64(-1.028343677520752), kurtosis=np.float32(4.0489635))
# 2025-07-12 20:29:33,443 : 				EOE
# DEBUG:__main__:				EOE
# 2025-07-12 20:29:33,456 :   FPR95 AUROC AUPR
# DEBUG:__main__:  FPR95 AUROC AUPR
# 2025-07-12 20:29:33,464 : & 0.11 & 99.96 & 99.91
# DEBUG:__main__:& 0.11 & 99.96 & 99.91
# 2025-07-12 20:29:33,469 :
#
# Mean Test Results
# DEBUG:__main__:
#
# Mean Test Results
# 2025-07-12 20:29:33,476 : 				EOE
# DEBUG:__main__:				EOE
# 2025-07-12 20:29:33,482 :   FPR95 AUROC AUPR
# DEBUG:__main__:  FPR95 AUROC AUPR
# 2025-07-12 20:29:33,487 : & 0.11 & 99.96 & 99.91
# DEBUG:__main__:& 0.11 & 99.96 & 99.91

# %% [markdown]
# L=300, Beta=0.25

# %%
sys.argv = [
    "eval_ood_detection.py",
    "--name",        "PET37_TEXTURE_300L_25B_far_evaluation",
    "--in_dataset",  "pet37",
    "--ood_task",    "far",
    "--score",       "EOE",
    "--root_dir",    "datasets",
    "--batch_size",  "256",
    "--gpu",         "0",
    "--L",           "300",
    "--generate_class",
]
main()
# Out:
# /usr/local/lib/python3.11/dist-packages/torch/utils/data/dataloader.py:624: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(
# Original ID Labels: ['Abyssinian', 'American Bulldog', 'American Pit Bull Terrier', 'Basset Hound', 'Beagle', 'Bengal', 'Birman', 'Bombay', 'Boxer', 'British Shorthair', 'Chihuahua', 'Egyptian Mau', 'English Cocker Spaniel', 'English Setter', 'German Shorthaired', 'Great Pyrenees', 'Havanese', 'Japanese Chin', 'Keeshond', 'Leonberger', 'Maine Coon', 'Miniature Pinscher', 'Newfoundland', 'Persian', 'Pomeranian', 'Pug', 'Ragdoll', 'Russian Blue', 'Saint Bernard', 'Samoyed', 'Scottish Terrier', 'Shiba Inu', 'Siamese', 'Sphynx', 'Staffordshire Bull Terrier', 'Wheaten Terrier', 'Yorkshire Terrier']
# Using original ID labels (no synonyms).
# Envisioning Outlier Exposure...
# 🔵 Generating via OpenAI GPT...
# Continuing vision 1/5
# Continuing vision 2/5
# Continuing vision 3/5
# Continuing vision 4/5
# Continuing vision 5/5
# 🔍 Raw GPT output:
#  - Sunflower
#         - Waterfall
#         - Desert
#         - Snowy Owl
#         - Coral Reef
#         - Aurora Borealis
#         - Bamboo Forest
#         - Red Panda
#         - Jellyfish
#         - Savannah
#         - Glacier
#         - Volcano
#         - Peacock
#         - Cherry Blossom
#         - Koala
#         - Northern Lights
#         - Sand Dunes
#         - Orchid
#         - Toucan
#         - Monarch Butterfly
#         - Redwood Forest
#         - Sea Turtle
#         - Lavender Field
#         - Polar Bear
#         - Rainbow
#         - Lotus Flower
#         - Kangaroo
#         - Cactus
#         - Bald Eagle
#         - Tulip Field
#         - Dolphin
#         - Maple Tree
#         - Elephant
#         - Water Lily
#         - Mountain Goat
#         - Fireworks
#         - Pine Forest
#         - Kingfisher
#         - Bison
#         - Poppy Field
#         - Hummingbird
#         - Iceberg
#         - Sunflower Field
#         - Seahorse
#         - Mossy Forest
#         - Flamingo
#         - Sandstone Formation
#         - Blue Morpho Butterfly- Lighthouse Sunset
# - Alpine Meadow
# - Desert Oasis
# - Arctic Fox
# - Bioluminescent Bay
# - Rainbow Eucalyptus
# - Golden Eagle
# - Sakura Blossoms
# - African Savannah
# - Northern Lights
# - Coral Reef
# - Mountain Gorilla
# - Cherry Blossoms
# - Red Fox
# - Jellyfish Bloom
# - Bamboo Grove
# - Snow Leopard
# - Orchid Garden
# - Toucan Bird
# - Monarch Migration
# - Redwood Forest
# - Sea Lion
# - Lavender Fields
# - Polar Bear
# - Rainbow Falls
# - Lotus Pond
# - Kangaroo Joey
# - Cactus Garden
# - Bald Cypress
# - Tulip Garden
# - Dolphin Pod
# - Maple Forest
# - Elephant Herd
# - Water Lily Pond
# - Mountain Lion
# - Firefly Swarm
# - Pine Cone
# - Kingfisher Bird
# - Bison Herd
# - Poppy Field
# - Hummingbird Feeder
# - Ice Cave
# - Sunflower Maze
# - Seahorse Reef
# - Moss Covered
# - Flamingo Flock
# - Sandstone Arch
# - Blue Jay Bird- Desert Mirage
# - Alpine Lake
# - Arctic Wolf
# - Bioluminescent Plankton
# - Rainbow Trout
# - Golden Retriever
# - Sakura Tree
# - African Elephant
# - Northern Cardinal
# - Coral Reef Fish
# - Mountain Range
# - Cherry Orchard
# - Red Panda
# - Jellyfish Tank
# - Bamboo Shoots
# - Snowy Mountain
# - Orchid Bouquet
# - Toucan Beak
# - Monarch Caterpillar
# - Redwood Tree
# - Sea Anemone
# - Lavender Scent
# - Polar Ice
# - Rainbow Bridge
# - Lotus Blossom
# - Kangaroo Pouch
# - Cactus Flower
# - Bald Eagle Nest
# - Tulip Bulbs
# - Dolphin Dive
# - Maple Leaf
# - Elephant Trunk
# - Water Lily Pad
# - Mountain Peak
# - Fire Ants
# - Pine Cone Forest
# - Kingfisher Dive
# - Bison Stampede
# - Poppy Seed
# - Hummingbird Nest
# - Ice Cream
# - Sunflower Field
# - Seahorse Tail
# - Mossy Rock
# - Flamingo Dance
# - Sandstone Wall
# - Blue Whale- Desert Cactus Bloom
# - Alpine Cabin
# - Arctic Tundra
# - Bioluminescent Jellyfish
# - Rainbow Lorikeet
# - Golden Gate Bridge
# - Sakura Blossom Viewing
# - African Safari Sunset
# - Northern Lights Reflection
# - Coral Reef Diving
# - Mountain Reflection Lake
# - Cherry Blossom Festival
# - Red Rock Canyon
# - Jellyfish Aquarium Exhibit
# - Bamboo Forest Path
# - Snowy Owl Perched
# - Orchid Garden Show
# - Toucan Tropical Bird
# - Monarch Butterfly Garden
# - Redwood Forest Trail
# - Sea Turtle Swimming
# - Lavender Field Sunset
# - Polar Bear Cub
# - Rainbow Waterfall
# - Lotus Flower Pond
# - Kangaroo Jumping
# - Cactus Garden Desert
# - Bald Eagle Flying
# - Tulip Field Blooming
# - Dolphin Jumping Waves
# - Maple Tree Leaves
# - Elephant Family Herd
# - Water Lily Pond Reflection
# - Mountain Goat Climbing
# - Fireworks Display Night
# - Pine Forest Hiking
# - Kingfisher Fishing
# - Bison Herd Grazing
# - Poppy Field Blooms
# - Hummingbird Feeding
# - Iceberg Floating Ocean
# - Sunflower Field Harvest
# - Seahorse Underwater World
# - Mossy Forest Floor
# - Flamingo Flock Standing
# - Sandstone Canyon Walls
# - Blue Morpho Butterfly Wings- Desert Sand Dunes
# - Alpine Meadow Flowers
# - Arctic Iceberg Glacier
# - Bioluminescent Sea Creatures
# - Rainbow Waterfall Mist
# - Golden Wheat Fields
# - Sakura Cherry Blossoms
# - African Safari Animals
# - Northern Lights Sky
# - Coral Reef Underwater
# - Mountain Snowy Peaks
# - Cherry Blossom Petals
# - Red Rock Formation
# - Jellyfish Underwater World
# - Bamboo Forest Canopy
# - Snowy Mountain Summit
# - Orchid Flower Bouquet
# - Toucan Tropical Forest
# - Monarch Butterfly Migration
# - Redwood Forest Canopy
# - Sea Turtle Hatchlings
# - Lavender Field Sunrise
# - Polar Bear Arctic
# - Rainbow Reflection Lake
# - Lotus Flower Blooming
# - Kangaroo Outback
# - Cactus Desert Landscape
# - Bald Eagle Soaring
# - Tulip Field Sunset
# - Dolphin Pod Swimming
# - Maple Tree Forest
# - Elephant Safari Encounter
# - Water Lily Pond Lily Pads
# - Mountain Goat Cliff
# - Fireworks Night Sky
# - Pine Forest Pinecones
# - Kingfisher River
# - Bison Herd Roaming
# - Poppy Field Sunset
# - Hummingbird Garden Feeder
# - Iceberg Glacier Ice
# - Sunflower Field Sunset
# - Seahorse Coral Reef
# - Mossy Forest Trees
# - Flamingo Lake Shore
# - Sandstone Canyon Formation
# - Blue Morpho Butterfly Garden- Desert Oasis Sunset
# - Alpine Meadow Sunrise
# - Arctic Ice Cave
# - Bioluminescent Deep Sea
# - Rainbow Waterfall Rainbow
# - Golden Wheat Field
# - Sakura Cherry Blossom Festival
# - African Safari Landscape
# - Northern Lights Aurora
# - Coral Reef Marine Life
# - Mountain Snowy Forest
# - Cherry Blossom Garden
# - Red Rock Canyon Sunset
# - Jellyfish Ocean Life
# - Bamboo Forest Zen
# - Snowy Mountain Hike
# - Orchid Flower Garden
# - Toucan Rainforest Bird
# - Monarch Butterfly Garden
# - Redwood Forest Trail
# - Sea Turtle Beach
# - Lavender Field Sunset
# - Polar Bear Arctic Circle
# - Rainbow Reflection Pond
# - Lotus Flower Pond
# - Kangaroo Outback Adventure
# - Cactus Desert Sunset
# - Bald Eagle Flight
# - Tulip Field Sunrise
# - Dolphin Pod Jumping
# - Maple Tree Autumn
# - Elephant Safari Wildlife
# - Water Lily Pond Reflection
# - Mountain Goat Climbing Rocks
# - Fireworks Night Celebration
# - Pine Forest Trail
# - Kingfisher Bird Watching
# - Bison Herd Grazing Field
# - Poppy Field Sunrise
# - Hummingbird Feeding Time
# - Iceberg Glacier Melting
# - Sunflower Field Sunrise
# - Seahorse Underwater World
# - Mossy Forest Floor
# - Flamingo Lake Sunset
# - Sandstone Canyon Sunset
# - Blue Morpho Butterfly Garden
#
# 💾 Saving hallucinated class descriptors to: envisioned_classes/far_300/pet37_gpt-3.5-turbo_0.json
# === load json:  envisioned_classes/far_300/pet37_gpt-3.5-turbo_0.json
# Get Envisioned Candidate Class Names.
# After set: 265
# After removing ID class overlaps: 265
# Final ID Labels passed to CLIP: ['Abyssinian', 'American Bulldog', 'American Pit Bull Terrier', 'Basset Hound', 'Beagle', 'Bengal', 'Birman', 'Bombay', 'Boxer', 'British Shorthair', 'Chihuahua', 'Egyptian Mau', 'English Cocker Spaniel', 'English Setter', 'German Shorthaired', 'Great Pyrenees', 'Havanese', 'Japanese Chin', 'Keeshond', 'Leonberger', 'Maine Coon', 'Miniature Pinscher', 'Newfoundland', 'Persian', 'Pomeranian', 'Pug', 'Ragdoll', 'Russian Blue', 'Saint Bernard', 'Samoyed', 'Scottish Terrier', 'Shiba Inu', 'Siamese', 'Sphynx', 'Staffordshire Bull Terrier', 'Wheaten Terrier', 'Yorkshire Terrier']
# Envisioned OOD labels (LLM): ['flamingo flock standing', 'monarch butterfly', 'orchid bouquet', 'lavender field sunset', 'dolphin dive', 'blue whale- desert cactus bloom', 'african elephant', 'lavender field sunrise', 'water lily pond', 'flamingo', 'lavender fields', 'bison stampede', 'mountain goat climbing rocks', 'northern cardinal', 'sakura tree', 'bamboo forest', 'desert oasis', 'pine cone', 'fireworks display night', 'cherry blossoms', 'rainbow reflection lake', 'bald eagle flight', 'alpine meadow flowers', 'moss covered', 'iceberg glacier ice', 'bioluminescent bay', 'orchid flower garden', 'sandstone canyon walls', 'bald eagle', 'golden gate bridge', 'bamboo forest canopy', 'water lily pond reflection', 'dolphin jumping waves', 'polar bear', 'jellyfish bloom', 'elephant safari encounter', 'poppy field sunset', 'arctic ice cave', 'orchid garden show', 'arctic tundra', 'golden eagle', 'sakura blossoms', 'jellyfish ocean life', 'kingfisher bird', 'kangaroo outback adventure', 'snowy mountain', 'sunflower field sunset', 'aurora borealis', 'seahorse', 'red rock canyon sunset', 'rainbow waterfall', 'lotus blossom', 'pine cone forest', 'mountain goat cliff', 'peacock', 'hummingbird', 'blue morpho butterfly- lighthouse sunset', 'elephant herd', 'bioluminescent plankton', 'arctic iceberg glacier', 'bison herd roaming', 'mossy rock', 'red rock canyon', 'bamboo forest path', 'monarch migration', 'pine forest', 'alpine meadow sunrise', 'coral reef', 'lotus flower blooming', 'northern lights aurora', 'fireworks night celebration', 'polar bear arctic circle', 'jellyfish aquarium exhibit', 'lavender field', 'cactus garden desert', 'sea turtle', 'bioluminescent jellyfish', 'northern lights reflection', 'sakura cherry blossom festival', 'african safari animals', 'rainbow bridge', 'elephant trunk', 'hummingbird feeding time', 'pine forest hiking', 'rainbow falls', 'lotus pond', 'hummingbird feeding', 'fire ants', 'bald eagle flying', 'monarch butterfly garden', 'poppy field', 'seahorse reef', 'mountain reflection lake', 'flamingo dance', 'desert', 'african safari sunset', 'bison herd grazing', 'sea anemone', 'red fox', 'kingfisher bird watching', 'glacier', 'mountain range', 'sea turtle swimming', 'toucan', 'polar bear arctic', 'blue jay bird- desert mirage', 'mountain peak', 'alpine meadow', 'tulip field', 'flamingo lake shore', 'alpine cabin', 'kangaroo outback', 'koala', 'hummingbird garden feeder', 'kangaroo jumping', 'rainbow waterfall rainbow', 'rainbow trout', 'coral reef underwater', 'cherry blossom petals', 'cactus desert sunset', 'dolphin pod', 'coral reef fish', 'snowy owl perched', 'sunflower field', 'polar bear cub', 'sea turtle hatchlings', 'tulip field sunset', 'maple tree leaves', 'flamingo flock', 'tulip field sunrise', 'seahorse coral reef', 'ice cream', 'kangaroo joey', 'cactus flower', 'mountain gorilla', 'african savannah', 'bald eagle soaring', 'mountain snowy forest', 'red rock formation', 'sunflower field sunrise', 'bamboo grove', 'sandstone formation', 'northern lights', 'cherry orchard', 'bald eagle nest', 'mountain goat climbing', 'sunflower field harvest', 'mountain lion', 'elephant safari wildlife', 'flamingo lake sunset', 'cherry blossom festival', 'waterfall', 'lotus flower', 'rainbow eucalyptus', 'hummingbird nest', 'tulip garden', 'elephant', 'golden wheat fields', 'cactus', 'toucan bird', 'bison', 'pine forest pinecones', 'water lily', 'tulip bulbs', 'sandstone canyon formation', 'monarch caterpillar', 'northern lights sky', 'snowy mountain hike', 'toucan rainforest bird', 'maple tree autumn', 'bison herd grazing field', 'kangaroo', 'fireworks night sky', 'poppy field sunrise', 'maple tree', 'bamboo shoots', 'sakura blossom viewing', 'toucan beak', 'coral reef diving', 'sea turtle beach', 'jellyfish', 'redwood forest', 'snowy owl', 'poppy seed', 'tulip field blooming', 'bioluminescent sea creatures', 'african safari landscape', 'sakura cherry blossoms', 'sandstone canyon sunset', 'alpine lake', 'cherry b ...
# 100%|██████████| 15/15 [00:53<00:00,  3.55s/it]
# 2025-07-12 20:30:49,999 : Evaluating OOD dataset dtd
# DEBUG:__main__:Evaluating OOD dataset dtd
# 100%|██████████| 23/23 [01:20<00:00,  3.48s/it]
# 2025-07-12 20:32:11,122 : in scores: DescribeResult(nobs=3669, minmax=(np.float32(-0.0032523335), np.float32(-0.002677844)), mean=np.float32(-0.0030013663), variance=np.float64(7.130334166434969e-09), skewness=np.float64(0.044339511543512344), kurtosis=np.float32(0.15889883))
# DEBUG:__main__:in scores: DescribeResult(nobs=3669, minmax=(np.float32(-0.0032523335), np.float32(-0.002677844)), mean=np.float32(-0.0030013663), variance=np.float64(7.130334166434969e-09), skewness=np.float64(0.044339511543512344), kurtosis=np.float32(0.15889883))
# 2025-07-12 20:32:11,127 : out scores: DescribeResult(nobs=5640, minmax=(np.float32(-0.0030496938), np.float32(-0.0023782845)), mean=np.float32(-0.0025753442), variance=np.float64(2.984718989666653e-09), skewness=np.float64(-0.6385309100151062), kurtosis=np.float32(3.2196708))
# DEBUG:__main__:out scores: DescribeResult(nobs=5640, minmax=(np.float32(-0.0030496938), np.float32(-0.0023782845)), mean=np.float32(-0.0025753442), variance=np.float64(2.984718989666653e-09), skewness=np.float64(-0.6385309100151062), kurtosis=np.float32(3.2196708))
# 2025-07-12 20:32:11,471 : 				EOE
# DEBUG:__main__:				EOE
# 2025-07-12 20:32:11,472 :   FPR95 AUROC AUPR
# DEBUG:__main__:  FPR95 AUROC AUPR
# 2025-07-12 20:32:11,474 : & 0.09 & 99.97 & 99.92
# DEBUG:__main__:& 0.09 & 99.97 & 99.92
# 2025-07-12 20:32:11,476 :
#
# Mean Test Results
# DEBUG:__main__:
#
# Mean Test Results
# 2025-07-12 20:32:11,478 : 				EOE
# DEBUG:__main__:				EOE
# 2025-07-12 20:32:11,479 :   FPR95 AUROC AUPR
# DEBUG:__main__:  FPR95 AUROC AUPR
# 2025-07-12 20:32:11,480 : & 0.09 & 99.97 & 99.92
# DEBUG:__main__:& 0.09 & 99.97 & 99.92

# %% [markdown]
# L=50, Beta=0.75

# %%
sys.argv = [
    "eval_ood_detection.py",
    "--name",        "PET37_TEXTURE_50L_75B_far_evaluation",
    "--in_dataset",  "pet37",
    "--ood_task",    "far",
    "--score",       "EOE",
    "--root_dir",    "datasets",
    "--batch_size",  "256",
    "--gpu",         "0",
    "--L",           "50",
    "--beta",        "0.75",
    "--generate_class",
]
main()
# Out:
# /usr/local/lib/python3.11/dist-packages/torch/utils/data/dataloader.py:624: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(
# Original ID Labels: ['Abyssinian', 'American Bulldog', 'American Pit Bull Terrier', 'Basset Hound', 'Beagle', 'Bengal', 'Birman', 'Bombay', 'Boxer', 'British Shorthair', 'Chihuahua', 'Egyptian Mau', 'English Cocker Spaniel', 'English Setter', 'German Shorthaired', 'Great Pyrenees', 'Havanese', 'Japanese Chin', 'Keeshond', 'Leonberger', 'Maine Coon', 'Miniature Pinscher', 'Newfoundland', 'Persian', 'Pomeranian', 'Pug', 'Ragdoll', 'Russian Blue', 'Saint Bernard', 'Samoyed', 'Scottish Terrier', 'Shiba Inu', 'Siamese', 'Sphynx', 'Staffordshire Bull Terrier', 'Wheaten Terrier', 'Yorkshire Terrier']
# Using original ID labels (no synonyms).
# Envisioning Outlier Exposure...
# 🔵 Generating via OpenAI GPT...
# 🔍 Raw GPT output:
#  - Sunflower
#         - Waterfall
#         - Desert
#         - Snowy Owl
#         - Coral Reef
#         - Bamboo Forest
#         - Aurora Borealis
#         - Red Panda
#         - Jellyfish
#         - Savannah
#         - Cherry Blossom
#         - Glacier
#         - Peacock
#         - Volcano
#         - Tundra
#         - Mangrove Forest
#         - Cactus
#         - Toucan
#         - Monarch Butterfly
#         - Lighthouse
#         - Rainbow
#         - Sand Dunes
#         - Fireworks
#         - Northern Lights
#         - Orchid
#         - Water Lily
#         - Koala
#         - Seashell
#         - Maple Tree
#         - Polar Bear
#         - Dolphin
#         - Zebra
#         - Kangaroo
#         - Tiger
#         - Elephant
#         - Giraffe
#         - Lion
#         - Penguin
#         - Flamingo
#         - Hippopotamus
#         - Crocodile
#         - Gorilla
#         - Orangutan
#         - Rhinoceros
#         - Camel
#         - Ostrich
#         - Peafowl
#         - Lemur
#
# 💾 Saving hallucinated class descriptors to: envisioned_classes/far_50/pet37_gpt-3.5-turbo_1.json
# === load json:  envisioned_classes/far_50/pet37_gpt-3.5-turbo_1.json
# Get Envisioned Candidate Class Names.
# After set: 48
# After removing ID class overlaps: 48
# Final ID Labels passed to CLIP: ['Abyssinian', 'American Bulldog', 'American Pit Bull Terrier', 'Basset Hound', 'Beagle', 'Bengal', 'Birman', 'Bombay', 'Boxer', 'British Shorthair', 'Chihuahua', 'Egyptian Mau', 'English Cocker Spaniel', 'English Setter', 'German Shorthaired', 'Great Pyrenees', 'Havanese', 'Japanese Chin', 'Keeshond', 'Leonberger', 'Maine Coon', 'Miniature Pinscher', 'Newfoundland', 'Persian', 'Pomeranian', 'Pug', 'Ragdoll', 'Russian Blue', 'Saint Bernard', 'Samoyed', 'Scottish Terrier', 'Shiba Inu', 'Siamese', 'Sphynx', 'Staffordshire Bull Terrier', 'Wheaten Terrier', 'Yorkshire Terrier']
# Envisioned OOD labels (LLM): ['lighthouse', 'coral reef', 'orangutan', 'monarch butterfly', 'sand dunes', 'crocodile', 'fireworks', 'flamingo', 'peafowl', 'northern lights', 'orchid', 'bamboo forest', 'hippopotamus', 'camel', 'seashell', 'sunflower', 'waterfall', 'dolphin', 'ostrich', 'elephant', 'cactus', 'desert', 'polar bear', 'water lily', 'penguin', 'giraffe', 'mangrove forest', 'savannah', 'lion', 'tundra', 'glacier', 'aurora borealis', 'toucan', 'maple tree', 'zebra', 'kangaroo', 'gorilla', 'rhinoceros', 'red panda', 'jellyfish', 'peacock', 'snowy owl', 'lemur', 'koala', 'cherry blossom', 'rainbow', 'volcano', 'tiger']
# 100%|██████████| 15/15 [00:50<00:00,  3.38s/it]
# 2025-07-12 20:33:10,684 : Evaluating OOD dataset dtd
# DEBUG:__main__:Evaluating OOD dataset dtd
# 100%|██████████| 23/23 [01:16<00:00,  3.33s/it]
# 2025-07-12 20:34:28,055 : in scores: DescribeResult(nobs=3669, minmax=(np.float32(-0.005047529), np.float32(-0.0030310126)), mean=np.float32(-0.0041524223), variance=np.float64(8.787326557278475e-08), skewness=np.float64(-0.029869332909584045), kurtosis=np.float32(-0.050022364))
# DEBUG:__main__:in scores: DescribeResult(nobs=3669, minmax=(np.float32(-0.005047529), np.float32(-0.0030310126)), mean=np.float32(-0.0041524223), variance=np.float64(8.787326557278475e-08), skewness=np.float64(-0.029869332909584045), kurtosis=np.float32(-0.050022364))
# 2025-07-12 20:34:28,060 : out scores: DescribeResult(nobs=5640, minmax=(np.float32(-0.004463773), np.float32(-0.0018975567)), mean=np.float32(-0.0029051085), variance=np.float64(4.7477518649993213e-08), skewness=np.float64(0.47780874371528625), kurtosis=np.float32(2.422954))
# DEBUG:__main__:out scores: DescribeResult(nobs=5640, minmax=(np.float32(-0.004463773), np.float32(-0.0018975567)), mean=np.float32(-0.0029051085), variance=np.float64(4.7477518649993213e-08), skewness=np.float64(0.47780874371528625), kurtosis=np.float32(2.422954))
# 2025-07-12 20:34:29,676 : 				EOE
# DEBUG:__main__:				EOE
# 2025-07-12 20:34:29,684 :   FPR95 AUROC AUPR
# DEBUG:__main__:  FPR95 AUROC AUPR
# 2025-07-12 20:34:29,693 : & 0.11 & 99.94 & 99.87
# DEBUG:__main__:& 0.11 & 99.94 & 99.87
# 2025-07-12 20:34:29,700 :
#
# Mean Test Results
# DEBUG:__main__:
#
# Mean Test Results
# 2025-07-12 20:34:29,708 : 				EOE
# DEBUG:__main__:				EOE
# 2025-07-12 20:34:29,717 :   FPR95 AUROC AUPR
# DEBUG:__main__:  FPR95 AUROC AUPR
# 2025-07-12 20:34:29,726 : & 0.11 & 99.94 & 99.87
# DEBUG:__main__:& 0.11 & 99.94 & 99.87

# %% [markdown]
# L=100, Beta=0.75

# %%
sys.argv = [
    "eval_ood_detection.py",
    "--name",        "PET37_TEXTURE_100L_75B_far_evaluation",
    "--in_dataset",  "pet37",
    "--ood_task",    "far",
    "--score",       "EOE",
    "--root_dir",    "datasets",
    "--batch_size",  "256",
    "--gpu",         "0",
    "--L",           "100",
    "--beta",        "0.75",
    "--generate_class",
]
main()
# Out:
# /usr/local/lib/python3.11/dist-packages/torch/utils/data/dataloader.py:624: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(
# Original ID Labels: ['Abyssinian', 'American Bulldog', 'American Pit Bull Terrier', 'Basset Hound', 'Beagle', 'Bengal', 'Birman', 'Bombay', 'Boxer', 'British Shorthair', 'Chihuahua', 'Egyptian Mau', 'English Cocker Spaniel', 'English Setter', 'German Shorthaired', 'Great Pyrenees', 'Havanese', 'Japanese Chin', 'Keeshond', 'Leonberger', 'Maine Coon', 'Miniature Pinscher', 'Newfoundland', 'Persian', 'Pomeranian', 'Pug', 'Ragdoll', 'Russian Blue', 'Saint Bernard', 'Samoyed', 'Scottish Terrier', 'Shiba Inu', 'Siamese', 'Sphynx', 'Staffordshire Bull Terrier', 'Wheaten Terrier', 'Yorkshire Terrier']
# Using original ID labels (no synonyms).
# Envisioning Outlier Exposure...
# 🔵 Generating via OpenAI GPT...
# Continuing vision 1/1
# 🔍 Raw GPT output:
#  - Sunflower
# - Waterfall
# - Desert
# - Snowy Owl
# - Coral Reef
# - Bamboo Forest
# - Aurora Borealis
# - Red Panda
# - Jellyfish
# - Peacock
# - Cherry Blossoms
# - Elephant
# - Glacier
# - Rainbow Lorikeet
# - Fireworks
# - Lighthouse
# - Monarch Butterfly
# - Redwood Forest
# - Sea Turtle
# - Tulip Fields
# - White Tiger
# - Golden Retriever
# - African Elephant
# - Blue Morpho Butterfly
# - Cherry Blossom Tree
# - Dolphin
# - Golden Gate Bridge
# - Grand Canyon
# - Kangaroo
# - Koala
# - Lavender Fields
# - Northern Lights
# - Orca
# - Panda
# - Polar Bear
# - Redwood Tree
# - Sakura Tree
# - Savannah
# - Snow Leopard
# - Tiger Lily
# - Tropical Beach
# - Water Lily
# - Waterfall
# - White Sands
# - Wolf
# - Zebra
# - Bald Eagle
# - Blue Whale- Autumn Forest
# - Desert Oasis
# - Mountain Lake
# - Starry Night
# - Cherry Blossom
# - Sunset Beach
# - Mossy Forest
# - Rainbow Sky
# - Lavender Field
# - Snowy Mountain
# - Desert Dunes
# - Ocean Sunset
# - Misty Forest
# - Aurora Sky
# - Cherry Orchard
# - Moonlit Lake
# - Sunflower Field
# - Tropical Sunset
# - Bamboo Grove
# - Coral Reef
# - Mountain Peak
# - Desert Canyon
# - Starry Sky
# - Cherry Tree
# - Sunset Lake
# - Mossy Rocks
# - Rainbow Clouds
# - Lavender Garden
# - Snowy Forest
# - Desert Sunset
# - Ocean Waves
# - Misty Mountains
# - Aurora Borealis
# - Cherry Blossoms
# - Moonlit Forest
# - Sunflower Garden
# - Tropical Forest
# - Bamboo Forest
# - Coral Cove
# - Mountain Range
# - Desert Landscape
# - Starry Evening
# - Cherry Blossom Tree
# - Sunset Horizon
# - Mossy Trees
# - Rainbow Waterfall
# - Lavender Meadows
# - Snowy Woods
# - Desert Mirage
#
# 💾 Saving hallucinated class descriptors to: envisioned_classes/far_100/pet37_gpt-3.5-turbo_1.json
# === load json:  envisioned_classes/far_100/pet37_gpt-3.5-turbo_1.json
# Get Envisioned Candidate Class Names.
# After set: 90
# After removing ID class overlaps: 90
# Final ID Labels passed to CLIP: ['Abyssinian', 'American Bulldog', 'American Pit Bull Terrier', 'Basset Hound', 'Beagle', 'Bengal', 'Birman', 'Bombay', 'Boxer', 'British Shorthair', 'Chihuahua', 'Egyptian Mau', 'English Cocker Spaniel', 'English Setter', 'German Shorthaired', 'Great Pyrenees', 'Havanese', 'Japanese Chin', 'Keeshond', 'Leonberger', 'Maine Coon', 'Miniature Pinscher', 'Newfoundland', 'Persian', 'Pomeranian', 'Pug', 'Ragdoll', 'Russian Blue', 'Saint Bernard', 'Samoyed', 'Scottish Terrier', 'Shiba Inu', 'Siamese', 'Sphynx', 'Staffordshire Bull Terrier', 'Wheaten Terrier', 'Yorkshire Terrier']
# Envisioned OOD labels (LLM): ['monarch butterfly', 'misty forest', 'african elephant', 'lavender fields', 'sakura tree', 'bamboo forest', 'desert oasis', 'blue morpho butterfly', 'wolf', 'cherry blossoms', 'desert sunset', 'sunset lake', 'bald eagle', 'golden gate bridge', 'sunflower garden', 'polar bear', 'tropical beach', 'snowy mountain', 'aurora borealis', 'zebra', 'rainbow waterfall', 'aurora sky', 'tropical sunset', 'peacock', 'lighthouse', 'coral reef', 'lavender garden', 'tulip fields', 'starry night', 'snowy woods', 'lavender field', 'sea turtle', 'desert mirage', 'ocean sunset', 'desert', 'cherry tree', 'white sands', 'mountain lake', 'glacier', 'mountain range', 'panda', 'sunset horizon', 'mountain peak', 'misty mountains', 'koala', 'tropical forest', 'moonlit lake', 'cherry blossom tree', 'sunflower field', 'grand canyon', 'starry evening', 'rainbow sky', 'desert dunes', 'bamboo grove', 'cherry orchard', 'northern lights', 'orca', 'waterfall', 'tiger lily', 'elephant', 'water lily', 'sunset beach', 'moonlit forest', 'mossy trees', 'lavender meadows', 'kangaroo', 'jellyfish', 'redwood forest', 'snowy owl', 'cherry blossom', 'coral cove', 'rainbow lorikeet', 'fireworks', 'mossy rocks', 'starry sky', 'blue whale- autumn forest', 'redwood tree', 'sunflower', 'dolphin', 'snowy forest', 'white tiger', 'mossy forest', 'desert canyon', 'golden retriever', 'savannah', 'rainbow clouds', 'red panda', 'desert landscape', 'snow leopard', 'ocean waves']
# 100%|██████████| 15/15 [00:51<00:00,  3.44s/it]
# 2025-07-12 20:35:32,274 : Evaluating OOD dataset dtd
# DEBUG:__main__:Evaluating OOD dataset dtd
# 100%|██████████| 23/23 [01:14<00:00,  3.25s/it]
# 2025-07-12 20:36:47,374 : in scores: DescribeResult(nobs=3669, minmax=(np.float32(-0.0035372293), np.float32(-0.0019188747)), mean=np.float32(-0.0027935952), variance=np.float64(4.09949656947243e-08), skewness=np.float64(0.0779123529791832), kurtosis=np.float32(0.3014114))
# DEBUG:__main__:in scores: DescribeResult(nobs=3669, minmax=(np.float32(-0.0035372293), np.float32(-0.0019188747)), mean=np.float32(-0.0027935952), variance=np.float64(4.09949656947243e-08), skewness=np.float64(0.0779123529791832), kurtosis=np.float32(0.3014114))
# 2025-07-12 20:36:47,379 : out scores: DescribeResult(nobs=5640, minmax=(np.float32(-0.0030966308), np.float32(-0.0012856238)), mean=np.float32(-0.0019356434), variance=np.float64(2.3753034883328552e-08), skewness=np.float64(0.31553182005882263), kurtosis=np.float32(2.02149))
# DEBUG:__main__:out scores: DescribeResult(nobs=5640, minmax=(np.float32(-0.0030966308), np.float32(-0.0012856238)), mean=np.float32(-0.0019356434), variance=np.float64(2.3753034883328552e-08), skewness=np.float64(0.31553182005882263), kurtosis=np.float32(2.02149))
# 2025-07-12 20:36:48,325 : 				EOE
# DEBUG:__main__:				EOE
# 2025-07-12 20:36:48,331 :   FPR95 AUROC AUPR
# DEBUG:__main__:  FPR95 AUROC AUPR
# 2025-07-12 20:36:48,338 : & 0.14 & 99.90 & 99.81
# DEBUG:__main__:& 0.14 & 99.90 & 99.81
# 2025-07-12 20:36:48,339 :
#
# Mean Test Results
# DEBUG:__main__:
#
# Mean Test Results
# 2025-07-12 20:36:48,343 : 				EOE
# DEBUG:__main__:				EOE
# 2025-07-12 20:36:48,345 :   FPR95 AUROC AUPR
# DEBUG:__main__:  FPR95 AUROC AUPR
# 2025-07-12 20:36:48,346 : & 0.14 & 99.90 & 99.81
# DEBUG:__main__:& 0.14 & 99.90 & 99.81

# %% [markdown]
# L=300, Beta=0.75

# %%
sys.argv = [
    "eval_ood_detection.py",
    "--name",        "PET37_TEXTURE_300L_75B_far_evaluation",
    "--in_dataset",  "pet37",
    "--ood_task",    "far",
    "--score",       "EOE",
    "--root_dir",    "datasets",
    "--batch_size",  "256",
    "--gpu",         "0",
    "--L",           "300",
    "--beta",        "0.75",
    "--generate_class",
]
main()
# Out:
# /usr/local/lib/python3.11/dist-packages/torch/utils/data/dataloader.py:624: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(
# Original ID Labels: ['Abyssinian', 'American Bulldog', 'American Pit Bull Terrier', 'Basset Hound', 'Beagle', 'Bengal', 'Birman', 'Bombay', 'Boxer', 'British Shorthair', 'Chihuahua', 'Egyptian Mau', 'English Cocker Spaniel', 'English Setter', 'German Shorthaired', 'Great Pyrenees', 'Havanese', 'Japanese Chin', 'Keeshond', 'Leonberger', 'Maine Coon', 'Miniature Pinscher', 'Newfoundland', 'Persian', 'Pomeranian', 'Pug', 'Ragdoll', 'Russian Blue', 'Saint Bernard', 'Samoyed', 'Scottish Terrier', 'Shiba Inu', 'Siamese', 'Sphynx', 'Staffordshire Bull Terrier', 'Wheaten Terrier', 'Yorkshire Terrier']
# Using original ID labels (no synonyms).
# Envisioning Outlier Exposure...
# 🔵 Generating via OpenAI GPT...
# Continuing vision 1/5
# Continuing vision 2/5
# Continuing vision 3/5
# Continuing vision 4/5
# Continuing vision 5/5
# 🔍 Raw GPT output:
#  - Sunflower
# - Waterfall
# - Desert
# - Snowy Owl
# - Coral Reef
# - Bamboo Forest
# - Aurora Borealis
# - Red Panda
# - Jellyfish
# - Peacock
# - Cherry Blossoms
# - Elephant
# - Glacier
# - Rainbow Lorikeet
# - Fireworks
# - Lighthouse
# - Monarch Butterfly
# - Redwood Forest
# - Sea Turtle
# - Lavender Fields
# - Polar Bear
# - Volcano
# - Kangaroo
# - Tulip Fields
# - Northern Lights
# - Cactus
# - Bald Eagle
# - Sand Dunes
# - Orca
# - Sakura Tree
# - Golden Retriever
# - Cherry Blossom Tree
# - Blue Morpho Butterfly
# - Water Lily
# - Red Fox
# - Grand Canyon
# - Bald Cypress Tree
# - Kingfisher
# - African Elephant
# - Black Panther
# - Sunflower Field
# - Snow Leopard
# - Rainbow Trout
# - Coral Reef Fish
# - Arctic Fox
# - Waterfall
# - Desert Rose
# - Snowy Mountain
# - Coral Reef Landscape- Bamboo Grove
# - Sunset Beach
# - Mossy Forest
# - Starry Night
# - Autumn Leaves
# - Sandstone Arch
# - Moss Covered
# - Frozen Lake
# - Cherry Orchard
# - Mossy Rocks
# - Sunset Sky
# - Mossy Stream
# - Starry Sky
# - Autumn Forest
# - Sandstone Canyon
# - Mossy Path
# - Frozen River
# - Cherry Blossom
# - Mossy Tree
# - Sunset Lake
# - Mossy Waterfall
# - Starry Evening
# - Autumn Trees
# - Sandstone Formation
# - Mossy Wall
# - Frozen Waterfall
# - Cherry Tree
# - Mossy Bridge
# - Sunset Mountain
# - Mossy Trail
# - Starry Landscape
# - Autumn Landscape
# - Sandstone Rock
# - Mossy Pond
# - Frozen Forest
# - Cherry Blossom Tree
# - Mossy Hill
# - Sunset Forest
# - Mossy Creek
# - Starry Night Sky
# - Autumn Sunset
# - Sandstone Cliffs
# - Mossy Garden
# - Frozen Lake
# - Cherry Blossom Grove
# - Mossy Pathway
# - Sunset River
# - Mossy Wood
# - Starry Night Sky- Rustic Cabin
# - Misty Forest
# - Alpine Meadow
# - Coastal Cliff
# - Prairie Sunset
# - Urban Skyline
# - Tropical Paradise
# - Desert Oasis
# - Mountain Peak
# - Countryside Farm
# - Lakeside Retreat
# - Enchanted Forest
# - Seaside Village
# - Snowy Mountain
# - Wildflower Field
# - Ancient Ruins
# - Coastal Harbor
# - Mountain Range
# - Desert Dunes
# - Forest Path
# - Waterfall Oasis
# - Sunset Pier
# - Mountain Lake
# - Coastal Sunset
# - Desert Canyon
# - Forest Glade
# - River Rapids
# - Sunset Beach
# - Mountain Trail
# - Coastal Lighthouse
# - Desert Mirage
# - Forest Stream
# - Rocky Outcrop
# - Sunset Cliffs
# - Mountain Ridge
# - Coastal Cove
# - Desert Landscape
# - Forest Canopy
# - River Bend
# - Sunset Bay
# - Mountain Pass
# - Coastal Seaside
# - Desert Plants
# - Forest Clearing
# - River Delta
# - Sunset View
# - Mountain Valley
# - Coastal Rocks
# - Desert Rose- Urban Street
# - Tropical Beach
# - Mountain Forest
# - Coastal Waters
# - Prairie Landscape
# - Desert Cactus
# - Forest Wildlife
# - Waterfall Cascade
# - Sunset Horizon
# - Mountain Sunset
# - Countryside Road
# - Lakeside Serenity
# - Enchanted Garden
# - Seaside Sunset
# - Snowy Landscape
# - Wildflower Meadow
# - Ancient Temple
# - Coastal Resort
# - Mountain View
# - Desert Mirage
# - Forest Wildlife
# - Waterfall Pool
# - Sunset Glow
# - Mountain Hike
# - Coastal Marina
# - Desert Sands
# - Forest Pathway
# - River Reflections
# - Sunset Glow
# - Mountain Retreat
# - Coastal Retreat
# - Desert Oasis
# - Forest Wonderland
# - Rocky Mountains
# - Sunset Reflection
# - Mountain Vista
# - Coastal Cliffs
# - Desert Plants
# - Forest Canopy
# - River Rapids
# - Sunset Glow
# - Mountain Ridge
# - Coastal Paradise
# - Desert Dunes
# - Forest Trail
# - River Valley
# - Sunset Glow
# - Mountain Range
# - Coastal Waters
# - Desert Sunset- Urban Park
# - Tropical Island
# - Mountain Valley
# - Coastal Sunrise
# - Prairie Grasslands
# - Desert Landscape
# - Forest Canopy
# - Waterfall Rapids
# - Sunset Silhouette
# - Mountain Peak
# - Countryside View
# - Lakeside Reflection
# - Enchanted Lake
# - Seaside Retreat
# - Snowy Peak
# - Wildflower Garden
# - Ancient Castle
# - Coastal Cliffs
# - Mountain Ridge
# - Desert Oasis
# - Forest Path
# - Waterfall Cove
# - Sunset Reflection
# - Mountain Trail
# - Coastal Village
# - Desert Canyon
# - Forest Glade
# - River Bend
# - Sunset Pier
# - Mountain Lake
# - Coastal Sunset
# - Desert Dunes
# - Forest Stream
# - Rocky Outcrop
# - Sunset Cliffs
# - Mountain Range
# - Coastal Cove
# - Desert Landscape
# - Forest Canopy
# - River Bend
# - Sunset Bay
# - Mountain Pass
# - Coastal Seaside
# - Desert Plants
# - Forest Clearing
# - River Delta
# - Sunset View
# - Mountain Valley
# - Coastal Rocks
# - Desert Rose- Urban Skyline
# - Tropical Paradise
# - Mountain Peak
# - Coastal Cliff
# - Prairie Sunset
# - Desert Oasis
# - Forest Path
# - Waterfall Oasis
# - Sunset Pier
# - Mountain Lake
# - Countryside Farm
# - Lakeside Retreat
# - Enchanted Forest
# - Seaside Village
# - Snowy Mountain
# - Wildflower Field
# - Ancient Ruins
# - Coastal Harbor
# - Mountain Range
# - Desert Dunes
# - Forest Glade
# - River Rapids
# - Sunset Beach
# - Mountain Trail
# - Coastal Lighthouse
# - Desert Mirage
# - Forest Stream
# - Rocky Outcrop
# - Sunset Cliffs
# - Mountain Ridge
# - Coastal Cove
# - Desert Landscape
# - Forest Canopy
# - River Bend
# - Sunset Bay
# - Mountain Pass
# - Coastal Seaside
# - Desert Plants
# - Forest Clearing
# - River Delta
# - Sunset View
# - Mountain Valley
# - Coastal Rocks
# - Desert Rose
# - Forest Wildlife
# - Waterfall Cascade
# - Sunset Horizon
# - Mountain Sunset
# - Countryside Road
# - Lakeside Serenity
#
# 💾 Saving hallucinated class descriptors to: envisioned_classes/far_300/pet37_gpt-3.5-turbo_1.json
# === load json:  envisioned_classes/far_300/pet37_gpt-3.5-turbo_1.json
# Get Envisioned Candidate Class Names.
# After set: 191
# After removing ID class overlaps: 191
# Final ID Labels passed to CLIP: ['Abyssinian', 'American Bulldog', 'American Pit Bull Terrier', 'Basset Hound', 'Beagle', 'Bengal', 'Birman', 'Bombay', 'Boxer', 'British Shorthair', 'Chihuahua', 'Egyptian Mau', 'English Cocker Spaniel', 'English Setter', 'German Shorthaired', 'Great Pyrenees', 'Havanese', 'Japanese Chin', 'Keeshond', 'Leonberger', 'Maine Coon', 'Miniature Pinscher', 'Newfoundland', 'Persian', 'Pomeranian', 'Pug', 'Ragdoll', 'Russian Blue', 'Saint Bernard', 'Samoyed', 'Scottish Terrier', 'Shiba Inu', 'Siamese', 'Sphynx', 'Staffordshire Bull Terrier', 'Wheaten Terrier', 'Yorkshire Terrier']
# Envisioned OOD labels (LLM): ['coral reef landscape- bamboo grove', 'mountain retreat', 'sunset cliffs', 'sunset sky', 'monarch butterfly', 'coastal cove', 'misty forest', 'lakeside reflection', 'prairie sunset', 'african elephant', 'river reflections', 'forest wildlife', 'lavender fields', 'mossy trail', 'ancient ruins', 'sakura tree', 'bamboo forest', 'desert oasis', 'starry night sky- rustic cabin', 'mossy tree', 'blue morpho butterfly', 'mossy wall', 'black panther', 'mossy creek', 'sunset bay', 'seaside sunset', 'cherry blossoms', 'moss covered', 'sunset lake', 'enchanted garden', 'bald eagle', 'mossy bridge', 'coastal waters', 'polar bear', 'desert sands', 'enchanted forest', 'sunset glow', 'tropical beach', 'snowy mountain', 'countryside farm', 'aurora borealis', 'mossy path', 'wildflower field', 'coastal harbor', 'peacock', 'coastal cliff', 'wildflower garden', 'sunset mountain', 'waterfall pool', 'sandstone cliffs', 'waterfall oasis', 'mossy hill', 'lighthouse', 'coral reef', 'desert rose- urban street', 'tulip fields', 'starry night', 'cherry blossom grove', 'sea turtle', 'forest clearing', 'desert mirage', 'ancient temple', 'mossy wood', 'mountain view', 'bald cypress tree', 'sunset view', 'autumn trees', 'ancient castle', 'mountain ridge', 'desert', 'autumn forest', 'countryside road', 'coastal sunrise', 'seaside retreat', 'cherry tree', 'river rapids', 'red fox', 'mossy pond', 'mountain lake', 'tropical paradise', 'wildflower meadow', 'coastal village', 'glacier', 'mountain range', 'sunset horizon', 'snowy landscape', 'mountain valley', 'forest pathway', 'mountain peak', 'alpine meadow', 'coastal seaside', 'lakeside serenity', 'sandstone rock', 'rainbow trout', 'coral reef fish', 'urban skyline', 'sunflower field', 'cherry blossom tree', 'mossy pathway', 'grand canyon', 'prairie grasslands', 'forest glade', 'waterfall cascade', 'sunset silhouette', 'desert cactus', 'rocky mountains', 'enchanted lake', 'sandstone canyon', 'starry evening', 'starry night sky', 'forest path', 'desert plants', 'desert dunes', 'river delta', 'sandstone formation', 'cherry orchard', 'northern lights', 'river valley', 'orca', 'prairie landscape', 'waterfall', 'autumn landscape', 'elephant', 'desert rose- urban skyline', 'cactus', 'waterfall cove', 'coastal lighthouse', 'water lily', 'lakeside retreat', 'sunset beach', 'frozen lake', 'autumn leaves', 'mountain pass', 'desert sunset- urban park', 'coastal resort', 'mountain sunset', 'mountain trail', 'kangaroo', 'mossy waterfall', 'forest stream', 'jellyfish', 'forest wonderland', 'redwood forest', 'snowy owl', 'coastal sunset', 'forest trail', 'river bend', 'sunset forest', 'frozen river', 'cherry blossom', 'mountain forest', 'countryside view', 'autumn sunset', 'desert rose', 'forest canopy', 'coastal rocks', 'sand dunes', 'rainbow lorikeet', 'fireworks', 'mountain hike', 'sandstone arch', 'sunset pier', 'mossy stream', 'sunset river', 'mossy rocks', 'starry sky', 'coastal paradise', 'arctic fox', 'sunflower', 'starry landscape', 'mountain vista', 'coastal retreat', 'mossy forest', 'seaside village', 'desert canyon', 'golden retriever', 'tropical island', 'snowy peak', 'mossy garden', 'coastal marina', 'sunset reflection', 'frozen forest', 'kingfisher', 'waterfall rapids', 'frozen waterfall', 'red panda', 'desert landscape', 'coastal cliffs', 'snow leopard', 'volcano', 'rocky outcrop']
# 100%|██████████| 15/15 [00:53<00:00,  3.54s/it]
# 2025-07-12 20:38:03,777 : Evaluating OOD dataset dtd
# DEBUG:__main__:Evaluating OOD dataset dtd
# 100%|██████████| 23/23 [01:17<00:00,  3.37s/it]
# 2025-07-12 20:39:22,430 : in scores: DescribeResult(nobs=3669, minmax=(np.float32(-0.0019781082), np.float32(-0.0010767658)), mean=np.float32(-0.001598173), variance=np.float64(1.624450522915433e-08), skewness=np.float64(0.4758723974227905), kurtosis=np.float32(0.78232574))
# DEBUG:__main__:in scores: DescribeResult(nobs=3669, minmax=(np.float32(-0.0019781082), np.float32(-0.0010767658)), mean=np.float32(-0.001598173), variance=np.float64(1.624450522915433e-08), skewness=np.float64(0.4758723974227905), kurtosis=np.float32(0.78232574))
# 2025-07-12 20:39:22,435 : out scores: DescribeResult(nobs=5640, minmax=(np.float32(-0.0016648634), np.float32(-0.0005732365)), mean=np.float32(-0.0010668567), variance=np.float64(9.559140384731409e-09), skewness=np.float64(0.5885664820671082), kurtosis=np.float32(2.1581101))
# DEBUG:__main__:out scores: DescribeResult(nobs=5640, minmax=(np.float32(-0.0016648634), np.float32(-0.0005732365)), mean=np.float32(-0.0010668567), variance=np.float64(9.559140384731409e-09), skewness=np.float64(0.5885664820671082), kurtosis=np.float32(2.1581101))
# 2025-07-12 20:39:24,147 : 				EOE
# DEBUG:__main__:				EOE
# 2025-07-12 20:39:24,159 :   FPR95 AUROC AUPR
# DEBUG:__main__:  FPR95 AUROC AUPR
# 2025-07-12 20:39:24,166 : & 0.20 & 99.85 & 99.78
# DEBUG:__main__:& 0.20 & 99.85 & 99.78
# 2025-07-12 20:39:24,173 :
#
# Mean Test Results
# DEBUG:__main__:
#
# Mean Test Results
# 2025-07-12 20:39:24,181 : 				EOE
# DEBUG:__main__:				EOE
# 2025-07-12 20:39:24,182 :   FPR95 AUROC AUPR
# DEBUG:__main__:  FPR95 AUROC AUPR
# 2025-07-12 20:39:24,183 : & 0.20 & 99.85 & 99.78
# DEBUG:__main__:& 0.20 & 99.85 & 99.78
