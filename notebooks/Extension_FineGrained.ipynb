# %% [markdown]
# # **Pre-Installation**

# %%
# !pip install transformers timm seaborn openai fastapi_poe
# !pip install absl-py torch torchvision numpy scipy scikit-learn fastapi python-dotenv
# !pip install open_clip_torch
# Out:
# Requirement already satisfied: transformers in /usr/local/lib/python3.11/dist-packages (4.53.2)
# Requirement already satisfied: timm in /usr/local/lib/python3.11/dist-packages (1.0.17)
# Requirement already satisfied: seaborn in /usr/local/lib/python3.11/dist-packages (0.13.2)
# Requirement already satisfied: openai in /usr/local/lib/python3.11/dist-packages (1.96.1)
# Collecting fastapi_poe
#   Downloading fastapi_poe-0.0.66-py3-none-any.whl.metadata (2.4 kB)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from transformers) (3.18.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.30.0 in /usr/local/lib/python3.11/dist-packages (from transformers) (0.33.4)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.11/dist-packages (from transformers) (2.0.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from transformers) (25.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.11/dist-packages (from transformers) (6.0.2)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.11/dist-packages (from transformers) (2024.11.6)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from transformers) (2.32.3)
# Requirement already satisfied: tokenizers<0.22,>=0.21 in /usr/local/lib/python3.11/dist-packages (from transformers) (0.21.2)
# Requirement already satisfied: safetensors>=0.4.3 in /usr/local/lib/python3.11/dist-packages (from transformers) (0.5.3)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.11/dist-packages (from transformers) (4.67.1)
# Requirement already satisfied: torch in /usr/local/lib/python3.11/dist-packages (from timm) (2.6.0+cu124)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.11/dist-packages (from timm) (0.21.0+cu124)
# Requirement already satisfied: pandas>=1.2 in /usr/local/lib/python3.11/dist-packages (from seaborn) (2.2.2)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.4 in /usr/local/lib/python3.11/dist-packages (from seaborn) (3.10.0)
# Requirement already satisfied: anyio<5,>=3.5.0 in /usr/local/lib/python3.11/dist-packages (from openai) (4.9.0)
# Requirement already satisfied: distro<2,>=1.7.0 in /usr/local/lib/python3.11/dist-packages (from openai) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /usr/local/lib/python3.11/dist-packages (from openai) (0.28.1)
# Requirement already satisfied: jiter<1,>=0.4.0 in /usr/local/lib/python3.11/dist-packages (from openai) (0.10.0)
# Requirement already satisfied: pydantic<3,>=1.9.0 in /usr/local/lib/python3.11/dist-packages (from openai) (2.11.7)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.11/dist-packages (from openai) (1.3.1)
# Requirement already satisfied: typing-extensions<5,>=4.11 in /usr/local/lib/python3.11/dist-packages (from openai) (4.14.1)
# Requirement already satisfied: fastapi in /usr/local/lib/python3.11/dist-packages (from fastapi_poe) (0.116.1)
# Collecting httpx-sse (from fastapi_poe)
#   Downloading httpx_sse-0.4.1-py3-none-any.whl.metadata (9.4 kB)
# Collecting sse-starlette>=2.2.1 (from fastapi_poe)
#   Downloading sse_starlette-2.4.1-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: uvicorn in /usr/local/lib/python3.11/dist-packages (from fastapi_poe) (0.35.0)
# Requirement already satisfied: idna>=2.8 in /usr/local/lib/python3.11/dist-packages (from anyio<5,>=3.5.0->openai) (3.10)
# Requirement already satisfied: certifi in /usr/local/lib/python3.11/dist-packages (from httpx<1,>=0.23.0->openai) (2025.7.14)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.11/dist-packages (from httpx<1,>=0.23.0->openai) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.11/dist-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai) (0.16.0)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub<1.0,>=0.30.0->transformers) (2025.3.2)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.2 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub<1.0,>=0.30.0->transformers) (1.1.5)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (4.58.5)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.4.8)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.11/dist-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (11.2.1)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.11/dist-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas>=1.2->seaborn) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas>=1.2->seaborn) (2025.2)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.11/dist-packages (from pydantic<3,>=1.9.0->openai) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /usr/local/lib/python3.11/dist-packages (from pydantic<3,>=1.9.0->openai) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in /usr/local/lib/python3.11/dist-packages (from pydantic<3,>=1.9.0->openai) (0.4.1)
# Requirement already satisfied: starlette<0.48.0,>=0.40.0 in /usr/local/lib/python3.11/dist-packages (from fastapi->fastapi_poe) (0.47.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->transformers) (3.4.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->transformers) (2.4.0)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch->timm) (3.5)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch->timm) (3.1.6)
# Collecting nvidia-cuda-nvrtc-cu12==12.4.127 (from torch->timm)
#   Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-runtime-cu12==12.4.127 (from torch->timm)
#   Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-cupti-cu12==12.4.127 (from torch->timm)
#   Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cudnn-cu12==9.1.0.70 (from torch->timm)
#   Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cublas-cu12==12.4.5.8 (from torch->timm)
#   Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cufft-cu12==11.2.1.3 (from torch->timm)
#   Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-curand-cu12==10.3.5.147 (from torch->timm)
#   Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cusolver-cu12==11.6.1.9 (from torch->timm)
#   Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cusparse-cu12==12.3.1.170 (from torch->timm)
#   Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.2 in /usr/local/lib/python3.11/dist-packages (from torch->timm) (0.6.2)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch->timm) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch->timm) (12.4.127)
# Collecting nvidia-nvjitlink-cu12==12.4.127 (from torch->timm)
#   Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Requirement already satisfied: triton==3.2.0 in /usr/local/lib/python3.11/dist-packages (from torch->timm) (3.2.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch->timm) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch->timm) (1.3.0)
# Requirement already satisfied: click>=7.0 in /usr/local/lib/python3.11/dist-packages (from uvicorn->fastapi_poe) (8.2.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.4->seaborn) (1.17.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch->timm) (3.0.2)
# Downloading fastapi_poe-0.0.66-py3-none-any.whl (31 kB)
# Downloading sse_starlette-2.4.1-py3-none-any.whl (10 kB)
# Downloading httpx_sse-0.4.1-py3-none-any.whl (8.1 kB)
# Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl (363.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 4.1 MB/s eta 0:00:00
# Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (13.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 39.1 MB/s eta 0:00:00
# Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (24.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 39.8 MB/s eta 0:00:00
# Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (883 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 28.0 MB/s eta 0:00:00
# Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl (664.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.1 MB/s eta 0:00:00
# Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl (211.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 2.5 MB/s eta 0:00:00
# Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl (56.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 17.3 MB/s eta 0:00:00
# Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl (127.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 6.7 MB/s eta 0:00:00
# Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl (207.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 2.3 MB/s eta 0:00:00
# Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (21.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 60.6 MB/s eta 0:00:00
# Installing collected packages: nvidia-nvjitlink-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, httpx-sse, sse-starlette, nvidia-cusparse-cu12, nvidia-cudnn-cu12, nvidia-cusolver-cu12, fastapi_poe
#   Attempting uninstall: nvidia-nvjitlink-cu12
#     Found existing installation: nvidia-nvjitlink-cu12 12.5.82
#     Uninstalling nvidia-nvjitlink-cu12-12.5.82:
#       Successfully uninstalled nvidia-nvjitlink-cu12-12.5.82
#   Attempting uninstall: nvidia-curand-cu12
#     Found existing installation: nvidia-curand-cu12 10.3.6.82
#     Uninstalling nvidia-curand-cu12-10.3.6.82:
#       Successfully uninstalled nvidia-curand-cu12-10.3.6.82
#   Attempting uninstall: nvidia-cufft-cu12
#     Found existing installation: nvidia-cufft-cu12 11.2.3.61
#     Uninstalling nvidia-cufft-cu12-11.2.3.61:
#       Successfully uninstalled nvidia-cufft-cu12-11.2.3.61
#   Attempting uninstall: nvidia-cuda-runtime-cu12
#     Found existing installation: nvidia-cuda-runtime-cu12 12.5.82
#     Uninstalling nvidia-cuda-runtime-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-runtime-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-nvrtc-cu12
#     Found existing installation: nvidia-cuda-nvrtc-cu12 12.5.82
#     Uninstalling nvidia-cuda-nvrtc-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-nvrtc-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-cupti-cu12
#     Found existing installation: nvidia-cuda-cupti-cu12 12.5.82
#     Uninstalling nvidia-cuda-cupti-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-cupti-cu12-12.5.82
#   Attempting uninstall: nvidia-cublas-cu12
#     Found existing installation: nvidia-cublas-cu12 12.5.3.2
#     Uninstalling nvidia-cublas-cu12-12.5.3.2:
#       Successfully uninstalled nvidia-cublas-cu12-12.5.3.2
#   Attempting uninstall: nvidia-cusparse-cu12
#     Found existing installation: nvidia-cusparse-cu12 12.5.1.3
#     Uninstalling nvidia-cusparse-cu12-12.5.1.3:
#       Successfully uninstalled nvidia-cusparse-cu12-12.5.1.3
#   Attempting uninstall: nvidia-cudnn-cu12
#     Found existing installation: nvidia-cudnn-cu12 9.3.0.75
#     Uninstalling nvidia-cudnn-cu12-9.3.0.75:
#       Successfully uninstalled nvidia-cudnn-cu12-9.3.0.75
#   Attempting uninstall: nvidia-cusolver-cu12
#     Found existing installation: nvidia-cusolver-cu12 11.6.3.83
#     Uninstalling nvidia-cusolver-cu12-11.6.3.83:
#       Successfully uninstalled nvidia-cusolver-cu12-11.6.3.83
# Successfully installed fastapi_poe-0.0.66 httpx-sse-0.4.1 nvidia-cublas-cu12-12.4.5.8 nvidia-cuda-cupti-cu12-12.4.127 nvidia-cuda-nvrtc-cu12-12.4.127 nvidia-cuda-runtime-cu12-12.4.127 nvidia-cudnn-cu12-9.1.0.70 nvidia-cufft-cu12-11.2.1.3 nvidia-curand-cu12-10.3.5.147 nvidia-cusolver-cu12-11.6.1.9 nvidia-cusparse-cu12-12.3.1.170 nvidia-nvjitlink-cu12-12.4.127 sse-starlette-2.4.1
# Requirement already satisfied: absl-py in /usr/local/lib/python3.11/dist-packages (1.4.0)
# Requirement already satisfied: torch in /usr/local/lib/python3.11/dist-packages (2.6.0+cu124)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.11/dist-packages (0.21.0+cu124)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (2.0.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.11/dist-packages (1.15.3)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.11/dist-packages (1.6.1)
# Requirement already satisfied: fastapi in /usr/local/lib/python3.11/dist-packages (0.116.1)
# Collecting python-dotenv
#   Downloading python_dotenv-1.1.1-py3-none-any.whl.metadata (24 kB)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from torch) (3.18.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.11/dist-packages (from torch) (4.14.1)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch) (3.5)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch) (3.1.6)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.11/dist-packages (from torch) (2025.3.2)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch) (12.4.127)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch) (12.4.127)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch) (12.4.127)
# Requirement already satisfied: nvidia-cudnn-cu12==9.1.0.70 in /usr/local/lib/python3.11/dist-packages (from torch) (9.1.0.70)
# Requirement already satisfied: nvidia-cublas-cu12==12.4.5.8 in /usr/local/lib/python3.11/dist-packages (from torch) (12.4.5.8)
# Requirement already satisfied: nvidia-cufft-cu12==11.2.1.3 in /usr/local/lib/python3.11/dist-packages (from torch) (11.2.1.3)
# Requirement already satisfied: nvidia-curand-cu12==10.3.5.147 in /usr/local/lib/python3.11/dist-packages (from torch) (10.3.5.147)
# Requirement already satisfied: nvidia-cusolver-cu12==11.6.1.9 in /usr/local/lib/python3.11/dist-packages (from torch) (11.6.1.9)
# Requirement already satisfied: nvidia-cusparse-cu12==12.3.1.170 in /usr/local/lib/python3.11/dist-packages (from torch) (12.3.1.170)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.2 in /usr/local/lib/python3.11/dist-packages (from torch) (0.6.2)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch) (12.4.127)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch) (12.4.127)
# Requirement already satisfied: triton==3.2.0 in /usr/local/lib/python3.11/dist-packages (from torch) (3.2.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch) (1.3.0)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.11/dist-packages (from torchvision) (11.2.1)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn) (1.5.1)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn) (3.6.0)
# Requirement already satisfied: starlette<0.48.0,>=0.40.0 in /usr/local/lib/python3.11/dist-packages (from fastapi) (0.47.1)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,!=2.0.0,!=2.0.1,!=2.1.0,<3.0.0,>=1.7.4 in /usr/local/lib/python3.11/dist-packages (from fastapi) (2.11.7)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.11/dist-packages (from pydantic!=1.8,!=1.8.1,!=2.0.0,!=2.0.1,!=2.1.0,<3.0.0,>=1.7.4->fastapi) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /usr/local/lib/python3.11/dist-packages (from pydantic!=1.8,!=1.8.1,!=2.0.0,!=2.0.1,!=2.1.0,<3.0.0,>=1.7.4->fastapi) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in /usr/local/lib/python3.11/dist-packages (from pydantic!=1.8,!=1.8.1,!=2.0.0,!=2.0.1,!=2.1.0,<3.0.0,>=1.7.4->fastapi) (0.4.1)
# Requirement already satisfied: anyio<5,>=3.6.2 in /usr/local/lib/python3.11/dist-packages (from starlette<0.48.0,>=0.40.0->fastapi) (4.9.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch) (3.0.2)
# Requirement already satisfied: idna>=2.8 in /usr/local/lib/python3.11/dist-packages (from anyio<5,>=3.6.2->starlette<0.48.0,>=0.40.0->fastapi) (3.10)
# Requirement already satisfied: sniffio>=1.1 in /usr/local/lib/python3.11/dist-packages (from anyio<5,>=3.6.2->starlette<0.48.0,>=0.40.0->fastapi) (1.3.1)
# Downloading python_dotenv-1.1.1-py3-none-any.whl (20 kB)
# Installing collected packages: python-dotenv
# Successfully installed python-dotenv-1.1.1
# Collecting open_clip_torch
#   Downloading open_clip_torch-2.32.0-py3-none-any.whl.metadata (31 kB)
# Requirement already satisfied: torch>=1.9.0 in /usr/local/lib/python3.11/dist-packages (from open_clip_torch) (2.6.0+cu124)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.11/dist-packages (from open_clip_torch) (0.21.0+cu124)
# Requirement already satisfied: regex in /usr/local/lib/python3.11/dist-packages (from open_clip_torch) (2024.11.6)
# Collecting ftfy (from open_clip_torch)
#   Downloading ftfy-6.3.1-py3-none-any.whl.metadata (7.3 kB)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (from open_clip_torch) (4.67.1)
# Requirement already satisfied: huggingface-hub in /usr/local/lib/python3.11/dist-packages (from open_clip_torch) (0.33.4)
# Requirement already satisfied: safetensors in /usr/local/lib/python3.11/dist-packages (from open_clip_torch) (0.5.3)
# Requirement already satisfied: timm in /usr/local/lib/python3.11/dist-packages (from open_clip_torch) (1.0.17)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from torch>=1.9.0->open_clip_torch) (3.18.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.11/dist-packages (from torch>=1.9.0->open_clip_torch) (4.14.1)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch>=1.9.0->open_clip_torch) (3.5)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch>=1.9.0->open_clip_torch) (3.1.6)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.11/dist-packages (from torch>=1.9.0->open_clip_torch) (2025.3.2)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=1.9.0->open_clip_torch) (12.4.127)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=1.9.0->open_clip_torch) (12.4.127)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=1.9.0->open_clip_torch) (12.4.127)
# Requirement already satisfied: nvidia-cudnn-cu12==9.1.0.70 in /usr/local/lib/python3.11/dist-packages (from torch>=1.9.0->open_clip_torch) (9.1.0.70)
# Requirement already satisfied: nvidia-cublas-cu12==12.4.5.8 in /usr/local/lib/python3.11/dist-packages (from torch>=1.9.0->open_clip_torch) (12.4.5.8)
# Requirement already satisfied: nvidia-cufft-cu12==11.2.1.3 in /usr/local/lib/python3.11/dist-packages (from torch>=1.9.0->open_clip_torch) (11.2.1.3)
# Requirement already satisfied: nvidia-curand-cu12==10.3.5.147 in /usr/local/lib/python3.11/dist-packages (from torch>=1.9.0->open_clip_torch) (10.3.5.147)
# Requirement already satisfied: nvidia-cusolver-cu12==11.6.1.9 in /usr/local/lib/python3.11/dist-packages (from torch>=1.9.0->open_clip_torch) (11.6.1.9)
# Requirement already satisfied: nvidia-cusparse-cu12==12.3.1.170 in /usr/local/lib/python3.11/dist-packages (from torch>=1.9.0->open_clip_torch) (12.3.1.170)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.2 in /usr/local/lib/python3.11/dist-packages (from torch>=1.9.0->open_clip_torch) (0.6.2)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch>=1.9.0->open_clip_torch) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=1.9.0->open_clip_torch) (12.4.127)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=1.9.0->open_clip_torch) (12.4.127)
# Requirement already satisfied: triton==3.2.0 in /usr/local/lib/python3.11/dist-packages (from torch>=1.9.0->open_clip_torch) (3.2.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch>=1.9.0->open_clip_torch) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch>=1.9.0->open_clip_torch) (1.3.0)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.11/dist-packages (from ftfy->open_clip_torch) (0.2.13)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub->open_clip_torch) (25.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub->open_clip_torch) (6.0.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from huggingface-hub->open_clip_torch) (2.32.3)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.2 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub->open_clip_torch) (1.1.5)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from torchvision->open_clip_torch) (2.0.2)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.11/dist-packages (from torchvision->open_clip_torch) (11.2.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch>=1.9.0->open_clip_torch) (3.0.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->huggingface-hub->open_clip_torch) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->huggingface-hub->open_clip_torch) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->huggingface-hub->open_clip_torch) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests->huggingface-hub->open_clip_torch) (2025.7.14)
# Downloading open_clip_torch-2.32.0-py3-none-any.whl (1.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 36.6 MB/s eta 0:00:00
# Downloading ftfy-6.3.1-py3-none-any.whl (44 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.8/44.8 kB 4.3 MB/s eta 0:00:00
# Installing collected packages: ftfy, open_clip_torch
# Successfully installed ftfy-6.3.1 open_clip_torch-2.32.0

# %%
import os
os.environ['OPENAI_API_KEY'] = 'YOUR_OPENAI_API_KEY'

# %% [markdown]
# # **args_pool**

# %%
ALL_ID_DATASET = [
    'bird200', 'pet37', 'cub100_ID', 'pet18_ID', 'cifar10_ID'
]

ALL_OOD_TASK = [
    'far', 'fine_grained', 'near'
]

ALL_LLM = [
    'gpt-3.5-turbo', 'gpt-3.5-turbo-16k', 'gpt-4'
]

dataset_mappings = {
    'bird200': ['dtd'],
    'pet37': ['dtd'],
    'cub100_ID': ['cub100_OOD'],
    'pet18_ID': ['pet19_OOD'],
    'cifar10_ID': ['cifar100_OOD']
}

# %% [markdown]
# # **common**

# %%
import torch
import torch.nn.functional as F
import os
import numpy as np
import json
import random
import ast
import logging

seed = 5

def setup_seed(seed):
    torch.manual_seed(seed)
    torch.cuda.manual_seed(seed)
    np.random.seed(seed)
    random.seed(seed)

    def get_test_labels(args, loader=None):
        if args.in_dataset in ['bird200', 'pet37', 'cub100_ID', 'pet18_ID']:
            test_labels = loader.dataset.class_names_str
        elif args.in_dataset in ['dtd', 'cifar10_ID', 'cifar100_OOD']:
            test_labels = loader.dataset.classes
        else:
            raise ValueError(f"Unknown dataset for labels: {args.in_dataset}")
        return test_labels

def get_num_cls(args):
    NUM_CLS_DICT = {
        'bird200': 200,
        'pet37': 37,
        'dtd': 47,
        'cub100_ID': 100,
        'cub100_OOD': 100,
        'pet18_ID': 18,
        'pet19_OOD': 19,
        'cifar10_ID': 10,
        'cifar100_OOD': 100,
    }
    try:
        n_cls = NUM_CLS_DICT[args.in_dataset]
    except KeyError:
        raise ValueError(f"Unknown dataset: {args.in_dataset}")
    return n_cls

# %% [markdown]
# # **imagenet-template (only if ensemble activated)**

# %%
openai_imagenet_template_subset = {
    0: [
    lambda c: f'a photo of a {c}.',
    lambda c: f'a blurry photo of a {c}.',
    lambda c: f'a photo of many {c}.',
    lambda c: f'a photo of the large {c}.',
    lambda c: f'a photo of the small {c}.',
    ],
}

# %% [markdown]
# # **detection util**

# %%
import torch
import numpy as np
from tqdm import tqdm
import sklearn.metrics as sk
from transformers import CLIPTokenizer
import torch.nn.functional as F

def clip_text_ens(net, tokenizer, test_labels, prompt_pool):
    prompts = [template(label) for label in test_labels for template in prompt_pool]
    text_inputs = tokenizer(
        prompts,
        padding=True,
        truncation=True,
        max_length=tokenizer.model_max_length,
        return_tensors="pt"
    )
    features = net.get_text_features(
        input_ids=text_inputs['input_ids'].cuda(),
        attention_mask=text_inputs['attention_mask'].cuda()
    ).float()

    text_features = torch.zeros(len(test_labels), features.shape[1]).cuda()
    num_templates = len(prompt_pool)
    for i in range(len(test_labels)):
        for j in range(num_templates):
            idx = i * num_templates + j
            normed = features[idx] / features[idx].norm(dim=-1, keepdim=True)
            text_features[i] += normed
    return text_features

def pre_filter(net, tokenizer, test_labels, gpt_labels, args, prompt_pool=None):
    net.eval()
    if not args.ensemble:
        test_prompts = [f"a photo of a {c}" for c in test_labels]
        gpt_prompts  = [f"a photo of a {c}" for c in gpt_labels]

        test_in = tokenizer(
            test_prompts,
            padding=True,
            truncation=True,
            max_length=tokenizer.model_max_length,
            return_tensors="pt"
        )
        gpt_in  = tokenizer(
            gpt_prompts,
            padding=True,
            truncation=True,
            max_length=tokenizer.model_max_length,
            return_tensors="pt"
        )

        test_feats = net.get_text_features(
            input_ids=test_in['input_ids'].cuda(),
            attention_mask=test_in['attention_mask'].cuda()
        ).float()
        gpt_feats  = net.get_text_features(
            input_ids=gpt_in['input_ids'].cuda(),
            attention_mask=gpt_in['attention_mask'].cuda()
        ).float()

    else:
        test_feats = clip_text_ens(net, tokenizer, test_labels, prompt_pool)
        gpt_feats  = clip_text_ens(net, tokenizer, gpt_labels,  prompt_pool)

    return torch.cat((test_feats, gpt_feats), dim=0)

def remove_overlap_class(test_labels, gpt_labels):
    words_set = {word for phrase in test_labels for word in phrase.split()}
    gpt_labels = [phrase for phrase in gpt_labels if not any(word in words_set for word in phrase.split())]

    return gpt_labels

def get_ood_scores_clip(args, net, loader, test_labels, gpt_labels, softmax = True):
    net.eval()
    to_np = lambda x: x.data.cpu().numpy()
    concat = lambda x: np.concatenate(x, axis=0)
    _score = []
    id_class_nums = len(test_labels)
    if args.model == 'CLIP':
        tokenizer = CLIPTokenizer.from_pretrained(args.ckpt)

    tqdm_object = tqdm(loader, total=len(loader))
    with torch.no_grad():
        for batch_idx, (images, labels) in enumerate(tqdm_object):
            labels = labels.long().cuda()
            images = images.cuda()

            image_features = net.get_image_features(pixel_values = images).float()
            image_features /= image_features.norm(dim=-1, keepdim=True)
            if args.score in ['MCM', 'energy', 'max-logit']:
                if not args.ensemble:
                    text_inputs = tokenizer([f"a photo of a {c}" for c in test_labels], padding=True, return_tensors="pt")
                    text_features = net.get_text_features(input_ids = text_inputs['input_ids'].cuda(),
                                                    attention_mask = text_inputs['attention_mask'].cuda()).float()
                else:
                    text_features = clip_text_ens(net, tokenizer, test_labels)
                text_features /= text_features.norm(dim=-1, keepdim=True)
                output = image_features @ text_features.T
            elif args.score == 'EOE':
                if args.ood_task == 'near':
                    gpt_labels = remove_overlap_class(test_labels, gpt_labels)
                total_features = pre_filter(net, tokenizer, test_labels, gpt_labels, args)
                total_features /= total_features.norm(dim=-1, keepdim=True)
                output = image_features @ total_features.T

            if softmax:
                smax = to_np(F.softmax(output/ args.T, dim=1))
            else:
                smax = to_np(output/ args.T)

            # cal score
            if args.score == 'EOE':
                if args.score_ablation == 'EOE':
                    smax = np.max(smax[:, :id_class_nums], axis=1) - args.beta * np.max(smax[:, id_class_nums:], axis=1)
                    _score.append(-smax)
                elif args.score_ablation == 'MAX':
                    iid_values, iid_indices = torch.max(output[:, :id_class_nums], dim=1)
                    ood_values, ood_indices = torch.max(output[:, id_class_nums:], dim=1)
                    condition = ood_values > iid_values
                    output[:, :id_class_nums][condition] = 1/id_class_nums
                    output = output[:, :id_class_nums]
                    smax = to_np(F.softmax(output/ args.T, dim=1))
                    smax = np.max(smax[:, :id_class_nums], axis=1)
                    _score.append(-smax)
                elif args.score_ablation == 'MSP':
                    smax = np.max(smax[:, :id_class_nums], axis=1)
                    _score.append(-smax)
                elif args.score_ablation == 'energy':
                    _score.append(-to_np((args.T*torch.logsumexp(output[:, :id_class_nums] / args.T, dim=1)) - (args.T*torch.logsumexp(output[:, id_class_nums:] / args.T, dim=1))))
                elif args.score_ablation == 'max-logit':
                    _score.append(-to_np(torch.max(output[:, :id_class_nums], 1)[0] - torch.max(output[:, id_class_nums:], 1)[0]))
                else:
                    raise NotImplementedError
            elif args.score == 'MCM':
                _score.append(-np.max(smax, axis=1))
            elif args.score == 'energy':
                #Energy = - T * logsumexp(logit_k / T), by default T = 1 in https://arxiv.org/pdf/2010.03759.pdf
                _score.append(-to_np((args.T*torch.logsumexp(output / args.T, dim=1))))  #energy score is expected to be smaller for ID
            elif args.score == 'max-logit':
                _score.append(-to_np(torch.max(output, 1)[0]))

    return concat(_score)[:len(loader.dataset)].copy()

# Metric Calculations
def stable_cumsum(arr, rtol=1e-05, atol=1e-08):
    out = np.cumsum(arr, dtype=np.float64)
    expected = np.sum(arr, dtype=np.float64)
    if not np.allclose(out[-1], expected, rtol=rtol, atol=atol):
        raise RuntimeError('unstable cumsum')
    return out

def fpr_and_fdr_at_recall(y_true, y_score, recall_level=0.95, pos_label=1):
    y_true = (y_true == pos_label)
    desc_score_indices = np.argsort(y_score)[::-1]
    y_score = y_score[desc_score_indices]
    y_true = y_true[desc_score_indices]
    distinct_value_indices = np.where(np.diff(y_score))[0]
    threshold_idxs = np.r_[distinct_value_indices, y_true.size - 1]
    tps = stable_cumsum(y_true)[threshold_idxs]
    fps = 1 + threshold_idxs - tps
    recall = tps / tps[-1]
    last_ind = tps.searchsorted(tps[-1])
    sl = slice(last_ind, None, -1)
    recall, fps = np.r_[recall[sl], 1], np.r_[fps[sl], 0]
    return fps[np.argmin(np.abs(recall - recall_level))] / np.sum(~y_true)

def get_measures(pos, neg, recall_level=0.95):
    pos = np.array(pos).reshape((-1, 1))
    neg = np.array(neg).reshape((-1, 1))
    examples = np.squeeze(np.vstack((pos, neg)))
    labels = np.zeros(len(examples), dtype=np.int32)
    labels[:len(pos)] = 1
    auroc = sk.roc_auc_score(labels, examples)
    aupr = sk.average_precision_score(labels, examples)
    fpr = fpr_and_fdr_at_recall(labels, examples, recall_level)
    return auroc, aupr, fpr

# Final Evaluation Output Printed
def get_and_print_results(args, log, in_score, out_score, auroc_list, aupr_list, fpr_list):
    auroc, aupr, fpr = get_measures(-in_score, -out_score)
    auroc_list.append(auroc)
    aupr_list.append(aupr)
    fpr_list.append(fpr)
    print_measures(log, auroc, aupr, fpr, args.score)

def print_measures(log, auroc, aupr, fpr, method_name='Ours', recall_level=0.95):
    if log is None:
        print(f'FPR{int(100 * recall_level)}:\t\t\t{100 * fpr:.2f}')
        print(f'AUROC: \t\t\t{100 * auroc:.2f}')
        print(f'AUPR:  \t\t\t{100 * aupr:.2f}')
    else:
        log.debug('\t\t\t\t' + method_name)
        log.debug(f'  FPR{int(100 * recall_level)} AUROC AUPR')
        log.debug(f'& {100*fpr:.2f} & {100*auroc:.2f} & {100*aupr:.2f}')

# %% [markdown]
# # **file_ops**

# %%
def save_scores(args, scores, dataset_name):
    os.makedirs(args.log_directory, exist_ok=True)
    with open(os.path.join(args.log_directory, f'{dataset_name}_scores.npy'), 'wb') as f:
        np.save(f, scores)

# prevent any recomputation
def load_scores(args, dataset_name):
    with open(os.path.join(args.log_directory, f'{dataset_name}_scores.npy'), 'rb') as f:
        scores = np.load(f)
    return scores

def setup_log(args):
    log = logging.getLogger(__name__)
    if not log.handlers:
        formatter = logging.Formatter('%(asctime)s : %(message)s')
        fileHandler = logging.FileHandler(os.path.join(args.log_directory, "ood_eval_info.log"), mode='w')
        fileHandler.setFormatter(formatter)
        streamHandler = logging.StreamHandler()
        streamHandler.setFormatter(formatter)
        log.setLevel(logging.DEBUG)
        log.addHandler(fileHandler)
        log.addHandler(streamHandler)
        log.debug(f"#########{args.name}############")
    return log

def save_as_dataframe(args, out_datasets, fpr_list, auroc_list, aupr_list):
    os.makedirs(args.log_directory, exist_ok=True)
    fpr_list = [float('{:.2f}'.format(100*fpr)) for fpr in fpr_list]
    auroc_list = [float('{:.2f}'.format(100*auroc)) for auroc in auroc_list]
    aupr_list = [float('{:.2f}'.format(100*aupr)) for aupr in aupr_list]
    import pandas as pd
    data = {k:v for k,v in zip(out_datasets, zip(fpr_list,auroc_list,aupr_list))}
    data['AVG'] = [np.mean(fpr_list),np.mean(auroc_list),np.mean(aupr_list) ]
    data['AVG']  = [float('{:.2f}'.format(metric)) for metric in data['AVG']]
    df = pd.DataFrame.from_dict(data, orient='index',
                       columns=['FPR95', 'AUROC', 'AUPR'])
    df.to_csv(os.path.join(args.log_directory,f'{args.name}_{args.json_number}.csv'))

# %% [markdown]
# # **prompt_pool**

# %%
class PromptGenerator:
    def __init__(self):
        self.dataset_info = {
            'bird200': {'class_type': None, 'num_classes': 200},
            'pet37': {'class_type': None, 'num_classes': 37},
            'cub100_ID': {'class_type': 'bird', 'num_classes': 100},
            'dtd47': {'class_type': 'texture', 'num_classes': 47},
            'pet18_ID': {'class_type': 'pet (including dogs and cats)', 'num_classes': 18},
            'cifar10_ID': {'class_type': None, 'num_classes': 10},
        }

    def _fine_grained_prompt(self, class_type, num_classes, class_info, envision_nums=50):
        return f"""Q: I have a dataset containing 10 unique species of dogs. I need a list of 10 distinct dog species that are NOT present in my dataset, and ensure there are no repetitions in the list you provide. For context, the species in my dataset are: ['husky dog', 'alaskan Malamute', 'cossack sled dog', 'golden retriever', 'German Shepherd', 'Beagle', 'Bulldog', 'Poodle', 'Dachshund', 'Doberman Pinscher']
        A: The other 10 dog species not in the dataset are:
        - Labrador Retriever
        - Rottweiler
        - Boxer
        - Border Collie
        - Shih Tzu
        - Akita
        - Saint Bernard
        - Australian Shepherd
        - Great Dane
        - Boston Terrier

        Q: I have a dataset containing {num_classes} different species of {class_type}. I need a list of {envision_nums} distinct {class_type} species that are NOT present in my dataset, and ensure there are no repetitions in the list you provide. For context, the species in my dataset are: {class_info}
        A: The other {envision_nums} {class_type} species not in the dataset are:
        """

    def _far_prompt(self, class_type, num_classes, class_info, envision_nums=50):
       return f"""Q: I have gathered images of 4 distinct categories: ['Husky dog', 'Garfield cat', 'churches', 'truck'].
       Summarize what broad categories these categories might fall into based on visual features.
       Now, I am looking to identify 5 categories that visually resemble to these broad categories but have no direct relation to these broad categories.
       Please list these 5 items for me.
        A: These 5 items are:
        - black stone
        - mountain
        - Ginkgo Tree
        - river
        - Rapeseed

        Q: I have gathered images of {num_classes} distinct categories: [{class_info}].
        Summarize what broad categories these categories might fall into based on visual features.
        Now, I am looking to identify {envision_nums} classes that visually resemble to these broad categories but have no direct relation to these broad categories.
        Please list these {envision_nums} items for me.
        A: These {envision_nums} items are:
        """

    def _near_prompt(self, class_type, num_classes, class_info, envision_nums=3):
        return f"""Q: Given the image category [husky dog], please suggest visually similar categories that are not directly related or belong to the same primary group as [husky dog]. Provide suggestions that share visual characteristics but are from broader and different domains than [husky dog].
        A: There are 3 classes similar to [husky dog], and they are from broader and different domains than [husky dog]:
        - gray wolf
        - black stone
        - red panda

        Q: Given the image category [basketball], please suggest visually similar categories that are not directly related or belong to the same primary group as [basketball]. Provide suggestions that share visual characteristics but are from broader and different domains than [basketball].
        A: There are 3 classes similar to [basketball], and they are from broader and different domains than [basketball]:
        - balloons
        - blowfish
        - hat

        Q: Given the image category [water jug], please suggest visually similar categories that are not directly related or belong to the same primary group as [water jug]. Provide suggestions that share visual characteristics but are from broader and different domains than [water jug].
        A: There are 3 classes similar to [water jug], and they are from broader and different domains than [water jug]:
        - trumpets
        - helmets
        - rucksacks

        Q: Given the image category [{class_info}], please suggest visually similar categories that are not directly related or belong to the same primary group as [{class_info}]. Provide suggestions that share visual characteristics but are from broader and different domains than [{class_info}].
        A: There are {envision_nums} classes similar to [{class_info}], and they are from broader and different domains than [{class_info}]:
        """

    def _fine_grained_prompt_again(self, in_dataset, envision_nums=50):
        dataset_info = self.dataset_info[in_dataset]
        class_type = dataset_info["class_type"]
        num_classes = dataset_info["num_classes"]
        return f"""Q: Provide {envision_nums} additional {class_type} categories that aren't in the set I gave you, and haven't been mentioned in your previous responses to me.
A: The {envision_nums} additional categories are:
"""

    def _far_prompt_again(self, in_dataset, envision_nums=50):
        return f"""Q: Give me {envision_nums} more categories that are visually similar to these broad categories you summarized in the dataset but have no direct relation to these broad categories. Each category you give cannot exceed three words and could not have appeared in your previous answers.
A: The other {envision_nums} categories are:
"""

    def get_prompt(self, ood_task, in_dataset, class_info=None, envision_nums=50):
        prompt_dispatcher = {
            'fine_grained': self._fine_grained_prompt,
            'far': self._far_prompt,
            'near': self._near_prompt
        }
        if ood_task not in prompt_dispatcher:
            raise ValueError("Unknown OOD task")
        info = self.dataset_info[in_dataset]
        return prompt_dispatcher[ood_task](info["class_type"], info["num_classes"], class_info, envision_nums)

    def get_prompt_again(self, ood_task, in_dataset, class_info=None, envision_nums=50):
        prompt_dispatcher = {
            'fine_grained': self._fine_grained_prompt_again,
            'far': self._far_prompt_again,
        }
        if ood_task not in prompt_dispatcher:
            raise ValueError("Unknown OOD task")
        return prompt_dispatcher[ood_task](in_dataset, envision_nums)

# %% [markdown]
# # **generate_llm_class**

# %%
import os
import json
import itertools
import fastapi_poe
import asyncio
import openai
from dotenv import load_dotenv
import re

load_dotenv()
openai.api_key = os.getenv("OPENAI_API_KEY")

def stringtolist(description):
    lines = description.split("\n")
    candidates = []
    for line in lines:
        line = line.strip()
        bullet_match = re.match(r"^[-•*]\s+(.*)", line)
        number_match = re.match(r"^\d+[\.\)]\s+(.*)", line)

        if bullet_match:
            candidates.append(bullet_match.group(1).strip())
        elif number_match:
            candidates.append(number_match.group(1).strip())
    return candidates

def get_next_number(args, folder_path):
    files = os.listdir(folder_path)
    numbers = []
    for file in files:
        if file.startswith(f"{args.in_dataset}_{args.llm_model}") and file.endswith(".json"):
            try:
                number = int(file.split('_')[-1].split('.')[0])
                numbers.append(number)
            except ValueError:
                pass

    return 0 if not numbers else max(numbers) + 1

def load_json(filename):
    if not filename.endswith('.json'):
        filename += '.json'
    with open(filename, 'r') as fp:
        return json.load(fp)

client = openai.OpenAI(api_key=os.getenv("OPENAI_API_KEY"))

def get_completion(args, prompt):
    try:
        response = client.chat.completions.create(
            model=args.llm_model,
            messages=[{"role": "user", "content": prompt}],
            temperature=0.0,
        )
        return response.choices[0].message.content
    except Exception as e:
        print(f"An error occurred: {e}")
        return ""

def get_completion_from_messages(args, context, new_prompt):
    try:
        context.append({"role": "user", "content": new_prompt})
        response = client.chat.completions.create(
            model=args.llm_model,
            messages=context,
            temperature=0.0,
        )
        generated_text = response.choices[0].message.content
        context.append({"role": "assistant", "content": generated_text})
        return generated_text, context
    except Exception as e:
        print(f"An error occurred: {e}")
        return "", context

def load_llm_classes(args, test_labels):
    assert args.ood_task in ['far', 'fine_grained', 'near'], "Only 'far' and 'fine_grained' supported"
    if args.ood_task in ['far', 'fine_grained']:
      assert args.L in [50, 100, 300, 500], "L must be one of [50, 100, 300, 500] for far/fine_grained"
    elif args.ood_task == 'near':
      assert args.L in [1, 3, 10], "L must be one of [1, 3, 10] for near"

    folder_path = os.path.join("envisioned_classes", f'{args.ood_task}_{args.L}')
    os.makedirs(folder_path, exist_ok=True)

    if args.generate_class:
        print('Envisioning Outlier Exposure...')
        json_number = get_next_number(args, folder_path)
        file_path = os.path.join(folder_path, f"{args.in_dataset}_{args.llm_model}_{json_number}.json")
        asyncio.run(obtain_gpt_class_and_save(args, file_path, test_labels))
    else:
        file_path = os.path.join(folder_path, f"{args.in_dataset}_{args.llm_model}_{args.json_number}.json")

    print('=== load json: ', file_path)
    gpt_class_dict = load_json(file_path)
    print('Get Envisioned Candidate Class Names.')

    gpt_class = []
    for value in gpt_class_dict.values():
        gpt_class.extend(value)

    # Normalize and remove duplicates and overlap with test set
    gpt_class = [item.lower() for item in gpt_class]
    gpt_class = list(set(gpt_class))
    print('After set:', len(gpt_class))

    test_labels = [item.lower() for item in test_labels]
    gpt_class = [item for item in gpt_class if item not in test_labels]
    print('After removing ID class overlaps:', len(gpt_class))

    return gpt_class

async def obtain_gpt_class_and_save(args, file_path, class_list):
    assert args.ood_task in ['far', 'fine_grained', 'near'], "Only 'far', 'fine_grained', or 'near' supported"

    # Adjust L constraint depending on task
    if args.ood_task in ['far', 'fine_grained']:
        assert args.L in [50, 100, 300, 500], "L must be one of [50, 100, 300, 500] for far/fine_grained"
        envision_nums = 50
        envision_times = max(int(args.L / envision_nums) - 1, 0)
    elif args.ood_task == 'near':
        assert args.L in [1, 3, 5, 10], "L must be small (e.g. [1, 3, 5, 10]) for near task"
        envision_nums = args.L
        envision_times = 0

    prompt_gen = PromptGenerator()

    # === NEAR TASK: prompt per class ===
    if args.ood_task == 'near':
        descriptors = {}
        response_texts = []
        for cls in class_list:
            prompt = prompt_gen.get_prompt(
                ood_task='near',
                in_dataset=args.in_dataset,
                class_info=cls,
                envision_nums=envision_nums
            )
            print(f"\n Prompt for class '{cls}':\n{prompt}\n")
            response = get_completion(args, prompt)
            response_texts.append(response)
            descriptors[cls] = stringtolist(response)

        print(f"\n Raw GPT output for all classes:\n{response_texts}")

    # === FAR or FINE_GRAINED: single prompt with multiple batches ===
    else:
        prompt = prompt_gen.get_prompt(
            ood_task=args.ood_task,
            in_dataset=args.in_dataset,
            class_info=class_list,
            envision_nums=envision_nums
        )
        print(" Generating via OpenAI GPT...")
        response_texts = get_completion(args, prompt)

        context = [
            {"role": "user", "content": prompt},
            {"role": "assistant", "content": response_texts}
        ]

        for i in range(envision_times):
            print(f"Continuing vision {i + 1}/{envision_times}")
            new_prompt = prompt_gen.get_prompt_again(
                ood_task=args.ood_task,
                in_dataset=args.in_dataset,
                class_info=class_list,
                envision_nums=envision_nums
            )
            generated_text, context = get_completion_from_messages(args, context, new_prompt)
            response_texts += generated_text

        print("Raw GPT output:\n", response_texts)
        descriptors_list = stringtolist(response_texts)
        descriptors = {args.ood_task: descriptors_list}

    # === Save Output ===
    print(f"\n Saving hallucinated class descriptors to: {file_path}")
    with open(file_path, 'w') as fp:
        json.dump(descriptors, fp)

# %% [markdown]
# # **plot_util**

# %%
import numpy as np
import seaborn as sns
from matplotlib import pyplot as plt
import os

class Args:
    def __init__(self):
        self.log_directory = "results/test_plot"
        self.score = "EOE"

args = Args()

def plot_distribution(args, id_scores, ood_scores, out_dataset):
    sns.set(style="white", palette="muted")
    palette = ['#8E8BFE', '#FEA3A2']

    import pandas as pd
    data = pd.DataFrame({
        "Score": np.concatenate([-1 * id_scores, -1 * ood_scores]),
        "Type": ["ID"] * len(id_scores) + ["OOD"] * len(ood_scores)
    })

    # Plot with seaborn
    plt.figure(figsize=(6, 4))
    sns.kdeplot(
        data=data,
        x="Score",
        hue="Type",
        fill=True,
        palette=palette,
        alpha=0.8,
        linewidth=2
    )

    # Add axis labels and ticks
    plt.xlabel("Score", fontsize=12)
    plt.ylabel("Density", fontsize=12)
    plt.xticks(fontsize=10)
    plt.yticks(fontsize=10)

    ax = plt.gca()
    for spine in ax.spines.values():
        spine.set_linewidth(1.5)

    # Save the figure
    os.makedirs(args.log_directory, exist_ok=True)
    plt.tight_layout()
    plt.savefig(os.path.join(args.log_directory, f"{args.score}_{out_dataset}.png"))
    plt.show()

# %% [markdown]
# # **dataloaders/cub200.py**

# %%
import os
import pandas as pd
from torchvision.datasets.folder import default_loader
from torch.utils.data import Dataset
import numpy as np
import pickle


class Cub2011(Dataset):
    base_folder = 'CUB_200_2011/images'

    def __init__(self, root, train=True, transform=None, loader=default_loader):
        self.root = os.path.expanduser(root)
        self.transform = transform
        self.loader = default_loader
        self.train = train

        self._load_metadata()

    def _load_metadata(self):
        images = pd.read_csv(os.path.join(self.root, 'CUB_200_2011', 'images.txt'), sep=' ',
                             names=['img_id', 'filepath'])
        image_class_labels = pd.read_csv(os.path.join(self.root, 'CUB_200_2011', 'image_class_labels.txt'),
                                         sep=' ', names=['img_id', 'target'])
        train_test_split = pd.read_csv(os.path.join(self.root, 'CUB_200_2011', 'train_test_split.txt'),
                                       sep=' ', names=['img_id', 'is_training_img'])

        data = images.merge(image_class_labels, on='img_id')
        self.data = data.merge(train_test_split, on='img_id')

        if self.train:
            self.data = self.data[self.data.is_training_img == 1]
        else:
            self.data = self.data[self.data.is_training_img == 0]

        class_names = pd.read_csv(os.path.join(self.root, 'CUB_200_2011', 'classes.txt'),
                                         sep=' ', names=['class_id', 'target'])
        self.class_names_str = [name.split(".")[1].replace('_', ' ') for name in class_names.target]

    def __len__(self):
        return len(self.data)

    def __getitem__(self, idx):
        sample = self.data.iloc[idx]
        path = os.path.join(self.root, self.base_folder, sample.filepath)
        target = sample.target - 1  # Targets start at 1 by default, so shift to 0
        img = self.loader(path)

        if self.transform is not None:
            img = self.transform(img)

        return img, target



class Cub100(Cub2011):
    def __init__(self, root, train=True, id=True, transform=None, loader=default_loader):
        self.id = id
        self.root = root
        self._select_or_load_classes()
        super().__init__(root, train, transform, loader)

    def _select_or_load_classes(self):
        subset_classes_file = os.path.join('data', 'CUB-100', "selected_100_classes.pkl")
        if os.path.exists(subset_classes_file):
            with open(subset_classes_file, 'rb') as f:
                self.selected_classes = pickle.load(f)
        else:
            all_classes = pd.read_csv(os.path.join(self.root, 'CUB_200_2011', 'classes.txt'),
                                      sep=' ', names=['class_id', 'target'])
            selected_class_ids = np.random.choice(all_classes['class_id'], 100, replace=False)
            self.selected_classes = all_classes[all_classes['class_id'].isin(selected_class_ids)]['target'].tolist()
            # self.selected_classes = all_classes['target'].iloc[:100].tolist()
            with open(subset_classes_file, 'wb') as f:
                pickle.dump(self.selected_classes, f)

    def _load_metadata(self):
        super()._load_metadata()

        all_classes = pd.read_csv(os.path.join(self.root, 'CUB_200_2011', 'classes.txt'),
                              sep=' ', names=['class_id', 'target'])

        selected_class_ids = all_classes[all_classes['target'].isin(self.selected_classes)]['class_id'].tolist()

        if self.id: # select cub100_iid
            self.data = self.data[self.data['target'].isin(selected_class_ids)]
            self.class_names_str = [name.split(".")[1].replace('_', ' ') for name in self.selected_classes]

            remaining_class_ids = set(all_classes['class_id']) - set(selected_class_ids)
            remaining_class_names = all_classes[all_classes['class_id'].isin(remaining_class_ids)]['target'].tolist()
            self.ood_class_name_str = [name.split(".")[1].replace('_', ' ') for name in remaining_class_names]
        else:  # select cub100_ood
            remaining_class_ids = set(all_classes['class_id']) - set(selected_class_ids)
            self.data = self.data[self.data['target'].isin(remaining_class_ids)]
            remaining_class_names = all_classes[all_classes['class_id'].isin(remaining_class_ids)]['target'].tolist()
            self.class_names_str = [name.split(".")[1].replace('_', ' ') for name in remaining_class_names]

# %% [markdown]
# # **datasets/pet37.py**

# %%
import os
import os.path

from typing import Any, Tuple, Callable, Optional, Union, Sequence
import torch
import pickle
import random
from PIL import Image
import pathlib
from torchvision.datasets.utils import download_and_extract_archive, verify_str_arg
from torchvision.datasets.vision import VisionDataset


class OxfordIIITPet(VisionDataset):
    _RESOURCES = (
        ("https://www.robots.ox.ac.uk/~vgg/data/pets/data/images.tar.gz", "5c4f3ee8e5d25df40f4fd59a7f44e54c"),
        ("https://www.robots.ox.ac.uk/~vgg/data/pets/data/annotations.tar.gz", "95a8c909bbe2e81eed6a22bccdf3f68f"),
    )
    _VALID_TARGET_TYPES = ("category", "segmentation")

    def __init__(
        self,
        root: str,
        split: str = "trainval",
        target_types: Union[Sequence[str], str] = "category",
        transforms: Optional[Callable] = None,
        transform: Optional[Callable] = None,
        target_transform: Optional[Callable] = None,
        download: bool = False,
    ):
        self._split = verify_str_arg(split, "split", ("trainval", "test"))
        if isinstance(target_types, str):
            target_types = [target_types]
        self._target_types = [
            verify_str_arg(target_type, "target_types", self._VALID_TARGET_TYPES) for target_type in target_types
        ]

        super().__init__(root, transforms=transforms, transform=transform, target_transform=target_transform)
        self._base_folder = pathlib.Path(self.root) / "oxford-iiit-pet"
        self._images_folder = self._base_folder / "images"
        self._anns_folder = self._base_folder / "annotations"
        self._segs_folder = self._anns_folder / "trimaps"

        if download:
            self._download()

        if not self._check_exists():
            raise RuntimeError("Dataset not found. You can use download=True to download it")

        image_ids = []
        self._labels = []
        with open(self._anns_folder / f"{self._split}.txt") as file:
            for line in file:
                image_id, label, *_ = line.strip().split()
                image_ids.append(image_id)
                self._labels.append(int(label) - 1)

        self.classes = [
            " ".join(part.title() for part in raw_cls.split("_"))
            for raw_cls, _ in sorted(
                {(image_id.rsplit("_", 1)[0], label) for image_id, label in zip(image_ids, self._labels)},
                key=lambda image_id_and_label: image_id_and_label[1],
            )
        ]
        self.class_to_idx = dict(zip(self.classes, range(len(self.classes))))

        self._images = [self._images_folder / f"{image_id}.jpg" for image_id in image_ids]
        self._segs = [self._segs_folder / f"{image_id}.png" for image_id in image_ids]

        self.class_names_str = self.classes

    def __len__(self) -> int:
        return len(self._images)

    def __getitem__(self, idx: int) -> Tuple[Any, Any]:
        image = Image.open(self._images[idx]).convert("RGB")

        target: Any = []
        for target_type in self._target_types:
            if target_type == "category":
                target.append(self._labels[idx])
            else:  # target_type == "segmentation"
                target.append(Image.open(self._segs[idx]))

        if not target:
            target = None
        elif len(target) == 1:
            target = target[0]
        else:
            target = tuple(target)

        if self.transforms:
            image, target = self.transforms(image, target)

        return image, target


    def _check_exists(self) -> bool:
        for folder in (self._images_folder, self._anns_folder):
            if not (os.path.exists(folder) and os.path.isdir(folder)):
                return False
        else:
            return True

    def _download(self) -> None:
        if self._check_exists():
            return

        for url, md5 in self._RESOURCES:
            download_and_extract_archive(url, download_root=str(self._base_folder), md5=md5)


class OxfordIIITPet_18(OxfordIIITPet):
    def __init__(self,
        root: str,
        split: str = "trainval",
        id: bool = True,
        target_types: Union[Sequence[str], str] = "category",
        transforms: Optional[Callable] = None,
        transform: Optional[Callable] = None,
        target_transform: Optional[Callable] = None,
        download: bool = False,
        ):
        super(OxfordIIITPet_18, self).__init__(root=root, split=split, target_types=target_types, transforms=transforms, transform=transform, target_transform=target_transform, download=download)

        subset_classes_file = os.path.join('data', 'Oxford-Pet-18', 'selected_18_classes.pkl')
        if os.path.exists(subset_classes_file):
            with open(subset_classes_file, 'rb') as f:
                stored_classes = pickle.load(f)
        else:
            stored_classes = random.sample(self.classes, 18)
            with open(subset_classes_file, 'wb') as f:
                pickle.dump(stored_classes, f)

        selected_classes = stored_classes if id else [cls for cls in self.classes if cls not in stored_classes]
        self.ood_class_name_str = [cls for cls in self.classes if cls not in stored_classes] if id else stored_classes

        selected_indices = [i for i, label in enumerate(self._labels) if self.classes[label] in selected_classes]
        self._images = [self._images[i] for i in selected_indices]
        self._segs = [self._segs[i] for i in selected_indices]
        self._labels = [self._labels[i] for i in selected_indices]

        self.classes = selected_classes
        self.class_to_idx = {cls: idx for idx, cls in enumerate(self.classes)}
        self.class_names_str = self.classes


def examine_count(counter, name = "train"):
    print(f"in the {name} set")
    for label in counter:
        print(label, counter[label])

# %% [markdown]
# # **train_eval_util**

# %%
import os
import torch
from torchvision import datasets, transforms
from transformers import CLIPModel
from torchvision.datasets import CIFAR10, CIFAR100

def set_model_clip(args):
    """Load the CLIP model and corresponding val transforms"""
    ckpt_mapping = {
        "ViT-B/16": "openai/clip-vit-base-patch16",
        "ViT-B/32": "openai/clip-vit-base-patch32",
        "ViT-L/14": "openai/clip-vit-large-patch14"
    }
    args.ckpt = ckpt_mapping[args.CLIP_ckpt]
    model = CLIPModel.from_pretrained(args.ckpt)

    normalize = transforms.Normalize(mean=(0.48145466, 0.4578275, 0.40821073),
                                     std=(0.26862954, 0.26130258, 0.27577711))
    val_preprocess = transforms.Compose([
        transforms.Resize(224),
        transforms.CenterCrop(224),
        transforms.ToTensor(),
        normalize
    ])

    return model.cuda(), val_preprocess

def set_val_loader(args, preprocess):
    """Create a dataloader for the selected ID dataset"""
    dataset_classes = {
        "bird200": lambda root, transform: Cub2011(root, train=False, transform=transform),
        "pet37": lambda root, transform: OxfordIIITPet(root, split="test", download=True, transform=transform),
        "cub100_ID": lambda root, transform: Cub100(root, train=False, id=True, transform=transform),
        "pet18_ID": lambda root, transform: OxfordIIITPet_18(root, split="test", id=True, download=True, transform=transform),
        "cifar10_ID": lambda root, transform: CIFAR10(root, train=False, download=True, transform=transform),
    }

    dataset_fn = dataset_classes.get(args.in_dataset)
    if dataset_fn is None:
        raise NotImplementedError(f"Unsupported ID dataset: {args.in_dataset}")

    return torch.utils.data.DataLoader(
        dataset_fn(args.root_dir, preprocess),
        batch_size=args.batch_size,
        shuffle=False,
        num_workers=4,
        pin_memory=True
    )

def set_ood_loader(args, out_dataset, preprocess):
    """Create a DataLoader for the selected OOD dataset."""
    dataset_paths = {
        'dtd': os.path.join(args.root_dir, 'dtd','dtd','images'),
    }

    ood_classes = {
        'bird200':  lambda root, tf: Cub2011(root, train=False, transform=tf),
        'pet37':    lambda root, tf: OxfordIIITPet(root, split='test', download=True, transform=tf),
        'cub100_OOD': lambda root, tf: Cub100(root, train=False, id=False, transform=tf),
        'pet19_OOD': lambda root, tf: OxfordIIITPet_18(root, split='test', id=False, download=True, transform=tf),
        'cifar100_OOD': lambda root, tf: CIFAR100(root, train=False, download=True, transform=tf),
    }

    if out_dataset in dataset_paths:
        dataset = datasets.ImageFolder(dataset_paths[out_dataset], transform=preprocess)
    elif out_dataset in ood_classes:
        dataset = ood_classes[out_dataset](args.root_dir, preprocess)
    else:
        raise ValueError(f"Unsupported OOD dataset: {out_dataset}")

    return torch.utils.data.DataLoader(
        dataset,
        batch_size=args.batch_size,
        shuffle=False,
        num_workers=getattr(args, 'num_workers', 4),
        pin_memory=getattr(args, 'pin_memory', True)
    )

# %% [markdown]
# # **Experiment Semantic Variant OOD PET-19 vs PET-18 (Beta=0.25,L=50,100,300,500)**

# %%
import os
import openai
import re

client = openai.OpenAI(api_key=os.getenv("OPENAI_API_KEY"))

def fetch_synonym(name: str) -> str:
    system_prompt = (
        "You are a fine-grained classification assistant. "
        "When given a pet(including dogs and cats) species name, reply with *exactly one* known synonym or scientific name or name in other language. "
        "If no widely used alternative exists, reply with the original label and do not return *none*. "
        "Only return the name. Do not include explanations, punctuation, or prefixes.\n\n"
        "Here are a few examples:\n"
        "Input: American Goldfinch → Output: Eastern Goldfinch\n"
        "Input: Indigo Bunting → Output: Passerina cyanea\n"
        "Input: Bengal Cat → Output: Leopardette"
        "Input: Gadwall → Output: Anas strepera\n"
    )

    user_prompt = f"Class label: {name}"

    response = client.chat.completions.create(
        model="gpt-3.5-turbo",
        messages=[
            {"role": "system", "content": system_prompt},
            {"role": "user",   "content": user_prompt}
        ],
        temperature=0
    )

    raw = response.choices[0].message.content.strip()

    if ":" in raw:
        raw = raw.split(":")[-1].strip()
    if "known as" in raw:
        raw = re.split(r"known as", raw, flags=re.IGNORECASE)[-1].strip()

    return raw.rstrip(".")

# %%
import os
os.environ['CURL_CA_BUNDLE'] = ''
import argparse
import numpy as np
import torch
from scipy import stats

def main():
    args = process_args()
    setup_seed(args.seed)
    log = setup_log(args)
    assert torch.cuda.is_available()
    torch.cuda.set_device(args.gpu)

    net, preprocess = set_model_clip(args)
    net.eval()

    if args.in_dataset.startswith("ImageNet_C"):
        out_datasets = ['iNaturalist', 'SUN', 'places365', 'dtd']
    elif args.in_dataset == 'ImageNet':
        out_datasets = ['iNaturalist', 'SUN', 'places365', 'dtd'] if args.ood_task.startswith("far") else ['ssb_hard', 'ninco']
    else:
        out_datasets = dataset_mappings.get(args.in_dataset, [])

    test_loader = set_val_loader(args, preprocess)
    test_labels = list(get_test_labels(args, test_loader))
    print("Original ID Labels:", test_labels)

    if args.score == 'EOE':
        print("Using LLM-generated OOD candidate classes...")
        base_ood_labels = load_llm_classes(args, test_labels)

        if args.use_synonyms:
            print("Augmenting OOD candidates with synonyms...")

            base_ood_labels = [lbl.strip().lower() for lbl in base_ood_labels]
            original_count = len(base_ood_labels)

            synonym_labels = []
            for lbl in base_ood_labels:
                syn = fetch_synonym(lbl).strip().lower()
                print(f"  → {lbl!r}  → synonym: {syn!r}")
                if syn != lbl:
                    synonym_labels.append(syn)

            combined = base_ood_labels + synonym_labels

            filtered = [label for label in combined if label and label.lower() not in {"none", "null"}]

            removed_count = len(combined) - len(filtered)
            print(f"Removed {removed_count} invalid synonym labels like 'none' or 'null'")

            llm_labels = list(dict.fromkeys(filtered))
            final_count = len(llm_labels)

            print(f"OOD classes before synonym expansion: {original_count}")
            print(f"OOD classes after synonym + deduplication: {final_count}")
        else:
            llm_labels = base_ood_labels
    else:
        llm_labels = []

    print(f"\n Final ID Labels passed to CLIP: {test_labels}")
    print(f"OOD candidate labels: {llm_labels}\n")

    in_score = get_ood_scores_clip(args, net, test_loader, test_labels, llm_labels)

    auroc_list, aupr_list, fpr_list = [], [], []
    for out_dataset in out_datasets:
        log.debug(f"Evaluating OOD dataset {out_dataset}")
        ood_loader = set_ood_loader(args, out_dataset, preprocess)
        out_score = get_ood_scores_clip(args, net, ood_loader, test_labels, llm_labels)

        log.debug(f"in scores: {stats.describe(in_score)}")
        log.debug(f"out scores: {stats.describe(out_score)}")
        plot_distribution(args, in_score, out_score, out_dataset)
        get_and_print_results(args, log, in_score, out_score, auroc_list, aupr_list, fpr_list)

    log.debug('\n\n Mean Test Results')
    print_measures(log, np.mean(auroc_list), np.mean(aupr_list),
                   np.mean(fpr_list), method_name=args.score)

    save_as_dataframe(args, out_datasets, fpr_list, auroc_list, aupr_list)


def process_args():
    parser = argparse.ArgumentParser(
        description='Leverage LLMs for OOD Detection',
        formatter_class=argparse.ArgumentDefaultsHelpFormatter
    )
    parser.add_argument('--in_dataset',
                        default='bird200',
                        choices=ALL_ID_DATASET,
                        help='in-distribution dataset')
    parser.add_argument('--root_dir',
                        default="datasets",
                        help='root dir of datasets')
    # prompt pipeline
    parser.add_argument('--ensemble',
                        action='store_true',
                        default=False,
                        help='CLIP text prompt engineering')
    parser.add_argument('--L',
                        type=int,
                        default=100,
                        help='the length of envisioned OOD class labels, for far/fine-grained: L=500, for near: L=3')
    parser.add_argument('--beta',
                        type=float,
                        default=0.25,
                        help='beta in Eq. 3')
    parser.add_argument('--ood_task',
                        type=str,
                        default='far',
                        choices=ALL_OOD_TASK,
                        help='choose ood task')
    parser.add_argument('--generate_class',
                        action='store_true',
                        help='whether to envision OOD candidate classes or loaded from existing JSONs')
    parser.add_argument('--json_number',
                        type=int,
                        default=0,
                        help='loaded json number')
    parser.add_argument('--llm_model',
                        default="gpt-3.5-turbo",
                        choices=ALL_LLM,
                        help='LLMs')
    parser.add_argument('--name',
                        default="eval_ood",
                        help="unique ID for the run")
    parser.add_argument('--seed',
                        type=int,
                        default=5,
                        help="random seed")
    parser.add_argument('--gpu',
                        type=int,
                        default=0,
                        help='the GPU indice to use')
    parser.add_argument('--batch_size',
                        type=int,
                        default=512,
                        help='mini-batch size')
    parser.add_argument('--T',
                        type=float,
                        default=1,
                        help='score temperature parameter')
    parser.add_argument('--model',
                        default='CLIP',
                        choices=['CLIP'],
                        help='model architecture')
    parser.add_argument('--CLIP_ckpt',
                        default='ViT-B/16',
                        choices=['ViT-B/16'],
                        help='which pretrained img encoder to use')
    parser.add_argument('--score',
                        default='EOE',
                        choices=['EOE', 'MCM', 'energy', 'max-logit'],
                        help='which scoring method')
    parser.add_argument('--score_ablation',
                        default='EOE',
                        choices=['MAX', 'MSP', 'energy', 'max-logit', 'EOE'],
                        help='ablations on the EOE score formula')
    parser.add_argument('--feat_dim',
                        type=int,
                        default=512,
                        help='feat dim, 512 for ViT-B and 768 for ViT-L')
    parser.add_argument('--use_synonyms',
                    default=False,
                    action='store_true',
                    help='Augment ID labels with synonyms using LLM')
    parser.add_argument('--prompt_pool_id',
                    type=int,
                    default=0,
                    help='Which index of openai_imagenet_template_subset to use when --ensemble')
    args = parser.parse_args()

    args.n_cls = get_num_cls(args)
    args.log_directory = f"results/{args.in_dataset}/{args.score}/" \
                         f"{args.model}_{args.CLIP_ckpt}_T_{args.T}_ID_{args.name}"
    os.makedirs(args.log_directory, exist_ok=True)

    return args

# %%
# !pip install -q nest_asyncio
import nest_asyncio
nest_asyncio.apply()
import os
os.environ['CURL_CA_BUNDLE'] = ''
import argparse
import numpy as np
import torch
from scipy import stats
import sys

sys.argv = [
    "eval_ood_detection.py",
    "--name",        "PET19_PET18_EOE_50L_finegrained_synonymOOD",
    "--in_dataset",  "pet18_ID",
    "--ood_task",    "fine_grained",
    "--score",       "EOE",
    "--score_ablation", "EOE",           # use standard EOE score
    "--generate_class",                  # generate OOD candidates via LLM
    "--use_synonyms",                   # apply synonym expansion to OOD classes
    "--root_dir",    "datasets",
    "--batch_size",  "256",
    "--gpu",         "0",
    "--L",           "50",
]
main()
# Out:
# /usr/local/lib/python3.11/dist-packages/torch/utils/data/dataloader.py:624: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(
# ✅ Original ID Labels: ['Havanese', 'Newfoundland', 'Sphynx', 'American Bulldog', 'Samoyed', 'Great Pyrenees', 'Maine Coon', 'Staffordshire Bull Terrier', 'Saint Bernard', 'Bengal', 'Basset Hound', 'Egyptian Mau', 'Shiba Inu', 'Bombay', 'English Cocker Spaniel', 'Japanese Chin', 'Ragdoll', 'Keeshond']
# 🔮 Using LLM-generated OOD candidate classes...
# Envisioning Outlier Exposure...
# 🔵 Generating via OpenAI GPT...
# 🔍 Raw GPT output:
#  - Siamese
# - Persian
# - Chihuahua
# - Siamese
# - Pomeranian
# - Abyssinian
# - Cavalier King Charles Spaniel
# - Russian Blue
# - Maltese
# - Ragamuffin
# - Scottish Fold
# - Papillon
# - Cornish Rex
# - Toyger
# - Devon Rex
# - Birman
# - Manx
# - Chartreux
# - Havana Brown
# - Tonkinese
# - American Shorthair
# - Burmese
# - Turkish Angora
# - Balinese
# - Singapura
# - Ocicat
# - Turkish Van
# - American Wirehair
# - Exotic Shorthair
# - Norwegian Forest Cat
# - British Shorthair
# - Himalayan
# - Devon Rex
# - Selkirk Rex
# - LaPerm
# - American Curl
# - Munchkin
# - Sphynx
# - Somali
# - Peterbald
# - Burmilla
# - Australian Mist
# - Egyptian Mau
# - Manx
# - Chartreux
# - Havana Brown
# - Tonkinese
# - American Shorthair
# - Burmese
#
# 💾 Saving hallucinated class descriptors to: envisioned_classes/fine_grained_50/pet18_ID_gpt-3.5-turbo_12.json
# === load json:  envisioned_classes/fine_grained_50/pet18_ID_gpt-3.5-turbo_12.json
# Get Envisioned Candidate Class Names.
# After set: 41
# After removing ID class overlaps: 39
# 🔁 Augmenting OOD candidates with synonyms...
#   → 'scottish fold'  → synonym: 'felis catus'
#   → 'birman'  → synonym: 'sacred birman'
#   → 'australian mist'  → synonym: 'spotted mist'
#   → 'balinese'  → synonym: 'long-haired siamese'
#   → 'tonkinese'  → synonym: 'tonkinese'
#   → 'selkirk rex'  → synonym: 'selkirk longhair'
#   → 'maltese'  → synonym: 'maltese dog'
#   → 'british shorthair'  → synonym: 'british blue'
#   → 'somali'  → synonym: 'abyssinian'
#   → 'havana brown'  → synonym: 'havana brown'
#   → 'toyger'  → synonym: 'toyger'
#   → 'chihuahua'  → synonym: 'chihuahua'
#   → 'himalayan'  → synonym: 'himalayan cat'
#   → 'american curl'  → synonym: 'none'
#   → 'peterbald'  → synonym: 'st. petersburg sphynx'
#   → 'turkish angora'  → synonym: 'turkish angora'
#   → 'persian'  → synonym: 'persian cat'
#   → 'abyssinian'  → synonym: 'abyssinian cat'
#   → 'pomeranian'  → synonym: 'zwergspitz'
#   → 'papillon'  → synonym: 'continental toy spaniel'
#   → 'turkish van'  → synonym: 'van cat'
#   → 'siamese'  → synonym: 'siamese cat'
#   → 'laperm'  → synonym: 'laperm'
#   → 'american shorthair'  → synonym: 'domestic shorthair'
#   → 'cavalier king charles spaniel'  → synonym: 'cavalier king charles spaniel'
#   → 'ragamuffin'  → synonym: 'none'
#   → 'devon rex'  → synonym: 'devon rex'
#   → 'american wirehair'  → synonym: 'american wirehair'
#   → 'munchkin'  → synonym: 'midget cat'
#   → 'singapura'  → synonym: 'singapore cat'
#   → 'manx'  → synonym: 'manx cat'
#   → 'burmese'  → synonym: 'burmese cat'
#   → 'norwegian forest cat'  → synonym: 'norsk skogkatt'
#   → 'ocicat'  → synonym: 'abyssinian'
#   → 'exotic shorthair'  → synonym: 'persian cat'
#   → 'burmilla'  → synonym: 'burmese chinchilla'
#   → 'russian blue'  → synonym: 'archangel'
#   → 'chartreux'  → synonym: 'french blue'
#   → 'cornish rex'  → synonym: 'cornish rex'
# 🧹 Removed 2 invalid synonym labels like 'none' or 'null'
# 📏 OOD classes before synonym expansion: 39
# 📐 OOD classes after synonym + deduplication: 63
#
# 🧪 Final ID Labels passed to CLIP: ['Havanese', 'Newfoundland', 'Sphynx', 'American Bulldog', 'Samoyed', 'Great Pyrenees', 'Maine Coon', 'Staffordshire Bull Terrier', 'Saint Bernard', 'Bengal', 'Basset Hound', 'Egyptian Mau', 'Shiba Inu', 'Bombay', 'English Cocker Spaniel', 'Japanese Chin', 'Ragdoll', 'Keeshond']
# 🚫 OOD candidate labels: ['scottish fold', 'birman', 'australian mist', 'balinese', 'tonkinese', 'selkirk rex', 'maltese', 'british shorthair', 'somali', 'havana brown', 'toyger', 'chihuahua', 'himalayan', 'american curl', 'peterbald', 'turkish angora', 'persian', 'abyssinian', 'pomeranian', 'papillon', 'turkish van', 'siamese', 'laperm', 'american shorthair', 'cavalier king charles spaniel', 'ragamuffin', 'devon rex', 'american wirehair', 'munchkin', 'singapura', 'manx', 'burmese', 'norwegian forest cat', 'ocicat', 'exotic shorthair', 'burmilla', 'russian blue', 'chartreux', 'cornish rex', 'felis catus', 'sacred birman', 'spotted mist', 'long-haired siamese', 'selkirk longhair', 'maltese dog', 'british blue', 'himalayan cat', 'st. petersburg sphynx', 'persian cat', 'abyssinian cat', 'zwergspitz', 'continental toy spaniel', 'van cat', 'siamese cat', 'domestic shorthair', 'midget cat', 'singapore cat', 'manx cat', 'burmese cat', 'norsk skogkatt', 'burmese chinchilla', 'archangel', 'french blue']
# 100%|██████████| 7/7 [00:27<00:00,  3.96s/it]
# 2025-07-15 14:43:48,186 : 📦 Evaluating OOD dataset pet19_OOD
# DEBUG:__main__:📦 Evaluating OOD dataset pet19_OOD
# 100%|██████████| 8/8 [00:29<00:00,  3.70s/it]
# 2025-07-15 14:44:18,220 : in scores: DescribeResult(nobs=1773, minmax=(np.float32(-0.011637364), np.float32(-0.009078004)), mean=np.float32(-0.010430075), variance=np.float64(2.1226057964107152e-07), skewness=np.float64(0.3876132369041443), kurtosis=np.float32(-0.13844514))
# DEBUG:__main__:in scores: DescribeResult(nobs=1773, minmax=(np.float32(-0.011637364), np.float32(-0.009078004)), mean=np.float32(-0.010430075), variance=np.float64(2.1226057964107152e-07), skewness=np.float64(0.3876132369041443), kurtosis=np.float32(-0.13844514))
# 2025-07-15 14:44:18,225 : out scores: DescribeResult(nobs=1896, minmax=(np.float32(-0.01097115), np.float32(-0.009015635)), mean=np.float32(-0.009858322), variance=np.float64(1.509253378737465e-07), skewness=np.float64(-0.3461184799671173), kurtosis=np.float32(-0.8088558))
# DEBUG:__main__:out scores: DescribeResult(nobs=1896, minmax=(np.float32(-0.01097115), np.float32(-0.009015635)), mean=np.float32(-0.009858322), variance=np.float64(1.509253378737465e-07), skewness=np.float64(-0.3461184799671173), kurtosis=np.float32(-0.8088558))
# 2025-07-15 14:44:18,654 : 				EOE
# DEBUG:__main__:				EOE
# 2025-07-15 14:44:18,659 :   FPR95 AUROC AUPR
# DEBUG:__main__:  FPR95 AUROC AUPR
# 2025-07-15 14:44:18,660 : & 75.58 & 82.40 & 83.69
# DEBUG:__main__:& 75.58 & 82.40 & 83.69
# 2025-07-15 14:44:18,661 :
#
# 📊 Mean Test Results
# DEBUG:__main__:
#
# 📊 Mean Test Results
# 2025-07-15 14:44:18,663 : 				EOE
# DEBUG:__main__:				EOE
# 2025-07-15 14:44:18,664 :   FPR95 AUROC AUPR
# DEBUG:__main__:  FPR95 AUROC AUPR
# 2025-07-15 14:44:18,669 : & 75.58 & 82.40 & 83.69
# DEBUG:__main__:& 75.58 & 82.40 & 83.69

# %%
sys.argv = [
    "eval_ood_detection.py",
    "--name",        "PET19_PET18_EOE_100L_finegrained_synonymOOD",
    "--in_dataset",  "pet18_ID",
    "--ood_task",    "fine_grained",
    "--score",       "EOE",
    "--score_ablation", "EOE",           # use standard EOE score
    "--generate_class",                  # generate OOD candidates via LLM
    "--use_synonyms",                   # apply synonym expansion to OOD classes
    "--root_dir",    "datasets",
    "--batch_size",  "256",
    "--gpu",         "0",
    "--L",           "100",
]
main()
# Out:
# /usr/local/lib/python3.11/dist-packages/torch/utils/data/dataloader.py:624: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(
# ✅ Original ID Labels: ['Havanese', 'Newfoundland', 'Sphynx', 'American Bulldog', 'Samoyed', 'Great Pyrenees', 'Maine Coon', 'Staffordshire Bull Terrier', 'Saint Bernard', 'Bengal', 'Basset Hound', 'Egyptian Mau', 'Shiba Inu', 'Bombay', 'English Cocker Spaniel', 'Japanese Chin', 'Ragdoll', 'Keeshond']
# 🔮 Using LLM-generated OOD candidate classes...
# Envisioning Outlier Exposure...
# 🔵 Generating via OpenAI GPT...
# Continuing vision 1/1
# 🔍 Raw GPT output:
#  - Siamese
# - Persian
# - Chihuahua
# - Siamese
# - Pomeranian
# - Abyssinian
# - Cavalier King Charles Spaniel
# - Russian Blue
# - Maltese
# - Ragamuffin
# - Scottish Fold
# - Cavalier King Charles Spaniel
# - Cornish Rex
# - Papillon
# - Devon Rex
# - Tibetan Mastiff
# - Manx
# - Toyger
# - Chartreux
# - American Shorthair
# - Australian Terrier
# - Birman
# - Burmese
# - Chartreux
# - Exotic Shorthair
# - Havana Brown
# - Himalayan
# - Korat
# - LaPerm
# - Munchkin
# - Nebelung
# - Ocicat
# - Oriental
# - Russian Blue
# - Scottish Fold
# - Selkirk Rex
# - Singapura
# - Snowshoe
# - Somali
# - Tonkinese
# - Turkish Angora
# - Turkish Van
# - American Curl
# - Balinese
# - Bombay
# - British Shorthair
# - Burmilla
# - Cymric
# - Egyptian Mau
# - European Burmese- Irish Wolfhound
# - Tibetan Spaniel
# - Toy Fox Terrier
# - Wire Fox Terrier
# - Xoloitzcuintli
# - Affenpinscher
# - Azawakh
# - Barbet
# - Bergamasco
# - Cirneco dell'Etna
# - Clumber Spaniel
# - Dandie Dinmont Terrier
# - Entlebucher Mountain Dog
# - Finnish Lapphund
# - Grand Basset Griffon Vendeen
# - Hamiltonstovare
# - Harrier
# - Ibizan Hound
# - Jindo
# - Kai Ken
# - Kooikerhondje
# - Lagotto Romagnolo
# - Lowchen
# - Manchester Terrier
# - Nederlandse Kooikerhondje
# - Otterhound
# - Peruvian Inca Orchid
# - Portuguese Podengo
# - Pumi
# - Pyrenean Shepherd
# - Rat Terrier
# - Redbone Coonhound
# - Schipperke
# - Sloughi
# - Spanish Water Dog
# - Sussex Spaniel
# - Swedish Vallhund
# - Thai Ridgeback
# - Tibetan Terrier
# - Tornjak
# - Toy Manchester Terrier
# - Treeing Walker Coonhound
# - Volpino Italiano
# - Welsh Terrier
# - West Highland White Terrier
# - Whippet
# - Wirehaired Pointing Griffon
# - Xiasi Dog
# - Yakutian Laika
# - Yorkshire Terrier
#
# 💾 Saving hallucinated class descriptors to: envisioned_classes/fine_grained_100/pet18_ID_gpt-3.5-turbo_14.json
# === load json:  envisioned_classes/fine_grained_100/pet18_ID_gpt-3.5-turbo_14.json
# Get Envisioned Candidate Class Names.
# After set: 94
# After removing ID class overlaps: 92
# 🔁 Augmenting OOD candidates with synonyms...
#   → 'portuguese podengo'  → synonym: 'podengo português'
#   → 'somali'  → synonym: 'abyssinian'
#   → 'chihuahua'  → synonym: 'chihuahua'
#   → 'havana brown'  → synonym: 'havana cat'
#   → 'clumber spaniel'  → synonym: 'clumber spaniel'
#   → 'american curl'  → synonym: 'none'
#   → 'european burmese- irish wolfhound'  → synonym: 'irish wolfhound'
#   → 'pomeranian'  → synonym: 'zwergspitz'
#   → 'harrier'  → synonym: 'circus aeruginosus'
#   → 'papillon'  → synonym: 'continental toy spaniel'
#   → 'turkish van'  → synonym: 'van cat'
#   → 'pumi'  → synonym: 'hungarian sheepdog'
#   → 'siamese'  → synonym: 'siamese cat'
#   → 'american shorthair'  → synonym: 'domestic shorthair'
#   → 'cavalier king charles spaniel'  → synonym: 'cavalier king charles spaniel'
#   → 'ragamuffin'  → synonym: 'none'
#   → 'entlebucher mountain dog'  → synonym: 'entlebucher sennenhund'
#   → 'swedish vallhund'  → synonym: 'viking dog'
#   → 'affenpinscher'  → synonym: 'monkey terrier'
#   → 'munchkin'  → synonym: 'midget cat'
#   → 'korat'  → synonym: 'thai blue cat'
#   → 'singapura'  → synonym: 'singapore cat'
#   → 'jindo'  → synonym: 'korean jindo'
#   → 'russian blue'  → synonym: 'archangel'
#   → 'chartreux'  → synonym: 'french blue'
#   → 'hamiltonstovare'  → synonym: 'hamilton hound'
#   → 'nederlandse kooikerhondje'  → synonym: 'kooikerhondje'
#   → 'tonkinese'  → synonym: 'tonkinese cat'
#   → 'british shorthair'  → synonym: 'british blue'
#   → 'finnish lapphund'  → synonym: 'finnish lapponian dog'
#   → 'turkish angora'  → synonym: 'turkish angora'
#   → 'abyssinian'  → synonym: 'abyssinian cat'
#   → 'toy manchester terrier'  → synonym: 'english toy terrier'
#   → 'azawakh'  → synonym: 'tuareg sloughi'
#   → 'barbet'  → synonym: 'capitonidae'
#   → 'thai ridgeback'  → synonym: 'mah thai dog'
#   → 'tibetan terrier'  → synonym: 'dokhi apso'
#   → 'volpino italiano'  → synonym: 'volpino italiano'
#   → 'ocicat'  → synonym: 'abyssinian'
#   → 'lagotto romagnolo'  → synonym: 'lagotto romagnolo'
#   → 'welsh terrier'  → synonym: 'old english terrier'
#   → 'lowchen'  → synonym: 'little lion dog'
#   → 'balinese'  → synonym: 'long-haired siamese'
#   → 'grand basset griffon vendeen'  → synonym: 'gbgv'
#   → 'selkirk rex'  → synonym: 'selkirk longhair'
#   → 'treeing walker coonhound'  → synonym: 'treeing walker'
#   → 'maltese'  → synonym: 'maltese dog'
#   → 'snowshoe'  → synonym: 'snowshoe cat'
#   → 'toyger'  → synonym: 'toyger'
#   → 'himalayan'  → synonym: 'himalayan cat'
#   → 'persian'  → synonym: 'persian cat'
#   → 'west highland white terrier'  → synonym: 'westie'
#   → 'kai ken'  → synonym: 'tora inu'
#   → 'devon rex'  → synonym: 'devon rex'
#   → 'yorkshire terrier'  → synonym: 'yorkie'
#   → 'wirehaired pointing griffon'  → synonym: 'korthals griffon'
#   → 'redbone coonhound'  → synonym: 'redbone hound'
#   → 'manx'  → synonym: 'manx cat'
#   → 'australian terrier'  → synonym: 'aussie terrier'
#   → 'manchester terrier'  → synonym: 'english toy terrier'
#   → 'burmilla'  → synonym: 'burmese shorthair'
#   → 'otterhound'  → synonym: 'otter hound'
#   → 'sussex spaniel'  → synonym: 'none'
#   → 'ibizan hound'  → synonym: 'podenco ibicenco'
#   → 'rat terrier'  → synonym: 'rat terrier'
#   → 'toy fox terrier'  → synonym: 'amertoy fox terrier'
#   → 'bergamasco'  → synonym: 'bergamasco shepherd'
#   → 'cornish rex'  → synonym: 'cornish rex'
#   → 'scottish fold'  → synonym: 'felis catus'
#   → 'birman'  → synonym: 'sacred birman'
#   → 'schipperke'  → synonym: 'belgian barge dog'
#   → 'oriental'  → synonym: 'siamese cat'
#   → 'whippet'  → synonym: 'english whippet'
#   → 'spanish water dog'  → synonym: 'perro de agua español'
#   → 'dandie dinmont terrier'  → synonym: 'dandie dinmont'
#   → 'yakutian laika'  → synonym: 'yakut laika'
#   → 'laperm'  → synonym: 'laperm'
#   → "cirneco dell'etna"  → synonym: "cirneco dell'etna"
#   → 'sloughi'  → synonym: 'arabian greyhound'
#   → 'pyrenean shepherd'  → synonym: 'pyrenean sheepdog'
#   → 'tibetan spaniel'  → synonym: 'tsang apso'
#   → 'xiasi dog'  → synonym: 'chinese chongqing dog'
#   → 'cymric'  → synonym: 'longhaired manx'
#   → 'burmese'  → synonym: 'burmese cat'
#   → 'xoloitzcuintli'  → synonym: 'mexican hairless dog'
#   → 'peruvian inca orchid'  → synonym: 'peruvian hairless dog'
#   → 'tibetan mastiff'  → synonym: 'do-khyi'
#   → 'exotic shorthair'  → synonym: 'persian cat'
#   → 'tornjak'  → synonym: 'bosnian-herzegovinian shepherd dog'
#   → 'wire fox terrier'  → synonym: 'wire-haired fox terrier'
#   → 'nebelung'  → synonym: 'russian blue'
#   → 'kooikerhondje'  → synonym: 'nederlandse kooikerhondje'
# 🧹 Removed 3 invalid synonym labels like 'none' or 'null'
# 📏 OOD classes before synonym expansion: 92
# 📐 OOD classes after synonym + deduplication: 161
#
# 🧪 Final ID Labels passed to CLIP: ['Havanese', 'Newfoundland', 'Sphynx', 'American Bulldog', 'Samoyed', 'Great Pyrenees', 'Maine Coon', 'Staffordshire Bull Terrier', 'Saint Bernard', 'Bengal', 'Basset Hound', 'Egyptian Mau', 'Shiba Inu', 'Bombay', 'English Cocker Spaniel', 'Japanese Chin', 'Ragdoll', 'Keeshond']
# 🚫 OOD candidate labels: ['portuguese podengo', 'somali', 'chihuahua', 'havana brown', 'clumber spaniel', 'american curl', 'european burmese- irish wolfhound', 'pomeranian', 'harrier', 'papillon', 'turkish van', 'pumi', 'siamese', 'american shorthair', 'cavalier king charles spaniel', 'ragamuffin', 'entlebucher mountain dog', 'swedish vallhund', 'affenpinscher', 'munchkin', 'korat', 'singapura', 'jindo', 'russian blue', 'chartreux', 'hamiltonstovare', 'nederlandse kooikerhondje', 'tonkinese', 'british shorthair', 'finnish lapphund', 'turkish angora', 'abyssinian', 'toy manchester terrier', 'azawakh', 'barbet', 'thai ridgeback', 'tibetan terrier', 'volpino italiano', 'ocicat', 'lagotto romagnolo', 'welsh terrier', 'lowchen', 'balinese', 'grand basset griffon vendeen', 'selkirk rex', 'treeing walker coonhound', 'maltese', 'snowshoe', 'toyger', 'himalayan', 'persian', 'west highland white terrier', 'kai ken', 'devon rex', 'yorkshire terrier', 'wirehaired pointing griffon', 'redbone coonhound', 'manx', 'australian terrier', 'manchester terrier', 'burmilla', 'otterhound', 'sussex spaniel', 'ibizan hound', 'rat terrier', 'toy fox terrier', 'bergamasco', 'cornish rex', 'scottish fold', 'birman', 'schipperke', 'oriental', 'whippet', 'spanish water dog', 'dandie dinmont terrier', 'yakutian laika', 'laperm', "cirneco dell'etna", 'sloughi', 'pyrenean shepherd', 'tibetan spaniel', 'xiasi dog', 'cymric', 'burmese', 'xoloitzcuintli', 'peruvian inca orchid', 'tibetan mastiff', 'exotic shorthair', 'tornjak', 'wire fox terrier', 'nebelung', 'kooikerhondje', 'podengo português', 'havana cat', 'irish wolfhound', 'zwergspitz', 'circus aeruginosus', 'continental toy spaniel', 'van cat', 'hungarian sheepdog', 'siamese cat', 'domestic shorthair', 'entlebucher sennenhund', 'viking dog', 'monkey terrier', 'midget cat', 'thai blue cat', 'singapore cat', 'korean jindo', 'archangel', 'french blue', 'hamilton hound', 'tonkinese cat', 'british blue', 'finnish lapponian dog', 'abyssinian cat', 'english toy terrier', 'tuareg sloughi', 'capitonidae', 'mah thai dog', 'dokhi apso', 'old english terrier', 'little lion dog', 'long-haired siamese', 'gbgv', 'selkirk longhair', 'treeing walker', 'maltese dog', 'snowshoe cat', 'himalayan cat', 'persian cat', 'westie', 'tora inu', 'yorkie', 'korthals griffon', 'redbone hound', 'manx cat', 'aussie terrier', 'burmese shorthair', 'otter hound', 'podenco ibicenco', 'amertoy fox terrier', 'bergamasco shepherd', 'felis catus', 'sacred birman', 'belgian barge dog', 'english whippet', 'perro de agua español', 'dandie dinmont', 'yakut laika', 'arabian greyhound', 'pyrenean sheepdog', 'tsang apso', 'chinese chongqing dog', 'longhaired manx', 'burmese cat', 'mexican hairless dog', 'peruvian hairless dog', 'do-khyi', 'bosnian-herzegovinian shepherd dog', 'wire-haired fox terrier']
# 100%|██████████| 7/7 [00:27<00:00,  3.88s/it]
# 2025-07-15 14:45:44,989 : 📦 Evaluating OOD dataset pet19_OOD
# DEBUG:__main__:📦 Evaluating OOD dataset pet19_OOD
# 100%|██████████| 8/8 [00:28<00:00,  3.57s/it]
# 2025-07-15 14:46:13,924 : in scores: DescribeResult(nobs=1773, minmax=(np.float32(-0.0050612846), np.float32(-0.0041718106)), mean=np.float32(-0.0046908017), variance=np.float64(2.1231889835436122e-08), skewness=np.float64(0.5400921702384949), kurtosis=np.float32(0.61490726))
# DEBUG:__main__:in scores: DescribeResult(nobs=1773, minmax=(np.float32(-0.0050612846), np.float32(-0.0041718106)), mean=np.float32(-0.0046908017), variance=np.float64(2.1231889835436122e-08), skewness=np.float64(0.5400921702384949), kurtosis=np.float32(0.61490726))
# 2025-07-15 14:46:13,931 : out scores: DescribeResult(nobs=1896, minmax=(np.float32(-0.004818797), np.float32(-0.004057007)), mean=np.float32(-0.004422023), variance=np.float64(2.0472497620819126e-08), skewness=np.float64(-0.10789380967617035), kurtosis=np.float32(-0.5783191))
# DEBUG:__main__:out scores: DescribeResult(nobs=1896, minmax=(np.float32(-0.004818797), np.float32(-0.004057007)), mean=np.float32(-0.004422023), variance=np.float64(2.0472497620819126e-08), skewness=np.float64(-0.10789380967617035), kurtosis=np.float32(-0.5783191))
# 2025-07-15 14:46:15,199 : 				EOE
# DEBUG:__main__:				EOE
# 2025-07-15 14:46:15,208 :   FPR95 AUROC AUPR
# DEBUG:__main__:  FPR95 AUROC AUPR
# 2025-07-15 14:46:15,212 : & 55.22 & 90.22 & 90.81
# DEBUG:__main__:& 55.22 & 90.22 & 90.81
# 2025-07-15 14:46:15,217 :
#
# 📊 Mean Test Results
# DEBUG:__main__:
#
# 📊 Mean Test Results
# 2025-07-15 14:46:15,222 : 				EOE
# DEBUG:__main__:				EOE
# 2025-07-15 14:46:15,226 :   FPR95 AUROC AUPR
# DEBUG:__main__:  FPR95 AUROC AUPR
# 2025-07-15 14:46:15,230 : & 55.22 & 90.22 & 90.81
# DEBUG:__main__:& 55.22 & 90.22 & 90.81

# %%
sys.argv = [
    "eval_ood_detection.py",
    "--name",        "PET19_PET18_EOE_300L_finegrained_synonymOOD",
    "--in_dataset",  "pet18_ID",
    "--ood_task",    "fine_grained",
    "--score",       "EOE",
    "--score_ablation", "EOE",           # use standard EOE score
    "--generate_class",                  # generate OOD candidates via LLM
    "--use_synonyms",                   # apply synonym expansion to OOD classes
    "--root_dir",    "datasets",
    "--batch_size",  "256",
    "--gpu",         "0",
    "--L",           "300",
]
main()
# Out:
# /usr/local/lib/python3.11/dist-packages/torch/utils/data/dataloader.py:624: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(
# ✅ Original ID Labels: ['Havanese', 'Newfoundland', 'Sphynx', 'American Bulldog', 'Samoyed', 'Great Pyrenees', 'Maine Coon', 'Staffordshire Bull Terrier', 'Saint Bernard', 'Bengal', 'Basset Hound', 'Egyptian Mau', 'Shiba Inu', 'Bombay', 'English Cocker Spaniel', 'Japanese Chin', 'Ragdoll', 'Keeshond']
# 🔮 Using LLM-generated OOD candidate classes...
# Envisioning Outlier Exposure...
# 🔵 Generating via OpenAI GPT...
# Continuing vision 1/5
# Continuing vision 2/5
# Continuing vision 3/5
# Continuing vision 4/5
# Continuing vision 5/5
# 🔍 Raw GPT output:
#  - Siamese
# - Persian
# - Chihuahua
# - Siamese
# - Pomeranian
# - Abyssinian
# - Cavalier King Charles Spaniel
# - Russian Blue
# - Maltese
# - Ragamuffin
# - Scottish Fold
# - Papillon
# - Cornish Rex
# - Toyger
# - Devon Rex
# - Birman
# - Manx
# - Chartreux
# - Burmese
# - American Shorthair
# - Tonkinese
# - Turkish Angora
# - Havana Brown
# - Singapura
# - Balinese
# - Ocicat
# - American Wirehair
# - Turkish Van
# - Norwegian Forest Cat
# - Exotic Shorthair
# - American Curl
# - British Shorthair
# - Bombay
# - Himalayan
# - Somali
# - Munchkin
# - LaPerm
# - Selkirk Rex
# - Peterbald
# - Sphynx
# - Australian Mist
# - Burmilla
# - Egyptian Mau
# - Korat
# - Nebelung
# - Ojos Azules
# - Pixie-Bob
# - Savannah
# - Serengeti- Irish Wolfhound
# - Tibetan Mastiff
# - Tibetan Spaniel
# - Tibetan Terrier
# - Toy Fox Terrier
# - Toy Manchester Terrier
# - Toy Poodle
# - Toy Terrier
# - Treeing Walker Coonhound
# - Vizsla
# - Weimaraner
# - Welsh Springer Spaniel
# - Welsh Terrier
# - West Highland White Terrier
# - Whippet
# - Wire Fox Terrier
# - Wirehaired Pointing Griffon
# - Xoloitzcuintli
# - Yorkshire Terrier
# - Affenpinscher
# - American Eskimo Dog
# - American Hairless Terrier
# - American Water Spaniel
# - Anatolian Shepherd Dog
# - Australian Cattle Dog
# - Australian Kelpie
# - Australian Terrier
# - Basenji
# - Basset Fauve de Bretagne
# - Basset Griffon Vendeen
# - Bearded Collie
# - Bedlington Terrier
# - Belgian Malinois
# - Belgian Sheepdog
# - Belgian Tervuren
# - Bergamasco
# - Berger Picard
# - Bernese Mountain Dog
# - Bichon Frise
# - Black and Tan Coonhound
# - Black Russian Terrier
# - Bloodhound
# - Bluetick Coonhound
# - Boerboel
# - Borzoi
# - Bouvier des Flandres
# - Bracco Italiano- Cane Corso
# - Cardigan Welsh Corgi
# - Catahoula Leopard Dog
# - Caucasian Shepherd Dog
# - Cesky Terrier
# - Chesapeake Bay Retriever
# - Chinese Crested
# - Chinese Shar-Pei
# - Chinook
# - Clumber Spaniel
# - Curly-Coated Retriever
# - Czechoslovakian Vlcak
# - Dandie Dinmont Terrier
# - Danish-Swedish Farmdog
# - Dingo
# - Dutch Shepherd
# - English Foxhound
# - English Setter
# - English Springer Spaniel
# - Entlebucher Mountain Dog
# - Estrela Mountain Dog
# - Eurasier
# - Field Spaniel
# - Finnish Lapphund
# - Finnish Spitz
# - Flat-Coated Retriever
# - Fox Terrier
# - French Bulldog
# - German Pinscher
# - Snowshoe
# - Somali
# - Sphynx
# - Tonkinese
# - Turkish Angora
# - Turkish Van
# - American Eskimo Dog
# - Australian Cattle Dog
# - Australian Shepherd
# - Basset Hound
# - Bearded Collie
# - Belgian Malinois
# - Bernese Mountain Dog
#
# 💾 Saving hallucinated class descriptors to: envisioned_classes/fine_grained_300/pet18_ID_gpt-3.5-turbo_5.json
# === load json:  envisioned_classes/fine_grained_300/pet18_ID_gpt-3.5-turbo_5.json
# Get Envisioned Candidate Class Names.
# After set: 209
# After removing ID class overlaps: 200
# 🔁 Augmenting OOD candidates with synonyms...
#   → 'german pinscher'  → synonym: 'deutscher pinscher'
#   → 'italian greyhound'  → synonym: 'piccolo levriero italiano'
#   → 'english setter'  → synonym: 'setter'
#   → 'portuguese podengo'  → synonym: 'portuguese warren hound'
#   → 'bearded collie'  → synonym: 'highland collie'
#   → 'savannah'  → synonym: 'serval'
#   → 'somali'  → synonym: 'abyssinian'
#   → 'miniature schnauzer'  → synonym: 'zwergschnauzer'
#   → 'chihuahua'  → synonym: 'chihuahua'
#   → 'havana brown'  → synonym: 'havana brown'
#   → 'peterbald'  → synonym: 'petersburg sphynx'
#   → 'american curl'  → synonym: 'none'
#   → 'clumber spaniel'  → synonym: 'clumber spaniel'
#   → 'bouvier des flandres'  → synonym: 'flanders cattle dog'
#   → 'australian shepherd'  → synonym: 'aussie'
#   → 'lhasa apso'  → synonym: 'lhasa terrier'
#   → 'saluki'  → synonym: 'persian greyhound'
#   → 'pomeranian'  → synonym: 'zwergspitz'
#   → 'bloodhound'  → synonym: 'chien de saint-hubert'
#   → 'harrier'  → synonym: 'circus aeruginosus'
#   → 'papillon'  → synonym: 'continental toy spaniel'
#   → 'turkish van'  → synonym: 'turkish vankedisi'
#   → 'siamese'  → synonym: 'siamese cat'
#   → 'american shorthair'  → synonym: 'domestic shorthair'
#   → 'cavalier king charles spaniel'  → synonym: 'cavalier king charles spaniel'
#   → 'ragamuffin'  → synonym: 'none'
#   → 'entlebucher mountain dog'  → synonym: 'entlebucher sennenhund'
#   → 'swedish vallhund'  → synonym: 'viking dog'
#   → 'affenpinscher'  → synonym: 'affenpinscher'
#   → 'munchkin'  → synonym: 'midget cat'
#   → 'miniature pinscher'  → synonym: 'zwergpinscher'
#   → 'korat'  → synonym: 'thai blue cat'
#   → 'singapura'  → synonym: 'singapore cat'
#   → 'toy terrier'  → synonym: 'english toy terrier'
#   → 'bracco italiano- cane corso'  → synonym: 'cane corso'
#   → 'nova scotia duck tolling retriever'  → synonym: 'toller'
#   → 'parson russell terrier'  → synonym: 'jack russell terrier'
#   → 'berger picard'  → synonym: 'picardy shepherd'
#   → 'russian blue'  → synonym: 'archangel'
#   → 'chartreux'  → synonym: 'french blue'
#   → 'hamiltonstovare'  → synonym: 'hamilton hound'
#   → 'spinone italiano'  → synonym: 'italian spinone'
#   → 'bedlington terrier'  → synonym: 'rothbury terrier'
#   → 'chinese crested'  → synonym: 'crested dog'
#   → 'black and tan coonhound'  → synonym: 'american black and tan coonhound'
#   → 'chinese shar-pei'  → synonym: 'chinese fighting dog'
#   → 'siberian husky'  → synonym: 'husky'
#   → 'tonkinese'  → synonym: 'tonkinese cat'
#   → 'irish terrier'  → synonym: 'irish red terrier'
#   → 'danish-swedish farmdog'  → synonym: 'dansk-svensk gårdshund'
#   → 'czechoslovakian vlcak'  → synonym: 'czechoslovakian wolfdog'
#   → 'british shorthair'  → synonym: 'british blue'
#   → 'basset fauve de bretagne'  → synonym: 'basset fauve de bretagne'
#   → 'finnish lapphund'  → synonym: 'finnish lapponian dog'
#   → 'pointer'  → synonym: 'english pointer'
#   → 'maremma sheepdog'  → synonym: 'pastore maremmano-abruzzese'
#   → 'turkish angora'  → synonym: 'turkish angora'
#   → 'abyssinian'  → synonym: 'abyssinian cat'
#   → 'toy manchester terrier'  → synonym: 'english toy terrier'
#   → 'flat-coated retriever'  → synonym: 'flat-coated retriever'
#   → 'belgian malinois'  → synonym: 'belgian shepherd'
#   → 'sealyham terrier'  → synonym: 'welsh border terrier'
#   → 'rhodesian ridgeback'  → synonym: 'african lion hound'
#   → 'hovawart'  → synonym: 'hovawart'
#   → 'japanese spitz'  → synonym: 'chrysanthemum dog'
#   → 'javanese'  → synonym: 'javanese cat'
#   → 'cardigan welsh corgi'  → synonym: 'cardigan welsh corgi'
#   → 'french bulldog'  → synonym: 'bouledogue français'
#   → 'karelian bear dog'  → synonym: 'karjalankarhukoira'
#   → 'cesky terrier'  → synonym: 'bohemian terrier'
#   → 'serengeti- irish wolfhound'  → synonym: 'canis lupus familiaris'
#   → 'bernese mountain dog'  → synonym: 'bernese sennenhund'
#   → 'boerboel'  → synonym: 'south african mastiff'
#   → 'japanese bobtail'  → synonym: 'mi-ke'
#   → 'tibetan terrier'  → synonym: 'dokhi apso'
#   → 'irish water spaniel'  → synonym: 'whiptail water spaniel'
#   → 'eurasier'  → synonym: 'eurasier'
#   → 'ocicat'  → synonym: 'abyssinian'
#   → 'polish lowland sheepdog'  → synonym: 'polski owczarek nizinny'
#   → 'welsh terrier'  → synonym: 'old english terrier'
#   → 'lagotto romagnolo'  → synonym: 'lagotto romagnolo'
#   → 'glen of imaal terrier'  → synonym: 'irish glen of imaal terrier'
#   → 'old english sheepdog'  → synonym: 'bobtail'
#   → 'lowchen'  → synonym: 'little lion dog'
#   → 'norfolk terrier'  → synonym: 'norwich terrier'
#   → 'portuguese water dog'  → synonym: 'cão de água português'
#   → 'australian mist'  → synonym: 'spotted mist'
#   → 'greenland dog'  → synonym: 'kalaallit qimmiq'
#   → 'miniature bull terrier'  → synonym: 'miniature bull terrier'
#   → 'standard schnauzer'  → synonym: 'mittelschnauzer'
#   → 'balinese'  → synonym: 'long-haired siamese'
#   → 'welsh springer spaniel'  → synonym: 'welsh spaniel'
#   → 'grand basset griffon vendeen'  → synonym: 'gbgv'
#   → 'bluetick coonhound'  → synonym: 'bluetick hound'
#   → 'belgian tervuren'  → synonym: 'belgian shepherd'
#   → 'tosa'  → synonym: 'tosa inu'
#   → 'selkirk rex'  → synonym: 'selkirk rex'
#   → 'treeing tennessee brindle'  → synonym: 'tennessee treeing brindle'
#   → 'treeing walker coonhound'  → synonym: 'treeing walker dog'
#   → 'great swiss mountain dog'  → synonym: 'grosser schweizer sennenhund'
#   → 'maltese'  → synonym: 'maltese dog'
#   → 'borzoi'  → synonym: 'russian wolfhound'
#   → 'snowshoe'  → synonym: 'snowshoe cat'
#   → 'pekingese'  → synonym: 'peking palasthund'
#   → 'toyger'  → synonym: 'toyger'
#   → 'himalayan'  → synonym: 'himalayan cat'
#   → 'basset griffon vendeen'  → synonym: 'basset fauve de bretagne'
#   → 'dingo'  → synonym: 'canis lupus dingo'
#   → 'icelandic sheepdog'  → synonym: 'icelandic spitz'
#   → 'persian'  → synonym: 'persian cat'
#   → 'vizsla'  → synonym: 'hungarian pointer'
#   → 'anatolian shepherd dog'  → synonym: 'anatolian karabash'
#   → 'estrela mountain dog'  → synonym: 'portuguese shepherd'
#   → 'field spaniel'  → synonym: 'field spaniel'
#   → 'plott'  → synonym: 'plott hound'
#   → 'west highland white terrier'  → synonym: 'westie'
#   → 'mastiff'  → synonym: 'canis lupus familiaris'
#   → 'rottweiler'  → synonym: 'rottweiler'
#   → 'kai ken'  → synonym: 'tora inu'
#   → 'devon rex'  → synonym: 'devon rex'
#   → 'pembroke welsh corgi'  → synonym: 'welsh corgi'
#   → 'silky terrier'  → synonym: 'australian silky terrier'
#   → 'pug'  → synonym: 'canis lupus familiaris'
#   → 'puli'  → synonym: 'hungarian puli'
#   → 'weimaraner'  → synonym: 'weimaraner'
#   → 'yorkshire terrier'  → synonym: 'yorkie'
#   → 'wirehaired pointing griffon'  → synonym: 'korthals griffon'
#   → 'redbone coonhound'  → synonym: 'redbone hound'
#   → 'manx'  → synonym: 'manx cat'
#   → 'black russian terrier'  → synonym: 'tchiorny terrier'
#   → 'scottish deerhound'  → synonym: 'deerhound'
#   → 'norwegian forest cat'  → synonym: 'norsk skogkatt'
#   → 'shetland sheepdog- shiba inu'  → synonym: 'sheltie\nshiba inu'
#   → 'toy poodle'  → synonym: 'caniche toy'
#   → 'pixie-bob'  → synonym: 'pixiebob'
#   → 'chesapeake bay retriever'  → synonym: 'chessie'
#   → 'australian terrier'  → synonym: 'aussie terrier'
#   → 'manchester terrier'  → synonym: 'english toy terrier'
#   → 'burmilla'  → synonym: 'burmese shorthair'
#   → 'otterhound'  → synonym: 'otter hound'
#   → 'sussex spaniel'  → synonym: 'none'
#   → 'ibizan hound'  → synonym: 'podenco ibicenco'
#   → 'rat terrier'  → synonym: 'rat terrier'
#   → 'grand bleu de gascogne'  → synonym: 'grand gascony blue'
#   → 'toy fox terrier'  → synonym: 'amertoy fox terrier'
#   → 'bergamasco'  → synonym: 'bergamasco shepherd'
#   → 'cornish rex'  → synonym: 'cornish rex'
#   → 'australian cattle dog'  → synonym: 'blue heeler'
#   → 'scottish fold'  → synonym: 'felis catus'
#   → 'soft coated wheaten terrier'  → synonym: 'irish soft coated wheaten terrier'
#   → 'birman'  → synonym: 'sacred birman'
#   → 'american bobtail'  → synonym: 'none'
#   → 'neapolitan mastiff'  → synonym: 'mastino napoletano'
#   → 'schipperke'  → synonym: 'spitzke'
#   → 'oriental'  → synonym: 'siamese cat'
#   → 'whippet'  → synonym: 'english whippet'
#   → 'lancashire heeler'  → synonym: 'ormskirk terrier'
#   → 'english foxhound'  → synonym: 'foxhound'
#   → 'basenji'  → synonym: 'congo terrier'
#   → 'ojos azules'  → synonym: 'ojos azules'
#   → 'english springer spaniel'  → synonym: 'springer spaniel'
#   → 'american hairless terrier'  → synonym: 'aht'
#   → 'shih tzu'  → synonym: 'shih tzu'
#   → 'skye terrier'  → synonym: 'skye terrier'
#   → 'american water spaniel'  → synonym: 'none'
#   → 'curly-coated retriever'  → synonym: 'curly-coated retriever'
#   → 'dandie dinmont terrier'  → synonym: 'dandie dinmont terrier'
#   → 'finnish spitz'  → synonym: 'finnish spitz'
#   → 'greyhound'  → synonym: 'english greyhound'
#   → 'leonberger'  → synonym: 'none'
#   → 'laperm'  → synonym: 'lāperm'
#   → 'american eskimo dog'  → synonym: 'german spitz'
#   → 'chinook'  → synonym: 'king salmon'
#   → 'australian kelpie'  → synonym: 'australian sheepdog'
#   → 'pharaoh hound'  → synonym: 'kelb tal-fenek'
#   → 'sloughi'  → synonym: 'arabian greyhound'
#   → 'fox terrier'  → synonym: 'smooth fox terrier'
#   → 'siberian'  → synonym: 'siberian cat'
#   → 'pyrenean shepherd'  → synonym: 'pyrenean sheepdog'
#   → 'american wirehair'  → synonym: 'american wirehair'
#   → 'tibetan spaniel'  → synonym: 'tsang apso'
#   → 'kuvasz'  → synonym: 'hungarian kuvasz'
#   → 'burmese'  → synonym: 'burmese cat'
#   → 'xoloitzcuintli'  → synonym: 'mexican hairless dog'
#   → 'belgian sheepdog'  → synonym: 'groenendael'
#   → 'petit basset griffon vendeen'  → synonym: 'pbgv'
#   → 'irish red and white setter'  → synonym: 'irish setter'
#   → 'bichon frise'  → synonym: 'bichon à poil frisé'
#   → 'dutch shepherd'  → synonym: 'hollandse herdershond'
#   → 'tibetan mastiff'  → synonym: 'do-khyi'
#   → 'norwich terrier'  → synonym: 'norwich terrier'
#   → 'exotic shorthair'  → synonym: 'persian cat'
#   → 'catahoula leopard dog'  → synonym: 'catahoula cur'
#   → 'kerry blue terrier'  → synonym: 'irish blue terrier'
#   → 'caucasian shepherd dog'  → synonym: 'caucasian ovcharka'
#   → 'kooikerhondje- keeshond'  → synonym: 'nederlandse kooikerhondje'
#   → 'wire fox terrier'  → synonym: 'wire-haired fox terrier'
#   → 'nebelung'  → synonym: 'russian blue'
#   → 'kooikerhondje'  → synonym: 'nederlandse kooikerhondje'
#   → 'sphynx- abyssinian'  → synonym: 'abyssinian'
# 🧹 Removed 6 invalid synonym labels like 'none' or 'null'
# 📏 OOD classes before synonym expansion: 200
# 📐 OOD classes after synonym + deduplication: 351
#
 'oriental', 'whippet', 'lancashire heeler', 'english foxhound', 'basenji', 'ojos azules', 'english springer spaniel', 'american hairless terrier', 'shih tzu', 'skye terrier', 'american water spaniel', 'curly-coated retriever', 'dandie dinmont terrier', 'finnish spitz', 'greyhound', 'leonberger', 'laperm', 'american eskimo dog', 'chinook', 'australian kelpie', 'pharaoh hound', 'sloughi', 'fox terrier', 'siberian', 'pyrenean shepherd', 'american wirehair', 'tibetan spaniel', 'kuvasz', 'burmese', 'xoloitzcuintli', 'belgian sheepdog', 'petit basset griffon vendeen', 'irish red and white setter', 'bichon frise', 'dutch shepherd', 'tibetan mastiff', 'norwich terrier', 'exotic shorthair', 'catahoula leopard dog', 'kerry blue terrier', 'caucasian shepherd dog', 'kooikerhondje- keeshond', 'wire fox terrier', 'nebelung', 'kooikerhondje', 'sphynx- abyssinian', 'deutscher pinscher', 'piccolo levriero italiano', 'setter', 'portuguese warren hound', 'highland collie', 'serval', 'zwergschnauzer', 'petersburg sphynx', 'flanders cattle dog', 'aussie', 'lhasa terrier', 'persian greyhound', 'zwergspitz ...
# 100%|██████████| 7/7 [00:27<00:00,  3.89s/it]
# 2025-07-15 14:49:11,436 : 📦 Evaluating OOD dataset pet19_OOD
# DEBUG:__main__:📦 Evaluating OOD dataset pet19_OOD
# 100%|██████████| 8/8 [00:28<00:00,  3.61s/it]
# 2025-07-15 14:49:40,700 : in scores: DescribeResult(nobs=1773, minmax=(np.float32(-0.002438955), np.float32(-0.0020476058)), mean=np.float32(-0.0022717915), variance=np.float64(4.143453756172434e-09), skewness=np.float64(0.45307978987693787), kurtosis=np.float32(0.33210254))
# DEBUG:__main__:in scores: DescribeResult(nobs=1773, minmax=(np.float32(-0.002438955), np.float32(-0.0020476058)), mean=np.float32(-0.0022717915), variance=np.float64(4.143453756172434e-09), skewness=np.float64(0.45307978987693787), kurtosis=np.float32(0.33210254))
# 2025-07-15 14:49:40,704 : out scores: DescribeResult(nobs=1896, minmax=(np.float32(-0.002359255), np.float32(-0.0019548042)), mean=np.float32(-0.0021419737), variance=np.float64(5.3643160907123176e-09), skewness=np.float64(-0.03281557559967041), kurtosis=np.float32(-0.4571116))
# DEBUG:__main__:out scores: DescribeResult(nobs=1896, minmax=(np.float32(-0.002359255), np.float32(-0.0019548042)), mean=np.float32(-0.0021419737), variance=np.float64(5.3643160907123176e-09), skewness=np.float64(-0.03281557559967041), kurtosis=np.float32(-0.4571116))
# 2025-07-15 14:49:41,004 : 				EOE
# DEBUG:__main__:				EOE
# 2025-07-15 14:49:41,008 :   FPR95 AUROC AUPR
# DEBUG:__main__:  FPR95 AUROC AUPR
# 2025-07-15 14:49:41,013 : & 48.21 & 90.50 & 90.07
# DEBUG:__main__:& 48.21 & 90.50 & 90.07
# 2025-07-15 14:49:41,014 :
#
# 📊 Mean Test Results
# DEBUG:__main__:
#
# 📊 Mean Test Results
# 2025-07-15 14:49:41,016 : 				EOE
# DEBUG:__main__:				EOE
# 2025-07-15 14:49:41,023 :   FPR95 AUROC AUPR
# DEBUG:__main__:  FPR95 AUROC AUPR
# 2025-07-15 14:49:41,025 : & 48.21 & 90.50 & 90.07
# DEBUG:__main__:& 48.21 & 90.50 & 90.07

# %%
sys.argv = [
    "eval_ood_detection.py",
    "--name",        "PET19_PET18_EOE_500L_finegrained_synonymOOD",
    "--in_dataset",  "pet18_ID",
    "--ood_task",    "fine_grained",
    "--score",       "EOE",
    "--score_ablation", "EOE",           # use standard EOE score
    "--generate_class",                  # generate OOD candidates via LLM
    "--use_synonyms",                   # apply synonym expansion to OOD classes
    "--root_dir",    "datasets",
    "--batch_size",  "256",
    "--gpu",         "0",
    "--L",           "500",
]
main()
# Out:
# /usr/local/lib/python3.11/dist-packages/torch/utils/data/dataloader.py:624: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(
# ✅ Original ID Labels: ['Havanese', 'Newfoundland', 'Sphynx', 'American Bulldog', 'Samoyed', 'Great Pyrenees', 'Maine Coon', 'Staffordshire Bull Terrier', 'Saint Bernard', 'Bengal', 'Basset Hound', 'Egyptian Mau', 'Shiba Inu', 'Bombay', 'English Cocker Spaniel', 'Japanese Chin', 'Ragdoll', 'Keeshond']
# 🔮 Using LLM-generated OOD candidate classes...
# Envisioning Outlier Exposure...
# 🔵 Generating via OpenAI GPT...
# Continuing vision 1/9
# Continuing vision 2/9
# Continuing vision 3/9
# Continuing vision 4/9
# Continuing vision 5/9
# Continuing vision 6/9
# Continuing vision 7/9
# Continuing vision 8/9
# Continuing vision 9/9
# 🔍 Raw GPT output:
#  - Siamese
# - Persian
# - Chihuahua
# - Siamese
# - Pomeranian
# - Abyssinian
# - Cavalier King Charles Spaniel
# - Russian Blue
# - Maltese
# - Ragamuffin
# - Scottish Fold
# - Cavalier King Charles Spaniel
# - Cornish Rex
# - Papillon
# - Devon Rex
# - Tibetan Mastiff
# - Manx
# - Toyger
# - American Shorthair
# - Tibetan Spaniel
# - Birman
# - Chartreux
# - Australian Terrier
# - Havana Brown
# - Burmese
# - Australian Mist
# - Singapura
# - Australian Cattle Dog
# - Tonkinese
# - Australian Kelpie
# - Turkish Angora
# - Australian Shepherd
# - Turkish Van
# - Australian Silky Terrier
# - British Shorthair
# - Australian Terrier
# - Burmilla
# - Australian Mist
# - Chartreux
# - Australian Kelpie
# - Havana Brown
# - Australian Shepherd
# - Burmese
# - Australian Silky Terrier
# - Singapura
# - Australian Terrier
# - Tonkinese
# - British Shorthair
# - Turkish Angora
# - Burmilla
# - Turkish Van- Irish Wolfhound
# - Bombay
# - Manx
# - Birman
# - Chartreux
# - Havana Brown
# - Burmese
# - Australian Mist
# - Singapura
# - Australian Cattle Dog
# - Tonkinese
# - Australian Kelpie
# - Turkish Angora
# - Australian Shepherd
# - Turkish Van
# - Australian Silky Terrier
# - British Shorthair
# - Burmilla
# - Australian Terrier
# - Chartreux
# - Havana Brown
# - Burmese
# - Australian Mist
# - Singapura
# - Australian Cattle Dog
# - Tonkinese
# - Australian Kelpie
# - Turkish Angora
# - Australian Shepherd
# - Turkish Van
# - Australian Silky Terrier
# - British Shorthair
# - Burmilla
# - Australian Terrier
# - Chartreux
# - Havana Brown
# - Burmese
# - Australian Mist
# - Singapura
# - Australian Cattle Dog
# - Tonkinese
# - Australian Kelpie
# - Turkish Angora
# - Australian Shepherd
# - Turkish Van
# - Australian Silky Terrier
# - British Shorthair
# - Burmilla
# - Australian Terrier- Abyssinian
# - Cavalier King Charles Spaniel
# - Russian Blue
# - Maltese
# - Ragamuffin
# - American Shorthair
# - Tibetan Spaniel
# - Birman
# - Chartreux
# - Havana Brown
# - Burmese
# - Australian Mist
# - Singapura
# - Australian Cattle Dog
# - Tonkinese
# - Australian Kelpie
# - Turkish Angora
# - Australian Shepherd
# - Turkish Van
# - Australian Silky Terrier
# - British Shorthair
# - Burmilla
# - Bombay
# - Manx
# - Chartreux
# - Havana Brown
# - Burmese
# - Australian Mist
# - Singapura
# - Australian Cattle Dog
# - Tonkinese
# - Australian Kelpie
# - Turkish Angora
# - Australian Shepherd
# - Turkish Van
# - Australian Silky Terrier
# - British Shorthair
# - Burmilla
#
# 💾 Saving hallucinated class descriptors to: envisioned_classes/fine_grained_500/pet18_ID_gpt-3.5-turbo_1.json
# === load json:  envisioned_classes/fine_grained_500/pet18_ID_gpt-3.5-turbo_1.json
# Get Envisioned Candidate Class Names.
# After set: 41
# After removing ID class overlaps: 40
# 🔁 Augmenting OOD candidates with synonyms...
#   → 'cavalier king charles spaniel'  → synonym: 'cavalier king charles spaniel'
#   → 'tibetan spaniel'  → synonym: 'tsang apso'
#   → 'australian kelpie'  → synonym: 'australian sheepdog'
#   → 'ragamuffin'  → synonym: 'none'
#   → 'devon rex'  → synonym: 'devon rex'
#   → 'persian'  → synonym: 'persian cat'
#   → 'australian terrier'  → synonym: 'aussie terrier'
#   → 'siamese'  → synonym: 'siamese cat'
#   → 'burmese'  → synonym: 'burmese cat'
#   → 'tonkinese'  → synonym: 'tonkinese cat'
#   → 'australian mist'  → synonym: 'spotted mist'
#   → 'pomeranian'  → synonym: 'zwergspitz'
#   → 'turkish angora'  → synonym: 'turkish angora'
#   → 'havana brown'  → synonym: 'havana brown'
#   → 'cornish rex'  → synonym: 'cornish rex'
#   → 'australian shepherd'  → synonym: 'aussie'
#   → 'singapura'  → synonym: 'singapore cat'
#   → 'australian terrier- siamese'  → synonym: 'australian terrier - silky terrier'
#   → 'tibetan mastiff'  → synonym: 'do-khyi'
#   → 'abyssinian'  → synonym: 'felis catus'
#   → 'birman'  → synonym: 'sacred birman'
#   → 'american shorthair'  → synonym: 'domestic shorthair'
#   → 'australian cattle dog'  → synonym: 'blue heeler'
#   → 'british shorthair'  → synonym: 'british blue'
#   → 'scottish fold'  → synonym: 'scottish fold'
#   → 'chartreux'  → synonym: 'french blue'
#   → 'maltese'  → synonym: 'maltese dog'
#   → 'papillon'  → synonym: 'continental toy spaniel'
#   → 'turkish van'  → synonym: 'turkish vankedisi'
#   → 'toyger'  → synonym: 'toyger'
#   → 'chihuahua'  → synonym: 'chihuahua'
#   → 'russian blue'  → synonym: 'archangel'
#   → 'australian silky terrier'  → synonym: 'silky terrier'
#   → 'turkish van- irish wolfhound'  → synonym: 'cú faoil'
#   → 'manx'  → synonym: 'manx cat'
#   → 'burmilla- siamese'  → synonym: 'burmese cat'
#   → 'manx- siamese'  → synonym: 'siamese cat'
#   → 'burmilla'  → synonym: 'burmese shorthair'
#   → 'australian terrier- abyssinian'  → synonym: 'abyssinian cat'
#   → 'burmilla- abyssinian'  → synonym: 'burmese-abyssinian'
# 🧹 Removed 1 invalid synonym labels like 'none' or 'null'
# 📏 OOD classes before synonym expansion: 40
# 📐 OOD classes after synonym + deduplication: 69
#
# 🧪 Final ID Labels passed to CLIP: ['Havanese', 'Newfoundland', 'Sphynx', 'American Bulldog', 'Samoyed', 'Great Pyrenees', 'Maine Coon', 'Staffordshire Bull Terrier', 'Saint Bernard', 'Bengal', 'Basset Hound', 'Egyptian Mau', 'Shiba Inu', 'Bombay', 'English Cocker Spaniel', 'Japanese Chin', 'Ragdoll', 'Keeshond']
# 🚫 OOD candidate labels: ['cavalier king charles spaniel', 'tibetan spaniel', 'australian kelpie', 'ragamuffin', 'devon rex', 'persian', 'australian terrier', 'siamese', 'burmese', 'tonkinese', 'australian mist', 'pomeranian', 'turkish angora', 'havana brown', 'cornish rex', 'australian shepherd', 'singapura', 'australian terrier- siamese', 'tibetan mastiff', 'abyssinian', 'birman', 'american shorthair', 'australian cattle dog', 'british shorthair', 'scottish fold', 'chartreux', 'maltese', 'papillon', 'turkish van', 'toyger', 'chihuahua', 'russian blue', 'australian silky terrier', 'turkish van- irish wolfhound', 'manx', 'burmilla- siamese', 'manx- siamese', 'burmilla', 'australian terrier- abyssinian', 'burmilla- abyssinian', 'tsang apso', 'australian sheepdog', 'persian cat', 'aussie terrier', 'siamese cat', 'burmese cat', 'tonkinese cat', 'spotted mist', 'zwergspitz', 'aussie', 'singapore cat', 'australian terrier - silky terrier', 'do-khyi', 'felis catus', 'sacred birman', 'domestic shorthair', 'blue heeler', 'british blue', 'french blue', 'maltese dog', 'continental toy spaniel', 'turkish vankedisi', 'archangel', 'silky terrier', 'cú faoil', 'manx cat', 'burmese shorthair', 'abyssinian cat', 'burmese-abyssinian']
# 100%|██████████| 7/7 [00:28<00:00,  4.02s/it]
# 2025-07-18 20:25:03,319 : 📦 Evaluating OOD dataset pet19_OOD
# DEBUG:__main__:📦 Evaluating OOD dataset pet19_OOD
# 100%|██████████| 8/8 [00:29<00:00,  3.73s/it]
# 2025-07-18 20:25:33,570 : in scores: DescribeResult(nobs=1773, minmax=(np.float32(-0.010785013), np.float32(-0.008520357)), mean=np.float32(-0.009701747), variance=np.float64(1.4674616324803406e-07), skewness=np.float64(0.33183467388153076), kurtosis=np.float32(0.20111084))
# DEBUG:__main__:in scores: DescribeResult(nobs=1773, minmax=(np.float32(-0.010785013), np.float32(-0.008520357)), mean=np.float32(-0.009701747), variance=np.float64(1.4674616324803406e-07), skewness=np.float64(0.33183467388153076), kurtosis=np.float32(0.20111084))
# 2025-07-18 20:25:33,575 : out scores: DescribeResult(nobs=1896, minmax=(np.float32(-0.01014705), np.float32(-0.008423168)), mean=np.float32(-0.009133453), variance=np.float64(1.108847827840799e-07), skewness=np.float64(-0.4484894573688507), kurtosis=np.float32(-0.57580996))
# DEBUG:__main__:out scores: DescribeResult(nobs=1896, minmax=(np.float32(-0.01014705), np.float32(-0.008423168)), mean=np.float32(-0.009133453), variance=np.float64(1.108847827840799e-07), skewness=np.float64(-0.4484894573688507), kurtosis=np.float32(-0.57580996))
# 2025-07-18 20:25:33,942 : 				EOE
# DEBUG:__main__:				EOE
# 2025-07-18 20:25:33,944 :   FPR95 AUROC AUPR
# DEBUG:__main__:  FPR95 AUROC AUPR
# 2025-07-18 20:25:33,947 : & 63.29 & 86.26 & 86.66
# DEBUG:__main__:& 63.29 & 86.26 & 86.66
# 2025-07-18 20:25:33,950 :
#
# 📊 Mean Test Results
# DEBUG:__main__:
#
# 📊 Mean Test Results
# 2025-07-18 20:25:33,952 : 				EOE
# DEBUG:__main__:				EOE
# 2025-07-18 20:25:33,954 :   FPR95 AUROC AUPR
# DEBUG:__main__:  FPR95 AUROC AUPR
# 2025-07-18 20:25:33,956 : & 63.29 & 86.26 & 86.66
# DEBUG:__main__:& 63.29 & 86.26 & 86.66

# %%
sys.argv = [
    "eval_ood_detection.py",
    "--name",        "PET19_PET18_EOE_500L_finegrained",
    "--in_dataset",  "pet18_ID",
    "--ood_task",    "fine_grained",
    "--score",       "EOE",
    "--score_ablation", "EOE",           # use standard EOE score
    "--generate_class",                  # generate OOD candidates via LLM
    "--root_dir",    "datasets",
    "--batch_size",  "256",
    "--gpu",         "0",
    "--L",           "500",
]
main()
# Out:
# /usr/local/lib/python3.11/dist-packages/torch/utils/data/dataloader.py:624: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(
# ✅ Original ID Labels: ['Havanese', 'Newfoundland', 'Sphynx', 'American Bulldog', 'Samoyed', 'Great Pyrenees', 'Maine Coon', 'Staffordshire Bull Terrier', 'Saint Bernard', 'Bengal', 'Basset Hound', 'Egyptian Mau', 'Shiba Inu', 'Bombay', 'English Cocker Spaniel', 'Japanese Chin', 'Ragdoll', 'Keeshond']
# 🔮 Using LLM-generated OOD candidate classes...
# Envisioning Outlier Exposure...
# 🔵 Generating via OpenAI GPT...
# Continuing vision 1/9
# Continuing vision 2/9
# Continuing vision 3/9
# Continuing vision 4/9
# Continuing vision 5/9
# Continuing vision 6/9
# Continuing vision 7/9
# Continuing vision 8/9
# Continuing vision 9/9
# 🔍 Raw GPT output:
#  - Siamese
# - Persian
# - Chihuahua
# - Siamese
# - Pomeranian
# - Abyssinian
# - Cavalier King Charles Spaniel
# - Ragamuffin
# - Scottish Fold
# - Maltese
# - Russian Blue
# - Papillon
# - Cornish Rex
# - Devon Rex
# - Manx
# - Birman
# - Burmese
# - Chartreux
# - Havana Brown
# - Tonkinese
# - Turkish Angora
# - Turkish Van
# - American Shorthair
# - British Shorthair
# - Exotic Shorthair
# - Himalayan
# - Javanese
# - Korat
# - Norwegian Forest Cat
# - Ocicat
# - Oriental
# - Russian Black
# - Russian White
# - Scottish Fold
# - Selkirk Rex
# - Singapura
# - Snowshoe
# - Somali
# - Sphynx
# - Tonkinese
# - Toyger
# - Turkish Van
# - Balinese
# - Birman
# - Bombay
# - British Shorthair
# - Burmese
# - Chartreux
# - Cornish Rex
# - Devon Rex- Irish Wolfhound
# - Tibetan Mastiff
# - Tibetan Spaniel
# - Tibetan Terrier
# - Toy Fox Terrier
# - Vizsla
# - Weimaraner
# - Welsh Corgi
# - West Highland White Terrier
# - Whippet
# - Wirehaired Pointing Griffon
# - Xoloitzcuintli
# - Yorkshire Terrier
# - American Eskimo Dog
# - Australian Terrier
# - Bedlington Terrier
# - Belgian Malinois
# - Belgian Sheepdog
# - Belgian Tervuren
# - Bernese Mountain Dog
# - Black and Tan Coonhound
# - Bloodhound
# - Border Terrier
# - Borzoi
# - Mudi
# - Nederlandse Kooikerhondje
# - Norrbottenspets
# - Peruvian Inca Orchid
# - Plott Hound
# - Pumi
# - Pyrenean Shepherd
# - Rat Terrier
# - Russian Toy
# - Saluki
# - Schapendoes
# - Schiller Hound
# - Sealyham Terrier
# - Shikoku
# - Slovakian Rough-haired Pointer
# - Slovensky Cuvac
# - Slovensky Kopov
# - Small Munsterlander
# - Spanish Water Dog
# - Stabyhoun
# - Sussex Spaniel
# - Swedish Lapphund
# - Thai Ridgeback
# - Tornjak
# - Tosa- Australian Cattle Dog
# - Australian Kelpie
# - Australian Shepherd
# - Basenji
# - Bearded Collie
# - Beauceron
# - Belgian Laekenois
# - Bergamasco
# - Bichon Frise
# - Black Russian Terrier
# - Bluetick Coonhound
# - Boerboel
# - Bouvier des Ardennes
# - Boykin Spaniel
# - Bracco Italiano
# - Braque du Bourbonnais
# - Briquet Griffon Vendeen
# - Broholmer
# - Brussels Griffon
# - Bullmastiff
# - Cairn Terrier
# - Canaan Dog
# - Cane Corso
# - Cardigan Welsh Corgi
# - Catahoula Leopard Dog
# - Caucasian Shepherd Dog
# - Cesky Terrier
# - Chesapeake Bay Retriever
# - Chinook
# - Clumber Spaniel
# - Curly-Coated Retriever
# - Dalmatian
# - Danish-Swedish Farmdog
# - Dingo
# - Dutch Shepherd
# - English Springer Spaniel
# - Entlebucher Mountain Dog
# - Estrela Mountain Dog
# - Eurasier
# - Field Spaniel
# - Finnish Spitz
# - Flat-Coated Retriever
# - Fox Terrier
# - French Bulldog
# - German Pinscher
# - Glen of Imaal Terrier
# - Gordon Setter
# - Grand Basset Griffon Vendeen- Hamiltonstovare
# - Harrier
# - Hovawart
# - Icelandic Sheepdog
# - Jagdterrier
# - Kai Ken
# - Kooikerhondje
# - Lagotto Romagnolo
# - Lancashire Heeler
# - Leonberger
# - Lhasa Apso
# - Mudi
# - Nederlandse Kooikerhondje
# - Norrbottenspets
# - Peruvian Inca Orchid
# - Plott Hound
# - Pumi
# - Pyrenean Shepherd
# - Rat Terrier
# - Russian Toy
# - Saluki
# - Schapendoes
# - Schiller Hound
# - Sealyham Terrier
# - Shikoku
# - Slovakian Rough-haired Pointer
# - Slovensky Cuvac
# - Slovensky Kopov
# - Small Munsterlander
# - Spanish Water Dog
# - Stabyhoun
# - Sussex Spaniel
# - Swedish Lapphund
# - Thai Ridgeback
# - Tornjak
# - Tosa
# - Affenpinscher
# - Azawakh
# - Barbet
# - Bolognese
# - Braque Francais
# - Cirneco dell'Etna
# - Drentse Patrijshond
# - Dutch Smoushond
# - Finnish Lapphund
# - German Pinscher
# - Grand Basset Griffon Vendeen
#
# 💾 Saving hallucinated class descriptors to: envisioned_classes/fine_grained_500/pet18_ID_gpt-3.5-turbo_3.json
# === load json:  envisioned_classes/fine_grained_500/pet18_ID_gpt-3.5-turbo_3.json
# Get Envisioned Candidate Class Names.
# After set: 269
# After removing ID class overlaps: 259
#
sh corgi', 'schiller hound', 'ragamuffin', 'labradoodle', 'schapendoes', 'burmese', 'bergamasco', 'bullmastiff', 'dandie dinmont terrier', 'bearded collie', 'polish lowland sheepdog', 'standard schnauzer', 'american curl', 'chinese shar-pei', 'tornjak', 'xoloitzcuintli', 'cairn terrier', 'javanese', 'caucasian shepherd dog', 'mudi', 'pug', 'stabyhoun', 'belgian laekenois', 'broholmer', 'chihuahua', 'pharaoh hound', 'irish terrier', 'russian toy', 'manchester terrier', 'welsh springer spaniel', 'norrbottenspets', 'papillon', 'old english sheepdog', 'fox terrier', 'singapura', 'borzoi', 'bernese mountain dog', 'cesky terrier', 'wirehaired vizsla', 'bouvier des ardennes', 'nebelung', 'irish water spaniel', 'eurasier', 'swedish lapphund', 'belgian tervuren', 'sloughi', 'manx', 'silky terrier', 'devon rex', 'collie', 'maremma sheepdog', 'sussex spaniel', 'bolognese', 'greenland dog', 'miniature bull terrier', 'treeing walker coonhound', 'curly-coated retriever', 'vizsla', 'himalayan', 'braque du bourbonnais', 'persian', 'pyrenean shepherd', 'sealyham terrier', 'portuguese podengo', 'norwegian forest cat', 'spinone italiano' ...
# 100%|██████████| 7/7 [00:29<00:00,  4.16s/it]
# 2025-07-20 08:28:22,408 : 📦 Evaluating OOD dataset pet19_OOD
# DEBUG:__main__:📦 Evaluating OOD dataset pet19_OOD
# 100%|██████████| 8/8 [00:27<00:00,  3.45s/it]
# 2025-07-20 08:28:50,349 : in scores: DescribeResult(nobs=1773, minmax=(np.float32(-0.0032745232), np.float32(-0.0027506126)), mean=np.float32(-0.003040666), variance=np.float64(8.046138423705609e-09), skewness=np.float64(0.3803585171699524), kurtosis=np.float32(0.020612478))
# DEBUG:__main__:in scores: DescribeResult(nobs=1773, minmax=(np.float32(-0.0032745232), np.float32(-0.0027506126)), mean=np.float32(-0.003040666), variance=np.float64(8.046138423705609e-09), skewness=np.float64(0.3803585171699524), kurtosis=np.float32(0.020612478))
# 2025-07-20 08:28:50,354 : out scores: DescribeResult(nobs=1896, minmax=(np.float32(-0.0031693177), np.float32(-0.0026151803)), mean=np.float32(-0.0028673443), variance=np.float64(9.869058933664245e-09), skewness=np.float64(-0.10776577889919281), kurtosis=np.float32(-0.44166183))
# DEBUG:__main__:out scores: DescribeResult(nobs=1896, minmax=(np.float32(-0.0031693177), np.float32(-0.0026151803)), mean=np.float32(-0.0028673443), variance=np.float64(9.869058933664245e-09), skewness=np.float64(-0.10776577889919281), kurtosis=np.float32(-0.44166183))
# 2025-07-20 08:28:50,653 : 				EOE
# DEBUG:__main__:				EOE
# 2025-07-20 08:28:50,656 :   FPR95 AUROC AUPR
# DEBUG:__main__:  FPR95 AUROC AUPR
# 2025-07-20 08:28:50,658 : & 47.84 & 89.76 & 89.15
# DEBUG:__main__:& 47.84 & 89.76 & 89.15
# 2025-07-20 08:28:50,660 :
#
# 📊 Mean Test Results
# DEBUG:__main__:
#
# 📊 Mean Test Results
# 2025-07-20 08:28:50,661 : 				EOE
# DEBUG:__main__:				EOE
# 2025-07-20 08:28:50,663 :   FPR95 AUROC AUPR
# DEBUG:__main__:  FPR95 AUROC AUPR
# 2025-07-20 08:28:50,665 : & 47.84 & 89.76 & 89.15
# DEBUG:__main__:& 47.84 & 89.76 & 89.15

# %% [markdown]
# # **Experiment Semantic Variant OOD PET-19 vs PET-18 (Beta=0.75,L=50,100,300,500)**

# %%
sys.argv = [
    "eval_ood_detection.py",
    "--name",        "PET19_PET18_EOE_50L_75B_finegrained_synonymOOD",
    "--in_dataset",  "pet18_ID",
    "--ood_task",    "fine_grained",
    "--score",       "EOE",
    "--score_ablation", "EOE",           # use standard EOE score
    "--generate_class",                  # generate OOD candidates via LLM
    "--use_synonyms",                   # apply synonym expansion to OOD classes
    "--root_dir",    "datasets",
    "--batch_size",  "256",
    "--gpu",         "0",
    "--beta",       "0.75",
    "--L",           "50",
]
main()
# Out:
# ✅ Original ID Labels: ['Havanese', 'Newfoundland', 'Sphynx', 'American Bulldog', 'Samoyed', 'Great Pyrenees', 'Maine Coon', 'Staffordshire Bull Terrier', 'Saint Bernard', 'Bengal', 'Basset Hound', 'Egyptian Mau', 'Shiba Inu', 'Bombay', 'English Cocker Spaniel', 'Japanese Chin', 'Ragdoll', 'Keeshond']
# 🔮 Using LLM-generated OOD candidate classes...
# Envisioning Outlier Exposure...
# 🔵 Generating via OpenAI GPT...
# 🔍 Raw GPT output:
#  - Siamese
#         - Persian
#         - Chihuahua
#         - Cavalier King Charles Spaniel
#         - Siamese
#         - Russian Blue
#         - Abyssinian
#         - Pomeranian
#         - Ragamuffin
#         - Cornish Rex
#         - Devon Rex
#         - Scottish Fold
#         - Manx
#         - Burmese
#         - Birman
#         - Himalayan
#         - Turkish Angora
#         - Turkish Van
#         - Exotic Shorthair
#         - American Shorthair
#         - British Shorthair
#         - Chartreux
#         - Havana Brown
#         - Tonkinese
#         - Balinese
#         - Singapura
#         - Ocicat
#         - Somali
#         - American Curl
#         - Norwegian Forest Cat
#         - Siberian
#         - Toyger
#         - Munchkin
#         - Selkirk Rex
#         - LaPerm
#         - Peterbald
#         - Lykoi
#         - Sphynx
#         - Manx
#         - Scottish Fold
#         - Burmilla
#         - Egyptian Mau
#         - Ocicat
#         - Singapura
#         - Toyger
#         - Munchkin
#         - Selkirk Rex
#         - LaPerm
#         - Peterbald
#
# 💾 Saving hallucinated class descriptors to: envisioned_classes/fine_grained_50/pet18_ID_gpt-3.5-turbo_13.json
# === load json:  envisioned_classes/fine_grained_50/pet18_ID_gpt-3.5-turbo_13.json
# Get Envisioned Candidate Class Names.
# After set: 39
# After removing ID class overlaps: 37
# 🔁 Augmenting OOD candidates with synonyms...
#   → 'cavalier king charles spaniel'  → synonym: 'cavalier king charles spaniel'
#   → 'himalayan'  → synonym: 'himalayan cat'
#   → 'ragamuffin'  → synonym: 'none'
#   → 'peterbald'  → synonym: 'st. petersburg sphynx'
#   → 'devon rex'  → synonym: 'devon rex'
#   → 'persian'  → synonym: 'persian cat'
#   → 'munchkin'  → synonym: 'midget cat'
#   → 'laperm'  → synonym: 'laperm'
#   → 'siamese'  → synonym: 'siamese cat'
#   → 'burmese'  → synonym: 'burmese cat'
#   → 'balinese'  → synonym: 'long-haired siamese'
#   → 'tonkinese'  → synonym: 'tonkinese cat'
#   → 'exotic shorthair'  → synonym: 'persian cat'
#   → 'american curl'  → synonym: 'ac'
#   → 'pomeranian'  → synonym: 'zwergspitz'
#   → 'somali'  → synonym: 'abyssinian'
#   → 'turkish angora'  → synonym: 'turkish angora'
#   → 'ocicat'  → synonym: 'abyssinian'
#   → 'havana brown'  → synonym: 'havana brown'
#   → 'cornish rex'  → synonym: 'cornish rex'
#   → 'singapura'  → synonym: 'singapore cat'
#   → 'abyssinian'  → synonym: 'felis catus'
#   → 'birman'  → synonym: 'sacred birman'
#   → 'american shorthair'  → synonym: 'domestic shorthair'
#   → 'norwegian forest cat'  → synonym: 'skogkatt'
#   → 'british shorthair'  → synonym: 'british blue'
#   → 'scottish fold'  → synonym: 'felis catus'
#   → 'chartreux'  → synonym: 'french blue'
#   → 'turkish van'  → synonym: 'van cat'
#   → 'toyger'  → synonym: 'toyger'
#   → 'selkirk rex'  → synonym: 'selkirk longhair'
#   → 'chihuahua'  → synonym: 'chihuahua'
#   → 'russian blue'  → synonym: 'archangel'
#   → 'siberian'  → synonym: 'siberian cat'
#   → 'manx'  → synonym: 'manx cat'
#   → 'lykoi'  → synonym: 'werewolf cat'
#   → 'burmilla'  → synonym: 'burmese shorthair'
# 🧹 Removed 1 invalid synonym labels like 'none' or 'null'
# 📏 OOD classes before synonym expansion: 37
# 📐 OOD classes after synonym + deduplication: 61
#
# 🧪 Final ID Labels passed to CLIP: ['Havanese', 'Newfoundland', 'Sphynx', 'American Bulldog', 'Samoyed', 'Great Pyrenees', 'Maine Coon', 'Staffordshire Bull Terrier', 'Saint Bernard', 'Bengal', 'Basset Hound', 'Egyptian Mau', 'Shiba Inu', 'Bombay', 'English Cocker Spaniel', 'Japanese Chin', 'Ragdoll', 'Keeshond']
# 🚫 OOD candidate labels: ['cavalier king charles spaniel', 'himalayan', 'ragamuffin', 'peterbald', 'devon rex', 'persian', 'munchkin', 'laperm', 'siamese', 'burmese', 'balinese', 'tonkinese', 'exotic shorthair', 'american curl', 'pomeranian', 'somali', 'turkish angora', 'ocicat', 'havana brown', 'cornish rex', 'singapura', 'abyssinian', 'birman', 'american shorthair', 'norwegian forest cat', 'british shorthair', 'scottish fold', 'chartreux', 'turkish van', 'toyger', 'selkirk rex', 'chihuahua', 'russian blue', 'siberian', 'manx', 'lykoi', 'burmilla', 'himalayan cat', 'st. petersburg sphynx', 'persian cat', 'midget cat', 'siamese cat', 'burmese cat', 'long-haired siamese', 'tonkinese cat', 'ac', 'zwergspitz', 'singapore cat', 'felis catus', 'sacred birman', 'domestic shorthair', 'skogkatt', 'british blue', 'french blue', 'van cat', 'selkirk longhair', 'archangel', 'siberian cat', 'manx cat', 'werewolf cat', 'burmese shorthair']
# tokenizer_config.json:   0%|          | 0.00/905 [00:00<?, ?B/s]
# vocab.json: 0.00B [00:00, ?B/s]
# merges.txt: 0.00B [00:00, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/389 [00:00<?, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# 100%|██████████| 7/7 [04:48<00:00, 41.17s/it]
# 2025-07-18 19:54:24,533 : 📦 Evaluating OOD dataset pet19_OOD
# DEBUG:__main__:📦 Evaluating OOD dataset pet19_OOD
# 100%|██████████| 8/8 [04:41<00:00, 35.16s/it]
# 2025-07-18 19:59:06,519 : in scores: DescribeResult(nobs=1773, minmax=(np.float32(-0.005074689), np.float32(-0.0025540264)), mean=np.float32(-0.0038396332), variance=np.float64(2.2988333880272876e-07), skewness=np.float64(0.2075515240430832), kurtosis=np.float32(-0.50963306))
# DEBUG:__main__:in scores: DescribeResult(nobs=1773, minmax=(np.float32(-0.005074689), np.float32(-0.0025540264)), mean=np.float32(-0.0038396332), variance=np.float64(2.2988333880272876e-07), skewness=np.float64(0.2075515240430832), kurtosis=np.float32(-0.50963306))
# 2025-07-18 19:59:06,524 : out scores: DescribeResult(nobs=1896, minmax=(np.float32(-0.0045473), np.float32(-0.0020425767)), mean=np.float32(-0.0032439595), variance=np.float64(2.3005060499736279e-07), skewness=np.float64(-0.15738844871520996), kurtosis=np.float32(-0.88079286))
# DEBUG:__main__:out scores: DescribeResult(nobs=1896, minmax=(np.float32(-0.0045473), np.float32(-0.0020425767)), mean=np.float32(-0.0032439595), variance=np.float64(2.3005060499736279e-07), skewness=np.float64(-0.15738844871520996), kurtosis=np.float32(-0.88079286))
# 2025-07-18 19:59:07,639 : 				EOE
# DEBUG:__main__:				EOE
# 2025-07-18 19:59:07,641 :   FPR95 AUROC AUPR
# DEBUG:__main__:  FPR95 AUROC AUPR
# 2025-07-18 19:59:07,643 : & 64.14 & 80.43 & 80.50
# DEBUG:__main__:& 64.14 & 80.43 & 80.50
# 2025-07-18 19:59:07,646 :
#
# 📊 Mean Test Results
# DEBUG:__main__:
#
# 📊 Mean Test Results
# 2025-07-18 19:59:07,649 : 				EOE
# DEBUG:__main__:				EOE
# 2025-07-18 19:59:07,655 :   FPR95 AUROC AUPR
# DEBUG:__main__:  FPR95 AUROC AUPR
# 2025-07-18 19:59:07,656 : & 64.14 & 80.43 & 80.50
# DEBUG:__main__:& 64.14 & 80.43 & 80.50

# %%
sys.argv = [
    "eval_ood_detection.py",
    "--name",        "PET19_PET18_EOE_100L_75B_finegrained_synonymOOD",
    "--in_dataset",  "pet18_ID",
    "--ood_task",    "fine_grained",
    "--score",       "EOE",
    "--score_ablation", "EOE",           # use standard EOE score
    "--generate_class",                  # generate OOD candidates via LLM
    "--use_synonyms",                   # apply synonym expansion to OOD classes
    "--root_dir",    "datasets",
    "--batch_size",  "256",
    "--gpu",         "0",
    "--beta",       "0.75",
    "--L",           "100",
]
main()
# Out:
# /usr/local/lib/python3.11/dist-packages/torch/utils/data/dataloader.py:624: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(
# ✅ Original ID Labels: ['Havanese', 'Newfoundland', 'Sphynx', 'American Bulldog', 'Samoyed', 'Great Pyrenees', 'Maine Coon', 'Staffordshire Bull Terrier', 'Saint Bernard', 'Bengal', 'Basset Hound', 'Egyptian Mau', 'Shiba Inu', 'Bombay', 'English Cocker Spaniel', 'Japanese Chin', 'Ragdoll', 'Keeshond']
# 🔮 Using LLM-generated OOD candidate classes...
# Envisioning Outlier Exposure...
# 🔵 Generating via OpenAI GPT...
# Continuing vision 1/1
# 🔍 Raw GPT output:
#  - Siamese
# - Persian
# - Chihuahua
# - Siamese
# - Pomeranian
# - Abyssinian
# - Cavalier King Charles Spaniel
# - Russian Blue
# - Maltese
# - Ragamuffin
# - Scottish Fold
# - Cavalier King Charles Spaniel
# - Cornish Rex
# - Papillon
# - Devon Rex
# - Tibetan Mastiff
# - Manx
# - Toyger
# - Chartreux
# - American Shorthair
# - Birman
# - Burmese
# - Tonkinese
# - Turkish Angora
# - Turkish Van
# - Exotic Shorthair
# - Havana Brown
# - Singapura
# - Ocicat
# - American Wirehair
# - Balinese
# - British Shorthair
# - Burmilla
# - Cymric
# - LaPerm
# - Munchkin
# - Nebelung
# - Norwegian Forest Cat
# - Ocicat
# - Oriental
# - Peterbald
# - Pixiebob
# - Selkirk Rex
# - Snowshoe
# - Somali
# - Sphynx
# - Toybob
# - Turkish Van
# - York Chocolate- Irish Wolfhound
# - Tibetan Spaniel
# - Singapura
# - Chartreux
# - Bombay
# - Havana Brown
# - American Wirehair
# - Burmilla
# - Cymric
# - LaPerm
# - Munchkin
# - Nebelung
# - Norwegian Forest Cat
# - Ocicat
# - Oriental
# - Peterbald
# - Pixiebob
# - Selkirk Rex
# - Snowshoe
# - Somali
# - Toybob
# - Turkish Van
# - York Chocolate
# - Australian Cattle Dog
# - Cavalier King Charles Spaniel
# - Dalmatian
# - English Springer Spaniel
# - French Bulldog
# - Greyhound
# - Irish Setter
# - Jack Russell Terrier
# - Komondor
# - Lhasa Apso
# - Maltese
# - Newfoundland
# - Old English Sheepdog
# - Papillon
# - Rhodesian Ridgeback
# - Scottish Terrier
# - Toy Poodle
# - Vizsla
# - Weimaraner
# - Xoloitzcuintli
# - Yorkshire Terrier
# - Zuchon
# - Abyssinian
# - Birman
# - Cornish Rex
# - Devon Rex
#
# 💾 Saving hallucinated class descriptors to: envisioned_classes/fine_grained_100/pet18_ID_gpt-3.5-turbo_15.json
# === load json:  envisioned_classes/fine_grained_100/pet18_ID_gpt-3.5-turbo_15.json
# Get Envisioned Candidate Class Names.
# After set: 67
# After removing ID class overlaps: 64
# 🔁 Augmenting OOD candidates with synonyms...
#   → 'cavalier king charles spaniel'  → synonym: 'cavalier king charles spaniel'
#   → 'tibetan spaniel'  → synonym: 'tsang apso'
#   → 'york chocolate- irish wolfhound'  → synonym: 'irish wolfhound'
#   → 'ragamuffin'  → synonym: 'none'
#   → 'peterbald'  → synonym: 'petersburg sphynx'
#   → 'devon rex'  → synonym: 'devon rex'
#   → 'persian'  → synonym: 'persian cat'
#   → 'american wirehair'  → synonym: 'american wirehair'
#   → 'yorkshire terrier'  → synonym: 'yorkie'
#   → 'nebelung'  → synonym: 'russian blue'
#   → 'laperm'  → synonym: 'lāperm'
#   → 'munchkin'  → synonym: 'midget cat'
#   → 'rhodesian ridgeback'  → synonym: 'african lion hound'
#   → 'zuchon'  → synonym: 'shichon'
#   → 'siamese'  → synonym: 'siamese cat'
#   → 'burmese'  → synonym: 'burmese cat'
#   → 'balinese'  → synonym: 'long-haired siamese'
#   → 'tonkinese'  → synonym: 'tonkinese cat'
#   → 'irish setter'  → synonym: 'canis lupus familiaris'
#   → 'exotic shorthair'  → synonym: 'persian cat'
#   → 'pomeranian'  → synonym: 'zwergspitz'
#   → 'old english sheepdog'  → synonym: 'bobtail'
#   → 'jack russell terrier'  → synonym: 'parson russell terrier'
#   → 'snowshoe'  → synonym: 'snowshoe cat'
#   → 'toy poodle'  → synonym: 'caniche toy'
#   → 'somali'  → synonym: 'abyssinian'
#   → 'turkish angora'  → synonym: 'turkish angora'
#   → 'toybob'  → synonym: 'russian toy'
#   → 'greyhound'  → synonym: 'english greyhound'
#   → 'english springer spaniel'  → synonym: 'springer spaniel'
#   → 'ocicat'  → synonym: 'abyssinian'
#   → 'havana brown'  → synonym: 'havana brown'
#   → 'cornish rex'  → synonym: 'cornish rex'
#   → 'singapura'  → synonym: 'singapore cat'
#   → 'scottish terrier'  → synonym: 'aberdeen terrier'
#   → 'xoloitzcuintli'  → synonym: 'mexican hairless dog'
#   → 'tibetan mastiff'  → synonym: 'do-khyi'
#   → 'abyssinian'  → synonym: 'abyssinian cat'
#   → 'birman'  → synonym: 'sacred birman'
#   → 'dalmatian'  → synonym: 'dalmatian'
#   → 'american shorthair'  → synonym: 'domestic shorthair'
#   → 'norwegian forest cat'  → synonym: 'skogkatt'
#   → 'komondor'  → synonym: 'hungarian sheepdog'
#   → 'british shorthair'  → synonym: 'british blue'
#   → 'australian cattle dog'  → synonym: 'blue heeler'
#   → 'scottish fold'  → synonym: 'felis catus'
#   → 'chartreux'  → synonym: 'french blue'
#   → 'maltese'  → synonym: 'maltese dog'
#   → 'papillon'  → synonym: 'continental toy spaniel'
#   → 'cymric'  → synonym: 'longhaired manx'
#   → 'york chocolate'  → synonym: 'york chocolate'
#   → 'weimaraner'  → synonym: 'weimaraner'
#   → 'turkish van'  → synonym: 'van cat'
#   → 'toyger'  → synonym: 'toyger'
#   → 'pixiebob'  → synonym: 'pixie-bob'
#   → 'selkirk rex'  → synonym: 'selkirk longhair'
#   → 'chihuahua'  → synonym: 'chihuahua'
#   → 'russian blue'  → synonym: 'archangel'
#   → 'vizsla'  → synonym: 'hungarian pointer'
#   → 'manx'  → synonym: 'manx cat'
#   → 'lhasa apso'  → synonym: 'lhasa terrier'
#   → 'french bulldog'  → synonym: 'bouledogue français'
#   → 'burmilla'  → synonym: 'burmese chinchilla'
#   → 'oriental'  → synonym: 'siamese cat'
# 🧹 Removed 1 invalid synonym labels like 'none' or 'null'
# 📏 OOD classes before synonym expansion: 64
# 📐 OOD classes after synonym + deduplication: 111
#
# 🧪 Final ID Labels passed to CLIP: ['Havanese', 'Newfoundland', 'Sphynx', 'American Bulldog', 'Samoyed', 'Great Pyrenees', 'Maine Coon', 'Staffordshire Bull Terrier', 'Saint Bernard', 'Bengal', 'Basset Hound', 'Egyptian Mau', 'Shiba Inu', 'Bombay', 'English Cocker Spaniel', 'Japanese Chin', 'Ragdoll', 'Keeshond']
# 🚫 OOD candidate labels: ['cavalier king charles spaniel', 'tibetan spaniel', 'york chocolate- irish wolfhound', 'ragamuffin', 'peterbald', 'devon rex', 'persian', 'american wirehair', 'yorkshire terrier', 'nebelung', 'laperm', 'munchkin', 'rhodesian ridgeback', 'zuchon', 'siamese', 'burmese', 'balinese', 'tonkinese', 'irish setter', 'exotic shorthair', 'pomeranian', 'old english sheepdog', 'jack russell terrier', 'snowshoe', 'toy poodle', 'somali', 'turkish angora', 'toybob', 'greyhound', 'english springer spaniel', 'ocicat', 'havana brown', 'cornish rex', 'singapura', 'scottish terrier', 'xoloitzcuintli', 'tibetan mastiff', 'abyssinian', 'birman', 'dalmatian', 'american shorthair', 'norwegian forest cat', 'komondor', 'british shorthair', 'australian cattle dog', 'scottish fold', 'chartreux', 'maltese', 'papillon', 'cymric', 'york chocolate', 'weimaraner', 'turkish van', 'toyger', 'pixiebob', 'selkirk rex', 'chihuahua', 'russian blue', 'vizsla', 'manx', 'lhasa apso', 'french bulldog', 'burmilla', 'oriental', 'tsang apso', 'irish wolfhound', 'petersburg sphynx', 'persian cat', 'yorkie', 'lāperm', 'midget cat', 'african lion hound', 'shichon', 'siamese cat', 'burmese cat', 'long-haired siamese', 'tonkinese cat', 'canis lupus familiaris', 'zwergspitz', 'bobtail', 'parson russell terrier', 'snowshoe cat', 'caniche toy', 'russian toy', 'english greyhound', 'springer spaniel', 'singapore cat', 'aberdeen terrier', 'mexican hairless dog', 'do-khyi', 'abyssinian cat', 'sacred birman', 'domestic shorthair', 'skogkatt', 'hungarian sheepdog', 'british blue', 'blue heeler', 'felis catus', 'french blue', 'maltese dog', 'continental toy spaniel', 'longhaired manx', 'van cat', 'pixie-bob', 'selkirk longhair', 'archangel', 'hungarian pointer', 'manx cat', 'lhasa terrier', 'bouledogue français', 'burmese chinchilla']
# 100%|██████████| 7/7 [00:28<00:00,  4.04s/it]
# 2025-07-18 20:02:49,613 : 📦 Evaluating OOD dataset pet19_OOD
# DEBUG:__main__:📦 Evaluating OOD dataset pet19_OOD
# 100%|██████████| 8/8 [00:30<00:00,  3.80s/it]
# 2025-07-18 20:03:20,363 : in scores: DescribeResult(nobs=1773, minmax=(np.float32(-0.0027902583), np.float32(-0.0015840307)), mean=np.float32(-0.0022516188), variance=np.float64(5.183309721840877e-08), skewness=np.float64(0.17673367261886597), kurtosis=np.float32(-0.51732206))
# DEBUG:__main__:in scores: DescribeResult(nobs=1773, minmax=(np.float32(-0.0027902583), np.float32(-0.0015840307)), mean=np.float32(-0.0022516188), variance=np.float64(5.183309721840877e-08), skewness=np.float64(0.17673367261886597), kurtosis=np.float32(-0.51732206))
# 2025-07-18 20:03:20,371 : out scores: DescribeResult(nobs=1896, minmax=(np.float32(-0.002513037), np.float32(-0.0012249104)), mean=np.float32(-0.0018456709), variance=np.float64(5.1359203634737935e-08), skewness=np.float64(-0.18681871891021729), kurtosis=np.float32(-0.37767053))
# DEBUG:__main__:out scores: DescribeResult(nobs=1896, minmax=(np.float32(-0.002513037), np.float32(-0.0012249104)), mean=np.float32(-0.0018456709), variance=np.float64(5.1359203634737935e-08), skewness=np.float64(-0.18681871891021729), kurtosis=np.float32(-0.37767053))
# 2025-07-18 20:03:20,853 : 				EOE
# DEBUG:__main__:				EOE
# 2025-07-18 20:03:20,858 :   FPR95 AUROC AUPR
# DEBUG:__main__:  FPR95 AUROC AUPR
# 2025-07-18 20:03:20,860 : & 44.73 & 89.08 & 88.74
# DEBUG:__main__:& 44.73 & 89.08 & 88.74
# 2025-07-18 20:03:20,864 :
#
# 📊 Mean Test Results
# DEBUG:__main__:
#
# 📊 Mean Test Results
# 2025-07-18 20:03:20,866 : 				EOE
# DEBUG:__main__:				EOE
# 2025-07-18 20:03:20,868 :   FPR95 AUROC AUPR
# DEBUG:__main__:  FPR95 AUROC AUPR
# 2025-07-18 20:03:20,869 : & 44.73 & 89.08 & 88.74
# DEBUG:__main__:& 44.73 & 89.08 & 88.74

# %%
sys.argv = [
    "eval_ood_detection.py",
    "--name",        "PET19_PET18_EOE_300L_75B_finegrained_synonymOOD",
    "--in_dataset",  "pet18_ID",
    "--ood_task",    "fine_grained",
    "--score",       "EOE",
    "--score_ablation", "EOE",           # use standard EOE score
    "--generate_class",                  # generate OOD candidates via LLM
    "--use_synonyms",                   # apply synonym expansion to OOD classes
    "--root_dir",    "datasets",
    "--batch_size",  "256",
    "--gpu",         "0",
    "--beta",       "0.75",
    "--L",           "300",
]
main()
# Out:
# /usr/local/lib/python3.11/dist-packages/torch/utils/data/dataloader.py:624: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(
# ✅ Original ID Labels: ['Havanese', 'Newfoundland', 'Sphynx', 'American Bulldog', 'Samoyed', 'Great Pyrenees', 'Maine Coon', 'Staffordshire Bull Terrier', 'Saint Bernard', 'Bengal', 'Basset Hound', 'Egyptian Mau', 'Shiba Inu', 'Bombay', 'English Cocker Spaniel', 'Japanese Chin', 'Ragdoll', 'Keeshond']
# 🔮 Using LLM-generated OOD candidate classes...
# Envisioning Outlier Exposure...
# 🔵 Generating via OpenAI GPT...
# Continuing vision 1/5
# Continuing vision 2/5
# Continuing vision 3/5
# Continuing vision 4/5
# Continuing vision 5/5
# 🔍 Raw GPT output:
#  - Siamese
# - Persian
# - Chihuahua
# - Siamese
# - Pomeranian
# - Abyssinian
# - Cavalier King Charles Spaniel
# - Russian Blue
# - Maltese
# - Ragamuffin
# - Scottish Fold
# - Papillon
# - Cornish Rex
# - Toyger
# - Devon Rex
# - Birman
# - Manx
# - Chartreux
# - Havana Brown
# - Tonkinese
# - American Shorthair
# - Burmese
# - Turkish Angora
# - Balinese
# - Singapura
# - Ocicat
# - Turkish Van
# - American Wirehair
# - Exotic Shorthair
# - Norwegian Forest Cat
# - British Shorthair
# - Bombay
# - Himalayan
# - Somali
# - American Curl
# - LaPerm
# - Selkirk Rex
# - Munchkin
# - Peterbald
# - Sphynx
# - Lykoi
# - Scottish Fold
# - Nebelung
# - Chartreux
# - Burmilla
# - Cymric
# - Manx
# - Toyger
# - Ocicat- Irish Wolfhound
# - Tibetan Mastiff
# - Tibetan Spaniel
# - Tibetan Terrier
# - Saluki
# - Borzoi
# - Basenji
# - Whippet
# - Italian Greyhound
# - Afghan Hound
# - Greyhound
# - Irish Setter
# - Gordon Setter
# - English Setter
# - Brittany Spaniel
# - Clumber Spaniel
# - Field Spaniel
# - Sussex Spaniel
# - Welsh Springer Spaniel
# - English Springer Spaniel
# - English Toy Spaniel
# - Cavalier King Charles Spaniel
# - King Charles Spaniel
# - Japanese Chin
# - Tibetan Spaniel
# - Shih Tzu
# - Lhasa Apso
# - Pekingese
# - Brussels Griffon
# - Affenpinscher
# - Yorkshire Terrier
# - Silky Terrier
# - Australian Terrier
# - Cairn Terrier
# - West Highland White Terrier
# - Skye Terrier
# - Scottish Terrier
# - Border Terrier
# - Norwich Terrier
# - Norfolk Terrier
# - Dandie Dinmont Terrier
# - Bedlington Terrier
# - Lakeland Terrier
# - Irish Terrier
# - Kerry Blue Terrier
# - Soft Coated Wheaten Terrier
# - Airedale Terrier
# - Fox Terrier
# - Miniature Schnauzer
# - Burmilla
# - Chartreux
# - Cornish Rex
# - Devon Rex
# - Egyptian Mau
# - Exotic Shorthair
# - Havana Brown
# - Himalayan
# - Japanese Bobtail
# - Korat
# - LaPerm
# - Maine Coon
# - Manx
# - Munchkin
# - Nebelung
# - Norwegian Forest Cat
# - Ocicat
# - Oriental
# - Persian
# - Peterbald
# - Pixiebob
# - Ragamuffin
# - Russian Blue
# - Scottish Fold
# - Selkirk Rex
# - Siamese
# - Siberian
# - Singapura
# - Snowshoe
# - Somali
# - Sphynx
# - Tonkinese
# - Toyger
# - Turkish Angora
# - Turkish Van
# - American Curl
# - American Shorthair
# - American Wirehair
#
# 💾 Saving hallucinated class descriptors to: envisioned_classes/fine_grained_300/pet18_ID_gpt-3.5-turbo_6.json
# === load json:  envisioned_classes/fine_grained_300/pet18_ID_gpt-3.5-turbo_6.json
# Get Envisioned Candidate Class Names.
# After set: 162
# After removing ID class overlaps: 149
# 🔁 Augmenting OOD candidates with synonyms...
#   → 'burmese- abyssinian'  → synonym: 'abyssinian'
#   → 'tibetan spaniel'  → synonym: 'tsang apso'
#   → 'chow chow'  → synonym: 'chow-chow'
#   → 'chinese crested'  → synonym: 'crested dog'
#   → 'laperm'  → synonym: 'laperm'
#   → 'cairn terrier'  → synonym: 'cairn terrier'
#   → 'pembroke welsh corgi'  → synonym: 'welsh corgi'
#   → 'exotic shorthair'  → synonym: 'persian cat'
#   → 'welsh springer spaniel'  → synonym: 'welsh spaniel'
#   → 'norfolk terrier'  → synonym: 'norwich terrier'
#   → 'kuvasz'  → synonym: 'hungarian kuvasz'
#   → 'pomeranian'  → synonym: 'zwergspitz'
#   → 'norwich terrier'  → synonym: 'norwich terrier'
#   → 'saluki'  → synonym: 'persian greyhound'
#   → 'greyhound'  → synonym: 'english greyhound'
#   → 'welsh terrier'  → synonym: 'old english terrier'
#   → 'american wirehair- balinese'  → synonym: 'balinese'
#   → 'poodle'  → synonym: 'caniche'
#   → 'tibetan mastiff'  → synonym: 'do-khyi'
#   → 'brussels griffon'  → synonym: 'griffon bruxellois'
#   → 'birman'  → synonym: 'sacred birman'
#   → 'dalmatian'  → synonym: 'dalmatian'
#   → 'giant schnauzer'  → synonym: 'riesenschnauzer'
#   → 'american shorthair'  → synonym: 'domestic shorthair'
#   → 'portuguese water dog'  → synonym: 'portuguese water dog'
#   → 'standard schnauzer'  → synonym: 'mittelschnauzer'
#   → 'komondor'  → synonym: 'hungarian sheepdog'
#   → 'scottish fold'  → synonym: 'felis catus'
#   → 'english toy spaniel'  → synonym: 'king charles spaniel'
#   → 'weimaraner'  → synonym: 'weimaraner'
#   → 'german shorthaired pointer'  → synonym: 'deutscher kurzhaar'
#   → 'standard schnauzer- australian cattle dog'  → synonym: 'australian cattle dog'
#   → 'bedlington terrier'  → synonym: 'rothbury terrier'
#   → 'scottish deerhound'  → synonym: 'deerhound'
#   → 'vizsla'  → synonym: 'hungarian pointer'
#   → 'french bulldog'  → synonym: 'bouledogue français'
#   → 'miniature pinscher'  → synonym: 'zwergpinscher'
#   → 'rhodesian ridgeback'  → synonym: 'african lion hound'
#   → 'brittany spaniel'  → synonym: 'brittany dog'
#   → 'siberian husky'  → synonym: 'canis lupus familiaris'
#   → 'labrador retriever- maltese'  → synonym: 'labrador retriever - maltese mix'
#   → 'border terrier'  → synonym: 'canis lupus familiaris'
#   → 'wirehaired pointing griffon'  → synonym: 'korthals griffon'
#   → 'bull terrier'  → synonym: 'english bull terrier'
#   → 'bloodhound'  → synonym: 'chien de saint-hubert'
#   → 'affenpinscher'  → synonym: 'affenpinscher'
#   → 'ragamuffin'  → synonym: 'domestic longhair'
#   → 'peterbald'  → synonym: 'st. petersburg sphynx'
#   → 'american wirehair'  → synonym: 'american wirehair'
#   → 'bullmastiff'  → synonym: 'none'
#   → 'munchkin'  → synonym: 'none'
#   → 'mastiff'  → synonym: 'canis lupus familiaris'
#   → 'siamese'  → synonym: 'siamese cat'
#   → 'burmese'  → synonym: 'burmese cat'
#   → 'fox terrier'  → synonym: 'smooth fox terrier'
#   → 'bouvier des flandres'  → synonym: 'flanders cattle dog'
#   → 'japanese bobtail'  → synonym: 'mi-ke'
#   → 'afghan hound'  → synonym: 'tazi'
#   → 'snowshoe'  → synonym: 'snowshoe cat'
#   → 'somali'  → synonym: 'abyssinian'
#   → 'west highland white terrier'  → synonym: 'westie'
#   → 'english springer spaniel'  → synonym: 'springer spaniel'
#   → 'cocker spaniel'  → synonym: 'english cocker spaniel'
#   → 'cornish rex'  → synonym: 'cornish rex'
#   → 'smooth fox terrier'  → synonym: 'fox terrier'
#   → 'flat-coated retriever'  → synonym: 'flat-coated retriever'
#   → 'gordon setter'  → synonym: 'scottish setter'
#   → 'norwegian forest cat'  → synonym: 'skogkatt'
#   → 'miniature schnauzer'  → synonym: 'zwergschnauzer'
#   → 'british shorthair'  → synonym: 'british blue'
#   → 'chartreux'  → synonym: 'french blue'
#   → 'maltese'  → synonym: 'maltese dog'
#   → 'korat'  → synonym: 'thai blue cat'
#   → 'cymric'  → synonym: 'longhaired manx'
#   → 'turkish van'  → synonym: 'van cat'
#   → 'toyger'  → synonym: 'toyger'
#   → 'dandie dinmont terrier'  → synonym: 'dandie dinmont terrier'
#   → 'selkirk rex'  → synonym: 'selkirk rex'
#   → 'chesapeake bay retriever'  → synonym: 'chessie'
#   → 'oriental'  → synonym: 'siamese cat'
#   → 'tibetan terrier'  → synonym: 'dokhi apso'
#   → 'cavalier king charles spaniel'  → synonym: 'cavalier king charles spaniel'
#   → 'yorkshire terrier'  → synonym: 'yorkie'
#   → 'nebelung'  → synonym: 'russian blue'
#   → 'tonkinese'  → synonym: 'tonkinese cat'
#   → 'belgian tervuren'  → synonym: 'belgian shepherd'
#   → 'pointer'  → synonym: 'english pointer'
#   → 'dogue de bordeaux'  → synonym: 'french mastiff'
#   → 'american bobtail'  → synonym: 'american shorthair'
#   → 'ocicat'  → synonym: 'abyssinian'
#   → 'havana brown'  → synonym: 'havana brown'
#   → 'ocicat- irish wolfhound'  → synonym: 'irish wolfhound'
#   → 'toy fox terrier'  → synonym: 'amertoy fox terrier'
#   → 'wire fox terrier'  → synonym: 'fox terrier'
#   → 'cardigan welsh corgi'  → synonym: 'welsh corgi'
#   → 'abyssinian'  → synonym: 'abyssinian cat'
#   → 'field spaniel'  → synonym: 'field spaniel'
#   → 'bernese mountain dog'  → synonym: 'berner sennenhund'
#   → 'pekingese'  → synonym: 'peking palasthund'
#   → 'kerry blue terrier'  → synonym: 'irish blue terrier'
#   → 'irish wolfhound'  → synonym: 'canis lupus familiaris'
#   → 'italian greyhound'  → synonym: 'piccolo levriero italiano'
#   → 'doberman pinscher'  → synonym: 'dobermann'
#   → 'chihuahua'  → synonym: 'chihuahua'
#   → 'russian blue'  → synonym: 'archangel'
#   → 'siberian'  → synonym: 'siberian cat'
#   → 'whippet'  → synonym: 'english whippet'
#   → 'rottweiler'  → synonym: 'rottweil metzgerhund'
#   → 'manx'  → synonym: 'manx cat'
#   → 'borzoi'  → synonym: 'russian wolfhound'
#   → 'sussex spaniel'  → synonym: 'none'
#   → 'pug'  → synonym: 'canis lupus familiaris'
#   → 'schipperke'  → synonym: 'belgian barge dog'
#   → 'himalayan'  → synonym: 'himalayan cat'
#   → 'shetland sheepdog'  → synonym: 'shetland collie'
#   → 'golden retriever'  → synonym: 'golden retriever'
#   → 'devon rex'  → synonym: 'devon rex'
#   → 'persian'  → synonym: 'persian cat'
#   → 'australian terrier'  → synonym: 'none'
#   → 'balinese'  → synonym: 'long-haired siamese'
#   → 'skye terrier'  → synonym: 'skye terrier'
#   → 'boston terrier'  → synonym: 'boston bull'
#   → 'irish setter'  → synonym: 'red setter'
#   → 'lakeland terrier'  → synonym: 'none'
#   → 'american curl'  → synonym: 'none'
#   → 'belgian malinois'  → synonym: 'belgian shepherd'
#   → 'english setter'  → synonym: 'setter'
#   → 'silky terrier'  → synonym: 'australian silky terrier'
#   → 'turkish angora'  → synonym: 'turkish angora'
#   → 'collie'  → synonym: 'border collie'
#   → 'irish terrier'  → synonym: 'irish red terrier'
#   → 'clumber spaniel'  → synonym: 'clumber spaniel'
#   → 'briard'  → synonym: 'chien berger de brie'
#   → 'singapura'  → synonym: 'singapore cat'
#   → 'scottish terrier'  → synonym: 'aberdeen terrier'
#   → 'basenji'  → synonym: 'congo terrier'
#   → 'xoloitzcuintli'  → synonym: 'mexican hairless dog'
#   → 'curly-coated retriever'  → synonym: 'curly-coated retriever'
#   → 'soft coated wheaten terrier'  → synonym: 'irish soft coated wheaten terrier'
#   → 'papillon'  → synonym: 'continental toy spaniel'
#   → 'great dane'  → synonym: 'german mastiff'
#   → 'pixiebob'  → synonym: 'pixie-bob'
#   → 'king charles spaniel'  → synonym: 'english toy spaniel'
#   → 'shih tzu'  → synonym: 'shih tzu'
#   → 'lhasa apso'  → synonym: 'lhasa terrier'
#   → 'lykoi'  → synonym: 'werewolf cat'
#   → 'burmilla'  → synonym: 'burmese chinchilla'
#   → 'greater swiss mountain dog'  → synonym: 'grosser schweizer sennenhund'
#   → 'airedale terrier'  → synonym: 'airedale terrier'
niel', 'shih tzu', 'lhasa apso', 'lykoi', 'burmilla', 'greater swiss mountain dog', 'airedale terrier', 'tsang apso', 'chow-chow', 'crested dog', 'welsh corgi', 'persian cat', 'welsh spaniel', 'hungarian kuvasz', 'zwergspitz', 'persian greyhound', 'english greyhound', 'old english terrier', 'caniche', 'do-khyi', 'griffon bruxellois', 'sacred birman', 'riesenschnauzer', 'domestic shorthair', 'mittelschnauzer', 'hungarian sheepdog', 'felis catus', 'deutscher kurzhaar', 'australian cattle dog', 'rothbury terrier', 'deerhound', 'hungarian pointer', 'bouledogue français', 'zwergpinscher', 'african lion hound', 'brittany dog', 'canis lupus familiaris', 'labrador retriever - maltese mix', 'korthals griffon', 'english bull terrier', 'chien de saint-hubert', 'domestic longhair', 'st. petersburg sphynx', 'siamese cat', 'burmese cat', 'flanders cattle dog', 'mi-ke', 'tazi', 'snowshoe cat', 'westie', 'springer spaniel', 'english cocker spaniel', 'scottish setter', 'skogkatt', 'zwergschnauzer', 'british blue', 'french blue', 'maltese dog', 'thai blue cat', 'longhaired manx', 'van cat', 'chessie', 'dokhi apso', 'yorkie', 'tonkinese cat', 'belgian shepherd', 'english pointer', 'french mastiff', 'amertoy fox terrier', 'abyssinian cat', 'berner sennenhund', 'peking palasthund', 'irish blue terrier', 'piccolo levriero italiano', 'dobermann', 'archangel', 'siberian cat', 'english whippet', 'rottweil metzgerhund', 'manx cat', 'russian wolfhound' ...
# 100%|██████████| 7/7 [00:29<00:00,  4.21s/it]
# 2025-07-18 20:05:39,590 : 📦 Evaluating OOD dataset pet19_OOD
# DEBUG:__main__:📦 Evaluating OOD dataset pet19_OOD
# 100%|██████████| 8/8 [00:30<00:00,  3.75s/it]
# 2025-07-18 20:06:10,489 : in scores: DescribeResult(nobs=1773, minmax=(np.float32(-0.0013271822), np.float32(-0.00078445836)), mean=np.float32(-0.0010781061), variance=np.float64(9.757699880602688e-09), skewness=np.float64(0.07231641560792923), kurtosis=np.float32(-0.37100577))
# DEBUG:__main__:in scores: DescribeResult(nobs=1773, minmax=(np.float32(-0.0013271822), np.float32(-0.00078445836)), mean=np.float32(-0.0010781061), variance=np.float64(9.757699880602688e-09), skewness=np.float64(0.07231641560792923), kurtosis=np.float32(-0.37100577))
# 2025-07-18 20:06:10,493 : out scores: DescribeResult(nobs=1896, minmax=(np.float32(-0.001185922), np.float32(-0.00055751717)), mean=np.float32(-0.00087517843), variance=np.float64(1.3434514660983371e-08), skewness=np.float64(-0.05181705206632614), kurtosis=np.float32(-0.40305758))
# DEBUG:__main__:out scores: DescribeResult(nobs=1896, minmax=(np.float32(-0.001185922), np.float32(-0.00055751717)), mean=np.float32(-0.00087517843), variance=np.float64(1.3434514660983371e-08), skewness=np.float64(-0.05181705206632614), kurtosis=np.float32(-0.40305758))
# 2025-07-18 20:06:10,799 : 				EOE
# DEBUG:__main__:				EOE
# 2025-07-18 20:06:10,803 :   FPR95 AUROC AUPR
# DEBUG:__main__:  FPR95 AUROC AUPR
# 2025-07-18 20:06:10,804 : & 38.24 & 90.51 & 89.44
# DEBUG:__main__:& 38.24 & 90.51 & 89.44
# 2025-07-18 20:06:10,805 :
#
# 📊 Mean Test Results
# DEBUG:__main__:
#
# 📊 Mean Test Results
# 2025-07-18 20:06:10,808 : 				EOE
# DEBUG:__main__:				EOE
# 2025-07-18 20:06:10,810 :   FPR95 AUROC AUPR
# DEBUG:__main__:  FPR95 AUROC AUPR
# 2025-07-18 20:06:10,812 : & 38.24 & 90.51 & 89.44
# DEBUG:__main__:& 38.24 & 90.51 & 89.44

# %%
sys.argv = [
    "eval_ood_detection.py",
    "--name",        "PET19_PET18_EOE_500L_75B_finegrained_synonymOOD",
    "--in_dataset",  "pet18_ID",
    "--ood_task",    "fine_grained",
    "--score",       "EOE",
    "--score_ablation", "EOE",           # use standard EOE score
    "--generate_class",                  # generate OOD candidates via LLM
    "--use_synonyms",                   # apply synonym expansion to OOD classes
    "--root_dir",    "datasets",
    "--batch_size",  "256",
    "--gpu",         "0",
    "--beta",       "0.75",
    "--L",           "500",
]
main()
# Out:
# /usr/local/lib/python3.11/dist-packages/torch/utils/data/dataloader.py:624: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(
# ✅ Original ID Labels: ['Havanese', 'Newfoundland', 'Sphynx', 'American Bulldog', 'Samoyed', 'Great Pyrenees', 'Maine Coon', 'Staffordshire Bull Terrier', 'Saint Bernard', 'Bengal', 'Basset Hound', 'Egyptian Mau', 'Shiba Inu', 'Bombay', 'English Cocker Spaniel', 'Japanese Chin', 'Ragdoll', 'Keeshond']
# 🔮 Using LLM-generated OOD candidate classes...
# Envisioning Outlier Exposure...
# 🔵 Generating via OpenAI GPT...
# Continuing vision 1/9
# Continuing vision 2/9
# Continuing vision 3/9
# Continuing vision 4/9
# Continuing vision 5/9
# Continuing vision 6/9
# Continuing vision 7/9
# Continuing vision 8/9
# Continuing vision 9/9
# 🔍 Raw GPT output:
#  - Siamese
# - Persian
# - Chihuahua
# - Siamese
# - Pomeranian
# - Abyssinian
# - Cavalier King Charles Spaniel
# - Russian Blue
# - Maltese
# - Ragamuffin
# - Scottish Fold
# - Cavalier King Charles Spaniel
# - Cornish Rex
# - Papillon
# - Devon Rex
# - Tibetan Mastiff
# - Manx
# - Toyger
# - Chartreux
# - American Shorthair
# - Australian Terrier
# - Birman
# - Burmese
# - Chartreux
# - Havana Brown
# - Himalayan
# - Korat
# - LaPerm
# - Munchkin
# - Nebelung
# - Ocicat
# - Oriental
# - Russian Blue
# - Scottish Fold
# - Selkirk Rex
# - Singapura
# - Snowshoe
# - Somali
# - Sphynx
# - Tonkinese
# - Turkish Angora
# - Turkish Van
# - American Curl
# - Balinese
# - Bombay
# - British Shorthair
# - Burmilla
# - Cymric
# - Exotic Shorthair
# - Japanese Bobtail- Irish Wolfhound
# - Tibetan Spaniel
# - Singapura
# - Chartreux
# - Havana Brown
# - Burmilla
# - Cymric
# - Exotic Shorthair
# - Japanese Bobtail
# - American Curl
# - Balinese
# - British Shorthair
# - Ocicat
# - Nebelung
# - LaPerm
# - Munchkin
# - Korat
# - Himalayan
# - Birman
# - Havana Brown
# - Manx
# - Toyger
# - Ragamuffin
# - Scottish Fold
# - Selkirk Rex
# - Snowshoe
# - Somali
# - Tonkinese
# - Turkish Angora
# - Turkish Van
# - American Curl
# - Balinese
# - Bombay
# - British Shorthair
# - Burmilla
# - Cymric
# - Exotic Shorthair
# - Japanese Bobtail
# - Irish Setter
# - Australian Terrier
# - Birman
# - Burmese
# - Yorkshire Terrier
# - American Curl
# - Balinese
# - Bombay
# - British Shorthair
# - Burmilla
# - Cymric
# - Exotic Shorthair
# - Japanese Bobtail
# - Manx
# - Ragamuffin
# - Scottish Fold
# - Selkirk Rex
# - Snowshoe
# - Somali
# - Tonkinese
# - Turkish Angora
# - Turkish Van
# - American Curl
# - Birman
# - Havana Brown
# - Himalayan
# - Korat
# - LaPerm
# - Munchkin
# - Nebelung- Affenpinscher
# - Borzoi
# - Clumber Spaniel
# - Dandie Dinmont Terrier
# - English Foxhound
# - Finnish Spitz
# - Glen of Imaal Terrier
# - Harrier
# - Ibizan Hound
# - Jindo
# - Kai Ken
# - Lagotto Romagnolo
# - Moscow Watchdog
# - Norwegian Lundehund
# - Otterhound
# - Petit Basset Griffon Vendeen
# - Rat Terrier
# - Schipperke
# - Tibetan Mastiff
# - Xoloitzcuintli
# - Yorkshire Terrier
# - American Curl
# - Balinese
# - Bombay
# - British Shorthair
# - Burmilla
# - Cymric
# - Exotic Shorthair
# - Japanese Bobtail
# - Manx
# - Ragamuffin
# - Scottish Fold
# - Selkirk Rex
# - Snowshoe
# - Somali
# - Tonkinese
# - Turkish Angora
# - Turkish Van
# - American Curl
# - Birman
# - Havana Brown
# - Himalayan
# - Korat
# - LaPerm
# - Munchkin
# - Nebelung
#
# 💾 Saving hallucinated class descriptors to: envisioned_classes/fine_grained_500/pet18_ID_gpt-3.5-turbo_0.json
# === load json:  envisioned_classes/fine_grained_500/pet18_ID_gpt-3.5-turbo_0.json
# Get Envisioned Candidate Class Names.
# After set: 136
# After removing ID class overlaps: 132
# 🔁 Augmenting OOD candidates with synonyms...
#   → 'tibetan spaniel'  → synonym: 'tsang apso'
#   → 'estrela mountain dog'  → synonym: 'portuguese shepherd'
#   → 'norwegian buhund'  → synonym: 'norwegian sheepdog'
#   → 'barbet'  → synonym: 'capitonidae'
#   → 'eurasier'  → synonym: 'eurasian dog'
#   → 'volpino italiano'  → synonym: 'volpino italiano'
#   → 'laperm'  → synonym: 'lāperm'
#   → 'cairn terrier'  → synonym: 'cairn terrier'
#   → 'exotic shorthair'  → synonym: 'persian cat'
#   → 'pomeranian'  → synonym: 'zwergspitz'
#   → 'norwich terrier'  → synonym: 'norwich terrier'
#   → 'saluki'  → synonym: 'persian greyhound'
#   → 'icelandic sheepdog'  → synonym: 'icelandic spitz'
#   → 'schapendoes'  → synonym: 'dutch sheepdog'
#   → 'tibetan mastiff'  → synonym: 'do-khyi'
#   → 'lancashire heeler'  → synonym: 'ormskirk terrier'
#   → 'birman'  → synonym: 'sacred birman'
#   → 'dalmatian'  → synonym: 'canis lupus familiaris'
#   → 'american shorthair'  → synonym: 'domestic shorthair'
#   → 'jämthund'  → synonym: 'swedish elkhound'
#   → 'scottish fold'  → synonym: 'felis catus'
#   → 'english toy spaniel'  → synonym: 'king charles spaniel'
#   → 'weimaraner'  → synonym: 'weimaraner'
#   → 'ibizan hound'  → synonym: 'podenco ibicenco'
#   → 'hamiltonstovare'  → synonym: 'hamilton hound'
#   → 'vizsla'  → synonym: 'hungarian pointer'
#   → 'danish-swedish farmdog'  → synonym: 'dansk-svensk gårdshund'
#   → 'ocicat- cavalier king charles spaniel'  → synonym: 'cavalier king charles spaniel'
#   → 'border terrier'  → synonym: 'canis lupus familiaris'
#   → 'ragamuffin'  → synonym: 'domestic cat'
#   → 'lagotto romagnolo'  → synonym: 'italian water dog'
#   → 'munchkin'  → synonym: 'midget cat'
#   → 'manchester terrier'  → synonym: 'english toy terrier'
#   → 'kooikerhondje'  → synonym: 'nederlandse kooikerhondje'
#   → 'siamese'  → synonym: 'siamese cat'
#   → 'burmese'  → synonym: 'burmese cat'
#   → 'japanese bobtail'  → synonym: 'mi-ke'
#   → 'ocicat- australian cattle dog'  → synonym: 'australian cattle dog'
#   → 'grand basset griffon vendeen'  → synonym: 'gbgv'
#   → 'english foxhound'  → synonym: 'foxhound'
#   → 'snowshoe'  → synonym: 'snowshoe cat'
#   → 'rat terrier'  → synonym: 'rat terrier'
#   → 'somali'  → synonym: 'abyssinian'
#   → 'mudi'  → synonym: 'canis lupus familiaris'
#   → 'greenland dog'  → synonym: 'kalaallit qimmiq'
#   → 'english springer spaniel'  → synonym: 'springer spaniel'
#   → 'vallhund'  → synonym: 'swedish vallhund'
#   → 'cornish rex'  → synonym: 'cornish rex'
#   → 'pumi'  → synonym: 'hungarian pumi'
#   → 'flat-coated retriever'  → synonym: 'flat-coated retriever'
#   → 'redbone coonhound'  → synonym: 'redbone hound'
#   → 'gordon setter'  → synonym: 'scottish setter'
#   → 'british shorthair'  → synonym: 'british blue'
#   → 'chartreux'  → synonym: 'french blue'
#   → 'maltese'  → synonym: 'maltese dog'
#   → 'korat'  → synonym: 'thai blue cat'
#   → 'cymric'  → synonym: 'longhaired manx'
#   → 'turkish van'  → synonym: 'van cat'
#   → 'toyger'  → synonym: 'toyger'
#   → 'dandie dinmont terrier'  → synonym: 'dandie dinmont terrier'
#   → 'selkirk rex'  → synonym: 'selkirk longhair'
#   → 'otterhound'  → synonym: 'otter hound'
#   → 'nebelung- azawakh'  → synonym: 'nebelung'
#   → 'chesapeake bay retriever'  → synonym: 'chessie'
#   → 'oriental'  → synonym: 'siamese cat'
#   → 'tibetan terrier'  → synonym: 'dokhi apso'
#   → 'dutch shepherd'  → synonym: 'hollandse herdershond'
#   → 'cavalier king charles spaniel'  → synonym: 'cavalier king charles spaniel'
#   → 'glen of imaal terrier'  → synonym: 'irish glen of imaal terrier'
#   → 'yorkshire terrier'  → synonym: 'yorkie'
#   → 'nebelung'  → synonym: 'russian blue'
#   → 'ocicat- afghan hound'  → synonym: 'abyssinian cat'
#   → 'nebelung- appenzeller sennenhund'  → synonym: 'appenzeller sennenhund'
#   → 'petit basset griffon vendeen'  → synonym: 'pbgv'
#   → 'tonkinese'  → synonym: 'tonkinese cat'
#   → 'dogue de bordeaux'  → synonym: 'french mastiff'
#   → 'kromfohrlander'  → synonym: 'kromfohrlander'
#   → 'finnish lapphund'  → synonym: 'finnish lapphund'
#   → 'ocicat'  → synonym: 'abyssinian'
#   → 'havana brown'  → synonym: 'havana brown'
#   → 'maremma sheepdog'  → synonym: 'pastore maremmano-abruzzese'
#   → 'tornjak'  → synonym: 'bosnian-herzegovinian shepherd dog'
#   → 'entlebucher mountain dog'  → synonym: 'entlebucher sennenhund'
#   → 'abyssinian'  → synonym: 'felis catus'
#   → 'jindo'  → synonym: 'korean jindo'
#   → 'norwegian lundehund'  → synonym: 'norsk lundehund'
#   → 'pekingese'  → synonym: 'peking palasthund'
#   → 'chinook'  → synonym: 'king salmon'
#   → 'kerry blue terrier'  → synonym: 'irish blue terrier'
#   → 'utonagan'  → synonym: 'northern inuit dog'
#   → 'lowchen'  → synonym: 'little lion dog'
#   → 'russian toy'  → synonym: 'russkiy toy'
#   → 'chihuahua'  → synonym: 'chihuahua'
#   → 'russian blue'  → synonym: 'archangel'
#   → 'kai ken'  → synonym: 'tora inu'
#   → 'whippet'  → synonym: 'english whippet'
#   → 'pharaoh hound'  → synonym: 'kelb tal-fenek'
#   → 'manx'  → synonym: 'manx cat'
#   → 'borzoi'  → synonym: 'russian wolfhound'
#   → 'bergamasco sheepdog'  → synonym: 'bergamasco shepherd'
#   → 'schipperke'  → synonym: 'belgian barge dog'
#   → 'himalayan'  → synonym: 'colorpoint longhair'
#   → 'shetland sheepdog'  → synonym: 'shetland collie'
#   → 'harrier'  → synonym: 'circus aeruginosus'
#   → "cirneco dell'etna"  → synonym: "cirneco dell'etna"
#   → 'devon rex'  → synonym: 'devon rex'
#   → 'persian'  → synonym: 'persian cat'
#   → 'australian terrier'  → synonym: 'aussie terrier'
#   → 'balinese'  → synonym: 'long-haired siamese'
#   → 'irish setter'  → synonym: 'red setter'
#   → 'australian mist'  → synonym: 'spotted mist'
#   → 'american curl'  → synonym: 'ac'
#   → 'belgian malinois'  → synonym: 'belgian shepherd'
#   → 'nebelung- affenpinscher'  → synonym: 'nebelung'
#   → 'finnish spitz'  → synonym: 'finnish spitz'
#   → 'turkish angora'  → synonym: 'turkish angora'
#   → 'japanese bobtail- irish wolfhound'  → synonym: 'cú faoil'
#   → 'clumber spaniel'  → synonym: 'clumber spaniel'
#   → 'singapura'  → synonym: 'singapore cat'
#   → 'basenji'  → synonym: 'congo terrier'
#   → 'xoloitzcuintli'  → synonym: 'mexican hairless dog'
#   → 'thai ridgeback'  → synonym: 'mah thai dog'
#   → 'hovawart'  → synonym: 'hovawart'
#   → 'nebelung- bergamasco'  → synonym: 'nebelung'
#   → 'papillon'  → synonym: 'continental toy spaniel'
#   → 'griffon nivernais'  → synonym: 'griffon nivernais'
#   → 'cesky terrier'  → synonym: 'bohemian terrier'
#   → 'drentse patrijshond'  → synonym: 'dutch partridge dog'
#   → 'irish red and white setter'  → synonym: 'irish setter'
#   → 'moscow watchdog'  → synonym: 'moscow guard dog'
#   → 'lhasa apso'  → synonym: 'lhasa terrier'
#   → 'burmilla'  → synonym: 'burmese shorthair'
# 🧹 Removed 0 invalid synonym labels like 'none' or 'null'
# 📏 OOD classes before synonym expansion: 132
sacred birman', 'canis lupus familiaris', 'domestic shorthair', 'swedish elkhound', 'felis catus', 'king charles spaniel', 'podenco ibicenco', 'hamilton hound', 'hungarian pointer', 'dansk-svensk gårdshund', 'domestic cat', 'italian water dog', 'midget cat', 'english toy terrier', 'nederlandse kooikerhondje', 'siamese cat', 'burmese cat', 'mi-ke', 'australian cattle dog', 'gbgv', 'foxhound', 'snowshoe cat', 'kalaallit qimmiq', 'springer spaniel', 'swedish vallhund', 'hungarian pumi', 'redbone hound', 'scottish setter', 'british blue', 'french blue', 'maltese dog', 'thai blue cat', 'longhaired manx', 'van cat', 'selkirk longhair', 'otter hound', 'chessie', 'dokhi apso', 'hollandse herdershond', 'irish glen of imaal terrier', 'yorkie', 'abyssinian cat', 'appenzeller sennenhund', 'pbgv', 'tonkinese cat', 'french mastiff', 'pastore maremmano-abruzzese', 'bosnian-herzegovinian shepherd dog', 'entlebucher sennenhund', 'korean jindo', 'norsk lundehund', 'peking palasthund', 'king salmon', 'irish blue terrier', 'northern inuit dog', 'little lion dog', 'russkiy toy', 'archangel', 'tora inu', 'english whippet', 'kelb tal-fenek', 'manx cat', 'russian wolfhound', 'bergamasco shepherd', 'belgian barge dog', 'colorpoint longhair', 'shetland collie', 'circus aeruginosus', 'aussie terrier', 'long-haired siamese', 'red setter', 'spotted mist', 'ac', 'belgian shepherd', 'cú faoil', 'singapore cat', 'congo terrier', 'mexican hairless dog', 'mah ...
# 100%|██████████| 7/7 [00:28<00:00,  4.03s/it]
# 2025-07-18 20:18:00,036 : 📦 Evaluating OOD dataset pet19_OOD
# DEBUG:__main__:📦 Evaluating OOD dataset pet19_OOD
# 100%|██████████| 8/8 [00:29<00:00,  3.67s/it]
# 2025-07-18 20:18:29,729 : in scores: DescribeResult(nobs=1773, minmax=(np.float32(-0.0013864764), np.float32(-0.0008039535)), mean=np.float32(-0.0011352487), variance=np.float64(9.177304090483462e-09), skewness=np.float64(0.17348656058311462), kurtosis=np.float32(0.116977215))
# DEBUG:__main__:in scores: DescribeResult(nobs=1773, minmax=(np.float32(-0.0013864764), np.float32(-0.0008039535)), mean=np.float32(-0.0011352487), variance=np.float64(9.177304090483462e-09), skewness=np.float64(0.17348656058311462), kurtosis=np.float32(0.116977215))
# 2025-07-18 20:18:29,733 : out scores: DescribeResult(nobs=1896, minmax=(np.float32(-0.0013029422), np.float32(-0.000625425)), mean=np.float32(-0.00093735027), variance=np.float64(1.2382794579334922e-08), skewness=np.float64(-0.04294738546013832), kurtosis=np.float32(-0.29223228))
# DEBUG:__main__:out scores: DescribeResult(nobs=1896, minmax=(np.float32(-0.0013029422), np.float32(-0.000625425)), mean=np.float32(-0.00093735027), variance=np.float64(1.2382794579334922e-08), skewness=np.float64(-0.04294738546013832), kurtosis=np.float32(-0.29223228))
# 2025-07-18 20:18:30,045 : 				EOE
# DEBUG:__main__:				EOE
# 2025-07-18 20:18:30,047 :   FPR95 AUROC AUPR
# DEBUG:__main__:  FPR95 AUROC AUPR
# 2025-07-18 20:18:30,049 : & 37.82 & 90.84 & 89.92
# DEBUG:__main__:& 37.82 & 90.84 & 89.92
# 2025-07-18 20:18:30,051 :
#
# 📊 Mean Test Results
# DEBUG:__main__:
#
# 📊 Mean Test Results
# 2025-07-18 20:18:30,053 : 				EOE
# DEBUG:__main__:				EOE
# 2025-07-18 20:18:30,055 :   FPR95 AUROC AUPR
# DEBUG:__main__:  FPR95 AUROC AUPR
# 2025-07-18 20:18:30,056 : & 37.82 & 90.84 & 89.92
# DEBUG:__main__:& 37.82 & 90.84 & 89.92

# %%
sys.argv = [
    "eval_ood_detection.py",
    "--name",        "PET19_PET18_EOE_500L_75B_finegrained",
    "--in_dataset",  "pet18_ID",
    "--ood_task",    "fine_grained",
    "--score",       "EOE",
    "--score_ablation", "EOE",           # use standard EOE score
    "--generate_class",                  # generate OOD candidates via LLM
    "--root_dir",    "datasets",
    "--batch_size",  "256",
    "--gpu",         "0",
    "--beta",       "0.75",
    "--L",           "500",
]
main()
# Out:
# 2025-07-20 08:19:14,626 : #########PET19_PET18_EOE_500L_75B_finegrained############
# DEBUG:__main__:#########PET19_PET18_EOE_500L_75B_finegrained############
# config.json: 0.00B [00:00, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/599M [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/599M [00:00<?, ?B/s]
# /usr/local/lib/python3.11/dist-packages/torch/utils/data/dataloader.py:624: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(
# ✅ Original ID Labels: ['Havanese', 'Newfoundland', 'Sphynx', 'American Bulldog', 'Samoyed', 'Great Pyrenees', 'Maine Coon', 'Staffordshire Bull Terrier', 'Saint Bernard', 'Bengal', 'Basset Hound', 'Egyptian Mau', 'Shiba Inu', 'Bombay', 'English Cocker Spaniel', 'Japanese Chin', 'Ragdoll', 'Keeshond']
# 🔮 Using LLM-generated OOD candidate classes...
# Envisioning Outlier Exposure...
# 🔵 Generating via OpenAI GPT...
# Continuing vision 1/9
# Continuing vision 2/9
# Continuing vision 3/9
# Continuing vision 4/9
# Continuing vision 5/9
# Continuing vision 6/9
# Continuing vision 7/9
# Continuing vision 8/9
# Continuing vision 9/9
# 🔍 Raw GPT output:
#  - Siamese
# - Persian
# - Chihuahua
# - Siamese Fighting Fish
# - Ferret
# - Guinea Pig
# - Hamster
# - Parrot
# - Cockatiel
# - Rabbit
# - Gerbil
# - Turtle
# - Gecko
# - Iguana
# - Tarantula
# - Hermit Crab
# - Axolotl
# - Hedgehog
# - Sugar Glider
# - Cockatoo
# - Macaw
# - Cockatoo
# - Macaw
# - Cockatoo
# - Macaw
# - Cockatoo
# - Macaw
# - Cockatoo
# - Macaw
# - Cockatoo
# - Macaw
# - Cockatoo
# - Macaw
# - Cockatoo
# - Macaw
# - Cockatoo
# - Macaw
# - Cockatoo
# - Macaw
# - Cockatoo
# - Macaw
# - Cockatoo
# - Macaw
# - Cockatoo
# - Macaw
# - Cockatoo
# - Macaw
# - Cockatoo
# - Macaw
# - Cockatoo
# - Macaw- Axolotl
# - Capybara
# - Ferret
# - Gerbil
# - Guinea Pig
# - Hamster
# - Hedgehog
# - Hermit Crab
# - Iguana
# - Parakeet
# - Parrotlet
# - Potbellied Pig
# - Rabbit
# - Rat
# - Sugar Glider
# - Tarantula
# - Tortoise
# - Axolotl
# - Capybara
# - Ferret
# - Gerbil
# - Guinea Pig
# - Hamster
# - Hedgehog
# - Hermit Crab
# - Iguana
# - Parakeet
# - Parrotlet
# - Potbellied Pig
# - Rabbit
# - Rat
# - Sugar Glider
# - Tarantula
# - Tortoise
# - Axolotl
# - Capybara
# - Ferret
# - Gerbil
# - Guinea Pig
# 45. Sun Conure
# 46. Timneh African Grey Parrot
# 47. Umbrella Cockatoo
# 48. Vasa Parrot
# 49. White Bellied Caique
# 50. Zonkey
#
# I hope this list provides you with the variety you were looking for.
#
# 💾 Saving hallucinated class descriptors to: envisioned_classes/fine_grained_500/pet18_ID_gpt-3.5-turbo_2.json
# === load json:  envisioned_classes/fine_grained_500/pet18_ID_gpt-3.5-turbo_2.json
# Get Envisioned Candidate Class Names.
# After set: 69
# After removing ID class overlaps: 69
#
# 🧪 Final ID Labels passed to CLIP: ['Havanese', 'Newfoundland', 'Sphynx', 'American Bulldog', 'Samoyed', 'Great Pyrenees', 'Maine Coon', 'Staffordshire Bull Terrier', 'Saint Bernard', 'Bengal', 'Basset Hound', 'Egyptian Mau', 'Shiba Inu', 'Bombay', 'English Cocker Spaniel', 'Japanese Chin', 'Ragdoll', 'Keeshond']
# 🚫 OOD candidate labels: ['gerbil', 'wallaby', 'gecko', 'lovebird', 'siamese', 'cockatoo', 'blue and gold macaw', 'sugar glider', 'pionus parrot', 'xoloitzcuintli (mexican hairless dog)', 'white bellied caique', 'hedgehog', 'capybara', 'toucan', 'kakariki', 'zebra finch', 'indian ringneck parrot', 'ferret', 'persian', 'harlequin macaw', 'marmoset', 'hyacinth macaw', 'kakapo', 'iguana', 'macaw- axolotl', 'tortoiseapologies for the repetition in previous responses. here are 50 new additional pet categories:', 'rose breasted cockatoo', 'quaker parrot', 'turtle', 'ragamuffin', 'siamese fighting fish', 'rabbit', 'degu', 'jack russell terrier', 'ocelot', 'zonkey', 'lorikeet', 'galah cockatoo', 'vasa parrot', 'potbellied pig', 'hamster', 'parrotlet', 'african grey parrot', 'macaw', 'dusky conure', 'cockatiel', 'finch', 'orange wing amazon parrot', 'timneh african grey parrot', 'sun conure', 'hermit crab', 'capuchin monkey', 'rat', 'tortoise- axolotl', 'guinea pig', 'green cheek conure', 'chihuahua', 'umbrella cockatoo', 'parakeet', 'jenday conure', 'tarantula', 'tortoise', 'nanday conure', 'serval', 'yorkshire terrier', 'fennec fox', 'eclectus parrot', 'axolotl', 'parrot']
# tokenizer_config.json:   0%|          | 0.00/905 [00:00<?, ?B/s]
# vocab.json: 0.00B [00:00, ?B/s]
# merges.txt: 0.00B [00:00, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/389 [00:00<?, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# 100%|██████████| 7/7 [03:37<00:00, 31.09s/it]
# 2025-07-20 08:23:39,021 : 📦 Evaluating OOD dataset pet19_OOD
# DEBUG:__main__:📦 Evaluating OOD dataset pet19_OOD
# 100%|██████████| 8/8 [03:33<00:00, 26.66s/it]
# 2025-07-20 08:27:12,911 : in scores: DescribeResult(nobs=1773, minmax=(np.float32(-0.00480943), np.float32(-0.0026388243)), mean=np.float32(-0.0038532708), variance=np.float64(1.5933053536577182e-07), skewness=np.float64(0.33474957942962646), kurtosis=np.float32(-0.19389868))
# DEBUG:__main__:in scores: DescribeResult(nobs=1773, minmax=(np.float32(-0.00480943), np.float32(-0.0026388243)), mean=np.float32(-0.0038532708), variance=np.float64(1.5933053536577182e-07), skewness=np.float64(0.33474957942962646), kurtosis=np.float32(-0.19389868))
# 2025-07-20 08:27:12,916 : out scores: DescribeResult(nobs=1896, minmax=(np.float32(-0.0042901915), np.float32(-0.002151982)), mean=np.float32(-0.0031878455), variance=np.float64(1.696456064442314e-07), skewness=np.float64(0.0597655326128006), kurtosis=np.float32(-0.57663536))
# DEBUG:__main__:out scores: DescribeResult(nobs=1896, minmax=(np.float32(-0.0042901915), np.float32(-0.002151982)), mean=np.float32(-0.0031878455), variance=np.float64(1.696456064442314e-07), skewness=np.float64(0.0597655326128006), kurtosis=np.float32(-0.57663536))
# 2025-07-20 08:27:13,829 : 				EOE
# DEBUG:__main__:				EOE
# 2025-07-20 08:27:13,840 :   FPR95 AUROC AUPR
# DEBUG:__main__:  FPR95 AUROC AUPR
# 2025-07-20 08:27:13,848 : & 56.12 & 87.29 & 87.74
# DEBUG:__main__:& 56.12 & 87.29 & 87.74
# 2025-07-20 08:27:13,855 :
#
# 📊 Mean Test Results
# DEBUG:__main__:
#
# 📊 Mean Test Results
# 2025-07-20 08:27:13,863 : 				EOE
# DEBUG:__main__:				EOE
# 2025-07-20 08:27:13,872 :   FPR95 AUROC AUPR
# DEBUG:__main__:  FPR95 AUROC AUPR
# 2025-07-20 08:27:13,880 : & 56.12 & 87.29 & 87.74
# DEBUG:__main__:& 56.12 & 87.29 & 87.74

# %% [markdown]
# # **Experiment Semantic Variant OOD CUB-100 vs CUB-100 (Beta=0.25,L=50,100,300,500)**

# %%
import os
import openai
import re

client = openai.OpenAI(api_key=os.getenv("OPENAI_API_KEY"))

def fetch_synonym(name: str) -> str:
    system_prompt = (
        "You are a fine-grained classification assistant. "
        "When given a pet(including birds) species name, reply with *exactly one* known synonym or scientific name or name in other language. "
        "If no widely used alternative exists, reply with the original label and do not return *none*. "
        "Only return the name. Do not include explanations, punctuation, or prefixes.\n\n"
        "Here are a few examples:\n"
        "Input: American Goldfinch → Output: Eastern Goldfinch\n"
        "Input: Indigo Bunting → Output: Passerina cyanea\n"
        "Input: Bengal Cat → Output: Leopardette"
        "Input: Gadwall → Output: Anas strepera\n"
    )

    user_prompt = f"Class label: {name}"

    response = client.chat.completions.create(
        model="gpt-3.5-turbo",
        messages=[
            {"role": "system", "content": system_prompt},
            {"role": "user",   "content": user_prompt}
        ],
        temperature=0
    )

    raw = response.choices[0].message.content.strip()

    if ":" in raw:
        raw = raw.split(":")[-1].strip()
    if "known as" in raw:
        raw = re.split(r"known as", raw, flags=re.IGNORECASE)[-1].strip()

    return raw.rstrip(".")

# %%
import os
os.environ['CURL_CA_BUNDLE'] = ''
import argparse
import numpy as np
import torch
from scipy import stats

def main():
    args = process_args()
    setup_seed(args.seed)
    log = setup_log(args)
    assert torch.cuda.is_available()
    torch.cuda.set_device(args.gpu)

    net, preprocess = set_model_clip(args)
    net.eval()

    if args.in_dataset.startswith("ImageNet_C"):
        out_datasets = ['iNaturalist', 'SUN', 'places365', 'dtd']
    elif args.in_dataset == 'ImageNet':
        out_datasets = ['iNaturalist', 'SUN', 'places365', 'dtd'] if args.ood_task.startswith("far") else ['ssb_hard', 'ninco']
    else:
        out_datasets = dataset_mappings.get(args.in_dataset, [])

    test_loader = set_val_loader(args, preprocess)
    test_labels = list(get_test_labels(args, test_loader))
    print("✅ Original ID Labels:", test_labels)

    if args.score == 'EOE':
        print("🔮 Using LLM-generated OOD candidate classes...")
        base_ood_labels = load_llm_classes(args, test_labels)

        if args.use_synonyms:
            print("🔁 Augmenting OOD candidates with synonyms...")

            # Normalize and count
            base_ood_labels = [lbl.strip().lower() for lbl in base_ood_labels]
            original_count = len(base_ood_labels)

            synonym_labels = []
            for lbl in base_ood_labels:
                syn = fetch_synonym(lbl).strip().lower()
                print(f"  → {lbl!r}  → synonym: {syn!r}")
                if syn != lbl:
                    synonym_labels.append(syn)

            combined = base_ood_labels + synonym_labels

            # Remove entries like "none", "None", "", "null", etc.
            filtered = [label for label in combined if label and label.lower() not in {"none", "null"}]

            removed_count = len(combined) - len(filtered)
            print(f"🧹 Removed {removed_count} invalid synonym labels like 'none' or 'null'")

            llm_labels = list(dict.fromkeys(filtered))
            final_count = len(llm_labels)

            print(f"📏 OOD classes before synonym expansion: {original_count}")
            print(f"📐 OOD classes after synonym + deduplication: {final_count}")
        else:
            llm_labels = base_ood_labels
    else:
        llm_labels = []

    print(f"\n🧪 Final ID Labels passed to CLIP: {test_labels}")
    print(f"🚫 OOD candidate labels: {llm_labels}\n")


    in_score = get_ood_scores_clip(args, net, test_loader, test_labels, llm_labels)

    auroc_list, aupr_list, fpr_list = [], [], []
    for out_dataset in out_datasets:
        log.debug(f"📦 Evaluating OOD dataset {out_dataset}")
        ood_loader = set_ood_loader(args, out_dataset, preprocess)
        out_score = get_ood_scores_clip(args, net, ood_loader, test_labels, llm_labels)

        log.debug(f"in scores: {stats.describe(in_score)}")
        log.debug(f"out scores: {stats.describe(out_score)}")
        plot_distribution(args, in_score, out_score, out_dataset)
        get_and_print_results(args, log, in_score, out_score, auroc_list, aupr_list, fpr_list)

    log.debug('\n\n📊 Mean Test Results')
    print_measures(log, np.mean(auroc_list), np.mean(aupr_list),
                   np.mean(fpr_list), method_name=args.score)

    save_as_dataframe(args, out_datasets, fpr_list, auroc_list, aupr_list)


def process_args():
    parser = argparse.ArgumentParser(
        description='Leverage LLMs for OOD Detection',
        formatter_class=argparse.ArgumentDefaultsHelpFormatter
    )
    parser.add_argument('--in_dataset',
                        default='bird200',
                        choices=ALL_ID_DATASET,
                        help='in-distribution dataset')
    parser.add_argument('--root_dir',
                        default="datasets",
                        help='root dir of datasets')
    # prompt pipeline
    parser.add_argument('--ensemble',
                        action='store_true',
                        default=False,
                        help='CLIP text prompt engineering')
    parser.add_argument('--L',
                        type=int,
                        default=100,
                        help='the length of envisioned OOD class labels, for far/fine-grained: L=500, for near: L=3')
    parser.add_argument('--beta',
                        type=float,
                        default=0.25,
                        help='beta in Eq. 3')
    parser.add_argument('--ood_task',
                        type=str,
                        default='far',
                        choices=ALL_OOD_TASK,
                        help='choose ood task')
    parser.add_argument('--generate_class',
                        action='store_true',
                        help='whether to envision OOD candidate classes or loaded from existing JSONs')
    parser.add_argument('--json_number',
                        type=int,
                        default=0,
                        help='loaded json number')
    parser.add_argument('--llm_model',
                        default="gpt-3.5-turbo",
                        choices=ALL_LLM,
                        help='LLMs')
    parser.add_argument('--name',
                        default="eval_ood",
                        help="unique ID for the run")
    parser.add_argument('--seed',
                        type=int,
                        default=5,
                        help="random seed")
    parser.add_argument('--gpu',
                        type=int,
                        default=0,
                        help='the GPU indice to use')
    parser.add_argument('--batch_size',
                        type=int,
                        default=512,
                        help='mini-batch size')
    parser.add_argument('--T',
                        type=float,
                        default=1,
                        help='score temperature parameter')
    parser.add_argument('--model',
                        default='CLIP',
                        choices=['CLIP'],
                        help='model architecture')
    parser.add_argument('--CLIP_ckpt',
                        default='ViT-B/16',
                        choices=['ViT-B/16'],
                        help='which pretrained img encoder to use')
    parser.add_argument('--score',
                        default='EOE',
                        choices=['EOE', 'MCM', 'energy', 'max-logit'],
                        help='which scoring method')
    parser.add_argument('--score_ablation',
                        default='EOE',
                        choices=['MAX', 'MSP', 'energy', 'max-logit', 'EOE'],
                        help='ablations on the EOE score formula')
    parser.add_argument('--feat_dim',
                        type=int,
                        default=512,
                        help='feat dim, 512 for ViT-B and 768 for ViT-L')
    parser.add_argument('--use_synonyms',
                    default=False,
                    action='store_true',
                    help='Augment ID labels with synonyms using LLM')
    parser.add_argument('--prompt_pool_id',
                    type=int,
                    default=0,
                    help='Which index of openai_imagenet_template_subset to use when --ensemble')
    args = parser.parse_args()

    args.n_cls = get_num_cls(args)
    args.log_directory = f"results/{args.in_dataset}/{args.score}/" \
                         f"{args.model}_{args.CLIP_ckpt}_T_{args.T}_ID_{args.name}"
    os.makedirs(args.log_directory, exist_ok=True)

    return args

# %%
# !pip install -q nest_asyncio
import nest_asyncio
nest_asyncio.apply()
import os
os.environ['CURL_CA_BUNDLE'] = ''
import argparse
import numpy as np
import torch
from scipy import stats
import sys
sys.argv = [
    "eval_ood_detection.py",
    "--name",        "CUB100_CUB100_EOE_50L_finegrained_synonymOOD",
    "--in_dataset",  "cub100_ID",
    "--ood_task",    "fine_grained",
    "--score",       "EOE",
    "--score_ablation", "EOE",           # use standard EOE score
    "--generate_class",                  # generate OOD candidates via LLM
    "--use_synonyms",                   # apply synonym expansion to OOD classes
    "--root_dir",    "datasets",
    "--batch_size",  "256",
    "--gpu",         "0",
    "--L",           "50",
]
main()
# Out:
# /usr/local/lib/python3.11/dist-packages/torch/utils/data/dataloader.py:624: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(
# ✅ Original ID Labels: ['Laysan Albatross', 'Groove billed Ani', 'Crested Auklet', 'Parakeet Auklet', 'Rusty Blackbird', 'Bobolink', 'Indigo Bunting', 'Painted Bunting', 'Spotted Catbird', 'Yellow breasted Chat', 'Eastern Towhee', 'Chuck will Widow', 'Red faced Cormorant', 'Pelagic Cormorant', 'Bronzed Cowbird', 'Shiny Cowbird', 'American Crow', 'Purple Finch', 'Acadian Flycatcher', 'Olive sided Flycatcher', 'Scissor tailed Flycatcher', 'Yellow bellied Flycatcher', 'Frigatebird', 'Gadwall', 'American Goldfinch', 'Boat tailed Grackle', 'Eared Grebe', 'Horned Grebe', 'Pied billed Grebe', 'Blue Grosbeak', 'Evening Grosbeak', 'Pine Grosbeak', 'Rose breasted Grosbeak', 'Pigeon Guillemot', 'Glaucous winged Gull', 'Herring Gull', 'Ivory Gull', 'Ring billed Gull', 'Anna Hummingbird', 'Pomarine Jaeger', 'Blue Jay', 'Green Jay', 'Gray Kingbird', 'Ringed Kingfisher', 'Red legged Kittiwake', 'Horned Lark', 'Western Meadowlark', 'Red breasted Merganser', 'White breasted Nuthatch', 'Hooded Oriole', 'Orchard Oriole', 'Ovenbird', 'Western Wood Pewee', 'Sayornis', 'Whip poor Will', 'White necked Raven', 'Great Grey Shrike', 'Brewer Sparrow', 'Chipping Sparrow', 'Clay colored Sparrow', 'House Sparrow', 'Fox Sparrow', 'Grasshopper Sparrow', 'Henslow Sparrow', 'Le Conte Sparrow', 'Savannah Sparrow', 'Vesper Sparrow', 'Bank Swallow', 'Cliff Swallow', 'Scarlet Tanager', 'Black Tern', 'Caspian Tern', 'Brown Thrasher', 'Sage Thrasher', 'Black capped Vireo', 'Blue headed Vireo', 'Philadelphia Vireo', 'Warbling Vireo', 'Yellow throated Vireo', 'Black throated Blue Warbler', 'Blue winged Warbler', 'Cape May Warbler', 'Golden winged Warbler', 'Hooded Warbler', 'Magnolia Warbler', 'Myrtle Warbler', 'Orange crowned Warbler', 'Palm Warbler', 'Pine Warbler', 'Prothonotary Warbler', 'Swainson Warbler', 'Tennessee Warbler', 'Worm eating Warbler', 'Northern Waterthrush', 'Cedar Waxwing', 'Red bellied Woodpecker', 'Downy Woodpecker', 'Bewick Wren', 'House Wren', 'Common Yellowthroat']
# 🔮 Using LLM-generated OOD candidate classes...
# Envisioning Outlier Exposure...
# 🔵 Generating via OpenAI GPT...
# 🔍 Raw GPT output:
#  - American Avocet
# - Black Skimmer
# - California Condor
# - Eurasian Collared Dove
# - Ferruginous Hawk
# - Green Heron
# - Harpy Eagle
# - Ivory billed Woodpecker
# - Jabiru
# - King Vulture
# - Long tailed Jaeger
# - Marbled Murrelet
# - Northern Mockingbird
# - Osprey
# - Painted Redstart
# - Quetzal
# - Red Knot
# - Snowy Owl
# - Tufted Puffin
# - Umbrellabird
# - Violet crowned Hummingbird
# - White throated Sparrow
# - Xantus's Hummingbird
# - Yellow billed Cuckoo
# - Zone tailed Hawk
# - American Kestrel
# - Black capped Chickadee
# - Carolina Wren
# - Dark eyed Junco
# - Eastern Bluebird
# - Ferruginous Pygmy Owl
# - Golden Eagle
# - Harris's Hawk
# - Inca Dove
# - Juniper Titmouse
# - King Rail
# - Least Tern
# - Mountain Bluebird
# - Northern Flicker
# - Olive sided Flycatcher
# - Prairie Warbler
# - Quail Dove
# - Red winged Blackbird
# - Snowy Egret
# - Tundra Swan
# - Upland Sandpiper
# - Vermilion Flycatcher
# - Western Tanager
# - Yellow Warbler
#
# 💾 Saving hallucinated class descriptors to: envisioned_classes/fine_grained_50/cub100_ID_gpt-3.5-turbo_4.json
# === load json:  envisioned_classes/fine_grained_50/cub100_ID_gpt-3.5-turbo_4.json
# Get Envisioned Candidate Class Names.
# After set: 49
# After removing ID class overlaps: 48
# 🔁 Augmenting OOD candidates with synonyms...
#   → 'king vulture'  → synonym: 'sarcoramphus papa'
#   → 'umbrellabird'  → synonym: 'cephalopterus penduliger'
#   → 'carolina wren'  → synonym: 'thryothorus ludovicianus'
#   → 'golden eagle'  → synonym: 'aquila chrysaetos'
#   → 'red winged blackbird'  → synonym: 'agelaius phoeniceus'
#   → 'black skimmer'  → synonym: 'rynchops niger'
#   → 'painted redstart'  → synonym: 'myioborus pictus'
#   → 'american avocet'  → synonym: 'recurvirostra americana'
#   → 'tundra swan'  → synonym: 'cygnus columbianus'
#   → 'western tanager'  → synonym: 'piranga ludoviciana'
#   → 'ivory billed woodpecker'  → synonym: 'campephilus principalis'
#   → 'red knot'  → synonym: 'calidris canutus'
#   → 'snowy egret'  → synonym: 'egretta thula'
#   → 'mountain bluebird'  → synonym: 'sialia currucoides'
#   → 'northern flicker'  → synonym: 'colaptes auratus'
#   → "xantus's hummingbird"  → synonym: 'basilinna xantusii'
#   → 'northern mockingbird'  → synonym: 'mimus polyglottos'
#   → 'ferruginous hawk'  → synonym: 'buteo regalis'
#   → 'prairie warbler'  → synonym: 'setophaga discolor'
#   → 'jabiru'  → synonym: 'black-necked stork'
#   → 'violet crowned hummingbird'  → synonym: 'amazilia violiceps'
#   → 'yellow warbler'  → synonym: 'dendroica petechia'
#   → 'black capped chickadee'  → synonym: 'poecile atricapillus'
#   → 'dark eyed junco'  → synonym: 'junco hyemalis'
#   → 'osprey'  → synonym: 'pandion haliaetus'
#   → 'ferruginous pygmy owl'  → synonym: 'glaucidium brasilianum'
#   → 'american kestrel'  → synonym: 'sparrow hawk'
#   → 'marbled murrelet'  → synonym: 'brachyramphus marmoratus'
#   → 'yellow billed cuckoo'  → synonym: 'coccyzus americanus'
#   → 'upland sandpiper'  → synonym: 'bartramia longicauda'
#   → 'least tern'  → synonym: 'sterna antillarum'
#   → 'eastern bluebird'  → synonym: 'sialia sialis'
#   → 'vermilion flycatcher'  → synonym: 'pyrocephalus rubinus'
#   → "harris's hawk"  → synonym: 'parabuteo unicinctus'
#   → 'king rail'  → synonym: 'rallus elegans'
#   → 'juniper titmouse'  → synonym: 'oak titmouse'
#   → 'eurasian collared dove'  → synonym: 'streptopelia decaocto'
#   → 'inca dove'  → synonym: 'columbina inca'
#   → 'long tailed jaeger'  → synonym: 'stercorarius longicaudus'
#   → 'green heron'  → synonym: 'butorides virescens'
#   → 'snowy owl'  → synonym: 'bubo scandiacus'
#   → 'tufted puffin'  → synonym: 'fratercula cirrhata'
#   → 'harpy eagle'  → synonym: 'harpia harpyja'
#   → 'white throated sparrow'  → synonym: 'zonotrichia albicollis'
#   → 'zone tailed hawk'  → synonym: 'buteo albonotatus'
#   → 'quail dove'  → synonym: 'geotrygon mystacea'
#   → 'california condor'  → synonym: 'gymnogyps californianus'
#   → 'quetzal'  → synonym: 'pharomachrus'
# 🧹 Removed 0 invalid synonym labels like 'none' or 'null'
# 📏 OOD classes before synonym expansion: 48
# 📐 OOD classes after synonym + deduplication: 96
#
# 🧪 Final ID Labels passed to CLIP: ['Laysan Albatross', 'Groove billed Ani', 'Crested Auklet', 'Parakeet Auklet', 'Rusty Blackbird', 'Bobolink', 'Indigo Bunting', 'Painted Bunting', 'Spotted Catbird', 'Yellow breasted Chat', 'Eastern Towhee', 'Chuck will Widow', 'Red faced Cormorant', 'Pelagic Cormorant', 'Bronzed Cowbird', 'Shiny Cowbird', 'American Crow', 'Purple Finch', 'Acadian Flycatcher', 'Olive sided
na xantusii', 'mimus polyglottos', 'buteo regalis', 'setophaga discolor', 'black-necked stork', 'amazilia violiceps', 'dendroica petechia', 'poecile atricapillus', 'junco hyemalis', 'pandion haliaetus', 'glaucidium brasilianum', 'sparrow hawk', 'brachyramphus marmoratus', 'coccyzus americanus', 'bartramia longicauda', 'sterna antillarum', 'sialia sialis', 'pyrocephalus rubinus', 'parabuteo unicinctus', 'rallus elegans', 'oak titmouse', 'streptopelia decaocto', 'columbina inca', 'stercorarius longicaudus', 'butorides virescens', 'bubo scandiacus', 'fratercula cirrhata', 'harpia harpyja', 'zonotrichia albicollis', 'buteo albonotatus', 'geotrygon mystacea', 'gymnogyps californianus', 'pharomachrus']
# 100%|██████████| 12/12 [00:40<00:00,  3.37s/it]
# 2025-07-15 15:01:24,734 : 📦 Evaluating OOD dataset cub100_OOD
# DEBUG:__main__:📦 Evaluating OOD dataset cub100_OOD
# /usr/local/lib/python3.11/dist-packages/torch/utils/data/dataloader.py:624: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(
# 100%|██████████| 12/12 [00:42<00:00,  3.51s/it]
# 2025-07-15 15:02:07,829 : in scores: DescribeResult(nobs=2895, minmax=(np.float32(-0.00485971), np.float32(-0.003986909)), mean=np.float32(-0.0043808157), variance=np.float64(1.4559622316808919e-08), skewness=np.float64(-0.10483930259943008), kurtosis=np.float32(0.20915532))
# DEBUG:__main__:in scores: DescribeResult(nobs=2895, minmax=(np.float32(-0.00485971), np.float32(-0.003986909)), mean=np.float32(-0.0043808157), variance=np.float64(1.4559622316808919e-08), skewness=np.float64(-0.10483930259943008), kurtosis=np.float32(0.20915532))
# 2025-07-15 15:02:07,852 : out scores: DescribeResult(nobs=2899, minmax=(np.float32(-0.0046604276), np.float32(-0.0039998377)), mean=np.float32(-0.004280043), variance=np.float64(1.2516065455422837e-08), skewness=np.float64(-0.1688791811466217), kurtosis=np.float32(-0.33494687))
# DEBUG:__main__:out scores: DescribeResult(nobs=2899, minmax=(np.float32(-0.0046604276), np.float32(-0.0039998377)), mean=np.float32(-0.004280043), variance=np.float64(1.2516065455422837e-08), skewness=np.float64(-0.1688791811466217), kurtosis=np.float32(-0.33494687))
# 2025-07-15 15:02:09,814 : 				EOE
# DEBUG:__main__:				EOE
# 2025-07-15 15:02:09,818 :   FPR95 AUROC AUPR
# DEBUG:__main__:  FPR95 AUROC AUPR
# 2025-07-15 15:02:09,819 : & 77.75 & 72.96 & 72.65
# DEBUG:__main__:& 77.75 & 72.96 & 72.65
# 2025-07-15 15:02:09,821 :
#
# 📊 Mean Test Results
# DEBUG:__main__:
#
# 📊 Mean Test Results
# 2025-07-15 15:02:09,824 : 				EOE
# DEBUG:__main__:				EOE
# 2025-07-15 15:02:09,830 :   FPR95 AUROC AUPR
# DEBUG:__main__:  FPR95 AUROC AUPR
# 2025-07-15 15:02:09,831 : & 77.75 & 72.96 & 72.65
# DEBUG:__main__:& 77.75 & 72.96 & 72.65

# %%
sys.argv = [
    "eval_ood_detection.py",
    "--name",        "CUB100_CUB100_EOE_100L_finegrained_synonymOOD",
    "--in_dataset",  "cub100_ID",
    "--ood_task",    "fine_grained",
    "--score",       "EOE",
    "--score_ablation", "EOE",           # use standard EOE score
    "--generate_class",                  # generate OOD candidates via LLM
    "--use_synonyms",                   # apply synonym expansion to OOD classes
    "--root_dir",    "datasets",
    "--batch_size",  "256",
    "--gpu",         "0",
    "--L",           "100",
]
main()
# Out:
# /usr/local/lib/python3.11/dist-packages/torch/utils/data/dataloader.py:624: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(
# ✅ Original ID Labels: ['Laysan Albatross', 'Groove billed Ani', 'Crested Auklet', 'Parakeet Auklet', 'Rusty Blackbird', 'Bobolink', 'Indigo Bunting', 'Painted Bunting', 'Spotted Catbird', 'Yellow breasted Chat', 'Eastern Towhee', 'Chuck will Widow', 'Red faced Cormorant', 'Pelagic Cormorant', 'Bronzed Cowbird', 'Shiny Cowbird', 'American Crow', 'Purple Finch', 'Acadian Flycatcher', 'Olive sided Flycatcher', 'Scissor tailed Flycatcher', 'Yellow bellied Flycatcher', 'Frigatebird', 'Gadwall', 'American Goldfinch', 'Boat tailed Grackle', 'Eared Grebe', 'Horned Grebe', 'Pied billed Grebe', 'Blue Grosbeak', 'Evening Grosbeak', 'Pine Grosbeak', 'Rose breasted Grosbeak', 'Pigeon Guillemot', 'Glaucous winged Gull', 'Herring Gull', 'Ivory Gull', 'Ring billed Gull', 'Anna Hummingbird', 'Pomarine Jaeger', 'Blue Jay', 'Green Jay', 'Gray Kingbird', 'Ringed Kingfisher', 'Red legged Kittiwake', 'Horned Lark', 'Western Meadowlark', 'Red breasted Merganser', 'White breasted Nuthatch', 'Hooded Oriole', 'Orchard Oriole', 'Ovenbird', 'Western Wood Pewee', 'Sayornis', 'Whip poor Will', 'White necked Raven', 'Great Grey Shrike', 'Brewer Sparrow', 'Chipping Sparrow', 'Clay colored Sparrow', 'House Sparrow', 'Fox Sparrow', 'Grasshopper Sparrow', 'Henslow Sparrow', 'Le Conte Sparrow', 'Savannah Sparrow', 'Vesper Sparrow', 'Bank Swallow', 'Cliff Swallow', 'Scarlet Tanager', 'Black Tern', 'Caspian Tern', 'Brown Thrasher', 'Sage Thrasher', 'Black capped Vireo', 'Blue headed Vireo', 'Philadelphia Vireo', 'Warbling Vireo', 'Yellow throated Vireo', 'Black throated Blue Warbler', 'Blue winged Warbler', 'Cape May Warbler', 'Golden winged Warbler', 'Hooded Warbler', 'Magnolia Warbler', 'Myrtle Warbler', 'Orange crowned Warbler', 'Palm Warbler', 'Pine Warbler', 'Prothonotary Warbler', 'Swainson Warbler', 'Tennessee Warbler', 'Worm eating Warbler', 'Northern Waterthrush', 'Cedar Waxwing', 'Red bellied Woodpecker', 'Downy Woodpecker', 'Bewick Wren', 'House Wren', 'Common Yellowthroat']
# 🔮 Using LLM-generated OOD candidate classes...
# Envisioning Outlier Exposure...
# 🔵 Generating via OpenAI GPT...
# Continuing vision 1/1
# 🔍 Raw GPT output:
#  - American Avocet
# - Black Skimmer
# - California Condor
# - Eurasian Collared Dove
# - Ferruginous Hawk
# - Green Heron
# - Harpy Eagle
# - Ivory billed Woodpecker
# - Jabiru
# - King Vulture
# - Long tailed Jaeger
# - Marbled Murrelet
# - Northern Mockingbird
# - Osprey
# - Painted Redstart
# - Quetzal
# - Red Knot
# - Snowy Owl
# - Toco Toucan
# - Umbrellabird
# - Violet crowned Hummingbird
# - White throated Sparrow
# - Xantus's Hummingbird
# - Yellow billed Cuckoo
# - Zone tailed Hawk
# - American Kestrel
# - Black capped Chickadee
# - Carolina Wren
# - Dark eyed Junco
# - Eastern Bluebird
# - Ferruginous Pygmy Owl
# - Greater Roadrunner
# - Harris's Hawk
# - Inca Dove
# - Juniper Titmouse
# - Killdeer
# - Loggerhead Shrike
# - Mountain Bluebird
# - Northern Flicker
# - Orchard Oriole
# - Painted Bunting
# - Quail
# - Red winged Blackbird
# - Snow Bunting
# - Tufted Titmouse
# - Upland Sandpiper
# - Vermilion Flycatcher
# - Western Bluebird
# - Yellow Warbler- African Grey Parrot
# - Blue and Gold Macaw
# - Cockatiel
# - Eclectus Parrot
# - Fischer's Lovebird
# - Green Cheek Conure
# - Hyacinth Macaw
# - Indian Ringneck Parrot
# - Jenday Conure
# - Kakapo
# - Lovebird
# - Macaw
# - Nanday Conure
# - Orange Winged Amazon
# - Pionus Parrot
# - Quaker Parrot
# - Rose Breasted Cockatoo
# - Sun Conure
# - Toucan
# - Umbrella Cockatoo
# - Vasa Parrot
# - White Bellied Caique
# - Xantus Murrelet
# - Yellow Naped Amazon
# - Zebra Finch
# - African Penguin
# - Blue Footed Booby
# - Crested Caracara
# - Dusky Grouse
# - Elegant Trogon
# - Frigatebird
# - Gila Woodpecker
# - Harlequin Duck
# - Inca Tern
# - Juniper Titmouse
# - King Eider
# - Least Tern
# - Magnificent Frigatebird
# - Northern Gannet
# - Ocellated Turkey
# - Piping Plover
# - Quail
# - Red Knot
# - Sanderling
# - Tufted Puffin
# - Upland Sandpiper
# - Violet Green Swallow
# - White Tern
# - Xantus's Murrelet
#
# 💾 Saving hallucinated class descriptors to: envisioned_classes/fine_grained_100/cub100_ID_gpt-3.5-turbo_4.json
# === load json:  envisioned_classes/fine_grained_100/cub100_ID_gpt-3.5-turbo_4.json
# Get Envisioned Candidate Class Names.
# After set: 93
# After removing ID class overlaps: 90
# 🔁 Augmenting OOD candidates with synonyms...
#   → 'killdeer'  → synonym: 'charadrius vociferus'
#   → 'umbrellabird'  → synonym: 'cephalopterus penduliger'
#   → 'carolina wren'  → synonym: 'thryothorus ludovicianus'
#   → 'african penguin'  → synonym: 'spheniscus demersus'
#   → 'black skimmer'  → synonym: 'rynchops niger'
#   → 'tufted titmouse'  → synonym: 'baeolophus bicolor'
#   → 'blue and gold macaw'  → synonym: 'ara ararauna'
#   → 'american avocet'  → synonym: 'recurvirostra americana'
#   → 'piping plover'  → synonym: 'charadrius melodus'
#   → 'nanday conure'  → synonym: 'black-hooded parakeet'
#   → 'blue footed booby'  → synonym: 'sula nebouxii'
#   → "xantus's murrelet"  → synonym: 'synthliboramphus hypoleucus'
#   → 'northern mockingbird'  → synonym: 'mimus polyglottos'
#   → 'vasa parrot'  → synonym: 'coracopsis vasa'
#   → 'yellow naped amazon'  → synonym: 'yellow-naped parrot'
#   → 'black capped chickadee'  → synonym: 'poecile atricapillus'
#   → 'dark eyed junco'  → synonym: 'junco hyemalis'
#   → 'osprey'  → synonym: 'pandion haliaetus'
#   → 'gila woodpecker'  → synonym: 'melanerpes uropygialis'
#   → 'american kestrel'  → synonym: 'sparrow hawk'
#   → 'marbled murrelet'  → synonym: 'brachyramphus marmoratus'
#   → "harris's hawk"  → synonym: 'parabuteo unicinctus'
#   → 'zebra finch'  → synonym: 'taeniopygia guttata'
#   → 'ocellated turkey'  → synonym: 'meleagris ocellata'
#   → 'greater roadrunner'  → synonym: 'geococcyx californianus'
#   → 'snowy owl'  → synonym: 'bubo scandiacus'
#   → 'tufted puffin'  → synonym: 'fratercula cirrhata'
#   → 'harpy eagle'  → synonym: 'harpia harpyja'
#   → 'quaker parrot'  → synonym: 'monk parakeet'
#   → 'california condor'  → synonym: 'gymnogyps californianus'
#   → 'red knot'  → synonym: 'calidris canutus'
#   → 'quetzal'  → synonym: 'pharomachrus'
#   → 'hyacinth macaw'  → synonym: 'anodorhynchus hyacinthinus'
#   → 'red winged blackbird'  → synonym: 'agelaius phoeniceus'
#   → 'painted redstart'  → synonym: 'myioborus pictus'
#   → 'ivory billed woodpecker'  → synonym: 'campephilus principalis'
#   → 'northern flicker'  → synonym: 'colaptes auratus'
#   → "xantus's hummingbird"  → synonym: 'baja california hummingbird'
#   → 'loggerhead shrike'  → synonym: 'lanius ludovicianus'
#   → 'ferruginous pygmy owl'  → synonym: 'glaucidium brasilianum'
#   → 'crested caracara'  → synonym: 'caracara cheriway'
#   → 'upland sandpiper'  → synonym: 'bartramia longicauda'
#   → 'vermilion flycatcher'  → synonym: 'pyrocephalus rubinus'
#   → 'least tern'  → synonym: 'sterna antillarum'
#   → "fischer's lovebird"  → synonym: 'agapornis fischeri'
#   → 'inca dove'  → synonym: 'columbina inca'
#   → 'green heron'  → synonym: 'butorides virescens'
#   → 'umbrella cockatoo'  → synonym: 'white cockatoo'
#   → 'white throated sparrow'  → synonym: 'zonotrichia albicollis'
#   → 'indian ringneck parrot'  → synonym: 'rose-ringed parakeet'
#   → 'snow bunting'  → synonym: 'plectrophenax nivalis'
#   → 'jenday conure'  → synonym: 'aratinga jandaya'
#   → 'mountain bluebird'  → synonym: 'sialia currucoides'
#   → 'sanderling'  → synonym: 'calidris alba'
#   → 'northern gannet'  → synonym: 'morus bassanus'
#   → 'violet crowned hummingbird'  → synonym: 'amazilia violiceps'
#   → 'king eider'  → synonym: 'somateria spectabilis'
#   → 'sun conure'  → synonym: 'aratinga solstitialis'
#   → 'yellow billed cuckoo'  → synonym: 'coccyzus americanus'
#   → 'toco toucan'  → synonym: 'ramphastos toco'
#   → 'rose breasted cockatoo'  → synonym: 'galah'
#   → 'magnificent frigatebird'  → synonym: "man o' war bird"
#   → 'xantus murrelet'  → synonym: 'synthliboramphus hypoleucus'
#   → 'inca tern'  → synonym: 'larosterna inca'
#   → 'eurasian collared dove'  → synonym: 'streptopelia decaocto'
#   → 'long tailed jaeger'  → synonym: 'stercorarius longicaudus'
#   → 'quail'  → synonym: 'coturnix'
#   → 'yellow warbler- african grey parrot'  → synonym: 'african grey parrot'
#   → 'zone tailed hawk'  → synonym: 'buteo albonotatus'
#   → 'pionus parrot'  → synonym: 'blue-headed parrot'
#   → 'white tern'  → synonym: 'gygis alba'
#   → 'white bellied caique'  → synonym: 'pionites leucogaster'
#   → 'green cheek conure'  → synonym: 'pyrrhura molinae'
#   → 'king vulture'  → synonym: 'sarcoramphus papa'
#   → 'orange winged amazon'  → synonym: 'amazona amazonica'
#   → 'violet green swallow'  → synonym: 'tachycineta thalassina'
#   → 'cockatiel'  → synonym: 'nymphicus hollandicus'
#   → 'dusky grouse'  → synonym: 'blue grouse'
#   → 'ferruginous hawk'  → synonym: 'buteo regalis'
#   → 'jabiru'  → synonym: 'black-necked stork'
#   → 'toucan'  → synonym: 'ramphastidae'
#   → 'elegant trogon'  → synonym: 'elegant quetzal'
#   → 'lovebird'  → synonym: 'agapornis'
#   → 'eastern bluebird'  → synonym: 'sialia sialis'
#   → 'juniper titmouse'  → synonym: 'oak titmouse'
#   → 'macaw'  → synonym: 'ara'
#   → 'eclectus parrot'  → synonym: 'eclectus roratus'
#   → 'kakapo'  → synonym: 'night parrot'
#   → 'harlequin duck'  → synonym: 'histrionicus histrionicus'
#   → 'western bluebird'  → synonym: 'sialia mexicana'
# 🧹 Removed 0 invalid synonym labels like 'none' or 'null'
# 📏 OOD classes before synonym expansion: 90
# 📐 OOD classes after synonym + deduplication: 179
#
# 🧪 Final ID Labels passed to CLIP: ['Laysan Albatross', 'Groove billed Ani', 'Crested Auklet', 'Parakeet Auklet', 'Rusty Blackbird', 'Bobolink', 'Indigo Bunting', 'Painted Bunting', 'Spotted Catbird', 'Yellow breasted Chat', 'Eastern Towhee', 'Chuck will Widow', 'Red faced Cormorant', 'Pelagic Cormorant', 'Bronzed Cowbird', 'Shiny Cowbird', 'American Crow', 'Purple Finch', 'Acadian Flycatcher', 'Olive sided Flycatcher', 'Scissor tailed Flycatcher', 'Yellow bellied Flycatcher', 'Frigatebird', 'Gadwall', 'American Goldfinch', 'Boat tailed Grackle', 'Eared Grebe', 'Horned Grebe', 'Pied billed Grebe', 'Blue Grosbeak', 'Evening Grosbeak', 'Pine Grosbeak', 'Rose breasted Grosbeak', 'Pigeon Guillemot', 'Glaucous winged Gull', 'Herring Gull', 'Ivory Gull', 'Ring billed Gull', 'Anna Hummingbird', 'Pomarine Jaeger', 'Blue Jay', 'Green Jay', 'Gray Kingbird', 'Ringed Kingfisher', 'Red legged Kittiwake', 'Horned Lark', 'Western Meadowlark', 'Red breasted Merganser', 'White breasted Nuthatch', 'Hooded Oriole', 'Orchard Oriole', 'Ovenbird', 'Western Wood Pewee', 'Sayornis', 'Whip poor Will', 'White necked Raven', 'Great Grey Shrike', 'Brewer Sparrow', 'Chipping Sparrow', 'Clay colored Sparrow', 'House Sparrow', 'Fox Sparrow', 'Grasshopper Sparrow', 'Henslow Sparrow', 'Le Conte Sparrow', 'Savannah Sparrow', 'Vesper Sparrow', 'Bank Swallow', 'Cliff Swallow', 'Scarlet Tanager', 'Black Tern', 'Caspian Tern', 'Brown Thrasher', 'Sage Thrasher', 'Black capped Vireo', 'Blue headed Vireo', 'Philadelphia Vireo', 'Warbling Vireo', 'Yellow throated Vireo', 'Black throated Blue Warbler', 'Blue winged Warbler',
ubinus', 'sterna antillarum', 'agapornis fischeri', 'columbina inca', 'butorides virescens', 'white cockatoo', 'zonotrichia albicollis', 'rose-ringed parakeet', 'plectrophenax nivalis', 'aratinga jandaya', 'sialia currucoides', 'calidris alba', 'morus bassanus', 'amazilia violiceps', 'somateria spectabilis', 'aratinga solstitialis', 'coccyzus americanus', 'ramphastos toco', 'galah', "man o' war bird", 'larosterna inca', 'streptopelia decaocto', 'stercorarius longicaudus', 'coturnix', 'african grey parrot', 'buteo albonotatus', 'blue-headed parrot', 'gygis alba', 'pionites leucogaster', 'pyrrhura molinae', 'sarcoramphus papa', 'amazona amazonica', 'tachycineta thalassina', 'nymphicus hollandicus', 'blue grouse', 'buteo regalis', 'black-necked stork', 'ramphastidae', 'elegant quetzal', 'agapornis', 'sialia sialis', 'oak titmouse', 'ara', 'eclectus roratus', 'night parrot', 'histrionicus histrionicus', 'sialia mexicana']
# 100%|██████████| 12/12 [00:40<00:00,  3.35s/it]
# 2025-07-15 15:04:03,700 : 📦 Evaluating OOD dataset cub100_OOD
# DEBUG:__main__:📦 Evaluating OOD dataset cub100_OOD
# /usr/local/lib/python3.11/dist-packages/torch/utils/data/dataloader.py:624: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(
# 100%|██████████| 12/12 [00:42<00:00,  3.54s/it]
# 2025-07-15 15:04:46,913 : in scores: DescribeResult(nobs=2895, minmax=(np.float32(-0.00337415), np.float32(-0.0027821914)), mean=np.float32(-0.0030888605), variance=np.float64(7.1889213310653275e-09), skewness=np.float64(0.08222252875566483), kurtosis=np.float32(0.26560903))
# DEBUG:__main__:in scores: DescribeResult(nobs=2895, minmax=(np.float32(-0.00337415), np.float32(-0.0027821914)), mean=np.float32(-0.0030888605), variance=np.float64(7.1889213310653275e-09), skewness=np.float64(0.08222252875566483), kurtosis=np.float32(0.26560903))
# 2025-07-15 15:04:46,918 : out scores: DescribeResult(nobs=2899, minmax=(np.float32(-0.0033339637), np.float32(-0.002794932)), mean=np.float32(-0.003015511), variance=np.float64(6.929741971723737e-09), skewness=np.float64(-0.18392695486545563), kurtosis=np.float32(-0.37296104))
# DEBUG:__main__:out scores: DescribeResult(nobs=2899, minmax=(np.float32(-0.0033339637), np.float32(-0.002794932)), mean=np.float32(-0.003015511), variance=np.float64(6.929741971723737e-09), skewness=np.float64(-0.18392695486545563), kurtosis=np.float32(-0.37296104))
# 2025-07-15 15:04:48,094 : 				EOE
# DEBUG:__main__:				EOE
# 2025-07-15 15:04:48,100 :   FPR95 AUROC AUPR
# DEBUG:__main__:  FPR95 AUROC AUPR
# 2025-07-15 15:04:48,104 : & 77.10 & 73.32 & 72.11
# DEBUG:__main__:& 77.10 & 73.32 & 72.11
# 2025-07-15 15:04:48,110 :
#
# 📊 Mean Test Results
# DEBUG:__main__:
#
# 📊 Mean Test Results
# 2025-07-15 15:04:48,115 : 				EOE
# DEBUG:__main__:				EOE
# 2025-07-15 15:04:48,116 :   FPR95 AUROC AUPR
# DEBUG:__main__:  FPR95 AUROC AUPR
# 2025-07-15 15:04:48,119 : & 77.10 & 73.32 & 72.11
# DEBUG:__main__:& 77.10 & 73.32 & 72.11

# %%
sys.argv = [
    "eval_ood_detection.py",
    "--name",        "CUB100_CUB100_EOE_300L_25B_finegrained_synonymOOD",
    "--in_dataset",  "cub100_ID",
    "--ood_task",    "fine_grained",
    "--score",       "EOE",
    "--score_ablation", "EOE",           # use standard EOE score
    "--generate_class",                  # generate OOD candidates via LLM
    "--use_synonyms",                   # apply synonym expansion to OOD classes
    "--root_dir",    "datasets",
    "--batch_size",  "256",
    "--gpu",         "0",
    "--L",           "300",
]
main()
# Out:
# /usr/local/lib/python3.11/dist-packages/torch/utils/data/dataloader.py:624: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(
# ✅ Original ID Labels: ['Laysan Albatross', 'Groove billed Ani', 'Crested Auklet', 'Parakeet Auklet', 'Rusty Blackbird', 'Bobolink', 'Indigo Bunting', 'Painted Bunting', 'Spotted Catbird', 'Yellow breasted Chat', 'Eastern Towhee', 'Chuck will Widow', 'Red faced Cormorant', 'Pelagic Cormorant', 'Bronzed Cowbird', 'Shiny Cowbird', 'American Crow', 'Purple Finch', 'Acadian Flycatcher', 'Olive sided Flycatcher', 'Scissor tailed Flycatcher', 'Yellow bellied Flycatcher', 'Frigatebird', 'Gadwall', 'American Goldfinch', 'Boat tailed Grackle', 'Eared Grebe', 'Horned Grebe', 'Pied billed Grebe', 'Blue Grosbeak', 'Evening Grosbeak', 'Pine Grosbeak', 'Rose breasted Grosbeak', 'Pigeon Guillemot', 'Glaucous winged Gull', 'Herring Gull', 'Ivory Gull', 'Ring billed Gull', 'Anna Hummingbird', 'Pomarine Jaeger', 'Blue Jay', 'Green Jay', 'Gray Kingbird', 'Ringed Kingfisher', 'Red legged Kittiwake', 'Horned Lark', 'Western Meadowlark', 'Red breasted Merganser', 'White breasted Nuthatch', 'Hooded Oriole', 'Orchard Oriole', 'Ovenbird', 'Western Wood Pewee', 'Sayornis', 'Whip poor Will', 'White necked Raven', 'Great Grey Shrike', 'Brewer Sparrow', 'Chipping Sparrow', 'Clay colored Sparrow', 'House Sparrow', 'Fox Sparrow', 'Grasshopper Sparrow', 'Henslow Sparrow', 'Le Conte Sparrow', 'Savannah Sparrow', 'Vesper Sparrow', 'Bank Swallow', 'Cliff Swallow', 'Scarlet Tanager', 'Black Tern', 'Caspian Tern', 'Brown Thrasher', 'Sage Thrasher', 'Black capped Vireo', 'Blue headed Vireo', 'Philadelphia Vireo', 'Warbling Vireo', 'Yellow throated Vireo', 'Black throated Blue Warbler', 'Blue winged Warbler', 'Cape May Warbler', 'Golden winged Warbler', 'Hooded Warbler', 'Magnolia Warbler', 'Myrtle Warbler', 'Orange crowned Warbler', 'Palm Warbler', 'Pine Warbler', 'Prothonotary Warbler', 'Swainson Warbler', 'Tennessee Warbler', 'Worm eating Warbler', 'Northern Waterthrush', 'Cedar Waxwing', 'Red bellied Woodpecker', 'Downy Woodpecker', 'Bewick Wren', 'House Wren', 'Common Yellowthroat']
# 🔮 Using LLM-generated OOD candidate classes...
# Envisioning Outlier Exposure...
# 🔵 Generating via OpenAI GPT...
# Continuing vision 1/5
# Continuing vision 2/5
# Continuing vision 3/5
# Continuing vision 4/5
# Continuing vision 5/5
# 🔍 Raw GPT output:
#  - American Avocet
# - Black Skimmer
# - California Condor
# - Eurasian Collared Dove
# - Ferruginous Hawk
# - Green Heron
# - Harpy Eagle
# - Ivory billed Woodpecker
# - Jabiru
# - King Vulture
# - Long tailed Jaeger
# - Marbled Murrelet
# - Northern Mockingbird
# - Osprey
# - Painted Redstart
# - Quetzal
# - Quail Dove
# - Red-breasted Merganser
# - Snowy Plover
# - Tufted Puffin
# - Upland Sandpiper
# - Varied Thrush
# - Western Tanager
# - Yellow-bellied Sapsucker
#
# 💾 Saving hallucinated class descriptors to: envisioned_classes/fine_grained_300/cub100_ID_gpt-3.5-turbo_3.json
# === load json:  envisioned_classes/fine_grained_300/cub100_ID_gpt-3.5-turbo_3.json
# Get Envisioned Candidate Class Names.
# After set: 193
# After removing ID class overlaps: 179
# 🔁 Augmenting OOD candidates with synonyms...
#   → 'killdeer'  → synonym: 'charadrius vociferus'
#   → 'dickcissel'  → synonym: 'spiza americana'
#   → 'umbrellabird'  → synonym: 'cotinga ridgwayi'
#   → 'orange-fronted parakeet'  → synonym: 'eupsittula canicularis'
#   → 'pink-headed warbler'  → synonym: 'cardellina versicolor'
#   → 'carolina wren'  → synonym: 'thryothorus ludovicianus'
#   → 'violet-green swallow'  → synonym: 'tachycineta thalassina'
#   → 'fulvous whistling duck'  → synonym: 'dendrocygna bicolor'
#   → 'black skimmer'  → synonym: 'rynchops niger'
#   → 'black-crowned night heron'  → synonym: 'nycticorax nycticorax'
#   → 'piping plover'  → synonym: 'charadrius melodus'
#   → 'blue and gold macaw'  → synonym: 'ara ararauna'
#   → 'american avocet'  → synonym: 'recurvirostra americana'
#   → 'tufted titmouse'  → synonym: 'baeolophus bicolor'
#   → 'nanday conure'  → synonym: 'black-hooded parakeet'
#   → 'cinnamon teal'  → synonym: 'anas cyanoptera'
#   → "xantus's murrelet"  → synonym: 'synthliboramphus hypoleucus'
#   → 'blue-crowned motmot'  → synonym: 'momotus momota'
#   → 'japanese quail'  → synonym: 'coturnix japonica'
#   → 'violet turaco- azure-winged magpie'  → synonym: 'cyanopica cyanus'
#   → 'northern mockingbird'  → synonym: 'mimus polyglottos'
#   → 'vasa parrot'  → synonym: 'coracopsis vasa'
#   → 'maroon oriole'  → synonym: 'black-naped oriole'
#   → 'pink-footed shearwater'  → synonym: 'ardenna creatopus'
#   → 'dark eyed junco'  → synonym: 'junco hyemalis'
#   → 'osprey'  → synonym: 'pandion haliaetus'
#   → 'elegant tern'  → synonym: 'thalasseus elegans'
#   → 'marbled murrelet'  → synonym: 'brachyramphus marmoratus'
#   → 'red-breasted nuthatch'  → synonym: 'sitta canadensis'
#   → 'kagu'  → synonym: 'rhynochetos jubatus'
#   → 'philippine eagle'  → synonym: 'pithecophaga jefferyi'
#   → 'andean condor'  → synonym: 'vultur gryphus'
#   → 'black throated green warbler'  → synonym: 'dendroica virens'
#   → 'rose-ringed parakeet'  → synonym: 'psittacula krameri'
#   → 'zebra finch'  → synonym: 'taeniopygia guttata'
#   → 'nicobar pigeon'  → synonym: 'caloenas nicobarica'
#   → 'african pygmy goose'  → synonym: 'nettapus auritus'
#   → 'greater roadrunner'  → synonym: 'geococcyx californianus'
#   → 'golden pheasant'  → synonym: 'chinese pheasant'
#   → 'yellow-bellied sapsucker'  → synonym: 'sphyrapicus varius'
#   → 'snowy owl'  → synonym: 'bubo scandiacus'
#   → 'tufted puffin'  → synonym: 'fratercula cirrhata'
#   → 'louisiana waterthrush'  → synonym: 'seiurus motacilla'
#   → 'harpy eagle'  → synonym: 'harpia harpyja'
#   → 'goliath heron'  → synonym: 'ardea goliath'
#   → 'chestnut-sided warbler'  → synonym: 'dendroica pensylvanica'
#   → 'quaker parrot'  → synonym: 'monk parakeet'
#   → 'california condor'  → synonym: 'gymnogyps californianus'
#   → 'red knot'  → synonym: 'calidris canutus'
#   → 'quetzal'  → synonym: 'pharomachrus'
#   → 'orange-crowned warbler'  → synonym: 'oreothlypis celata'
#   → "townsend's warbler"  → synonym: 'setophaga townsendi'
#   → 'moluccan cockatoo'  → synonym: 'salmon-crested cockatoo'
#   → 'hyacinth macaw'  → synonym: 'anodorhynchus hyacinthinus'
#   → 'snowy plover'  → synonym: 'charadrius nivosus'
#   → 'red winged blackbird'  → synonym: 'agelaius phoeniceus'
#   → 'ivory-billed aracari'  → synonym: 'ivory-billed toucan'
#   → 'american woodcock'  → synonym: 'scolopax minor'
#   → 'japanese white-eye'  → synonym: 'zosterops japonicus'
#   → 'eastern screech owl'  → synonym: 'megascops asio'
#   → 'painted redstart'  → synonym: 'myioborus pictus'
#   → 'yellow-crowned amazon'  → synonym: 'amazona ochrocephala'
#   → 'black-throated trogon'  → synonym: 'trogon rufus'
#   → 'ivory billed woodpecker'  → synonym: 'campephilus principalis'
#   → 'white-throated magpie-jay'  → synonym: 'calocitta formosa'
#   → 'black-throated green warbler'  → synonym: 'dendroica virens'
#   → 'snowy egret'  → synonym: 'egretta thula'
#   → 'chestnut sided warbler'  → synonym: 'dendroica pensylvanica'
#   → 'northern flicker'  → synonym: 'colaptes auratus'
#   → "xantus's hummingbird"  → synonym: 'basilinna xantusii'
#   → 'white-throated magpie-jay- andean cock-of-the-rock'  → synonym: 'cotinga maynana'
#   → 'loggerhead shrike'  → synonym: 'lanius ludovicianus'
#   → 'african pygmy kingfisher'  → synonym: 'ispidina picta'
#   → 'red-billed leiothrix'  → synonym: 'leiothrix lutea'
#   → 'ferruginous pygmy owl'  → synonym: 'glaucidium brasilianum'
#   → 'crested caracara'  → synonym: 'caracara cheriway'
#   → 'harlequin quail'  → synonym: 'chinese painted quail'
#   → 'sulphur-crested cockatoo'  → synonym: 'cacatua galerita'
#   → 'black-capped chickadee'  → synonym: 'poecile atricapillus'
#   → 'ostrich'  → synonym: 'struthio camelus'
#   → 'upland sandpiper'  → synonym: 'bartramia longicauda'
#   → 'zebra dove'  → synonym: 'geopelia striata'
#   → 'least tern'  → synonym: 'sterna antillarum'
#   → 'vermilion flycatcher'  → synonym: 'pyrocephalus rubinus'
#   → 'emerald toucanet'  → synonym: 'aulacorhynchus prasinus'
#   → 'golden-crowned kinglet'  → synonym: 'regulus satrapa'
#   → 'double-crested cormorant'  → synonym: 'phalacrocorax auritus'
#   → 'fairy pitta'  → synonym: 'pitta nympha'
#   → 'rufous-tailed jacamar'  → synonym: 'rufous-tailed jacamar'
#   → "fischer's lovebird"  → synonym: 'agapornis fischeri'
#   → 'yellow-billed magpie'  → synonym: 'pica nuttalli'
#   → 'gray catbird'  → synonym: 'dumetella carolinensis'
#   → 'yellow-bellied flycatcher- american kestrel'  → synonym: 'american kestrel'
#   → 'green heron'  → synonym: 'butorides virescens'
#   → 'umbrella cockatoo'  → synonym: 'white cockatoo'
#   → 'white throated sparrow'  → synonym: 'zonotrichia albicollis'
#   → 'nicobar megapode'  → synonym: 'nicobar scrubfowl'
#   → 'crimson sunbird'  → synonym: 'aethopyga siparaja'
#   → 'quail dove'  → synonym: 'geotrygon mystacea'
#   → 'olive-sided flycatcher'  → synonym: 'contopus cooperi'
#   → 'common redpoll'  → synonym: 'acanthis flammea'
#   → 'fairy tern'  → synonym: 'white tern'
#   → 'northern bobwhite'  → synonym: 'colinus virginianus'
#   → 'imperial amazon'  → synonym: 'amazona imperialis'
#   → 'fork-tailed flycatcher'  → synonym: 'tyrannus savana'
#   → 'mountain bluebird'  → synonym: 'sialia currucoides'
#   → 'sanderling'  → synonym: 'calidris alba'
#   → 'long-tailed jaeger'  → synonym: 'stercorarius longicaudus'
#   → 'yellow warbler- american woodcock'  → synonym: 'scolopax minor'
#   → 'violet crowned hummingbird'  → synonym: 'amazilia violiceps'
#   → 'marabou stork'  → synonym: 'leptoptilos crumeniferus'
#   → 'king eider'  → synonym: 'somateria spectabilis'
#   → 'white-throated sparrow'  → synonym: 'zonotrichia albicollis'
#   → 'house finch'  → synonym: 'haemorhous mexicanus'
#   → 'violet turaco'  → synonym: 'violaceous turaco'
#   → 'sun conure'  → synonym: 'aratinga solstitialis'
#   → 'yellow billed cuckoo'  → synonym: 'coccyzus americanus'
#   → 'sora'  → synonym: 'porzana carolina'
#   → 'crested guan'  → synonym: 'penelope purpurascens'
#   → 'king rail'  → synonym: 'rallus elegans'
#   → 'java sparrow'  → synonym: 'java finch'
#   → 'red-billed tropicbird'  → synonym: 'phaethon aethereus'
#   → 'toco toucan'  → synonym: 'ramphastos toco'
#   → 'marbled godwit'  → synonym: 'limosa fedoa'
#   → 'magnificent frigatebird'  → synonym: "man o' war bird"
#   → 'black-throated sparrow'  → synonym: 'amphispiza bilineata'
#   → 'eurasian collared dove'  → synonym: 'streptopelia decaocto'
#   → 'long tailed jaeger'  → synonym: 'stercorarius longicaudus'
#   → 'white-crowned pigeon'  → synonym: 'columba leucocephala'
#   → 'red-winged blackbird'  → synonym: 'agelaius phoeniceus'
#   → 'varied thrush'  → synonym: 'ixoreus naevius'
#   → 'red-breasted merganser'  → synonym: 'mergus serrator'
#   → 'mourning dove'  → synonym: 'zenaida macroura'
#   → 'mourning warbler'  → synonym: 'geothlypis philadelphia'
#   → 'great horned owl'  → synonym: 'bubo virginianus'
#   → 'tawny owl'  → synonym: 'strix aluco'
#   → 'zone tailed hawk'  → synonym: 'buteo albonotatus'
#   → 'pionus parrot'  → synonym: 'blue-headed parrot'
#   → 'ural owl'  → synonym: 'strix uralensis'
#   → 'ivory-billed woodpecker'  → synonym: 'campephilus principalis'
#   → 'least bittern'  → synonym: 'ixobrychus exilis'
#   → 'keel-billed toucan'  → synonym: 'rainbow-billed toucan'
#   → 'dusky sunbird'  → synonym: 'cinnyris fuscus'
#   → 'king vulture'  → synonym: 'sarcoramphus papa'
#   → 'western grebe'  → synonym: 'aechmophorus occidentalis'
#   → 'long-tailed duck'  → synonym: 'oldsquaw'
#   → 'eurasian bullfinch'  → synonym: 'common bullfinch'
#   → 'cockatiel'  → synonym: 'nymphicus hollandicus'
#   → 'green hermit'  → synonym: 'phaethornis guy'
#   → 'western tanager'  → synonym: 'piranga ludoviciana'
#   → 'dusky grouse'  → synonym: 'blue grouse'
#   → 'ferruginous hawk'  → synonym: 'buteo regalis'
#   → 'ivory-billed woodcreeper'  → synonym: 'ivory-billed woodcreeper'
#   → 'jabiru'  → synonym: 'black-necked stork'
#   → 'violet sabrewing'  → synonym: 'campylopterus hemileucurus'
#   → 'yellow warbler'  → synonym: 'dendroica petechia'
#   → 'eastern whip-poor-will'  → synonym: 'antrostomus vociferus'
#   → 'flame-colored tanager'  → synonym: 'piranga bidentata'
#   → 'elegant trogon'  → synonym: 'elegant quetzal'
#   → 'eastern bluebird'  → synonym: 'sialia sialis'
#   → 'tawny frogmouth'  → synonym: 'podargus strigoides'
#   → 'indian ringneck parakeet'  → synonym: 'rose-ringed parakeet'
#   → 'juniper titmouse'  → synonym: 'oak titmouse'
#   → 'kentucky warbler'  → synonym: 'geothlypis formosa'
#   → 'gouldian finch'  → synonym: 'erythrura gouldiae'
#   → 'northern cardinal'  → synonym: 'cardinalis cardinalis'
#   → 'dusky lory'  → synonym: 'pseudeos fuscata'
#   → 'jamaican tody'  → synonym: 'todus todus'
#   → 'hooded merganser'  → synonym: 'lophodytes cucullatus'
#   → 'black-capped vireo'  → synonym: 'vireo atricapilla'
#   → 'green honeycreeper'  → synonym: 'chlorophanes spiza'
#   → 'orange-bellied parrot'  → synonym: 'neophema chrysogaster'
#   → 'scarlet macaw'  → synonym: 'ara macao'
#   → 'eclectus parrot'  → synonym: 'eclectus roratus'
#   → 'lilac-breasted roller'  → synonym: 'coracias caudatus'
#   → 'harlequin duck'  → synonym: 'histrionicus histrionicus'
#   → 'western bluebird'  → synonym: 'sialia mexicana'
#   → 'yellow crowned night heron- african grey parrot'  → synonym: 'african gray parrot'
#   → 'pileated woodpecker'  → synonym: 'dryocopus pileatus'
# 🧹 Removed 0 invalid synonym labels like 'none' or 'null'
# 📏 OOD classes before synonym expansion: 179
# 📐 OOD classes after synonym + deduplication: 348
#
# 🧪 Final ID Labels passed to CLIP: ['Laysan Albatross', 'Groove billed Ani', 'Crested Auklet', 'Parakeet Auklet', 'Rusty Blackbird', 'Bobolink', 'Indigo Bunting', 'Painted Bunting', 'Spotted Catbird', 'Yellow breasted Chat', 'Eastern Towhee', 'Chuck will Widow', 'Red faced Cormorant', 'Pelagic Cormorant', 'Bronzed Cowbird', 'Shiny Cowbird', 'American Crow', 'Purple Finch', 'Acadian Flycatcher', 'Olive sided Flycatcher', 'Scissor tailed Flycatcher', 'Yellow bellied Fl
# /usr/local/lib/python3.11/dist-packages/torch/utils/data/dataloader.py:624: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(
# 100%|██████████| 12/12 [00:43<00:00,  3.60s/it]
# 2025-07-15 15:08:29,711 : in scores: DescribeResult(nobs=2895, minmax=(np.float32(-0.00210095), np.float32(-0.001722838)), mean=np.float32(-0.0019062195), variance=np.float64(2.362749463944539e-09), skewness=np.float64(0.12586815655231476), kurtosis=np.float32(0.27740836))
# DEBUG:__main__:in scores: DescribeResult(nobs=2895, minmax=(np.float32(-0.00210095), np.float32(-0.001722838)), mean=np.float32(-0.0019062195), variance=np.float64(2.362749463944539e-09), skewness=np.float64(0.12586815655231476), kurtosis=np.float32(0.27740836))
# 2025-07-15 15:08:29,715 : out scores: DescribeResult(nobs=2899, minmax=(np.float32(-0.0020426402), np.float32(-0.0017198878)), mean=np.float32(-0.0018630819), variance=np.float64(2.3788359113995547e-09), skewness=np.float64(-0.009573370218276978), kurtosis=np.float32(-0.37862325))
# DEBUG:__main__:out scores: DescribeResult(nobs=2899, minmax=(np.float32(-0.0020426402), np.float32(-0.0017198878)), mean=np.float32(-0.0018630819), variance=np.float64(2.3788359113995547e-09), skewness=np.float64(-0.009573370218276978), kurtosis=np.float32(-0.37862325))
# 2025-07-15 15:08:31,199 : 				EOE
# DEBUG:__main__:				EOE
# 2025-07-15 15:08:31,207 :   FPR95 AUROC AUPR
# DEBUG:__main__:  FPR95 AUROC AUPR
# 2025-07-15 15:08:31,217 : & 76.75 & 73.45 & 72.78
# DEBUG:__main__:& 76.75 & 73.45 & 72.78
# 2025-07-15 15:08:31,219 :
#
# 📊 Mean Test Results
# DEBUG:__main__:
#
# 📊 Mean Test Results
# 2025-07-15 15:08:31,225 : 				EOE
# DEBUG:__main__:				EOE
# 2025-07-15 15:08:31,228 :   FPR95 AUROC AUPR
# DEBUG:__main__:  FPR95 AUROC AUPR
# 2025-07-15 15:08:31,235 : & 76.75 & 73.45 & 72.78
# DEBUG:__main__:& 76.75 & 73.45 & 72.78

# %%
sys.argv = [
    "eval_ood_detection.py",
    "--name",        "CUB100_CUB100_EOE_500L_25B_finegrained_synonymOOD",
    "--in_dataset",  "cub100_ID",
    "--ood_task",    "fine_grained",
    "--score",       "EOE",
    "--score_ablation", "EOE",           # use standard EOE score
    "--generate_class",                  # generate OOD candidates via LLM
    "--use_synonyms",                   # apply synonym expansion to OOD classes
    "--root_dir",    "datasets",
    "--batch_size",  "256",
    "--gpu",         "0",
    "--L",           "500",
]
main()
# Out:
# /usr/local/lib/python3.11/dist-packages/torch/utils/data/dataloader.py:624: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(
# ✅ Original ID Labels: ['Laysan Albatross', 'Groove billed Ani', 'Crested Auklet', 'Parakeet Auklet', 'Rusty Blackbird', 'Bobolink', 'Indigo Bunting', 'Painted Bunting', 'Spotted Catbird', 'Yellow breasted Chat', 'Eastern Towhee', 'Chuck will Widow', 'Red faced Cormorant', 'Pelagic Cormorant', 'Bronzed Cowbird', 'Shiny Cowbird', 'American Crow', 'Purple Finch', 'Acadian Flycatcher', 'Olive sided Flycatcher', 'Scissor tailed Flycatcher', 'Yellow bellied Flycatcher', 'Frigatebird', 'Gadwall', 'American Goldfinch', 'Boat tailed Grackle', 'Eared Grebe', 'Horned Grebe', 'Pied billed Grebe', 'Blue Grosbeak', 'Evening Grosbeak', 'Pine Grosbeak', 'Rose breasted Grosbeak', 'Pigeon Guillemot', 'Glaucous winged Gull', 'Herring Gull', 'Ivory Gull', 'Ring billed Gull', 'Anna Hummingbird', 'Pomarine Jaeger', 'Blue Jay', 'Green Jay', 'Gray Kingbird', 'Ringed Kingfisher', 'Red legged Kittiwake', 'Horned Lark', 'Western Meadowlark', 'Red breasted Merganser', 'White breasted Nuthatch', 'Hooded Oriole', 'Orchard Oriole', 'Ovenbird', 'Western Wood Pewee', 'Sayornis', 'Whip poor Will', 'White necked Raven', 'Great Grey Shrike', 'Brewer Sparrow', 'Chipping Sparrow', 'Clay colored Sparrow', 'House Sparrow', 'Fox Sparrow', 'Grasshopper Sparrow', 'Henslow Sparrow', 'Le Conte Sparrow', 'Savannah Sparrow', 'Vesper Sparrow', 'Bank Swallow', 'Cliff Swallow', 'Scarlet Tanager', 'Black Tern', 'Caspian Tern', 'Brown Thrasher', 'Sage Thrasher', 'Black capped Vireo', 'Blue headed Vireo', 'Philadelphia Vireo', 'Warbling Vireo', 'Yellow throated Vireo', 'Black throated Blue Warbler', 'Blue winged Warbler', 'Cape May Warbler', 'Golden winged Warbler', 'Hooded Warbler', 'Magnolia Warbler', 'Myrtle Warbler', 'Orange crowned Warbler', 'Palm Warbler', 'Pine Warbler', 'Prothonotary Warbler', 'Swainson Warbler', 'Tennessee Warbler', 'Worm eating Warbler', 'Northern Waterthrush', 'Cedar Waxwing', 'Red bellied Woodpecker', 'Downy Woodpecker', 'Bewick Wren', 'House Wren', 'Common Yellowthroat']
# 🔮 Using LLM-generated OOD candidate classes...
# Envisioning Outlier Exposure...
# 🔵 Generating via OpenAI GPT...
# Continuing vision 1/9
# Continuing vision 2/9
# Continuing vision 3/9
# Continuing vision 4/9
# Continuing vision 5/9
# Continuing vision 6/9
# Continuing vision 7/9
# Continuing vision 8/9
# Continuing vision 9/9
# 🔍 Raw GPT output:
#  - American Avocet
# - Black Skimmer
# - California Condor
# - Eurasian Collared Dove
# - Ferruginous Hawk
# - Green Heron
# - Harpy Eagle
# - Ivory billed Woodpecker
# - Jabiru
# - King Vulture
# - Long tailed Jaeger
# - Marbled Murrelet
# - Northern Mockingbird
# - Osprey
# - Painted Redstart
# - Quetzal
# - Red Knot
# - Snowy Owl
# - Toco Toucan
# - Umbrellabird
# - Violet crowned Hummingbird
# - White throated Sparrow
# - Xantus's Hummingbird
# - Yellow billed Cuckoo
# - Zone tailed Hawk
# - American Woodcock
# - Black capped Chickadee
# - Carolina Wren
# - Dickcissel
# - Eastern Bluebird
# - Ferruginous Pygmy Owl
# - Green Jay
# - Harris's Hawk
# - Inca Dove
# - Juniper Titmouse
# - King Rail
# - Least Tern
# - Mountain Bluebird
# - Northern Flicker
# - Olive sided Flycatcher
# - Painted Bunting
# - Quail Dove
# - Red winged Blackbird
# - Snowy Egret
# - Tufted Puffin
# - Violet green Swallow
# - Western Grebe
# - Yellow billed Magpie
# - Zone tailed Hawk- African Grey Parrot
# - Blue and Gold Macaw
# - Cockatiel
# - Eclectus Parrot
# - Fischer's Lovebird
# - Green Cheek Conure
# - Hyacinth Macaw
# - Indian Ringneck Parakeet
# - Jenday Conure
# - Kakapo
# - Lorikeet
# - Moluccan Cockatoo
# - Nanday Conure
# - Orange Winged Amazon
# - Pionus Parrot
# - Quaker Parrot
# - Rose Breasted Cockatoo
# - Senegal Parrot
# - Toucan
# - Umbrella Cockatoo
# - Vasa Parrot
# - White Bellied Caique
# - Xantus Murrelet
# - Yellow Naped Amazon
# - Zebra Finch
# - African Penguin
# - Ural Owl
# - Varied Lorikeet
# - White-bellied Antbird
# - Xingu Scale-backed Antbird
# - Yellow-bellied Eremomela
# - Zebra Dove
# - African Pygmy Kingfisher
# - Black-throated Magpie-Jay
# - Collared Falconet
# - Double-toothed Barbet
# - Elegant Crescentchest
# - Flame-faced Tanager
# - Gould's Inca
# - Hoopoe Starling
# - Ivory-billed Coucal
# - Jacutinga
# - Kaempfer's Tody-Tyrant
# - Long-tailed Duck
# - Malachite Sunbird
# - Nightingale Wren
# - Ochre-collared Piculet
# - Paradise Riflebird
# - Quail-Plover
# - Red-and-yellow Barbet
# - Sunbittern
# - Tawny-crested Tanager
# - Umbrellabird
# - Violet-throated Starfrontlet
# - White-bellied Tanager
#
# 💾 Saving hallucinated class descriptors to: envisioned_classes/fine_grained_500/cub100_ID_gpt-3.5-turbo_0.json
# === load json:  envisioned_classes/fine_grained_500/cub100_ID_gpt-3.5-turbo_0.json
# Get Envisioned Candidate Class Names.
# After set: 238
# After removing ID class overlaps: 234
# 🔁 Augmenting OOD candidates with synonyms...
#   → 'sanderling'  → synonym: 'calidris alba'
#   → 'green-headed tanager'  → synonym: 'tangara seledon'
#   → 'red-billed leiothrix'  → synonym: 'leiothrix lutea'
#   → 'saddleback tanager'  → synonym: 'creole tanager'
#   → 'quail-plover'  → synonym: 'dotterel'
#   → 'juniper titmouse'  → synonym: 'oak titmouse'
#   → 'xantus murrelet'  → synonym: 'synthliboramphus hypoleucus'
#   → 'painted snipe'  → synonym: 'rostratula benghalensis'
#   → 'kagu'  → synonym: 'rhynochetos jubatus'
#   → 'orange-breasted bunting'  → synonym: 'passerina leclancherii'
#   → 'green cheek conure'  → synonym: 'pyrrhura molinae'
#   → 'blue footed booby'  → synonym: 'sula nebouxii'
#   → 'marabou stork'  → synonym: 'leptoptilos crumeniferus'
#   → 'black-throated magpie-robin'  → synonym: 'oriental magpie-robin'
#   → 'jacana'  → synonym: 'jesus bird'
#   → 'ivory billed woodpecker'  → synonym: 'campephilus principalis'
#   → 'violet sabrewing'  → synonym: 'campylopterus hemileucurus'
#   → 'gila woodpecker'  → synonym: 'melanerpes uropygialis'
#   → 'double-collared sunbird'  → synonym: 'nectarinia chalybea'
#   → 'emerald starling'  → synonym: 'lamprotornis iris'
#   → 'pink-throated twinspot'  → synonym: 'hypargos margaritatus'
#   → 'ivory-backed woodswallow'  → synonym: 'artamus monachus'
#   → 'king vulture'  → synonym: 'sarcoramphus papa'
#   → 'flame-breasted sunbird'  → synonym: 'nectarinia solaris'
#   → 'zebra finch'  → synonym: 'taeniopygia guttata'
#   → 'yellow-billed magpie'  → synonym: 'pica nuttalli'
#   → 'marbled godwit'  → synonym: 'limosa fedoa'
#   → 'hyacinth macaw'  → synonym: 'anodorhynchus hyacinthinus'
#   → 'ivory-billed woodcreeper'  → synonym: 'ivory-billed woodcreeper'
#   → 'sunbittern'  → synonym: 'eurypyga helias'
#   → 'nicobar scops owl'  → synonym: 'otus alius'
#   → 'eclectus parrot'  → synonym: 'eclectus roratus'
#   → 'hoopoe starling'  → synonym: 'common hoopoe'
#   → 'black-throated green warbler'  → synonym: 'dendroica virens'
#   → 'orange bishop weaver'  → synonym: 'euplectes franciscanus'
#   → 'dusky lory'  → synonym: 'pulchra gracilis'
#   → 'umbrella cockatoo'  → synonym: 'white cockatoo'
#   → 'black skimmer'  → synonym: 'rynchops niger'
#   → 'inca jay'  → synonym: 'cyanocorax yncas'
#   → 'violet turaco'  → synonym: 'violaceous plantain eater'
#   → 'least bittern'  → synonym: 'ixobrychus exilis'
#   → 'malachite sunbird'  → synonym: 'nectarinia famosa'
#   → 'tawny-shouldered blackbird'  → synonym: 'agelaius humeralis'
#   → 'american avocet'  → synonym: 'recurvirostra americana'
#   → 'nightingale wren'  → synonym: 'microcerculus philomela'
#   → 'collared falconet'  → synonym: 'microhierax caerulescens'
#   → 'white-headed woodpecker- azure tit'  → synonym: 'azure tit'
#   → "xantus's murrelet- andean condor"  → synonym: "xantus's murrelet  \nandean condor"
#   → 'painted redstart'  → synonym: 'myioborus pictus'
#   → 'inca tern'  → synonym: 'larosterna inca'
#   → 'white-bellied tanager- amethyst sunbird'  → synonym: 'white-bellied tanager'
#   → 'kakapo'  → synonym: 'night parrot'
#   → 'zone tailed hawk'  → synonym: 'buteo albonotatus'
#   → 'nightjar'  → synonym: 'caprimulgidae'
#   → 'flame-colored tanager'  → synonym: 'piranga bidentata'
#   → 'yellow naped amazon'  → synonym: 'yellow-naped parrot'
#   → 'indian peafowl'  → synonym: 'pavo cristatus'
#   → 'pink-footed shearwater'  → synonym: 'ardenna creatopus'
#   → "xantus's murrelet"  → synonym: 'synthliboramphus hypoleucus'
#   → 'flame-faced tanager'  → synonym: 'emberizoides ypiranganus'
#   → 'snowy egret'  → synonym: 'egretta thula'
#   → 'african pygmy goose'  → synonym: 'nettapus auritus'
#   → 'varied thrush'  → synonym: 'ixoreus naevius'
#   → 'varied lorikeet'  → synonym: 'psitteuteles versicolor'
#   → 'white-bellied antbird'  → synonym: 'myrmeciza longipes'
#   → 'black-throated magpie-jay'  → synonym: 'calocitta colliei'
#   → 'black-capped chickadee'  → synonym: 'poecile atricapillus'
#   → 'red-and-yellow barbet'  → synonym: 'trachyphonus erythrocephalus'
#   → 'pink-necked green pigeon'  → synonym: 'treron vernans'
#   → 'dickcissel'  → synonym: 'spiza americana'
#   → 'violet green swallow'  → synonym: 'tachycineta thalassina'
#   → 'quokka finch'  → synonym: 'red-eared firetail'
#   → 'collared aracari'  → synonym: 'pteroglossus torquatus'
#   → 'yellow-bellied sapsucker'  → synonym: 'sphyrapicus varius'
#   → 'umbrellabird'  → synonym: 'cotinga ridgwayi'
#   → 'harpy eagle'  → synonym: 'harpia harpyja'
#   → 'dusky woodswallow'  → synonym: 'artamus cyanopterus'
#   → 'white-bellied sea eagle'  → synonym: 'haliaeetus leucogaster'
#   → 'long-tailed broadbill'  → synonym: 'psarisomus dalhousiae'
#   → 'japanese white-eye'  → synonym: 'zosterops japonicus'
#   → 'quetzal thrush'  → synonym: 'black-throated trogon'
#   → 'orange-bellied parrot'  → synonym: 'neophema chrysogaster'
#   → 'quail'  → synonym: 'coturnix'
#   → "xantus's hummingbird"  → synonym: 'baja california hummingbird'
#   → 'secretary bird'  → synonym: 'sagittarius serpentarius'
#   → 'cinnamon teal'  → synonym: 'anas cyanoptera'
#   → "gould's inca finch"  → synonym: 'gouldian finch'
#   → 'long-tailed duck'  → synonym: 'oldsquaw'
#   → 'grey-crowned babbler'  → synonym: 'pomatostomus temporalis'
#   → 'upland sandpiper'  → synonym: 'bartramia longicauda'
#   → 'harlequin duck'  → synonym: 'histrionicus histrionicus'
#   → 'quailfinch'  → synonym: 'ornate finch'
#   → 'ferruginous hawk'  → synonym: 'buteo regalis'
#   → 'ural owl'  → synonym: 'strix uralensis'
#   → 'quaker parrot'  → synonym: 'monk parakeet'
#   → 'snow partridge'  → synonym: 'lerwa lerwa'
#   → 'paradise riflebird'  → synonym: 'ptiloris paradiseus'
#   → 'lorikeet'  → synonym: 'rainbow lorikeet'
#   → 'emerald toucanet'  → synonym: 'aulacorhynchus prasinus'
#   → 'dusky grouse'  → synonym: 'blue grouse'
#   → 'king rail'  → synonym: 'rallus elegans'
#   → 'tufted puffin'  → synonym: 'fratercula cirrhata'
#   → 'maroon-chested ground dove'  → synonym: 'claravis mondetoura'
#   → 'quail dove'  → synonym: 'geotrygon mystacea'
#   → 'american woodcock'  → synonym: 'scolopax minor'
#   → 'tawny-crested tanager'  → synonym: 'tachyphonus delatrii'
#   → 'harlequin quail'  → synonym: 'chinese painted quail'
#   → 'eastern blue-tit'  → synonym: 'cyanistes caeruleus'
#   → 'marbled murrelet'  → synonym: 'brachyramphus marmoratus'
#   → 'northern bobwhite'  → synonym: 'colinus virginianus'
#   → 'rufous-backed robin'  → synonym: 'turdus rufopalliatus'
#   → 'flame-crowned flowerpecker'  → synonym: 'flame-crowned flowerpecker'
#   → 'jenday conure'  → synonym: 'aratinga jandaya'
#   → 'pionus parrot'  → synonym: 'blue-headed parrot'
#   → 'violet crowned hummingbird'  → synonym: 'amazilia violiceps'
#   → 'northern flicker'  → synonym: 'colaptes auratus'
#   → 'elegant trogon'  → synonym: 'elegant quetzal'
#   → 'ocellated turkey'  → synonym: 'meleagris ocellata'
#   → 'maroon oriole'  → synonym: 'black-naped oriole'
#   → 'crimson rosella'  → synonym: 'platycercus elegans'
#   → 'california condor'  → synonym: 'gymnogyps californianus'
#   → 'black-throated weaver'  → synonym: 'ploceus benghalensis'
#   → 'varied sittella'  → synonym: 'daphoenositta chrysoptera'
#   → 'white throated sparrow'  → synonym: 'zonotrichia albicollis'
#   → 'orange winged amazon'  → synonym: 'amazona amazonica'
#   → 'zebra dove'  → synonym: 'geopelia striata'
#   → 'orange-fronted parakeet'  → synonym: 'eupsittula canicularis'
#   → 'ferruginous pygmy owl'  → synonym: 'glaucidium brasilianum'
#   → 'green iora'  → synonym: 'aegithina viridissima'
#   → 'flame robin'  → synonym: 'petroica phoenicea'
#   → 'african pygmy kingfisher'  → synonym: 'ispidina picta'
#   → 'philippine eagle'  → synonym: 'pithecophaga jefferyi'
#   → 'green honeycreeper'  → synonym: 'chlorophanes spiza'
#   → 'king-of-saxony bird-of-paradise'  → synonym: 'pteridophora alberti'
#   → 'yellow-bellied bulbul'  → synonym: 'pycnonotus xantholaemus'
#   → 'white tern'  → synonym: 'gygis alba'
#   → 'jacutinga'  → synonym: 'aburria jacutinga'
#   → 'gouldian finch'  → synonym: 'erythrura gouldiae'
#   → 'long tailed jaeger'  → synonym: 'stercorarius longicaudus'
#   → 'white-headed woodpecker- azure-winged magpie'  → synonym: 'cyanopica cyanus'
#   → 'fulvous whistling duck'  → synonym: 'dendrocygna bicolor'
#   → 'rose breasted cockatoo'  → synonym: 'galah'
#   → 'eastern whip-poor-will'  → synonym: 'antrostomus vociferus'
#   → 'japanese paradise flycatcher'  → synonym: 'terpsiphone atrocaudata'
#   → "kaempfer's tody-tyrant"  → synonym: 'hemitriccus kaempferi'
#   → 'malachite kingfisher'  → synonym: 'corythornis cristatus'
#   → 'elegant crescentchest'  → synonym: 'elegant crescent-chested parakeet'
#   → 'least tern'  → synonym: 'sterna antillarum'
#   → 'oriental dwarf kingfisher'  → synonym: 'ceyx erithaca'
#   → 'japanese cormorant'  → synonym: "temminck's cormorant"
#   → 'senegal parrot'  → synonym: 'poicephalus senegalus'
#   → "kirtland's warbler"  → synonym: 'setophaga kirtlandii'
#   → 'white-bellied tanager- amethyst woodstar'  → synonym: 'white-bellied tanager'
#   → 'green heron'  → synonym: 'butorides virescens'
#   → 'double-toothed barbet'  → synonym: 'pogonornis bidentatus'
#   → 'african penguin'  → synonym: 'spheniscus demersus'
#   → 'indian ringneck parakeet'  → synonym: 'rose-ringed parakeet'
#   → 'double-crested cormorant'  → synonym: 'phalacrocorax auritus'
#   → 'golden pheasant'  → synonym: 'chinese pheasant'
#   → 'white-throated kingfisher'  → synonym: 'halcyon smyrnensis'
#   → 'yellow billed cuckoo'  → synonym: 'coccyzus americanus'
#   → 'elegant crested tinamou'  → synonym: 'eudromia elegans'
#   → 'pink-headed warbler'  → synonym: 'cardellina versicolor'
#   → 'nicobar imperial pigeon'  → synonym: 'ducula nicobarica'
#   → 'ivory-billed aracari'  → synonym: 'ivory-billed toucan'
#   → 'moluccan cockatoo'  → synonym: 'salmon-crested cockatoo'
#   → 'nicobar megapode'  → synonym: 'nicobar scrubfowl'
#   → 'nanday conure'  → synonym: 'black-hooded parakeet'
#   → 'double-striped thick-knee'  → synonym: 'burhinus bistriatus'
#   → 'rufous-capped warbler'  → synonym: 'basileuterus rufifrons'
#   → 'white-bellied tanager'  → synonym: 'white-vented tanager'
#   → 'blue and gold macaw'  → synonym: 'ara ararauna'
#   → 'white-headed woodpecker- amethyst starling'  → synonym: 'white-bellied woodpecker'
#   → 'japanese murrelet'  → synonym: 'synthliboramphus wumizusume'
#   → 'northern mockingbird'  → synonym: 'mimus polyglottos'
#   → 'tawny owl'  → synonym: 'strix aluco'
#   → 'black-throated trogon'  → synonym: 'trogon rufus'
#   → 'nicobar pigeon'  → synonym: 'caloenas nicobarica'
#   → 'white-headed woodpecker- amethyst woodstar'  → synonym: 'amethyst woodstar'
#   → 'zone tailed hawk- african grey parrot'  → synonym: 'african grey parrot'
#   → 'lilac-breasted tern'  → synonym: 'gygis alba'
#   → 'snowy owl'  → synonym: 'bubo scandiacus'
#   → 'vasa parrot'  → synonym: 'african grey parrot'
#   → 'ivory-billed coucal'  → synonym: 'ivory-billed coucal'
#   → 'violet-throated starfrontlet'  → synonym: 'coeligena violifer'
#   → 'toco toucan'  → synonym: 'ramphastos toco'
#   → 'yellow-crowned night heron'  → synonym: 'nyctanassa violacea'
#   → 'mountain bluebird'  → synonym: 'sialia currucoides'
#   → 'white-bellied antpitta'  → synonym: 'grallaria hypoleuca'
#   → 'osprey'  → synonym: 'pandion haliaetus'
#   → 'eastern bluebird'  → synonym: 'sialia sialis'
#   → 'crimson-collared grosbeak'  → synonym: 'rhodospingus cruentus'
#   → 'rufous hornbill'  → synonym: 'philippine hornbill'
#   → 'blue-crowned motmot'  → synonym: 'momotus momota'
#   → 'orange-bellied leafbird'  → synonym: 'chloropsis hardwickii'
#   → 'white bellied caique'  → synonym: 'pionites leucogaster'
#   → 'inca dove'  → synonym: 'columbina inca'
#   → 'black capped chickadee'  → synonym: 'poecile atricapillus'
#   → 'hoopoe'  → synonym: 'upupa epops'
#   → 'tawny-crested puffbird'  → synonym: 'lophotriccus erythopthalmus'
#   → 'carolina wren'  → synonym: 'thryothorus ludovicianus'
#   → 'lilac-breasted roller'  → synonym: 'coracias caudatus'
#   → 'crested caracara'  → synonym: 'caracara cheriway'
#   → 'tawny frogmouth'  → synonym: 'podargus strigoides'
#   → 'paradise tanager'  → synonym: 'tangara chilensis'
#   → 'saddle-billed stork'  → synonym: 'ephippiorhynchus senegalensis'
#   → 'xingu scale-backed antbird'  → synonym: 'willisornis poecilinotus'
#   → 'western grebe'  → synonym: 'aechmophorus occidentalis'
#   → 'eastern whipbird'  → synonym: 'psophodes olivaceus'
#   → "fischer's lovebird"  → synonym: 'agapornis fischeri'
#   → 'flame bowerbird'  → synonym: 'sericulus aureus'
#   → 'red winged blackbird'  → synonym: 'agelaius phoeniceus'
#   → 'eurasian collared dove'  → synonym: 'streptopelia decaocto'
#   → 'black-throated sparrow'  → synonym: 'amphispiza bilineata'
#   → 'eastern meadowlark'  → synonym: 'sturnella magna'
#   → 'ochre-collared piculet'  → synonym: 'picumnus temminckii'
#   → 'collared falcon'  → synonym: 'collared sparrowhawk'
#   → 'crimson sunbird'  → synonym: 'aethopyga siparaja'
#   → 'red knot'  → synonym: 'calidris canutus'
#   → 'long-tailed tit'  → synonym: 'aegithalos caudatus'
#   → 'toucan'  → synonym: 'ramphastidae'
#   → 'cockatiel'  → synonym: 'nymphicus hollandicus'
#   → 'xingu antbird'  → synonym: 'thamnophilus ochraceiceps'
#   → 'magnificent frigatebird'  → synonym: "man o' war bird"
#   → 'quetzal'  → synonym: 'pharomachrus'
#   → 'red-legged honeycreeper'  → synonym: 'cyanerpes cyaneus'
#   → 'jabiru'  → synonym: 'black-necked stork'
#   → 'double-barred finch'  → synonym: 'owl finch'
#   → 'fairy pitta'  → synonym: 'pitta nympha'
#   → "gould's inca"  → synonym: 'coeligena inca'
#   → 'king eider'  → synonym: 'somateria spectabilis'
#   → 'yellow billed magpie'  → synonym: 'pica nuttalli'
#   → 'yellow-bellied eremomela'  → synonym: 'eremomela flavicrissalis'
#   → "harris's hawk"  → synonym: 'parabuteo unicinctus'
# 🧹 Removed 0 invalid synonym labels like 'none' or 'null'
# 📏 OOD classes before synonym expansion: 234
# 📐 OOD classes after synonym + deduplication: 456
#
# 🧪 Final ID Labels passed to CLIP: ['Laysan Albatross', 'Groove billed Ani', 'Crested Auklet', 'Parakeet Auklet', 'Rusty Blackbird', 'Bobolink', 'Indigo Bunting', 'Painted Bunting', 'Spotted Catbird', 'Yellow breasted Chat', 'Eastern Towhee', 'Chuck will Widow', 'Red faced Cormorant', 'Pelagic Cormorant', 'Bronzed Cowbird', 'Shiny Cowbird', 'American Crow', 'Purple Finch', 'Acadian Flycatcher', 'Olive sided Flycatcher', 'Scissor tailed Flycatcher', 'Yellow bellied Flycatcher', 'Frigatebird', 'Gadwall', 'American Goldfinch', 'Boat tailed Grackle', 'Eared Grebe', 'Horned Grebe', 'Pied billed Grebe', 'Blue Grosbeak', 'Evening Grosbeak', 'Pine Grosbeak', 'Rose breasted Grosbeak', 'Pigeon Guillemot', 'Glaucous winged Gull', 'Herring Gull', 'Ivory Gull', 'Ring billed Gull', 'Anna Hummingbird', 'Pomarine Jaeger', 'Blue Jay', 'Green Jay', 'Gray Kingbird', 'Ringed Kingfisher', 'Red legged Kittiwake', 'Horned Lark', 'Western Meadowlark', 'Red breasted Merganser', 'White breasted Nuthatch', 'Hooded Oriole', 'Orchard Oriole', 'Ovenbird', 'Western Wood Pewee', 'Sayornis', 'Whip poor Will', 'White necked Raven', 'Great Grey Shrike', 'Brewer Sparrow', 'Chipping Sparrow', 'Clay colored Sparrow', 'House Sparrow', 'Fox Sparrow', 'Grasshopper Sparrow', 'Henslow Sparrow', 'Le Conte Sparrow', 'Savannah Sparrow', 'Vesper Sparrow', 'Bank Swallow', 'Cliff Swallow', 'Scarlet Tanager', 'Black Tern', 'Caspian Tern', 'Brown Thrasher', 'Sage Thrasher', 'Black capped Vireo', 'Blue headed Vireo', 'Philadelphia Vireo', 'Warbling Vireo', 'Yellow throated Vireo', 'Black throated Blue Warbler', 'Blue winged Warbler', 'Cape May Warbler', 'Golden winged Warbler', 'Hooded Warbler', 'Magnolia Warbler', 'Myrtle Warbler', 'Orange crowned Warbler', 'Palm Warbler', 'Pine Warbler', 'Prothonotary Warbler', 'Swainson Warbler', 'Tennessee Warbler', 'Worm eating Warbler', 'Northern Waterthrush', 'Cedar Waxwing', 'Red bellied Woodpecker', 'Downy Woodpecker', 'Bewick Wren', 'House Wren', 'Common Yellowthroat']
ron', 'double-toothed barbet', 'african penguin', 'indian ringneck parakeet', 'double-crested cormorant', 'golden pheasant', 'white-throated kingfisher', 'yellow billed cuckoo', 'elegant crested tinamou', 'pink-headed warbler', 'nicobar imperial pigeon', 'ivory-billed aracari', 'moluccan cockatoo', 'nicobar megapode', 'nanday conure', 'double-striped thick-knee', 'rufous-capped warbler', 'white-bellied tanager', 'blue and gold macaw', 'white-headed woodpecker- amethyst starling', 'japanese murrelet', 'northern mockingbird', 'tawny owl', 'black-throated trogon', 'nicobar pigeon', 'white-headed woodpecker- amethyst woodstar', 'zone tailed hawk- african grey parrot', 'lilac-breasted tern', ...
# 100%|██████████| 12/12 [07:15<00:00, 36.30s/it]
# 2025-07-18 20:46:53,468 : 📦 Evaluating OOD dataset cub100_OOD
# DEBUG:__main__:📦 Evaluating OOD dataset cub100_OOD
# /usr/local/lib/python3.11/dist-packages/torch/utils/data/dataloader.py:624: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(
# 100%|██████████| 12/12 [07:15<00:00, 36.25s/it]
# 2025-07-18 20:54:09,024 : in scores: DescribeResult(nobs=2895, minmax=(np.float32(-0.0016960478), np.float32(-0.0013735613)), mean=np.float32(-0.0015328389), variance=np.float64(1.6279799870536643e-09), skewness=np.float64(0.3441019654273987), kurtosis=np.float32(0.44945574))
# DEBUG:__main__:in scores: DescribeResult(nobs=2895, minmax=(np.float32(-0.0016960478), np.float32(-0.0013735613)), mean=np.float32(-0.0015328389), variance=np.float64(1.6279799870536643e-09), skewness=np.float64(0.3441019654273987), kurtosis=np.float32(0.44945574))
# 2025-07-18 20:54:09,028 : out scores: DescribeResult(nobs=2899, minmax=(np.float32(-0.0016431068), np.float32(-0.0013706547)), mean=np.float32(-0.0014994869), variance=np.float64(1.6350332256731363e-09), skewness=np.float64(0.04778539016842842), kurtosis=np.float32(-0.3072784))
# DEBUG:__main__:out scores: DescribeResult(nobs=2899, minmax=(np.float32(-0.0016431068), np.float32(-0.0013706547)), mean=np.float32(-0.0014994869), variance=np.float64(1.6350332256731363e-09), skewness=np.float64(0.04778539016842842), kurtosis=np.float32(-0.3072784))
# 2025-07-18 20:54:09,460 : 				EOE
# DEBUG:__main__:				EOE
# 2025-07-18 20:54:09,466 :   FPR95 AUROC AUPR
# DEBUG:__main__:  FPR95 AUROC AUPR
# 2025-07-18 20:54:09,473 : & 79.89 & 72.36 & 71.67
# DEBUG:__main__:& 79.89 & 72.36 & 71.67
# 2025-07-18 20:54:09,475 :
#
# 📊 Mean Test Results
# DEBUG:__main__:
#
# 📊 Mean Test Results
# 2025-07-18 20:54:09,484 : 				EOE
# DEBUG:__main__:				EOE
# 2025-07-18 20:54:09,491 :   FPR95 AUROC AUPR
# DEBUG:__main__:  FPR95 AUROC AUPR
# 2025-07-18 20:54:09,495 : & 79.89 & 72.36 & 71.67
# DEBUG:__main__:& 79.89 & 72.36 & 71.67

# %%
sys.argv = [
    "eval_ood_detection.py",
    "--name",        "CUB100_CUB100_EOE_500L_25B_finegrained",
    "--in_dataset",  "cub100_ID",
    "--ood_task",    "fine_grained",
    "--score",       "EOE",
    "--score_ablation", "EOE",           # use standard EOE score
    "--generate_class",                  # generate OOD candidates via LLM
    "--root_dir",    "datasets",
    "--batch_size",  "256",
    "--gpu",         "0",
    "--L",           "500",
]
main()
# Out:
# 2025-07-20 13:22:22,528 : #########CUB100_CUB100_EOE_500L_25B_finegrained############
# DEBUG:__main__:#########CUB100_CUB100_EOE_500L_25B_finegrained############
# config.json: 0.00B [00:00, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/599M [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/599M [00:00<?, ?B/s]
# /usr/local/lib/python3.11/dist-packages/torch/utils/data/dataloader.py:624: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(
# ✅ Original ID Labels: ['Laysan Albatross', 'Groove billed Ani', 'Crested Auklet', 'Parakeet Auklet', 'Rusty Blackbird', 'Bobolink', 'Indigo Bunting', 'Painted Bunting', 'Spotted Catbird', 'Yellow breasted Chat', 'Eastern Towhee', 'Chuck will Widow', 'Red faced Cormorant', 'Pelagic Cormorant', 'Bronzed Cowbird', 'Shiny Cowbird', 'American Crow', 'Purple Finch', 'Acadian Flycatcher', 'Olive sided Flycatcher', 'Scissor tailed Flycatcher', 'Yellow bellied Flycatcher', 'Frigatebird', 'Gadwall', 'American Goldfinch', 'Boat tailed Grackle', 'Eared Grebe', 'Horned Grebe', 'Pied billed Grebe', 'Blue Grosbeak', 'Evening Grosbeak', 'Pine Grosbeak', 'Rose breasted Grosbeak', 'Pigeon Guillemot', 'Glaucous winged Gull', 'Herring Gull', 'Ivory Gull', 'Ring billed Gull', 'Anna Hummingbird', 'Pomarine Jaeger', 'Blue Jay', 'Green Jay', 'Gray Kingbird', 'Ringed Kingfisher', 'Red legged Kittiwake', 'Horned Lark', 'Western Meadowlark', 'Red breasted Merganser', 'White breasted Nuthatch', 'Hooded Oriole', 'Orchard Oriole', 'Ovenbird', 'Western Wood Pewee', 'Sayornis', 'Whip poor Will', 'White necked Raven', 'Great Grey Shrike', 'Brewer Sparrow', 'Chipping Sparrow', 'Clay colored Sparrow', 'House Sparrow', 'Fox Sparrow', 'Grasshopper Sparrow', 'Henslow Sparrow', 'Le Conte Sparrow', 'Savannah Sparrow', 'Vesper Sparrow', 'Bank Swallow', 'Cliff Swallow', 'Scarlet Tanager', 'Black Tern', 'Caspian Tern', 'Brown Thrasher', 'Sage Thrasher', 'Black capped Vireo', 'Blue headed Vireo', 'Philadelphia Vireo', 'Warbling Vireo', 'Yellow throated Vireo', 'Black throated Blue Warbler', 'Blue winged Warbler', 'Cape May Warbler', 'Golden winged Warbler', 'Hooded Warbler', 'Magnolia Warbler', 'Myrtle Warbler', 'Orange crowned Warbler', 'Palm Warbler', 'Pine Warbler', 'Prothonotary Warbler', 'Swainson Warbler', 'Tennessee Warbler', 'Worm eating Warbler', 'Northern Waterthrush', 'Cedar Waxwing', 'Red bellied Woodpecker', 'Downy Woodpecker', 'Bewick Wren', 'House Wren', 'Common Yellowthroat']
# 🔮 Using LLM-generated OOD candidate classes...
# Envisioning Outlier Exposure...
# 🔵 Generating via OpenAI GPT...
# Continuing vision 1/9
# Continuing vision 2/9
# Continuing vision 3/9
# Continuing vision 4/9
# Continuing vision 5/9
# Continuing vision 6/9
# Continuing vision 7/9
# Continuing vision 8/9
# Continuing vision 9/9
# 🔍 Raw GPT output:
#  - American Avocet
# - Black Skimmer
# - California Condor
# - Eurasian Collared Dove
# - Ferruginous Hawk
# - Green Heron
# - Harpy Eagle
# - Ivory billed Woodpecker
# - Jabiru
# - King Vulture
# - Long tailed Jaeger
# - Marbled Murrelet
# - Northern Mockingbird
# - Osprey
# - Painted Redstart
# - Quetzal
# - Red Knot
# - Snowy Owl
# - Alder Flycatcher
# - Black-capped Vireo
# - Common Eider
# - Dusky Warbler
# - Eastern Whip-poor-will
# - Fulvous Whistling Duck
# - Gray Catbird
# - Hooded Warbler
# - Indigo Bunting
# - Juniper Titmouse
# - King Eider
# - Least Tern
# - Magnificent Frigatebird
# - Northern Mockingbird
# - Orange-crowned Warbler
# - Painted Bunting
# - Quetzal
# - Red Knot
# - Snowy Plover
# - Tufted Puffin
# - Upland Sandpiper
# - Violet-green Swallow
# - Western Tanager- American Woodcock
# - Bateleur Eagle
# - Chestnut-collared Longspur
# - Dusky Grouse
# - Elegant Trogon
# - Fork-tailed Flycatcher
# - Green Jay
# - Harlequin Duck
# - Ivory Gull
# - Juniper Titmouse
# - King Rail
# - Least Bittern
# - Marbled Murrelet
# - Northern Bobwhite
# - Orange-crowned Warbler
# - Piping Plover
# - Quetzal
# - Red-cockaded Woodpecker
# - Sanderling
# - Tufted Puffin
# - Upland Sandpiper
# - Varied Thrush
# - Western Grebe
# - Xantus's Murrelet
# - Yellow-billed Cuckoo
# - Zone-tailed Hawk
# - Alder Flycatcher
# - Black-capped Vireo
# - Common Eider
# - Dusky Warbler
# - Eastern Whip-poor-will
# - Fulvous Whistling Duck
# - Gray Catbird
# - Hooded Warbler
# - Indigo Bunting
# - Juniper Titmouse
# - King Eider
# - Least Tern
# - Magnificent Frigatebird
# - Northern Mockingbird
# - Orange-crowned Warbler
# - Painted Bunting
# - Quetzal
# - Red Knot
# - Snowy Plover
# - Tufted Puffin
# - Upland Sandpiper
# - Violet-green Swallow
# - Western Tanager
#
# 💾 Saving hallucinated class descriptors to: envisioned_classes/fine_grained_500/cub100_ID_gpt-3.5-turbo_4.json
# === load json:  envisioned_classes/fine_grained_500/cub100_ID_gpt-3.5-turbo_4.json
# Get Envisioned Candidate Class Names.
# After set: 191
# After removing ID class overlaps: 185
#
# 🧪 Final ID Labels passed to CLIP: ['Laysan Albatross', 'Groove billed Ani', 'Crested Auklet', 'Parakeet Auklet', 'Rusty Blackbird', 'Bobolink', 'Indigo Bunting', 'Painted Bunting', 'Spotted Catbird', 'Yellow breasted Chat', 'Eastern Towhee', 'Chuck will Widow', 'Red faced Cormorant', 'Pelagic Cormorant', 'Bronzed Cowbird', 'Shiny Cowbird', 'American Crow', 'Purple Finch', 'Acadian Flycatcher', 'Olive sided Flycatcher', 'Scissor tailed Flycatcher', 'Yellow bellied Flycatcher', 'Frigatebird', 'Gadwall', 'American Goldfinch', 'Boat tailed Grackle', 'Eared Grebe', 'Horned Grebe', 'Pied billed Grebe', 'Blue Grosbeak', 'Evening Grosbeak', 'Pine Grosbeak', 'Rose breasted Grosbeak', 'Pigeon Guillemot', 'Glaucous winged Gull', 'Herring Gull', 'Ivory Gull', 'Ring billed Gull', 'Anna Hummingbird', 'Pomarine Jaeger', 'Blue Jay', 'Green Jay', 'Gray Kingbird', 'Ringed Kingfisher', 'Red legged Kittiwake', 'Horned Lark', 'Western Meadowlark', 'Red breasted Merganser', 'White breasted Nuthatch', 'Hooded Oriole
', 'palm cockatoo', 'least bittern', 'red knot', 'blue-crowned laughingthrush', 'northern bobwhite', 'white throated sparrow', 'flame robin', 'vermilion flycatcher', 'dusky warbler', 'red winged blackbird', 'black-throated sparrow', 'himalayan monal', 'yellow-bellied sunbird', 'marbled godwit', 'crimson sunbird', 'japanese quail', 'jabiru stork', 'kagu', 'bateleur eagle', 'zebra finch', 'yellow-billed cuckoo', 'common eider', 'harlequin quail', 'african pygmy kingfisher', 'california condor', 'gouldian finch', 'tawny eagle', 'tawny-flanked prinia', 'white-throated dipper- azure-winged magpie', 'rufous hornbill', 'least tern', "fischer's lovebird", 'imperial amazon', 'yellow warbler- american woodcock', 'orange-bellied parrot', 'upland sandpiper', 'zebra dove', 'java sparrow', 'long-tailed broadbill', 'zebra dove- african fish eagle', 'yellow warbler- african grey parrot', 'zone tailed hawk', 'american avocet', 'white-throated dipper- american woodcock', 'fork-tailed flycatcher', 'northern flicker', 'upland goose', 'sulphur-crested cockatoo', 'tufted puffin', 'moluccan cockatoo', 'eclectus parrot', 'common nighthawk', 'yellow-crowned amazon', 'fairy pitta', 'cinnamon teal', 'black capped chickadee', 'ivory-billed aracari', 'western tanager', 'western grebe', 'yellow-billed stork', 'varied thrush', 'luzon bleeding-heart', 'snowy plover', 'grey-crowned rosy-finch', 'juniper titmouse', 'ural owl', 'harpy eagle', 'nicobar pigeon', 'quaker parrot', 'violet sabrewing', 'ferruginous pygmy owl', 'black-capped vireo', 'gray catbird', 'scarlet macaw', 'philippine cockatoo', 'african pygmy goose', 'sulphur-bellied flycatcher', 'american kestrel', 'tawny frogmouth', 'indian ringneck parakeet', 'long-tailed duck', 'golden pheasant', 'alder flycatcher', 'prairie warbler', 'eurasian collared dove', 'marabou stork', 'chestnut-collared longspur', 'victoria crowned pigeon', 'red-crested pochard', 'king rail', 'king eider', 'crimson rosella', 'king vulture']
# tokenizer_config.json:   0%|          | 0.00/905 [00:00<?, ?B/s]
# vocab.json: 0.00B [00:00, ?B/s]
# merges.txt: 0.00B [00:00, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/389 [00:00<?, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# 100%|██████████| 12/12 [10:07<00:00, 50.65s/it]
# 2025-07-20 13:33:30,447 : 📦 Evaluating OOD dataset cub100_OOD
# DEBUG:__main__:📦 Evaluating OOD dataset cub100_OOD
# /usr/local/lib/python3.11/dist-packages/torch/utils/data/dataloader.py:624: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(
# 100%|██████████| 12/12 [10:35<00:00, 52.97s/it]
# 2025-07-20 13:44:06,843 : in scores: DescribeResult(nobs=2895, minmax=(np.float32(-0.0033582635), np.float32(-0.0027749576)), mean=np.float32(-0.0030558566), variance=np.float64(7.025335634590707e-09), skewness=np.float64(0.10971865803003311), kurtosis=np.float32(0.084772825))
# DEBUG:__main__:in scores: DescribeResult(nobs=2895, minmax=(np.float32(-0.0033582635), np.float32(-0.0027749576)), mean=np.float32(-0.0030558566), variance=np.float64(7.025335634590707e-09), skewness=np.float64(0.10971865803003311), kurtosis=np.float32(0.084772825))
# 2025-07-20 13:44:06,848 : out scores: DescribeResult(nobs=2899, minmax=(np.float32(-0.0032862397), np.float32(-0.0027456204)), mean=np.float32(-0.0029846507), variance=np.float64(6.997514711371636e-09), skewness=np.float64(-0.006593186873942614), kurtosis=np.float32(-0.38916516))
# DEBUG:__main__:out scores: DescribeResult(nobs=2899, minmax=(np.float32(-0.0032862397), np.float32(-0.0027456204)), mean=np.float32(-0.0029846507), variance=np.float64(6.997514711371636e-09), skewness=np.float64(-0.006593186873942614), kurtosis=np.float32(-0.38916516))
# 2025-07-20 13:44:08,027 : 				EOE
# DEBUG:__main__:				EOE
# 2025-07-20 13:44:08,028 :   FPR95 AUROC AUPR
# DEBUG:__main__:  FPR95 AUROC AUPR
# 2025-07-20 13:44:08,031 : & 77.44 & 72.53 & 72.02
# DEBUG:__main__:& 77.44 & 72.53 & 72.02
# 2025-07-20 13:44:08,034 :
#
# 📊 Mean Test Results
# DEBUG:__main__:
#
# 📊 Mean Test Results
# 2025-07-20 13:44:08,035 : 				EOE
# DEBUG:__main__:				EOE
# 2025-07-20 13:44:08,038 :   FPR95 AUROC AUPR
# DEBUG:__main__:  FPR95 AUROC AUPR
# 2025-07-20 13:44:08,040 : & 77.44 & 72.53 & 72.02
# DEBUG:__main__:& 77.44 & 72.53 & 72.02

# %% [markdown]
# # **Experiment Semantic Variant OOD CUB-100 vs CUB-100 (Beta=0.75,L=50,100,300,500)**

# %%
sys.argv = [
    "eval_ood_detection.py",
    "--name",        "CUB100_CUB100_EOE_50L_75B_finegrained_synonymOOD",
    "--in_dataset",  "cub100_ID",
    "--ood_task",    "fine_grained",
    "--score",       "EOE",
    "--score_ablation", "EOE",           # use standard EOE score
    "--generate_class",                  # generate OOD candidates via LLM
    "--use_synonyms",                   # apply synonym expansion to OOD classes
    "--root_dir",    "datasets",
    "--batch_size",  "256",
    "--gpu",         "0",
    "--beta",       "0.75",
    "--L",           "50",
]
main()
# Out:
# /usr/local/lib/python3.11/dist-packages/torch/utils/data/dataloader.py:624: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(
# ✅ Original ID Labels: ['Laysan Albatross', 'Groove billed Ani', 'Crested Auklet', 'Parakeet Auklet', 'Rusty Blackbird', 'Bobolink', 'Indigo Bunting', 'Painted Bunting', 'Spotted Catbird', 'Yellow breasted Chat', 'Eastern Towhee', 'Chuck will Widow', 'Red faced Cormorant', 'Pelagic Cormorant', 'Bronzed Cowbird', 'Shiny Cowbird', 'American Crow', 'Purple Finch', 'Acadian Flycatcher', 'Olive sided Flycatcher', 'Scissor tailed Flycatcher', 'Yellow bellied Flycatcher', 'Frigatebird', 'Gadwall', 'American Goldfinch', 'Boat tailed Grackle', 'Eared Grebe', 'Horned Grebe', 'Pied billed Grebe', 'Blue Grosbeak', 'Evening Grosbeak', 'Pine Grosbeak', 'Rose breasted Grosbeak', 'Pigeon Guillemot', 'Glaucous winged Gull', 'Herring Gull', 'Ivory Gull', 'Ring billed Gull', 'Anna Hummingbird', 'Pomarine Jaeger', 'Blue Jay', 'Green Jay', 'Gray Kingbird', 'Ringed Kingfisher', 'Red legged Kittiwake', 'Horned Lark', 'Western Meadowlark', 'Red breasted Merganser', 'White breasted Nuthatch', 'Hooded Oriole', 'Orchard Oriole', 'Ovenbird', 'Western Wood Pewee', 'Sayornis', 'Whip poor Will', 'White necked Raven', 'Great Grey Shrike', 'Brewer Sparrow', 'Chipping Sparrow', 'Clay colored Sparrow', 'House Sparrow', 'Fox Sparrow', 'Grasshopper Sparrow', 'Henslow Sparrow', 'Le Conte Sparrow', 'Savannah Sparrow', 'Vesper Sparrow', 'Bank Swallow', 'Cliff Swallow', 'Scarlet Tanager', 'Black Tern', 'Caspian Tern', 'Brown Thrasher', 'Sage Thrasher', 'Black capped Vireo', 'Blue headed Vireo', 'Philadelphia Vireo', 'Warbling Vireo', 'Yellow throated Vireo', 'Black throated Blue Warbler', 'Blue winged Warbler', 'Cape May Warbler', 'Golden winged Warbler', 'Hooded Warbler', 'Magnolia Warbler', 'Myrtle Warbler', 'Orange crowned Warbler', 'Palm Warbler', 'Pine Warbler', 'Prothonotary Warbler', 'Swainson Warbler', 'Tennessee Warbler', 'Worm eating Warbler', 'Northern Waterthrush', 'Cedar Waxwing', 'Red bellied Woodpecker', 'Downy Woodpecker', 'Bewick Wren', 'House Wren', 'Common Yellowthroat']
# 🔮 Using LLM-generated OOD candidate classes...
# Envisioning Outlier Exposure...
# 🔵 Generating via OpenAI GPT...
# 🔍 Raw GPT output:
#  - American Avocet
# - Black Skimmer
# - California Condor
# - Eurasian Collared Dove
# - Ferruginous Hawk
# - Green Heron
# - Harpy Eagle
# - Ivory billed Woodpecker
# - Jabiru
# - King Vulture
# - Long tailed Jaeger
# - Marbled Murrelet
# - Northern Mockingbird
# - Osprey
# - Painted Redstart
# - Quetzal
# - Red Knot
# - Snowy Owl
# - Toco Toucan
# - Umbrellabird
# - Violet crowned Hummingbird
# - White throated Sparrow
# - Xantus's Hummingbird
# - Yellow billed Cuckoo
# - Zone tailed Hawk
# - American Kestrel
# - Black capped Chickadee
# - Common Loon
# - Double crested Cormorant
# - Eurasian Wigeon
# - Ferruginous Hawk
# - Greater Roadrunner
# - Harlequin Duck
# - Ivory Gull
# - Juniper Titmouse
# - King Rail
# - Least Tern
# - Mountain Bluebird
# - Northern Flicker
# - Olive sided Flycatcher
# - Painted Bunting
# - Quaker Parrot
# - Red winged Blackbird
# - Snowy Egret
# - Tufted Puffin
# - Upland Sandpiper
# - Violet green Swallow
# - Western Grebe
# - Yellow crowned Night Heron
#
# 💾 Saving hallucinated class descriptors to: envisioned_classes/fine_grained_50/cub100_ID_gpt-3.5-turbo_5.json
# === load json:  envisioned_classes/fine_grained_50/cub100_ID_gpt-3.5-turbo_5.json
# Get Envisioned Candidate Class Names.
# After set: 48
# After removing ID class overlaps: 45
# 🔁 Augmenting OOD candidates with synonyms...
#   → 'northern mockingbird'  → synonym: 'mimus polyglottos'
#   → 'violet crowned hummingbird'  → synonym: 'amazilia violiceps'
#   → 'american kestrel'  → synonym: 'sparrow hawk'
#   → 'northern flicker'  → synonym: 'colaptes auratus'
#   → 'snowy egret'  → synonym: 'egretta thula'
#   → 'juniper titmouse'  → synonym: 'oak titmouse'
#   → 'california condor'  → synonym: 'gymnogyps californianus'
#   → 'snowy owl'  → synonym: 'bubo scandiacus'
#   → 'toco toucan'  → synonym: 'ramphastos toco'
#   → 'mountain bluebird'  → synonym: 'sialia currucoides'
#   → 'yellow crowned night heron'  → synonym: 'nyctanassa violacea'
#   → 'osprey'  → synonym: 'pandion haliaetus'
#   → 'white throated sparrow'  → synonym: 'zonotrichia albicollis'
#   → 'violet green swallow'  → synonym: 'tachycineta thalassina'
#   → 'ivory billed woodpecker'  → synonym: 'campephilus principalis'
#   → 'common loon'  → synonym: 'great northern diver'
#   → 'double crested cormorant'  → synonym: 'phalacrocorax auritus'
#   → 'black capped chickadee'  → synonym: 'poecile atricapillus'
#   → 'king vulture'  → synonym: 'sarcoramphus papa'
#   → 'umbrellabird'  → synonym: 'cotinga ridgwayi'
#   → 'harpy eagle'  → synonym: 'harpia harpyja'
#   → 'long tailed jaeger'  → synonym: 'stercorarius longicaudus'
#   → 'western grebe'  → synonym: 'aechmophorus occidentalis'
#   → "xantus's hummingbird"  → synonym: 'basilinna xantusii'
#   → 'least tern'  → synonym: 'sterna antillarum'
#   → 'eurasian wigeon'  → synonym: 'eurasian wigeon'
#   → 'eurasian collared dove'  → synonym: 'streptopelia decaocto'
#   → 'black skimmer'  → synonym: 'rynchops niger'
#   → 'green heron'  → synonym: 'butorides virescens'
#   → 'red winged blackbird'  → synonym: 'agelaius phoeniceus'
#   → 'upland sandpiper'  → synonym: 'bartramia longicauda'
#   → 'red knot'  → synonym: 'calidris canutus'
#   → 'yellow billed cuckoo'  → synonym: 'coccyzus americanus'
#   → 'harlequin duck'  → synonym: 'histrionicus histrionicus'
#   → 'ferruginous hawk'  → synonym: 'buteo regalis'
#   → 'greater roadrunner'  → synonym: 'geococcyx californianus'
#   → 'quaker parrot'  → synonym: 'monk parakeet'
#   → 'american avocet'  → synonym: 'recurvirostra americana'
#   → 'quetzal'  → synonym: 'pharomachrus'
#   → 'jabiru'  → synonym: 'black-necked stork'
#   → 'king rail'  → synonym: 'rallus elegans'
#   → 'tufted puffin'  → synonym: 'fratercula cirrhata'
#   → 'painted redstart'  → synonym: 'myioborus pictus'
#   → 'zone tailed hawk'  → synonym: 'buteo albonotatus'
#   → 'marbled murrelet'  → synonym: 'brachyramphus marmoratus'
# 🧹 Removed 0 invalid synonym labels like 'none' or 'null'
# 📏 OOD classes before synonym expansion: 45
# 📐 OOD classes after synonym + deduplication: 89
#
# 🧪 Final ID Labels passed to CLIP: ['Laysan Albatross', 'Groove billed Ani', 'Crested Auklet', 'Parakeet Auklet', 'Rusty Blackbird', 'Bobolink', 'Indigo Bunting', 'Painted Bunting', 'Spotted Catbird', 'Yellow breasted Chat', 'Eastern Towhee', 'Chuck will Widow', 'Red faced Cormorant', 'Pelagic Cormorant', 'Bronzed Cowbird', 'Shiny Cowbird', 'American Crow', 'Purple Finch', 'Acadian Flycatcher', 'Olive sided Flycatcher', 'Scissor tailed Flycatcher', 'Yellow bellied Flycatcher', 'Frigatebird', 'Gadwall', 'American Goldfinch', 'Boat tailed Grackle', 'Eared Grebe', 'Horned Grebe', 'Pied billed Grebe', 'Blue Grosbeak', 'Evening Grosbeak', 'Pine Grosbeak', 'Rose breasted Grosbeak', 'Pigeon Guillemot', 'Glaucous winged Gull', 'Herring Gull', 'Ivory Gull', 'Ring billed Gull', 'Anna Hummingbird', 'Pomarine Jaeger', 'Blue Jay', 'Green Jay', 'Gray Kingbird', 'Ringed Kingfisher', 'Red legged Kittiwake', 'Horned Lark', 'Western Meadowlark', 'Red breasted Merganser', 'White breasted Nuthatch', 'Hooded Oriole', 'Orchard Oriole
# /usr/local/lib/python3.11/dist-packages/torch/utils/data/dataloader.py:624: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(
# 100%|██████████| 12/12 [00:40<00:00,  3.36s/it]
# 2025-07-18 20:56:13,838 : in scores: DescribeResult(nobs=2895, minmax=(np.float32(-0.0021954575), np.float32(-0.0011481564)), mean=np.float32(-0.0016632788), variance=np.float64(1.559840825958324e-08), skewness=np.float64(0.17390798032283783), kurtosis=np.float32(0.25539565))
# DEBUG:__main__:in scores: DescribeResult(nobs=2895, minmax=(np.float32(-0.0021954575), np.float32(-0.0011481564)), mean=np.float32(-0.0016632788), variance=np.float64(1.559840825958324e-08), skewness=np.float64(0.17390798032283783), kurtosis=np.float32(0.25539565))
# 2025-07-18 20:56:13,845 : out scores: DescribeResult(nobs=2899, minmax=(np.float32(-0.0020233626), np.float32(-0.0010209391)), mean=np.float32(-0.0015433066), variance=np.float64(2.088348394543034e-08), skewness=np.float64(0.183298721909523), kurtosis=np.float32(-0.22772121))
# DEBUG:__main__:out scores: DescribeResult(nobs=2899, minmax=(np.float32(-0.0020233626), np.float32(-0.0010209391)), mean=np.float32(-0.0015433066), variance=np.float64(2.088348394543034e-08), skewness=np.float64(0.183298721909523), kurtosis=np.float32(-0.22772121))
# 2025-07-18 20:56:14,171 : 				EOE
# DEBUG:__main__:				EOE
# 2025-07-18 20:56:14,173 :   FPR95 AUROC AUPR
# DEBUG:__main__:  FPR95 AUROC AUPR
# 2025-07-18 20:56:14,175 : & 72.92 & 73.26 & 71.25
# DEBUG:__main__:& 72.92 & 73.26 & 71.25
# 2025-07-18 20:56:14,177 :
#
# 📊 Mean Test Results
# DEBUG:__main__:
#
# 📊 Mean Test Results
# 2025-07-18 20:56:14,179 : 				EOE
# DEBUG:__main__:				EOE
# 2025-07-18 20:56:14,181 :   FPR95 AUROC AUPR
# DEBUG:__main__:  FPR95 AUROC AUPR
# 2025-07-18 20:56:14,183 : & 72.92 & 73.26 & 71.25
# DEBUG:__main__:& 72.92 & 73.26 & 71.25

# %%
sys.argv = [
    "eval_ood_detection.py",
    "--name",        "CUB100_CUB100_EOE_100L_75B_finegrained_synonymOOD",
    "--in_dataset",  "cub100_ID",
    "--ood_task",    "fine_grained",
    "--score",       "EOE",
    "--score_ablation", "EOE",           # use standard EOE score
    "--generate_class",                  # generate OOD candidates via LLM
    "--use_synonyms",                   # apply synonym expansion to OOD classes
    "--root_dir",    "datasets",
    "--batch_size",  "256",
    "--gpu",         "0",
    "--beta",       "0.75",
    "--L",           "100",
]
main()
# Out:
# /usr/local/lib/python3.11/dist-packages/torch/utils/data/dataloader.py:624: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(
# ✅ Original ID Labels: ['Laysan Albatross', 'Groove billed Ani', 'Crested Auklet', 'Parakeet Auklet', 'Rusty Blackbird', 'Bobolink', 'Indigo Bunting', 'Painted Bunting', 'Spotted Catbird', 'Yellow breasted Chat', 'Eastern Towhee', 'Chuck will Widow', 'Red faced Cormorant', 'Pelagic Cormorant', 'Bronzed Cowbird', 'Shiny Cowbird', 'American Crow', 'Purple Finch', 'Acadian Flycatcher', 'Olive sided Flycatcher', 'Scissor tailed Flycatcher', 'Yellow bellied Flycatcher', 'Frigatebird', 'Gadwall', 'American Goldfinch', 'Boat tailed Grackle', 'Eared Grebe', 'Horned Grebe', 'Pied billed Grebe', 'Blue Grosbeak', 'Evening Grosbeak', 'Pine Grosbeak', 'Rose breasted Grosbeak', 'Pigeon Guillemot', 'Glaucous winged Gull', 'Herring Gull', 'Ivory Gull', 'Ring billed Gull', 'Anna Hummingbird', 'Pomarine Jaeger', 'Blue Jay', 'Green Jay', 'Gray Kingbird', 'Ringed Kingfisher', 'Red legged Kittiwake', 'Horned Lark', 'Western Meadowlark', 'Red breasted Merganser', 'White breasted Nuthatch', 'Hooded Oriole', 'Orchard Oriole', 'Ovenbird', 'Western Wood Pewee', 'Sayornis', 'Whip poor Will', 'White necked Raven', 'Great Grey Shrike', 'Brewer Sparrow', 'Chipping Sparrow', 'Clay colored Sparrow', 'House Sparrow', 'Fox Sparrow', 'Grasshopper Sparrow', 'Henslow Sparrow', 'Le Conte Sparrow', 'Savannah Sparrow', 'Vesper Sparrow', 'Bank Swallow', 'Cliff Swallow', 'Scarlet Tanager', 'Black Tern', 'Caspian Tern', 'Brown Thrasher', 'Sage Thrasher', 'Black capped Vireo', 'Blue headed Vireo', 'Philadelphia Vireo', 'Warbling Vireo', 'Yellow throated Vireo', 'Black throated Blue Warbler', 'Blue winged Warbler', 'Cape May Warbler', 'Golden winged Warbler', 'Hooded Warbler', 'Magnolia Warbler', 'Myrtle Warbler', 'Orange crowned Warbler', 'Palm Warbler', 'Pine Warbler', 'Prothonotary Warbler', 'Swainson Warbler', 'Tennessee Warbler', 'Worm eating Warbler', 'Northern Waterthrush', 'Cedar Waxwing', 'Red bellied Woodpecker', 'Downy Woodpecker', 'Bewick Wren', 'House Wren', 'Common Yellowthroat']
# 🔮 Using LLM-generated OOD candidate classes...
# Envisioning Outlier Exposure...
# 🔵 Generating via OpenAI GPT...
# Continuing vision 1/1
# 🔍 Raw GPT output:
#  - American Avocet
# - Black Skimmer
# - California Condor
# - Eurasian Collared Dove
# - Ferruginous Hawk
# - Green Heron
# - Harpy Eagle
# - Ivory billed Woodpecker
# - Jabiru
# - King Vulture
# - Long tailed Jaeger
# - Marbled Murrelet
# - Northern Mockingbird
# - Osprey
# - Painted Redstart
# - Quetzal
# - Red Knot
# - Snowy Owl
# - Tufted Puffin
# - Umbrellabird
# - Violet crowned Hummingbird
# - White throated Sparrow
# - Xantus's Hummingbird
# - Yellow billed Cuckoo
# - Zone tailed Hawk
# - American Kestrel
# - Black capped Chickadee
# - Carolina Wren
# - Dark eyed Junco
# - Eastern Bluebird
# - Ferruginous Pygmy Owl
# - Golden Eagle
# - Harris's Hawk
# - Ivory billed Aracari
# - Juniper Titmouse
# - King Rail
# - Least Tern
# - Mountain Bluebird
# - Northern Flicker
# - Olive sided Warbler
# - Painted Bunting
# - Quail Dove
# - Red winged Blackbird
# - Snowy Egret
# - Turkey Vulture
# - Upland Sandpiper
# - Varied Thrush
# - Western Grebe
# - Yellow billed Magpie- African Grey Parrot
# - Blue and Gold Macaw
# - Cockatiel
# - Eclectus Parrot
# - Fischer's Lovebird
# - Gouldian Finch
# - Hyacinth Macaw
# - Indian Ringneck Parakeet
# - Java Sparrow
# - Keel-billed Toucan
# - Lilac-breasted Roller
# - Moluccan Cockatoo
# - Nanday Conure
# - Ostrich
# - Pionus Parrot
# - Quaker Parrot
# - Rainbow Lorikeet
# - Sun Conure
# - Toco Toucan
# - Umbrella Cockatoo
# - Vasa Parrot
# - White-faced Cockatiel
# - Xantus's Murrelet
# - Yellow-crowned Amazon
# - Zebra Finch
# - African Pygmy Goose
# - Black-throated Magpie-Jay
# - Crimson Rosella
# - Dusky Lory
# - Elegant Trogon
# - Fairy Bluebird
# - Green Aracari
# - Harlequin Macaw
# - Inca Tern
# - Jamaican Tody
# - Kirtland's Warbler
# - Luzon Bleeding-heart
# - Maroon Oriole
# - Nicobar Pigeon
# - Orange-fronted Parakeet
# - Philippine Eagle
# - Quetzalcoatlus
# - Red-crested Turaco
# - Sulphur-crested Cockatoo
# - Tawny Frogmouth
# - Ural Owl
# - Violet Turaco
# - White-throated Bee-eater
#
# 💾 Saving hallucinated class descriptors to: envisioned_classes/fine_grained_100/cub100_ID_gpt-3.5-turbo_5.json
# === load json:  envisioned_classes/fine_grained_100/cub100_ID_gpt-3.5-turbo_5.json
# Get Envisioned Candidate Class Names.
# After set: 96
# After removing ID class overlaps: 95
# 🔁 Augmenting OOD candidates with synonyms...
#   → 'american kestrel'  → synonym: 'sparrow hawk'
#   → 'juniper titmouse'  → synonym: 'oak titmouse'
#   → 'ivory billed woodpecker'  → synonym: 'campephilus principalis'
#   → 'king vulture'  → synonym: 'sarcoramphus papa'
#   → 'zebra finch'  → synonym: 'taeniopygia guttata'
#   → 'hyacinth macaw'  → synonym: 'anodorhynchus hyacinthinus'
#   → 'eclectus parrot'  → synonym: 'eclectus roratus'
#   → 'dusky lory'  → synonym: 'pseudeos fuscata'
#   → 'umbrella cockatoo'  → synonym: 'white cockatoo'
#   → 'black skimmer'  → synonym: 'rynchops niger'
#   → 'violet turaco'  → synonym: 'violaceous turaco'
#   → 'olive sided warbler'  → synonym: 'contopus cooperi'
#   → 'ivory billed aracari'  → synonym: 'ivory-billed aracari'
#   → 'american avocet'  → synonym: 'recurvirostra americana'
#   → 'painted redstart'  → synonym: 'myioborus pictus'
#   → 'inca tern'  → synonym: 'larosterna inca'
#   → 'zone tailed hawk'  → synonym: 'buteo albonotatus'
#   → 'sun conure'  → synonym: 'aratinga solstitialis'
#   → 'harlequin macaw'  → synonym: 'ara ararauna x ara chloropterus'
#   → 'yellow-crowned amazon'  → synonym: 'amazona ochrocephala'
#   → "xantus's murrelet"  → synonym: 'synthliboramphus hypoleucus'
#   → 'snowy egret'  → synonym: 'egretta thula'
#   → 'african pygmy goose'  → synonym: 'nettapus auritus'
#   → 'varied thrush'  → synonym: 'ixoreus naevius'
#   → 'black-throated magpie-jay'  → synonym: 'calocitta colliei'
#   → 'red-crested turaco'  → synonym: 'tauraco erythrolophus'
#   → 'umbrellabird'  → synonym: 'cotinga ridgwayi'
#   → 'harpy eagle'  → synonym: 'harpia harpyja'
#   → 'dark eyed junco'  → synonym: 'junco hyemalis'
#   → "xantus's hummingbird"  → synonym: 'basilinna xantusii'
#   → 'upland sandpiper'  → synonym: 'bartramia longicauda'
#   → 'ferruginous hawk'  → synonym: 'buteo regalis'
#   → 'ural owl'  → synonym: 'strix uralensis'
#   → 'quaker parrot'  → synonym: 'monk parakeet'
#   → 'quetzalcoatlus'  → synonym: 'none'
#   → 'king rail'  → synonym: 'rallus elegans'
#   → 'tufted puffin'  → synonym: 'fratercula cirrhata'
#   → 'quail dove'  → synonym: 'geotrygon mystacea'
#   → 'marbled murrelet'  → synonym: 'brachyramphus marmoratus'
#   → 'pionus parrot'  → synonym: 'blue-headed parrot'
#   → 'violet crowned hummingbird'  → synonym: 'amazilia violiceps'
#   → 'northern flicker'  → synonym: 'colaptes auratus'
#   → 'elegant trogon'  → synonym: 'elegant quetzal'
#   → 'maroon oriole'  → synonym: 'black-naped oriole'
#   → 'crimson rosella'  → synonym: 'platycercus elegans'
#   → 'java sparrow'  → synonym: 'java finch'
#   → 'california condor'  → synonym: 'gymnogyps californianus'
#   → 'white throated sparrow'  → synonym: 'zonotrichia albicollis'
#   → 'orange-fronted parakeet'  → synonym: 'eupsittula canicularis'
#   → 'ferruginous pygmy owl'  → synonym: 'glaucidium brasilianum'
#   → 'philippine eagle'  → synonym: 'pithecophaga jefferyi'
#   → 'white-throated bee-eater'  → synonym: 'merops albicollis'
#   → 'green aracari'  → synonym: 'pteroglossus viridis'
#   → 'gouldian finch'  → synonym: 'erythrura gouldiae'
#   → 'long tailed jaeger'  → synonym: 'stercorarius longicaudus'
#   → 'fairy bluebird'  → synonym: 'irena puella'
#   → 'least tern'  → synonym: 'sterna antillarum'
#   → "kirtland's warbler"  → synonym: 'setophaga kirtlandii'
#   → 'green heron'  → synonym: 'butorides virescens'
#   → 'indian ringneck parakeet'  → synonym: 'rose-ringed parakeet'
#   → 'yellow billed cuckoo'  → synonym: 'coccyzus americanus'
#   → 'sulphur-crested cockatoo'  → synonym: 'cacatua galerita'
#   → 'moluccan cockatoo'  → synonym: 'salmon-crested cockatoo'
#   → 'yellow billed magpie- african grey parrot'  → synonym: 'african grey parrot'
#   → 'nanday conure'  → synonym: 'black-hooded parakeet'
#   → 'blue and gold macaw'  → synonym: 'ara ararauna'
#   → 'northern mockingbird'  → synonym: 'mimus polyglottos'
#   → 'ostrich'  → synonym: 'struthio camelus'
#   → 'nicobar pigeon'  → synonym: 'caloenas nicobarica'
#   → 'snowy owl'  → synonym: 'bubo scandiacus'
#   → 'vasa parrot'  → synonym: 'coracopsis vasa'
#   → 'toco toucan'  → synonym: 'ramphastos toco'
#   → 'mountain bluebird'  → synonym: 'sialia currucoides'
#   → 'rainbow lorikeet'  → synonym: 'trichoglossus moluccanus'
#   → 'osprey'  → synonym: 'pandion haliaetus'
#   → 'eastern bluebird'  → synonym: 'sialia sialis'
#   → 'white-faced cockatiel'  → synonym: 'white-faced cockatiel'
#   → 'black capped chickadee'  → synonym: 'poecile atricapillus'
#   → 'carolina wren'  → synonym: 'thryothorus ludovicianus'
#   → 'lilac-breasted roller'  → synonym: 'coracias caudatus'
#   → 'tawny frogmouth'  → synonym: 'podargus strigoides'
#   → 'turkey vulture'  → synonym: 'cathartes aura'
#   → 'western grebe'  → synonym: 'aechmophorus occidentalis'
#   → "fischer's lovebird"  → synonym: 'agapornis fischeri'
#   → 'red winged blackbird'  → synonym: 'agelaius phoeniceus'
#   → 'eurasian collared dove'  → synonym: 'streptopelia decaocto'
#   → 'jamaican tody'  → synonym: 'todus todus'
#   → 'keel-billed toucan'  → synonym: 'rainbow-billed toucan'
#   → 'golden eagle'  → synonym: 'aquila chrysaetos'
#   → 'red knot'  → synonym: 'calidris canutus'
#   → 'luzon bleeding-heart'  → synonym: 'gallicolumba luzonica'
#   → 'cockatiel'  → synonym: 'nymphicus hollandicus'
#   → 'quetzal'  → synonym: 'pharomachrus'
#   → 'jabiru'  → synonym: 'black-necked stork'
#   → "harris's hawk"  → synonym: 'parabuteo unicinctus'
# 🧹 Removed 1 invalid synonym labels like 'none' or 'null'
# 📏 OOD classes before synonym expansion: 95
# 📐 OOD classes after synonym + deduplication: 188
#
# 🧪 Final ID Labels passed to CLIP: ['Laysan Albatross', 'Groove billed Ani', 'Crested Auklet', 'Parakeet Auklet', 'Rusty Blackbird', 'Bobolink', 'Indigo Bunting', 'Painted Bunting', 'Spotted Catbird', 'Yellow breasted Chat', 'Eastern Towhee', 'Chuck will Widow', 'Red faced Cormorant', 'Pelagic Cormorant', 'Bronzed Cowbird', 'Shiny Cowbird', 'American Crow', 'Purple Finch', 'Acadian Flycatcher', 'Olive sided Flycatcher', 'Scissor tailed Flycatcher', 'Yellow bellied Flycatcher', 'Frigatebird', 'Gadwall', 'American Goldfinch', 'Boat tailed Grackle', 'Eared Grebe', 'Horned Grebe', 'Pied billed Grebe', 'Blue Grosbeak', 'Evening Grosbeak', 'Pine Grosbeak', 'Rose breasted Grosbeak', 'Pigeon Guillemot', 'Glaucous winged Gull', 'Herring Gull', 'Ivory Gull', 'Ring billed Gull', 'Anna Hummingbird', 'Pomarine Jaeger', 'Blue Jay', 'Green Jay', 'Gray Kingbird', 'Ringed Kingfisher', 'Red legged Kittiwake', 'Horned Lark', 'Western Meadowlark', 'Red breasted Merganser', 'White breasted Nuthatch', 'Hooded Oriole', 'Orchard Oriole', 'Ovenbird', 'Western Wood Pewee', 'Sayornis', 'Whip poor Will', 'White necked Raven', 'Great Grey Shrike', 'Brewer Sparrow', 'Chipping Sparrow', 'Clay colored Sparrow', 'House Sparrow', 'Fox Sparrow', 'Grasshopper Sparrow', 'Henslow Sparrow', 'Le Conte Sparrow', 'Savannah Sparrow', 'Vesper Sparrow', 'Bank Swallow', 'Cliff Swallow', 'Scarlet Tanager', 'Black Tern', 'Caspian Tern', 'Brown Thrasher', 'Sage Thrasher', 'Black capped Vireo', 'Blue headed Vireo', 'Philadelphia Vireo', 'Warbling Vireo', 'Yellow throated Vireo', 'Black throated Blue Warbler', 'Blue winged Warbler', 'Cape May Warbler', 'Golden winged Warbler', 'Hooded Warbler', 'Magnolia Warbler', 'Myrtle Warbler', 'Orange crowned Warbler', 'Palm Warbler', 'Pine Warbler', 'Prothonotary Warbler', 'Swainson Warbler', 'Tennessee Warbler', 'Worm eating Warbler', 'Northern Waterthrush', 'Cedar Waxwing', 'Red bellied Woodpecker', 'Downy Woodpecker', 'Bewick Wren', 'House Wren', 'Common Yellowthroat']
asilianum', 'pithecophaga jefferyi', 'merops albicollis', 'pteroglossus viridis', 'erythrura gouldiae', 'stercorarius longicaudus', 'irena puella', 'sterna antillarum', 'setophaga kirtlandii', 'butorides virescens', 'rose-ringed parakeet', 'coccyzus americanus', 'cacatua galerita', 'salmon-crested cockatoo', 'african grey parrot', 'black-hooded parakeet', 'ara ararauna', 'mimus polyglottos', 'struthio camelus', 'caloenas nicobarica', 'bubo scandiacus', 'coracopsis vasa', 'ramphastos toco', 'sialia currucoides', 'trichoglossus moluccanus', 'pandion haliaetus', 'sialia sialis', 'poecile atricapillus', 'thryothorus ludovicianus', 'coracias caudatus', 'podargus strigoides', 'cathartes aura', 'aechmophorus occidentalis', 'agapornis fischeri', 'agelaius phoeniceus', 'streptopelia decaocto', 'todus todus', 'rainbow-billed toucan', 'aquila chrysaetos', 'calidris canutus', 'gallicolumba luzonica', 'nymphicus hollandicus', 'pharomachrus', 'black-necked stork', 'parabuteo unicinctus']
# 100%|██████████| 12/12 [00:47<00:00,  3.93s/it]
# 2025-07-18 20:58:38,924 : 📦 Evaluating OOD dataset cub100_OOD
# DEBUG:__main__:📦 Evaluating OOD dataset cub100_OOD
# /usr/local/lib/python3.11/dist-packages/torch/utils/data/dataloader.py:624: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(
# 100%|██████████| 12/12 [00:41<00:00,  3.48s/it]
# 2025-07-18 20:59:21,168 : in scores: DescribeResult(nobs=2895, minmax=(np.float32(-0.0013669464), np.float32(-0.0007291485)), mean=np.float32(-0.0010724394), variance=np.float64(6.491123616499675e-09), skewness=np.float64(0.16591469943523407), kurtosis=np.float32(0.51885533))
# DEBUG:__main__:in scores: DescribeResult(nobs=2895, minmax=(np.float32(-0.0013669464), np.float32(-0.0007291485)), mean=np.float32(-0.0010724394), variance=np.float64(6.491123616499675e-09), skewness=np.float64(0.16591469943523407), kurtosis=np.float32(0.51885533))
# 2025-07-18 20:59:21,189 : out scores: DescribeResult(nobs=2899, minmax=(np.float32(-0.0012494219), np.float32(-0.0007172646)), mean=np.float32(-0.0009985358), variance=np.float64(7.378203836254437e-09), skewness=np.float64(0.14900466799736023), kurtosis=np.float32(-0.17049265))
# DEBUG:__main__:out scores: DescribeResult(nobs=2899, minmax=(np.float32(-0.0012494219), np.float32(-0.0007172646)), mean=np.float32(-0.0009985358), variance=np.float64(7.378203836254437e-09), skewness=np.float64(0.14900466799736023), kurtosis=np.float32(-0.17049265))
# 2025-07-18 20:59:23,193 : 				EOE
# DEBUG:__main__:				EOE
# 2025-07-18 20:59:23,196 :   FPR95 AUROC AUPR
# DEBUG:__main__:  FPR95 AUROC AUPR
# 2025-07-18 20:59:23,201 : & 76.10 & 73.54 & 72.32
# DEBUG:__main__:& 76.10 & 73.54 & 72.32
# 2025-07-18 20:59:23,208 :
#
# 📊 Mean Test Results
# DEBUG:__main__:
#
# 📊 Mean Test Results
# 2025-07-18 20:59:23,213 : 				EOE
# DEBUG:__main__:				EOE
# 2025-07-18 20:59:23,216 :   FPR95 AUROC AUPR
# DEBUG:__main__:  FPR95 AUROC AUPR
# 2025-07-18 20:59:23,220 : & 76.10 & 73.54 & 72.32
# DEBUG:__main__:& 76.10 & 73.54 & 72.32

# %%
sys.argv = [
    "eval_ood_detection.py",
    "--name",        "CUB100_CUB100_EOE_300L_75B_finegrained_synonymOOD",
    "--in_dataset",  "cub100_ID",
    "--ood_task",    "fine_grained",
    "--score",       "EOE",
    "--score_ablation", "EOE",           # use standard EOE score
    "--generate_class",                  # generate OOD candidates via LLM
    "--use_synonyms",                   # apply synonym expansion to OOD classes
    "--root_dir",    "datasets",
    "--batch_size",  "256",
    "--gpu",         "0",
    "--beta",       "0.75",
    "--L",           "300",
]
main()
# Out:
# /usr/local/lib/python3.11/dist-packages/torch/utils/data/dataloader.py:624: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(
# ✅ Original ID Labels: ['Laysan Albatross', 'Groove billed Ani', 'Crested Auklet', 'Parakeet Auklet', 'Rusty Blackbird', 'Bobolink', 'Indigo Bunting', 'Painted Bunting', 'Spotted Catbird', 'Yellow breasted Chat', 'Eastern Towhee', 'Chuck will Widow', 'Red faced Cormorant', 'Pelagic Cormorant', 'Bronzed Cowbird', 'Shiny Cowbird', 'American Crow', 'Purple Finch', 'Acadian Flycatcher', 'Olive sided Flycatcher', 'Scissor tailed Flycatcher', 'Yellow bellied Flycatcher', 'Frigatebird', 'Gadwall', 'American Goldfinch', 'Boat tailed Grackle', 'Eared Grebe', 'Horned Grebe', 'Pied billed Grebe', 'Blue Grosbeak', 'Evening Grosbeak', 'Pine Grosbeak', 'Rose breasted Grosbeak', 'Pigeon Guillemot', 'Glaucous winged Gull', 'Herring Gull', 'Ivory Gull', 'Ring billed Gull', 'Anna Hummingbird', 'Pomarine Jaeger', 'Blue Jay', 'Green Jay', 'Gray Kingbird', 'Ringed Kingfisher', 'Red legged Kittiwake', 'Horned Lark', 'Western Meadowlark', 'Red breasted Merganser', 'White breasted Nuthatch', 'Hooded Oriole', 'Orchard Oriole', 'Ovenbird', 'Western Wood Pewee', 'Sayornis', 'Whip poor Will', 'White necked Raven', 'Great Grey Shrike', 'Brewer Sparrow', 'Chipping Sparrow', 'Clay colored Sparrow', 'House Sparrow', 'Fox Sparrow', 'Grasshopper Sparrow', 'Henslow Sparrow', 'Le Conte Sparrow', 'Savannah Sparrow', 'Vesper Sparrow', 'Bank Swallow', 'Cliff Swallow', 'Scarlet Tanager', 'Black Tern', 'Caspian Tern', 'Brown Thrasher', 'Sage Thrasher', 'Black capped Vireo', 'Blue headed Vireo', 'Philadelphia Vireo', 'Warbling Vireo', 'Yellow throated Vireo', 'Black throated Blue Warbler', 'Blue winged Warbler', 'Cape May Warbler', 'Golden winged Warbler', 'Hooded Warbler', 'Magnolia Warbler', 'Myrtle Warbler', 'Orange crowned Warbler', 'Palm Warbler', 'Pine Warbler', 'Prothonotary Warbler', 'Swainson Warbler', 'Tennessee Warbler', 'Worm eating Warbler', 'Northern Waterthrush', 'Cedar Waxwing', 'Red bellied Woodpecker', 'Downy Woodpecker', 'Bewick Wren', 'House Wren', 'Common Yellowthroat']
# 🔮 Using LLM-generated OOD candidate classes...
# Envisioning Outlier Exposure...
# 🔵 Generating via OpenAI GPT...
# Continuing vision 1/5
# Continuing vision 2/5
# Continuing vision 3/5
# Continuing vision 4/5
# Continuing vision 5/5
# 🔍 Raw GPT output:
#  - American Avocet
# - Black Skimmer
# - California Condor
# - Eurasian Collared Dove
# - Ferruginous Hawk
# - Green Heron
# - Harpy Eagle
# - Ivory billed Woodpecker
# - Jabiru
# - King Vulture
# - Long tailed Jaeger
# - Golden Plover
# - Harpy Eagle
# - Inca Tern
# - Japanese Quail
# - King Vulture
# - Luzon Bleeding-heart
# - Masked Lapwing
# - Nicobar Megapode
# - Orange-breasted Sunbird
# - Paradise Tanager
# - Quailfinch
# - Red-billed Streamertail
# - Sulphur-crested Cockatoo
# - Tawny Frogmouth
# - Ural Owl
# - Violet-green Swallow
# - White-throated Kingfisher
#
# 💾 Saving hallucinated class descriptors to: envisioned_classes/fine_grained_300/cub100_ID_gpt-3.5-turbo_4.json
# === load json:  envisioned_classes/fine_grained_300/cub100_ID_gpt-3.5-turbo_4.json
# Get Envisioned Candidate Class Names.
# After set: 182
# After removing ID class overlaps: 178
# 🔁 Augmenting OOD candidates with synonyms...
#   → 'sanderling'  → synonym: 'calidris alba'
#   → 'american kestrel'  → synonym: 'sparrow hawk'
#   → 'red-billed leiothrix'  → synonym: 'leiothrix lutea'
#   → 'long-tailed jaeger'  → synonym: 'stercorarius longicaudus'
#   → 'juniper titmouse'  → synonym: 'oak titmouse'
#   → 'scarlet macaw'  → synonym: 'ara macao'
#   → 'philippine duck'  → synonym: 'anas luzonica'
#   → 'marabou stork'  → synonym: 'leptoptilos crumeniferus'
#   → 'ivory billed woodpecker'  → synonym: 'campephilus principalis'
#   → 'violet sabrewing'  → synonym: 'campylopterus hemileucurus'
#   → 'western tanager'  → synonym: 'piranga ludoviciana'
#   → 'snowy-crowned robin-chat'  → synonym: 'cossypha niveicapilla'
#   → 'red-crowned amazon'  → synonym: 'amazona viridigenalis'
#   → 'orange-breasted sunbird'  → synonym: 'anthobaphes violacea'
#   → 'king vulture'  → synonym: 'sarcoramphus papa'
#   → 'northern lapwing'  → synonym: 'vanellus vanellus'
#   → 'common myna'  → synonym: 'indian myna'
#   → 'zebra finch'  → synonym: 'taeniopygia guttata'
#   → 'hyacinth macaw'  → synonym: 'anodorhynchus hyacinthinus'
#   → 'ivory-billed woodcreeper'  → synonym: 'ivory-billed woodcreeper'
#   → 'eclectus parrot'  → synonym: 'eclectus roratus'
#   → 'dusky lory'  → synonym: 'pseudeos fuscata'
#   → 'umbrella cockatoo'  → synonym: 'white cockatoo'
#   → 'black skimmer'  → synonym: 'rynchops niger'
#   → 'eurasian spoonbill'  → synonym: 'platalea leucorodia'
#   → 'trumpeter swan'  → synonym: 'cygnus buccinator'
#   → 'least bittern'  → synonym: 'ixobrychus exilis'
#   → 'uralian owl'  → synonym: 'strix uralensis'
#   → 'tawny-shouldered blackbird'  → synonym: 'agelaius humeralis'
#   → 'american avocet'  → synonym: 'recurvirostra americana'
#   → 'goliath heron'  → synonym: 'ardea goliath'
#   → 'painted redstart'  → synonym: 'myioborus pictus'
#   → 'inca tern'  → synonym: 'larosterna inca'
#   → 'zone tailed hawk'  → synonym: 'buteo albonotatus'
#   → 'harlequin macaw'  → synonym: 'ara chloropterus'
#   → 'indian peafowl'  → synonym: 'pavo cristatus'
#   → 'yellow-crowned amazon'  → synonym: 'amazona ochrocephala'
#   → "xantus's murrelet"  → synonym: 'synthliboramphus hypoleucus'
#   → 'african pygmy goose'  → synonym: 'nettapus auritus'
#   → 'prairie warbler'  → synonym: 'setophaga discolor'
#   → 'varied thrush'  → synonym: 'ixoreus naevius'
#   → 'blue-crowned conure'  → synonym: 'aratinga acuticaudata'
#   → 'black-throated magpie-jay'  → synonym: 'calocitta colliei'
#   → 'black-capped chickadee'  → synonym: 'poecile atricapillus'
#   → 'dickcissel'  → synonym: 'spiza americana'
#   → 'fork-tailed flycatcher'  → synonym: 'tyrannus savana'
#   → 'white-faced ibis'  → synonym: 'plegadis chihi'
#   → 'quokka finch'  → synonym: 'red-eared firetail'
#   → 'cape petrel'  → synonym: 'daption capense'
#   → 'red-crested turaco'  → synonym: 'tauraco erythrolophus'
#   → 'yellow-bellied sapsucker'  → synonym: 'sphyrapicus varius'
#   → 'umbrellabird'  → synonym: 'cephalopterus penduliger'
#   → 'victoria crowned pigeon'  → synonym: 'goura victoria'
#   → 'violet-green swallow'  → synonym: 'tachycineta thalassina'
#   → 'victoria crowned pigeon- andean condor'  → synonym: 'andean condor'
#   → 'harpy eagle'  → synonym: 'harpia harpyja'
#   → 'dusky woodswallow'  → synonym: 'artamus cyanopterus'
#   → 'japanese white-eye'  → synonym: 'zosterops japonicus'
#   → 'dark eyed junco'  → synonym: 'junco hyemalis'
#   → 'orange-bellied parrot'  → synonym: 'neophema chrysogaster'
#   → "xantus's hummingbird"  → synonym: 'baja california hummingbird'
#   → 'secretary bird'  → synonym: 'sagittarius serpentarius'
#   → 'eurasian bullfinch'  → synonym: 'common bullfinch'
#   → 'cinnamon teal'  → synonym: 'anas cyanoptera'
#   → 'black-crowned night heron'  → synonym: 'nycticorax nycticorax'
#   → 'long-tailed duck'  → synonym: 'oldsquaw'
#   → 'northern gannet'  → synonym: 'morus bassanus'
#   → 'piping plover'  → synonym: 'charadrius melodus'
#   → 'upland sandpiper'  → synonym: 'bartramia longicauda'
#   → 'harlequin duck'  → synonym: 'histrionicus histrionicus'
#   → 'quailfinch'  → synonym: 'ortygospiza atricollis'
#   → 'ferruginous hawk'  → synonym: 'buteo regalis'
#   → 'ural owl'  → synonym: 'strix uralensis'
#   → 'quaker parrot'  → synonym: 'monk parakeet'
#   → 'himalayan monal'  → synonym: 'lophophorus impejanus'
#   → 'yellow-billed loon'  → synonym: 'gavia adamsii'
#   → 'white-throated dipper'  → synonym: 'cinclus cinclus'
#   → 'emerald toucanet'  → synonym: 'aulacorhynchus prasinus'
#   → 'eurasian wren'  → synonym: 'troglodytes troglodytes'
#   → 'dusky grouse'  → synonym: 'blue grouse'
#   → 'king rail'  → synonym: 'rallus elegans'
#   → 'tufted puffin'  → synonym: 'fratercula cirrhata'
#   → 'bateleur eagle'  → synonym: 'terathopius ecaudatus'
#   → 'quail dove'  → synonym: 'geotrygon mystacea'
#   → 'marbled murrelet'  → synonym: 'brachyramphus marmoratus'
#   → 'northern bobwhite'  → synonym: 'colinus virginianus'
#   → 'great blue heron'  → synonym: 'ardea herodias'
#   → 'violet crowned hummingbird'  → synonym: 'amazilia violiceps'
#   → 'northern flicker'  → synonym: 'colaptes auratus'
#   → 'palm cockatoo'  → synonym: 'probosciger aterrimus'
#   → 'maroon oriole'  → synonym: 'black-naped oriole'
#   → 'elegant trogon'  → synonym: 'elegant quetzal'
#   → 'crimson rosella'  → synonym: 'platycercus elegans'
#   → 'japanese quail'  → synonym: 'coturnix japonica'
#   → 'java sparrow'  → synonym: 'java finch'
#   → 'california condor'  → synonym: 'gymnogyps californianus'
#   → 'nene (hawaiian goose)'  → synonym: 'branta sandvicensis'
#   → 'white throated sparrow'  → synonym: 'zonotrichia albicollis'
#   → 'zebra dove'  → synonym: 'geopelia striata'
#   → 'orange-fronted parakeet'  → synonym: 'eupsittula canicularis'
#   → 'ferruginous pygmy owl'  → synonym: 'glaucidium brasilianum'
#   → 'african pygmy kingfisher'  → synonym: 'ispidina picta'
#   → 'snow bunting'  → synonym: 'plectrophenax nivalis'
#   → 'flame robin'  → synonym: 'petroica phoenicea'
#   → 'philippine eagle'  → synonym: 'pithecophaga jefferyi'
#   → 'white-throated kingfisher- american woodcock'  → synonym: 'halcyon smyrnensis - scolopax minor'
#   → 'gouldian finch'  → synonym: 'erythrura gouldiae'
#   → 'long tailed jaeger'  → synonym: 'stercorarius longicaudus'
#   → 'fulvous whistling duck'  → synonym: 'dendrocygna bicolor'
#   → 'eastern whip-poor-will'  → synonym: 'antrostomus vociferus'
#   → 'least tern'  → synonym: 'sterna antillarum'
#   → 'oriental dwarf kingfisher'  → synonym: 'ceyx erithaca'
#   → 'green heron'  → synonym: 'butorides virescens'
#   → 'indian ringneck parakeet'  → synonym: 'rose-ringed parakeet'
#   → 'double-crested cormorant'  → synonym: 'phalacrocorax auritus'
#   → 'golden pheasant'  → synonym: 'chinese pheasant'
#   → 'white-throated kingfisher'  → synonym: 'halcyon smyrnensis'
#   → 'yellow billed cuckoo'  → synonym: 'coccyzus americanus'
#   → "fischer's turaco"  → synonym: 'tauraco fischeri'
#   → 'sulphur-crested cockatoo'  → synonym: 'cacatua galerita'
#   → 'ivory-billed aracari'  → synonym: 'ivory-billed toucan'
#   → 'moluccan cockatoo'  → synonym: 'salmon-crested cockatoo'
#   → 'sun parakeet'  → synonym: 'aratinga solstitialis'
#   → 'nicobar megapode'  → synonym: 'nicobar scrubfowl'
#   → 'african jacana'  → synonym: 'actophilornis africanus'
#   → 'blue and gold macaw'  → synonym: 'ara ararauna'
#   → 'golden plover'  → synonym: 'pluvialis apricaria'
#   → 'white-throated kingfisher- azure-winged magpie'  → synonym: 'halcyon smyrnensis - cyanopica cyanus'
#   → 'northern mockingbird'  → synonym: 'mimus polyglottos'
#   → 'ostrich'  → synonym: 'struthio camelus'
#   → 'grey-crowned rosy-finch'  → synonym: 'leucosticte tephrocotis'
#   → 'tawny owl'  → synonym: 'strix aluco'
#   → 'nicobar pigeon'  → synonym: 'caloenas nicobarica'
#   → 'masked lapwing'  → synonym: 'vanellus miles'
#   → 'yellow warbler'  → synonym: 'dendroica petechia'
#   → 'zone tailed hawk- african grey parrot'  → synonym: 'african grey parrot'
#   → 'orange-crowned warbler'  → synonym: 'oreothlypis celata'
#   → 'white-throated sparrow'  → synonym: 'zonotrichia albicollis'
#   → 'snowy owl'  → synonym: 'bubo scandiacus'
#   → 'toco toucan'  → synonym: 'ramphastos toco'
#   → 'mountain bluebird'  → synonym: 'sialia currucoides'
#   → 'rainbow lorikeet'  → synonym: 'trichoglossus moluccanus'
#   → 'osprey'  → synonym: 'pandion haliaetus'
#   → 'eastern bluebird'  → synonym: 'sialia sialis'
#   → 'white-faced cockatiel'  → synonym: 'white-mantled cockatiel'
#   → 'white-throated kingfisher- american dipper'  → synonym: 'white-breasted kingfisher - cinclus mexicanus'
#   → 'inca dove'  → synonym: 'columbina inca'
#   → 'black capped chickadee'  → synonym: 'poecile atricapillus'
#   → 'carolina wren'  → synonym: 'thryothorus ludovicianus'
#   → 'lilac-breasted roller'  → synonym: 'coracias caudatus'
#   → 'crested caracara'  → synonym: 'caracara cheriway'
#   → 'tawny frogmouth'  → synonym: 'podargus strigoides'
#   → 'paradise tanager'  → synonym: 'tangara chilensis'
#   → 'kori bustard'  → synonym: 'ardeotis kori'
#   → "fischer's lovebird"  → synonym: 'agapornis fischeri'
#   → 'red winged blackbird'  → synonym: 'agelaius phoeniceus'
#   → 'eurasian collared dove'  → synonym: 'streptopelia decaocto'
#   → 'black-throated sparrow'  → synonym: 'amphispiza bilineata'
#   → 'jamaican tody'  → synonym: 'todus todus'
#   → 'hooded merganser'  → synonym: 'lophodytes cucullatus'
#   → 'keel-billed toucan'  → synonym: 'rainbow-billed toucan'
#   → 'red knot'  → synonym: 'calidris canutus'
#   → 'long-tailed tit'  → synonym: 'aegithalos caudatus'
#   → 'greater roadrunner'  → synonym: 'geococcyx californianus'
#   → 'luzon bleeding-heart'  → synonym: 'gallicolumba luzonica'
#   → 'red-billed streamertail'  → synonym: 'trochilus polytmus'
#   → "townsend's warbler"  → synonym: 'setophaga townsendi'
#   → 'cockatiel'  → synonym: 'nymphicus hollandicus'
#   → 'magnificent frigatebird'  → synonym: "man o' war bird"
#   → 'quetzal'  → synonym: 'pharomachrus'
#   → 'red-legged honeycreeper'  → synonym: 'cyanerpes cyaneus'
#   → 'jabiru'  → synonym: 'black-necked stork'
#   → 'kaka'  → synonym: 'nestor meridionalis'
#   → 'oriental stork'  → synonym: 'ciconia boyciana'
#   → 'fairy pitta'  → synonym: 'pitta nympha'
#   → 'king eider'  → synonym: 'somateria spectabilis'
#   → "harris's hawk"  → synonym: 'parabuteo unicinctus'
#   → 'jabiru stork'  → synonym: 'jabiru'
# 🧹 Removed 0 invalid synonym labels like 'none' or 'null'
# 📏 OOD classes before synonym expansion: 178
# 📐 OOD classes after synonym + deduplication: 350
#
# /usr/local/lib/python3.11/dist-packages/torch/utils/data/dataloader.py:624: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(
# 100%|██████████| 12/12 [00:42<00:00,  3.52s/it]
# 2025-07-18 21:02:55,660 : in scores: DescribeResult(nobs=2895, minmax=(np.float32(-0.00087190093), np.float32(-0.0004627132)), mean=np.float32(-0.0006716444), variance=np.float64(2.5395216153418487e-09), skewness=np.float64(0.09785906970500946), kurtosis=np.float32(0.40892816))
# DEBUG:__main__:in scores: DescribeResult(nobs=2895, minmax=(np.float32(-0.00087190093), np.float32(-0.0004627132)), mean=np.float32(-0.0006716444), variance=np.float64(2.5395216153418487e-09), skewness=np.float64(0.09785906970500946), kurtosis=np.float32(0.40892816))
# 2025-07-18 21:02:55,669 : out scores: DescribeResult(nobs=2899, minmax=(np.float32(-0.0007921872), np.float32(-0.00043672533)), mean=np.float32(-0.0006198835), variance=np.float64(3.2086201684251645e-09), skewness=np.float64(0.18635118007659912), kurtosis=np.float32(-0.1157279))
# DEBUG:__main__:out scores: DescribeResult(nobs=2899, minmax=(np.float32(-0.0007921872), np.float32(-0.00043672533)), mean=np.float32(-0.0006198835), variance=np.float64(3.2086201684251645e-09), skewness=np.float64(0.18635118007659912), kurtosis=np.float32(-0.1157279))
# 2025-07-18 21:02:56,139 : 				EOE
# DEBUG:__main__:				EOE
# 2025-07-18 21:02:56,141 :   FPR95 AUROC AUPR
# DEBUG:__main__:  FPR95 AUROC AUPR
# 2025-07-18 21:02:56,144 : & 71.09 & 75.13 & 73.56
# DEBUG:__main__:& 71.09 & 75.13 & 73.56
# 2025-07-18 21:02:56,149 :
#
# 📊 Mean Test Results
# DEBUG:__main__:
#
# 📊 Mean Test Results
# 2025-07-18 21:02:56,150 : 				EOE
# DEBUG:__main__:				EOE
# 2025-07-18 21:02:56,152 :   FPR95 AUROC AUPR
# DEBUG:__main__:  FPR95 AUROC AUPR
# 2025-07-18 21:02:56,153 : & 71.09 & 75.13 & 73.56
# DEBUG:__main__:& 71.09 & 75.13 & 73.56

# %%
sys.argv = [
    "eval_ood_detection.py",
    "--name",        "CUB100_CUB100_EOE_500L_75B_finegrained_synonymOOD",
    "--in_dataset",  "cub100_ID",
    "--ood_task",    "fine_grained",
    "--score",       "EOE",
    "--score_ablation", "EOE",           # use standard EOE score
    "--generate_class",                  # generate OOD candidates via LLM
    "--use_synonyms",                   # apply synonym expansion to OOD classes
    "--root_dir",    "datasets",
    "--batch_size",  "256",
    "--gpu",         "0",
    "--beta",       "0.75",
    "--L",           "500",
]
main()
# Out:
# /usr/local/lib/python3.11/dist-packages/torch/utils/data/dataloader.py:624: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(
# ✅ Original ID Labels: ['Laysan Albatross', 'Groove billed Ani', 'Crested Auklet', 'Parakeet Auklet', 'Rusty Blackbird', 'Bobolink', 'Indigo Bunting', 'Painted Bunting', 'Spotted Catbird', 'Yellow breasted Chat', 'Eastern Towhee', 'Chuck will Widow', 'Red faced Cormorant', 'Pelagic Cormorant', 'Bronzed Cowbird', 'Shiny Cowbird', 'American Crow', 'Purple Finch', 'Acadian Flycatcher', 'Olive sided Flycatcher', 'Scissor tailed Flycatcher', 'Yellow bellied Flycatcher', 'Frigatebird', 'Gadwall', 'American Goldfinch', 'Boat tailed Grackle', 'Eared Grebe', 'Horned Grebe', 'Pied billed Grebe', 'Blue Grosbeak', 'Evening Grosbeak', 'Pine Grosbeak', 'Rose breasted Grosbeak', 'Pigeon Guillemot', 'Glaucous winged Gull', 'Herring Gull', 'Ivory Gull', 'Ring billed Gull', 'Anna Hummingbird', 'Pomarine Jaeger', 'Blue Jay', 'Green Jay', 'Gray Kingbird', 'Ringed Kingfisher', 'Red legged Kittiwake', 'Horned Lark', 'Western Meadowlark', 'Red breasted Merganser', 'White breasted Nuthatch', 'Hooded Oriole', 'Orchard Oriole', 'Ovenbird', 'Western Wood Pewee', 'Sayornis', 'Whip poor Will', 'White necked Raven', 'Great Grey Shrike', 'Brewer Sparrow', 'Chipping Sparrow', 'Clay colored Sparrow', 'House Sparrow', 'Fox Sparrow', 'Grasshopper Sparrow', 'Henslow Sparrow', 'Le Conte Sparrow', 'Savannah Sparrow', 'Vesper Sparrow', 'Bank Swallow', 'Cliff Swallow', 'Scarlet Tanager', 'Black Tern', 'Caspian Tern', 'Brown Thrasher', 'Sage Thrasher', 'Black capped Vireo', 'Blue headed Vireo', 'Philadelphia Vireo', 'Warbling Vireo', 'Yellow throated Vireo', 'Black throated Blue Warbler', 'Blue winged Warbler', 'Cape May Warbler', 'Golden winged Warbler', 'Hooded Warbler', 'Magnolia Warbler', 'Myrtle Warbler', 'Orange crowned Warbler', 'Palm Warbler', 'Pine Warbler', 'Prothonotary Warbler', 'Swainson Warbler', 'Tennessee Warbler', 'Worm eating Warbler', 'Northern Waterthrush', 'Cedar Waxwing', 'Red bellied Woodpecker', 'Downy Woodpecker', 'Bewick Wren', 'House Wren', 'Common Yellowthroat']
# 🔮 Using LLM-generated OOD candidate classes...
# Envisioning Outlier Exposure...
# 🔵 Generating via OpenAI GPT...
# Continuing vision 1/9
# Continuing vision 2/9
# Continuing vision 3/9
# Continuing vision 4/9
# Continuing vision 5/9
# Continuing vision 6/9
# Continuing vision 7/9
# Continuing vision 8/9
# Continuing vision 9/9
# 🔍 Raw GPT output:
#  - American Avocet
# - Black Skimmer
# - California Condor
# - Eurasian Collared Dove
# - Ferruginous Hawk
# - Green Heron
# - Harpy Eagle
# - Ivory billed Woodpecker
# - Jabiru
# - King Vulture
# - Long tailed Jaeger
# - Marbled Murrelet
# - Northern Mockingbird
# - Osprey
# - Painted Redstart
# - Quetzal
# - Red footed Booby
# - Snowy Owl
# - Toco Toucan
# - Umbrellabird
# - Violet crowned Hummingbird
# - White throated Sparrow
# - Xantus's Hummingbird
# - Yellow billed Cuckoo
# - Zone tailed Hawk
# - American Kestrel
# - Black capped Chickadee
# - Common Loon
# - Double crested Cormorant
# - Eurasian Wigeon
# - Ferruginous Hawk
# - Greater Roadrunner
# - Harlequin Duck
# - Ivory Gull
# - Juniper Titmouse
# - King Rail
# - Least Tern
# - Mountain Bluebird
# - Northern Flicker
# - Olive sided Flycatcher
# - Painted Bunting
# - Quaker Parrot
# - Red winged Blackbird
# - Snowy Egret
# - Tufted Puffin
# - Upland Sandpiper
# - Varied Thrush
# - Western Grebe
# - Yellow crowned Night Heron- African Grey Parrot
# - Blue and Gold Macaw
# - Crimson Rosella
# - Eclectus Parrot
# - Fischer's Lovebird
# - Gouldian Finch
# - Hyacinth Macaw
# - Indian Ringneck Parakeet
# - Java Sparrow
# - Keel-billed Toucan
# - Lilac-breasted Roller
# - Emerald Starling
# - Flame-colored Tanager
# - Grey-crowned Tanager
# - Harlequin Duck
# - Ivory-billed Woodcreeper
# - Japanese Sparrowhawk
# - King Rail
# - Lilac-breasted Tern
# - Maroon-chested Ground Dove
# - Nicobar Imperial Pigeon
# - Orange-breasted Falcon
# - Pink-throated Becard
# - Quetzal Thrush
# - Red-billed Pigeon
# - Superb Fairywren
# - Tawny-crested Tanager
# - Ural Owl
# - Violet-crowned Woodnymph
# - White-throated Mountain Gem
# - Xantus's Hummingbird
# - Yellow-bellied Euphonia
# - Zebra Dove
# - African Pygmy Kingfisher
# - Blue-crowned Manakin
# - Crimson-fronted Parakeet
# - Dusky-headed Parakeet
# - Elegant Crescentchest
# - Fairy Bluebird
# - Green Honeyeater
# - Hoopoe Lark
# - Indian Robin
# - Jungle Prinia
# - King Vulture
# - Lilac-breasted Roller
# - Maroon Oriole
# - Nicobar Pigeon
# - Oriental Dwarf Kingfisher
# - Painted Snipe
# - Quetzal Trogon
# - Red-billed Quelea
# - Superb Lyrebird
# - Toco Toucan
# - Umbrellabird
# - Violet Sabrewing
#
# 💾 Saving hallucinated class descriptors to: envisioned_classes/fine_grained_500/cub100_ID_gpt-3.5-turbo_1.json
# === load json:  envisioned_classes/fine_grained_500/cub100_ID_gpt-3.5-turbo_1.json
# Get Envisioned Candidate Class Names.
# After set: 211
# After removing ID class overlaps: 206
# 🔁 Augmenting OOD candidates with synonyms...
#   → 'yellow-headed blackbird'  → synonym: 'xanthocephalus xanthocephalus'
#   → 'american kestrel'  → synonym: 'sparrow hawk'
#   → 'red-billed leiothrix'  → synonym: 'leiothrix lutea'
#   → 'juniper titmouse'  → synonym: 'oak titmouse'
#   → 'scarlet macaw'  → synonym: 'ara macao'
#   → 'jungle babbler'  → synonym: 'turdoides striata'
#   → 'painted snipe'  → synonym: 'rostratula australis'
#   → 'orange-breasted bunting'  → synonym: 'passerina leclancherii'
#   → 'marabou stork'  → synonym: 'leptoptilos crumeniferus'
#   → 'indian robin'  → synonym: 'copsychus fulicatus'
#   → 'ivory billed woodpecker'  → synonym: 'campephilus principalis'
#   → 'violet sabrewing'  → synonym: 'campylopterus hemileucurus'
#   → 'gila woodpecker'  → synonym: 'melanerpes uropygialis'
#   → 'emerald starling'  → synonym: 'lamprotornis iris'
#   → 'pink-throated twinspot'  → synonym: 'hypargos margaritatus'
#   → 'king vulture'  → synonym: 'sarcoramphus papa'
#   → 'zebra finch'  → synonym: 'taeniopygia guttata'
#   → 'red-billed pigeon'  → synonym: 'columba flavirostris'
#   → 'hyacinth macaw'  → synonym: 'anodorhynchus hyacinthinus'
#   → 'ibisbill'  → synonym: 'ibidorhyncha struthersii'
#   → 'ivory-billed woodcreeper'  → synonym: 'ivory-billed woodcreeper'
#   → 'violet-crowned woodnymph'  → synonym: 'thalurania colombica'
#   → 'eclectus parrot'  → synonym: 'eclectus roratus'
#   → 'black-throated green warbler'  → synonym: 'setophaga virens'
#   → 'dusky lory'  → synonym: 'pseudeos fuscata'
#   → 'red-billed oxpecker'  → synonym: 'buphagus erythrorhynchus'
#   → 'umbrella cockatoo'  → synonym: 'white cockatoo'
#   → 'black skimmer'  → synonym: 'rynchops niger'
#   → 'violet turaco'  → synonym: 'violaceous plantain eater'
#   → 'vulturine guineafowl'  → synonym: 'acryllium vulturinum'
#   → 'cape gannet'  → synonym: 'morus capensis'
#   → 'orange-breasted falcon'  → synonym: 'orange-breasted falcon'
#   → 'american avocet'  → synonym: 'recurvirostra americana'
#   → 'japanese sparrowhawk'  → synonym: 'eurasian sparrowhawk'
#   → 'painted redstart'  → synonym: 'myioborus pictus'
#   → 'inca tern'  → synonym: 'larosterna inca'
#   → 'zone tailed hawk'  → synonym: 'buteo albonotatus'
#   → 'flame-colored tanager'  → synonym: 'piranga bidentata'
#   → 'yellow-bellied eremomela'  → synonym: 'eremomela flavicrissalis'
#   → 'indian peafowl'  → synonym: 'pavo cristatus'
#   → 'yellow-crowned amazon'  → synonym: 'amazona ochrocephala'
#   → 'yellow-bellied sunbird'  → synonym: 'olive-backed sunbird'
#   → "xantus's murrelet"  → synonym: 'synthliboramphus hypoleucus'
#   → 'flame-faced tanager'  → synonym: 'tangara parzudakii'
#   → 'snowy egret'  → synonym: 'egretta thula'
#   → 'african pygmy goose'  → synonym: 'nettapus auritus'
#   → 'varied thrush'  → synonym: 'ixoreus naevius'
#   → 'black-throated magpie-jay'  → synonym: 'calocitta colliei'
#   → 'black-capped chickadee'  → synonym: 'poecile atricapillus'
#   → 'nicobar bulbul'  → synonym: 'alophoixus finschii'
#   → 'black-throated antshrike'  → synonym: 'frederickena viridis'
#   → 'white-crowned pigeon'  → synonym: 'columba leucocephala'
#   → 'quokka finch'  → synonym: 'red-eared firetail'
#   → 'tawny-crowned honeyeater'  → synonym: 'phylidonyris melanops'
#   → 'collared aracari'  → synonym: 'pteroglossus torquatus'
#   → 'yellow-bellied sapsucker'  → synonym: 'sphyrapicus varius'
#   → 'umbrellabird'  → synonym: 'cephalopterus penduliger'
#   → 'grey-crowned crane'  → synonym: 'balearica regulorum'
#   → 'roseate spoonbill'  → synonym: 'platalea ajaja'
#   → 'harpy eagle'  → synonym: 'harpia harpyja'
#   → 'dusky woodswallow'  → synonym: 'artamus cyanopterus'
#   → 'grey-crowned tanager'  → synonym: 'iridosornis unicolor'
#   → 'japanese white-eye'  → synonym: 'zosterops japonicus'
#   → 'quetzal thrush'  → synonym: 'black-throated trogon'
#   → 'orange-bellied parrot'  → synonym: 'neophema chrysogaster'
#   → 'dusky lark'  → synonym: 'dusky lark'
#   → 'quail'  → synonym: 'coturnix'
#   → 'white-throated mountain gem'  → synonym: 'lampornis castaneoventris'
#   → "xantus's hummingbird"  → synonym: 'basilinna xantusii'
#   → 'secretary bird'  → synonym: 'sagittarius serpentarius'
#   → 'black-crowned night heron'  → synonym: 'nycticorax nycticorax'
#   → 'cinnamon teal'  → synonym: 'anas cyanoptera'
#   → 'eurasian bullfinch'  → synonym: 'common bullfinch'
#   → 'eurasian wigeon'  → synonym: 'anas penelope'
#   → 'junglefowl'  → synonym: 'gallus gallus'
#   → 'dusky pigeon'  → synonym: 'dusky turtle dove'
#   → 'grey-crowned babbler'  → synonym: 'pomatostomus temporalis'
#   → 'pink-headed duck'  → synonym: 'rhodonessa caryophyllacea'
#   → 'japanese grosbeak'  → synonym: 'eophona personata'
#   → 'upland sandpiper'  → synonym: 'bartramia longicauda'
#   → 'harlequin duck'  → synonym: 'histrionicus histrionicus'
#   → 'grey-crowned rosy finch'  → synonym: 'leucosticte tephrocotis'
#   → 'ferruginous hawk'  → synonym: 'buteo regalis'
#   → 'ural owl'  → synonym: 'strix uralensis'
#   → 'quaker parrot'  → synonym: 'monk parakeet'
#   → 'himalayan monal'  → synonym: 'lophophorus impejanus'
#   → 'pink-throated becard'  → synonym: 'rose-throated becard'
#   → 'white-throated dipper'  → synonym: 'cinclus cinclus'
#   → 'emerald toucanet'  → synonym: 'aulacorhynchus prasinus'
#   → 'king rail'  → synonym: 'rallus elegans'
#   → 'white-headed buffalo weaver- andean condor'  → synonym: 'andean condor'
#   → 'tufted puffin'  → synonym: 'fratercula cirrhata'
#   → 'montezuma oropendola'  → synonym: 'psarocolius montezuma'
#   → 'maroon-chested ground dove'  → synonym: 'claravis mondetoura'
#   → 'bateleur eagle'  → synonym: 'terathopius ecaudatus'
#   → 'superb fairywren'  → synonym: 'superb blue-wren'
#   → 'tawny-crested tanager'  → synonym: 'tachyphonus delatrii'
#   → 'harlequin quail'  → synonym: 'chinese painted quail'
#   → 'marbled murrelet'  → synonym: 'brachyramphus marmoratus'
#   → 'crimson-fronted parakeet'  → synonym: 'crimson-fronted conure'
#   → 'violet crowned hummingbird'  → synonym: 'amazilia violiceps'
#   → 'northern flicker'  → synonym: 'colaptes auratus'
#   → 'palm cockatoo'  → synonym: 'probosciger aterrimus'
#   → 'elegant trogon'  → synonym: 'elegant quetzal'
#   → 'ocellated turkey'  → synonym: 'meleagris ocellata'
#   → 'maroon oriole'  → synonym: 'black-naped oriole'
#   → 'dusky nightjar'  → synonym: 'caprimulgus saturatus'
#   → 'crimson rosella'  → synonym: 'platycercus elegans'
#   → 'japanese quail'  → synonym: 'coturnix japonica'
#   → 'java sparrow'  → synonym: 'java finch'
#   → 'california condor'  → synonym: 'gymnogyps californianus'
#   → 'nene (hawaiian goose)'  → synonym: 'branta sandvicensis'
#   → 'jungle prinia'  → synonym: 'prinia sylvatica'
#   → 'violet sabrewing- amethyst sunbird'  → synonym: 'amethyst sunbird'
#   → 'white throated sparrow'  → synonym: 'zonotrichia albicollis'
#   → 'zebra dove'  → synonym: 'geopelia striata'
#   → 'orange-fronted parakeet'  → synonym: 'eupsittula canicularis'
#   → 'common loon'  → synonym: 'great northern diver'
#   → 'african pygmy kingfisher'  → synonym: 'ispidina picta'
#   → 'flame robin'  → synonym: 'petroica phoenicea'
#   → 'philippine eagle'  → synonym: 'pithecophaga jefferyi'
#   → 'green honeycreeper'  → synonym: 'chlorophanes spiza'
#   → 'yellow-bellied euphonia'  → synonym: 'euphonia flaviventris'
#   → 'white-throated bee-eater'  → synonym: 'merops albicollis'
#   → 'green aracari'  → synonym: 'pteroglossus viridis'
#   → 'gouldian finch'  → synonym: 'erythrura gouldiae'
#   → 'long tailed jaeger'  → synonym: 'stercorarius longicaudus'
#   → 'tawny-crowned greenlet'  → synonym: 'olivaceous greenlet'
#   → 'violet sabrewing- amethyst starling'  → synonym: 'violet sabrewing'
#   → 'japanese paradise flycatcher'  → synonym: 'terpsiphone atrocaudata'
#   → 'white-throated mountain babbler'  → synonym: 'collar babbler'
#   → 'blue-crowned manakin'  → synonym: 'lepidothrix coronata'
#   → 'fairy bluebird'  → synonym: 'irena puella'
#   → 'elegant crescentchest'  → synonym: 'elegant crescent-chest'
#   → 'least tern'  → synonym: 'sterna antillarum'
#   → 'dalmatian pelican'  → synonym: 'pelecanus crispus'
#   → "kirtland's warbler"  → synonym: 'setophaga kirtlandii'
#   → 'oriental dwarf kingfisher'  → synonym: 'ceyx erithaca'
#   → 'quetzal trogon'  → synonym: 'resplendent quetzal'
#   → 'red-billed quelea'  → synonym: 'quelea quelea'
#   → 'green heron'  → synonym: 'butorides virescens'
#   → 'indian ringneck parakeet'  → synonym: 'rose-ringed parakeet'
#   → 'yellow billed cuckoo'  → synonym: 'coccyzus americanus'
#   → 'yellow crowned night heron- african grey parrot'  → synonym: 'african gray parrot'
#   → 'dusky warbler'  → synonym: 'phylloscopus fuscatus'
#   → 'pink-headed warbler'  → synonym: 'cardellina versicolor'
#   → 'sulphur-crested cockatoo'  → synonym: 'cacatua galerita'
#   → 'red-billed blue magpie'  → synonym: 'urocissa erythroryncha'
#   → 'nicobar imperial pigeon'  → synonym: 'ducula nicobarica'
#   → 'ivory-billed aracari'  → synonym: 'ivory-billed toucan'
#   → 'moluccan cockatoo'  → synonym: 'salmon-crested cockatoo'
#   → 'nicobar megapode'  → synonym: 'nicobar scrubfowl'
#   → 'african jacana'  → synonym: 'actophilornis africanus'
#   → 'crimson finch'  → synonym: 'neochmia phaeton'
#   → 'green honeyeater'  → synonym: 'green-backed honeyeater'
#   → 'indian pitta'  → synonym: 'pitta brachyura'
#   → 'blue and gold macaw'  → synonym: 'ara ararauna'
#   → 'northern mockingbird'  → synonym: 'mimus polyglottos'
#   → 'ostrich'  → synonym: 'struthio camelus'
#   → 'nicobar pigeon'  → synonym: 'caloenas nicobarica'
#   → 'dusky munia'  → synonym: 'lonchura fuscans'
#   → 'lilac-breasted tern'  → synonym: 'gygis alba'
#   → 'snowy owl'  → synonym: 'bubo scandiacus'
#   → 'vasa parrot'  → synonym: 'coracopsis vasa'
#   → 'ivory-billed coucal'  → synonym: 'ivory-billed coucal'
#   → 'violet sabrewing- amethyst-throated sunangel'  → synonym: 'violet sabrewing'
#   → 'toco toucan'  → synonym: 'ramphastos toco'
#   → 'vulturine guineafowl- azure-winged magpie'  → synonym: 'cyanopica cyanus'
#   → 'mountain bluebird'  → synonym: 'sialia currucoides'
#   → 'rainbow lorikeet'  → synonym: 'trichoglossus moluccanus'
#   → 'osprey'  → synonym: 'pandion haliaetus'
#   → 'egyptian vulture'  → synonym: 'neophron percnopterus'
#   → 'black-throated magpie'  → synonym: 'yellow-billed magpie'
#   → 'crimson-collared grosbeak'  → synonym: 'rhodospingus cruentus'
#   → 'dusky-headed parakeet'  → synonym: 'aratinga weddellii'
#   → 'double crested cormorant'  → synonym: 'phalacrocorax auritus'
#   → 'black capped chickadee'  → synonym: 'poecile atricapillus'
#   → 'hoopoe'  → synonym: 'upupa epops'
#   → 'lilac-breasted roller'  → synonym: 'coracias caudatus'
#   → 'violet sabrewing- amethyst woodstar'  → synonym: 'campylopterus hemileucurus'
#   → 'crested caracara'  → synonym: 'caracara cheriway'
#   → 'red-legged seriema'  → synonym: 'cariama cristata'
#   → 'wattled crane'  → synonym: 'bugeranus carunculatus'
#   → 'black-throated shrike-babbler'  → synonym: 'colluricincla macroryncha'
#   → 'tawny frogmouth'  → synonym: 'podargus strigoides'
#   → 'western grebe'  → synonym: 'aechmophorus occidentalis'
#   → 'kori bustard'  → synonym: 'ardeotis kori'
#   → 'lammergeier'  → synonym: 'bearded vulture'
#   → "fischer's lovebird"  → synonym: 'agapornis fischeri'
#   → 'superb lyrebird'  → synonym: 'menura novaehollandiae'
#   → 'flame bowerbird'  → synonym: 'sericulus aureus'
#   → 'red winged blackbird'  → synonym: 'agelaius phoeniceus'
#   → 'eurasian collared dove'  → synonym: 'streptopelia decaocto'
#   → 'black-throated sparrow'  → synonym: 'amphispiza bilineata'
#   → 'keel-billed toucan'  → synonym: 'rainbow-billed toucan'
#   → 'crimson sunbird'  → synonym: 'aethopyga siparaja'
#   → 'long-tailed tit'  → synonym: 'aegithalos caudatus'
#   → 'greater roadrunner'  → synonym: 'geococcyx californianus'
#   → 'luzon bleeding-heart'  → synonym: 'gallicolumba luzonica'
#   → 'hoopoe lark'  → synonym: 'alaemon alaudipes'
#   → 'quetzal'  → synonym: 'pharomachrus'
#   → 'jabiru'  → synonym: 'jabiru stork'
#   → 'red footed booby'  → synonym: 'sula sula'
#   → 'fairy pitta'  → synonym: 'pitta nympha'
#   → 'king eider'  → synonym: 'somateria spectabilis'
#   → 'blue-crowned laughingthrush'  → synonym: "courtois's laughingthrush"
# 🧹 Removed 0 invalid synonym labels like 'none' or 'null'
# 📏 OOD classes before synonym expansion: 206
# 📐 OOD classes after synonym + deduplication: 404
#
# 🧪 Final ID Labels passed to CLIP: ['Laysan Albatross', 'Groove billed Ani', 'Crested Auklet', 'Parakeet Auklet', 'Rusty Blackbird', 'Bobolink', 'Indigo Bunting', 'Painted Bunting', 'Spotted Catbird', 'Yellow breasted Chat', 'Eastern Towhee', 'Chuck will Widow', 'Red faced Cormorant', 'Pelagic Cormorant', 'Bronzed Cowbird', 'Shiny Cowbird', 'American Crow', 'Purple Finch', 'Acadian Flycatcher', 'Olive sided Flycatcher', 'Scissor tailed Flycatcher', 'Yellow bellied Flycatcher', 'Frigatebird', 'Gadwall', 'American Goldfinch', 'Boat tailed Grackle', 'Eared Grebe', 'Horned Grebe', 'Pied billed Grebe
# DEBUG:__main__:in scores: DescribeResult(nobs=2895, minmax=(np.float32(-0.00078024203), np.float32(-0.00036840187)), mean=np.float32(-0.00059189374), variance=np.float64(2.024900698625023e-09), skewness=np.float64(0.4382409453392029), kurtosis=np.float32(1.3346362))
# 2025-07-18 21:16:11,329 : out scores: DescribeResult(nobs=2899, minmax=(np.float32(-0.0006980831), np.float32(-0.00037370424)), mean=np.float32(-0.0005521762), variance=np.float64(2.4203268234782055e-09), skewness=np.float64(0.252468079328537), kurtosis=np.float32(-0.06771898))
# DEBUG:__main__:out scores: DescribeResult(nobs=2899, minmax=(np.float32(-0.0006980831), np.float32(-0.00037370424)), mean=np.float32(-0.0005521762), variance=np.float64(2.4203268234782055e-09), skewness=np.float64(0.252468079328537), kurtosis=np.float32(-0.06771898))
# 2025-07-18 21:16:11,789 : 				EOE
# DEBUG:__main__:				EOE
# 2025-07-18 21:16:11,794 :   FPR95 AUROC AUPR
# DEBUG:__main__:  FPR95 AUROC AUPR
# 2025-07-18 21:16:11,797 : & 75.44 & 72.84 & 71.20
# DEBUG:__main__:& 75.44 & 72.84 & 71.20
# 2025-07-18 21:16:11,803 :
#
# 📊 Mean Test Results
# DEBUG:__main__:
#
# 📊 Mean Test Results
# 2025-07-18 21:16:11,804 : 				EOE
# DEBUG:__main__:				EOE
# 2025-07-18 21:16:11,806 :   FPR95 AUROC AUPR
# DEBUG:__main__:  FPR95 AUROC AUPR
# 2025-07-18 21:16:11,808 : & 75.44 & 72.84 & 71.20
# DEBUG:__main__:& 75.44 & 72.84 & 71.20

# %%
sys.argv = [
    "eval_ood_detection.py",
    "--name",        "CUB100_CUB100_EOE_500L_75B_finegrained",
    "--in_dataset",  "cub100_ID",
    "--ood_task",    "fine_grained",
    "--score",       "EOE",
    "--score_ablation", "EOE",           # use standard EOE score
    "--generate_class",                  # generate OOD candidates via LLM
    "--root_dir",    "datasets",
    "--batch_size",  "256",
    "--gpu",         "0",
    "--beta",       "0.75",
    "--L",           "500",
]
main()
# Out:
# /usr/local/lib/python3.11/dist-packages/torch/utils/data/dataloader.py:624: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(
# ✅ Original ID Labels: ['Laysan Albatross', 'Groove billed Ani', 'Crested Auklet', 'Parakeet Auklet', 'Rusty Blackbird', 'Bobolink', 'Indigo Bunting', 'Painted Bunting', 'Spotted Catbird', 'Yellow breasted Chat', 'Eastern Towhee', 'Chuck will Widow', 'Red faced Cormorant', 'Pelagic Cormorant', 'Bronzed Cowbird', 'Shiny Cowbird', 'American Crow', 'Purple Finch', 'Acadian Flycatcher', 'Olive sided Flycatcher', 'Scissor tailed Flycatcher', 'Yellow bellied Flycatcher', 'Frigatebird', 'Gadwall', 'American Goldfinch', 'Boat tailed Grackle', 'Eared Grebe', 'Horned Grebe', 'Pied billed Grebe', 'Blue Grosbeak', 'Evening Grosbeak', 'Pine Grosbeak', 'Rose breasted Grosbeak', 'Pigeon Guillemot', 'Glaucous winged Gull', 'Herring Gull', 'Ivory Gull', 'Ring billed Gull', 'Anna Hummingbird', 'Pomarine Jaeger', 'Blue Jay', 'Green Jay', 'Gray Kingbird', 'Ringed Kingfisher', 'Red legged Kittiwake', 'Horned Lark', 'Western Meadowlark', 'Red breasted Merganser', 'White breasted Nuthatch', 'Hooded Oriole', 'Orchard Oriole', 'Ovenbird', 'Western Wood Pewee', 'Sayornis', 'Whip poor Will', 'White necked Raven', 'Great Grey Shrike', 'Brewer Sparrow', 'Chipping Sparrow', 'Clay colored Sparrow', 'House Sparrow', 'Fox Sparrow', 'Grasshopper Sparrow', 'Henslow Sparrow', 'Le Conte Sparrow', 'Savannah Sparrow', 'Vesper Sparrow', 'Bank Swallow', 'Cliff Swallow', 'Scarlet Tanager', 'Black Tern', 'Caspian Tern', 'Brown Thrasher', 'Sage Thrasher', 'Black capped Vireo', 'Blue headed Vireo', 'Philadelphia Vireo', 'Warbling Vireo', 'Yellow throated Vireo', 'Black throated Blue Warbler', 'Blue winged Warbler', 'Cape May Warbler', 'Golden winged Warbler', 'Hooded Warbler', 'Magnolia Warbler', 'Myrtle Warbler', 'Orange crowned Warbler', 'Palm Warbler', 'Pine Warbler', 'Prothonotary Warbler', 'Swainson Warbler', 'Tennessee Warbler', 'Worm eating Warbler', 'Northern Waterthrush', 'Cedar Waxwing', 'Red bellied Woodpecker', 'Downy Woodpecker', 'Bewick Wren', 'House Wren', 'Common Yellowthroat']
# 🔮 Using LLM-generated OOD candidate classes...
# Envisioning Outlier Exposure...
# 🔵 Generating via OpenAI GPT...
# Continuing vision 1/9
# Continuing vision 2/9
# Continuing vision 3/9
# Continuing vision 4/9
# Continuing vision 5/9
# Continuing vision 6/9
# Continuing vision 7/9
# Continuing vision 8/9
# Continuing vision 9/9
# 🔍 Raw GPT output:
#  - American Avocet
# - Black Skimmer
# - California Condor
# - Eurasian Collared Dove
# - Ferruginous Hawk
# - Green Heron
# - Harpy Eagle
# - Ivory billed Woodpecker
# - Jabiru
# - King Vulture
# - Long tailed Jaeger
# - Marbled Murrelet
# - Northern Mockingbird
# - Osprey
# - Painted Redstart
# - Quetzal
# - Red Knot
# - Snowy Owl
# - Toco Toucan
# - Umbrellabird
# - Violet crowned Hummingbird
# - White throated Sparrow
# - Xantus's Hummingbird
# - Yellow billed Cuckoo
# - Zone tailed Hawk
# - American Kestrel
# - Black capped Chickadee
# - Carolina Wren
# - Dark eyed Junco
# - Eastern Bluebird
# - Ferruginous Pygmy Owl
# - Greater Roadrunner
# - Harris's Hawk
# - Inca Dove
# - Juniper Titmouse
# - Killdeer
# - Loggerhead Shrike
# - Mountain Bluebird
# - Northern Flicker
# - Orchard Oriole
# - Painted Bunting
# - Quail
# - Red winged Blackbird
# - Snowy Egret
# - Tufted Titmouse
# - Upland Sandpiper
# - Vermilion Flycatcher
# - Western Tanager
# - Yellow Warbler- African Grey Parrot
# - Blue and Gold Macaw
# - Cockatiel
# - Eclectus Parrot
# - Fischer's Lovebird
# - Gouldian Finch
# - Hyacinth Macaw
# - Indian Ringneck Parakeet
# - Java Sparrow
# - Keel-billed Toucan
# - Lilac-breasted Roller
# - Moluccan Cockatoo
# - Nanday Conure
# - Ostrich
# - Peach-faced Lovebird
# - Quaker Parrot
# - Rainbow Lorikeet
# - Sun Conure
# - Toco Toucan
# - Umbrella Cockatoo
# - Vasa Parrot
# - White-crowned Pigeon
# - Xantus's Murrelet
# - Yellow-chevroned Parakeet
# - Zebra Finch
# - African Pygmy Goose
# - Black-throated Magpie-Jay
# - Crimson Rosella
# - Dusky Lory
# - Emerald Toucanet
# - Fairy Bluebird
# - White-crowned Sparrow
# - Xantus's Murrelet
# - Yellow-bellied Sunbird
# - Zebra Dove
# - American Woodcock
# - Black-crowned Night Heron
# - Crested Shrike-tit
# - Dusky Woodswallow
# - Eastern Whipbird
# - Ferruginous Pygmy Owl
# - Green Honeycreeper
# - Inca Tern
# - Least Grebe
# - Mountain Bluebird
# - Olive Sunbird
# - Pale-billed Flowerpecker
# - Red-legged Honeycreeper
# - Saffron Finch
# - Tawny Eagle
# - Ural Owl
# - Violet-green Swallow
# - White-bellied Sea Eagle
# - Yellow-bellied Sapsucker
# - Zitting Cisticola
# - American Oystercatcher
# - Black Skimmer
# - Common Loon
# - Elegant Trogon
# - Fork-tailed Drongo
#
# 💾 Saving hallucinated class descriptors to: envisioned_classes/fine_grained_500/cub100_ID_gpt-3.5-turbo_5.json
# === load json:  envisioned_classes/fine_grained_500/cub100_ID_gpt-3.5-turbo_5.json
# Get Envisioned Candidate Class Names.
# After set: 204
# After removing ID class overlaps: 200
#
# 🧪 Final ID Labels passed to CLIP: ['Laysan Albatross', 'Groove billed Ani', 'Crested Auklet', 'Parakeet Auklet', 'Rusty Blackbird', 'Bobolink', 'Indigo Bunting', 'Painted Bunting', 'Spotted Catbird', 'Yellow breasted Chat', 'Eastern Towhee', 'Chuck will Widow', 'Red faced Cormorant', 'Pelagic Cormorant', 'Bronzed Cowbird', 'Shiny Cowbird', 'American Crow', 'Purple Finch', 'Acadian Flycatcher', 'Olive sided Flycatcher', 'Scissor tailed Flycatcher', 'Yellow bellied Flycatcher', 'Frigatebird', 'Gadwall', 'American Goldfinch', 'Boat tailed Grackle', 'Eared Grebe', 'Horned Grebe', 'Pied billed Grebe', 'Blue Grosbeak', 'Evening Grosbeak', 'Pine Grosbeak', 'Rose breasted Grosbeak', 'Pigeon Guillemot', 'Glaucous winged Gull', 'Herring Gull', 'Ivory Gull', 'Ring billed Gull', 'Anna Hummingbird', 'Pomarine Jaeger', 'Blue Jay', 'Green Jay', 'Gray Kingbird', 'Ringed Kingfisher', 'Red legged Kittiwake', 'Horned Lark', 'Western Meadowlark', 'Red breasted Merganser', 'White breasted Nuthatch', 'Hooded Oriole', 'Orchard Oriole', 'Ovenbird', 'Western Wood Pewee', 'Sayornis', 'Whip poor Will', 'White necked Raven', 'Great Grey Shrike', 'Brewer Sparrow', 'Chipping Sparrow', 'Clay colored Sparrow', 'House Sparrow', 'Fox Sparrow', 'Grasshopper Sparrow', 'Henslow Sparrow', 'Le Conte Sparrow', 'Savannah Sparrow', 'Vesper Sparrow', 'Bank Swallow', 'Cliff Swallow', 'Scarlet Tanager', 'Black Tern', 'Caspian Tern', 'Brown Thrasher', 'Sage Thrasher', 'Black capped Vireo', 'Blue headed Vireo', 'Philadelphia Vireo', 'Warbling Vireo', 'Yellow throated Vireo', 'Black throated Blue Warbler', 'Blue winged Warbler', 'Cape May Warbler', 'Golden winged Warbler', 'Hooded Warbler', 'Magnolia Warbler', 'Myrtle Warbler', 'Orange crowned Warbler', 'Palm Warbler', 'Pine Warbler', 'Prothonotary Warbler', 'Swainson Warbler', 'Tennessee Warbler', 'Worm eating Warbler', 'Northern Waterthrush', 'Cedar Waxwing', 'Red bellied Woodpecker', 'Downy Woodpecker', 'Bewick Wren', 'House Wren', 'Common Yellowthroat']
'dusky nightjar', 'yellow-bellied warbler', 'northern gannet', "fischer's lovebird", 'least tern', 'orange-bellied parrot', 'upland sandpiper', 'zebra dove', 'painted sandgrouse', 'peach-faced lovebird', 'java sparrow', 'northern shoveler', 'long-tailed broadbill', 'american oystercatcher', 'yellow warbler- african grey parrot', 'zone tailed hawk', 'american avocet', 'fork-tailed drongo- african pygmy kingfisher', 'northern flicker', 'red-legged honeycreeper', 'sulphur-crested cockatoo', 'moluccan cockatoo', 'tufted puffin', 'eclectus parrot', 'crimson-breasted shrike', 'greater roadrunner', 'japanese sparrowhawk', 'dusky lark', 'crested shrike-tit', 'cinnamon teal', 'common merganser', 'black capped chickadee', 'white-crowned plover', 'ivory-billed aracari', 'eastern yellow robin', 'western tanager', 'western grebe', 'varied thrush', 'loggerhead shrike', 'snowy plover', 'pale-billed flowerpecker', 'juniper titmouse', 'blue-crowned hanging parrot', 'white-crowned sparrow', 'eastern whipbird', 'ural owl', 'varied sittella', 'harpy eagle', 'nicobar pigeon', 'quaker parrot', 'ferruginous pygmy owl', 'african pygmy goo ...
# 100%|██████████| 12/12 [00:40<00:00,  3.35s/it]
# 2025-07-20 13:45:37,779 : 📦 Evaluating OOD dataset cub100_OOD
# DEBUG:__main__:📦 Evaluating OOD dataset cub100_OOD
# /usr/local/lib/python3.11/dist-packages/torch/utils/data/dataloader.py:624: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(
# 100%|██████████| 12/12 [00:41<00:00,  3.43s/it]
# 2025-07-20 13:46:19,621 : in scores: DescribeResult(nobs=2895, minmax=(np.float32(-0.0013199169), np.float32(-0.000639742)), mean=np.float32(-0.0010107938), variance=np.float64(6.186017312306792e-09), skewness=np.float64(0.1777188628911972), kurtosis=np.float32(1.2426248))
# DEBUG:__main__:in scores: DescribeResult(nobs=2895, minmax=(np.float32(-0.0013199169), np.float32(-0.000639742)), mean=np.float32(-0.0010107938), variance=np.float64(6.186017312306792e-09), skewness=np.float64(0.1777188628911972), kurtosis=np.float32(1.2426248))
# 2025-07-20 13:46:19,629 : out scores: DescribeResult(nobs=2899, minmax=(np.float32(-0.0012051482), np.float32(-0.00065669394)), mean=np.float32(-0.0009414249), variance=np.float64(7.071610798049177e-09), skewness=np.float64(0.02378292940557003), kurtosis=np.float32(-0.18347573))
# DEBUG:__main__:out scores: DescribeResult(nobs=2899, minmax=(np.float32(-0.0012051482), np.float32(-0.00065669394)), mean=np.float32(-0.0009414249), variance=np.float64(7.071610798049177e-09), skewness=np.float64(0.02378292940557003), kurtosis=np.float32(-0.18347573))
# 2025-07-20 13:46:21,208 : 				EOE
# DEBUG:__main__:				EOE
# 2025-07-20 13:46:21,210 :   FPR95 AUROC AUPR
# DEBUG:__main__:  FPR95 AUROC AUPR
# 2025-07-20 13:46:21,212 : & 73.89 & 73.09 & 70.65
# DEBUG:__main__:& 73.89 & 73.09 & 70.65
# 2025-07-20 13:46:21,214 :
#
# 📊 Mean Test Results
# DEBUG:__main__:
#
# 📊 Mean Test Results
# 2025-07-20 13:46:21,216 : 				EOE
# DEBUG:__main__:				EOE
# 2025-07-20 13:46:21,218 :   FPR95 AUROC AUPR
# DEBUG:__main__:  FPR95 AUROC AUPR
# 2025-07-20 13:46:21,220 : & 73.89 & 73.09 & 70.65
# DEBUG:__main__:& 73.89 & 73.09 & 70.65
